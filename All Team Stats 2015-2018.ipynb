# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import re
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
url = 'https://www.baseball-reference.com/leagues/MLB/2019.shtml'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
teams = soup.find_all('th', attrs = {'scope': 'row'})

# %%
Teams = []
for x in teams:
    Teams.append(str(x))

# %%
final_teams = []
for x in range(len(Teams)):
    bg = re.compile(r'>(\D+)</a>')
    lemmon =bg.findall(Teams[x])
    final_teams.append(lemmon)

# %%
from itertools import chain
final_teams = list(chain.from_iterable(final_teams))

# %% [markdown]
# # Team Batting Stats

# %%
def get_stat(stat):
    statistic = soup.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    del final_stat[-1]
    return final_stat

# %%
games = get_stat('G')

# %%
PAs = get_stat('PA')

# %%
ABs = get_stat('AB')

# %%
runs = get_stat('R')

# %%
hits = get_stat('H')

# %%
doubles = get_stat('2B')

# %%
triples = get_stat('3B')

# %%
home_runs = get_stat('HR')

# %%
rbis = get_stat('RBI')

# %%
SBs = get_stat('SB')

# %%
CS = get_stat('CS')

# %%
BBs = get_stat('BB')

# %%
SOs = get_stat('SO')

# %%
BA = get_stat('batting_avg')

# %%
OBP = get_stat('onbase_perc')

# %%
OBP_plus = get_stat('onbase_plus_slugging_plus')

# %%
TBs = get_stat('TB')

# %%
GIDPs = get_stat('GIDP')

# %%
HBPs = get_stat('HBP')

# %%
SH = get_stat('SH')

# %%
SF = get_stat('SF')

# %%
IBBs = get_stat('IBB')

# %%
LOBs = get_stat('LOB')

# %%
team_batting_stats = pd.DataFrame({'Team': final_teams, 'Games': games, 'PAs': PAs, 'ABs': ABs, 'Runs': runs, 'Hits':hits, '2Bs':doubles,'3Bs': triples, 'HRs':home_runs, 'RBIs':rbis,'SBs':SBs, 'CS':CS, 'BBs':BBs, 'SOs':SOs, 'BA': BA, 'OBP': OBP, 'OBP+': OBP_plus, 'TBs':TBs, 'GIDPs': GIDPs, 'HBPs':HBPs, 'SH':SH,'SF':SF,'IBBs':IBBs,'LOB':LOBs})

# %%
team_batting_stats
# Out:
#    Team Games   PAs   ABs Runs  Hits  2Bs 3Bs  HRs RBIs SBs  CS  BBs   SOs  \
# 0   ARI   103  4054  3630  531   943  200  26  144  508  58   6  329   868
# 1   ATL   103  4012  3562  538   931  179  19  156  521  51  18  370   904
# 2   BAL   102  3862  3514  440   853  153  17  130  415  50  20  271   939
# 3   BOS   104  4183  3714  601  1018  222  16  156  570  53  18  397   867
# 4   CHC   102  3915  3444  514   876  173  16  160  495  28  17  381   934
# 5   CHW   100  3692  3379  421   856  147   8  115  401  48  20  239   951
# 6   CIN   100  3762  3369  450   825  146  21  137  436  47  25  292   883
# 7   CLE   102  3853  3407  466   843  174  12  133  436  72  25  362   836
# 8   COL   103  4005  3615  553   956  220  31  133  532  38  22  303   979
# 9   DET    99  3706  3383  354   783  188  23   90  337  40  12  259   978
# 10  HOU   104  4054  3567  543   964  196  14  170  530  48  20  393   740
# ...

# %% [markdown]
# # Team Pitching Stats

# %%
url1 = 'https://www.baseball-reference.com/leagues/MLB/2019-standard-pitching.shtml'
page1 = requests.get(url1)
soup1 = BeautifulSoup(page1.text, 'html.parser')

# %%
def get_stat1(stat):
    statistic = soup1.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    del final_stat[-2:]
    return final_stat

# %%
wins = get_stat1('W')

# %%
losses = get_stat1('L')

# %%
saves = get_stat1('SV')

# %%
innings_pitched = get_stat1('IP')

# %%
hits_allowed = get_stat1('H')

# %%
runs_allowed = get_stat1('R')

# %%
earned_runs_allowed = get_stat1('ER')

# %%
homers_allowed = get_stat1('HR')

# %%
walks_allowed = get_stat1('BB')

# %%
intentional_walks = get_stat1('IBB')

# %%
strikeouts = get_stat1('SO')

# %%
hit_batters = get_stat1('HBP')

# %%
balks = get_stat1('BK')

# %%
WHIP = get_stat1('whip')

# %%
H9 = get_stat1('hits_per_nine')

# %%
HR9 = get_stat1('home_runs_per_nine')

# %%
BB9 = get_stat1('bases_on_balls_per_nine')

# %%
SO9 = get_stat1('strikeouts_per_nine')

# %%
LOB = get_stat1('LOB')

# %%
team_pitching_stats = pd.DataFrame({'Team': final_teams, 'W': wins, 'L':losses, 'SV':saves,'IP':innings_pitched, 'H':hits_allowed,'R':runs_allowed,'ER':earned_runs_allowed,'HR':homers_allowed,'BB':walks_allowed,'IBB':intentional_walks, 'K':strikeouts,'HBP':hit_batters,'B':balks,'WHIP':WHIP,'H9':H9,'HR9':HR9,'BB9':BB9,'SO9':SO9,'LOB':LOB})

# %% [markdown]
# # 2019 Phillies Batting Stats

# %%
url2 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PHI&t=b&year=2019'
page2 = requests.get(url2)
soup2 = BeautifulSoup(page2.text, 'html.parser')

# %%
def get_stat2(stat):
    statistic = soup2.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

# %%
game_num = get_stat2('team_game_num')

# %%
PHI_PA = get_stat2('PA')

# %%
PHI_AB = get_stat2('AB')

# %%
PHI_R = get_stat2('R')

# %%
PHI_H = get_stat2('H')

# %%
PHI_2B = get_stat2('2B')

# %%
PHI_3B = get_stat2('3B')

# %%
PHI_HR = get_stat2('HR')

# %%
PHI_RBI = get_stat2('RBI')

# %%
PHI_BB = get_stat2('BB')

# %%
PHI_SO = get_stat2('SO')

# %%
PHI_SB = get_stat2('SB')

# %%
PHI_CS = get_stat2('CS')

# %%
PHI_BA = get_stat2('batting_avg')

# %%
PHI_OBP = get_stat2('onbase_perc')

# %%
PHI_SLG = get_stat2('slugging_perc')

# %%
PHI_OPS = get_stat2('onbase_plus_slugging')

# %%
PHI_LOB = get_stat2('LOB')

# %%
phillies_offense = pd.DataFrame({'PA': PHI_PA, 'AB': PHI_AB, 'R':PHI_R,'H':PHI_H,'2B':PHI_2B, '3B': PHI_3B, 'HR':PHI_HR, 'RBI':PHI_RBI,'BB':PHI_BB,'SO':PHI_SO,'SB': PHI_SB,'CS':PHI_CS,'LOB':PHI_LOB})

# %% [markdown]
# # 2019 Phillies Pitching Stats

# %%
url3 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PHI&t=p&year=2019'
page3 = requests.get(url3)
soup3 = BeautifulSoup(page3.text, 'html.parser')

def get_stat3(stat):
    statistic = soup3.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

# %%
PHI_P_game_num = get_stat3('team_game_num')

# %%
PHI_P_IP = get_stat3('IP')

# %%
PHI_P_H = get_stat3('H')

# %%
PHI_P_R = get_stat3('R')

# %%
PHI_P_ER = get_stat3('ER')

# %%
PHI_P_UER = get_stat3('UER')

# %%
PHI_P_BB = get_stat3('BB')

# %%
PHI_P_SO = get_stat3('SO')

# %%
PHI_P_HR = get_stat3('HR')

# %%
PHI_P_HBP = get_stat3('HBP')

# %%
PHI_P_ERA = get_stat3('earned_run_avg')

# %%
phillies_pitching = pd.DataFrame({'Game': PHI_P_game_num, 'IP':PHI_P_IP, 'H':PHI_P_H,'R':PHI_P_R,'ER':PHI_P_ER,'UER':PHI_P_UER,'BB':PHI_P_BB,'SO':PHI_P_SO,'HR':PHI_P_HR,'HBP':PHI_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

phillies_pitching = phillies_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [phillies_pitching, phillies_offense]

phillies = pd.concat(frames, axis=1)

phillies['Win'] =''

columns_int = ['Game', 'Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(phillies[x])):
        phillies.loc[y,x] = int(phillies.loc[y, x])
        
for x in columns_float:
    for y in range(len(phillies[x])):
        phillies.loc[y,x] = float(phillies.loc[y, x])  

for x in range(len(phillies['Game'])):
    if phillies.loc[x, 'Runs'] > phillies.loc[x, 'R']:
        phillies.loc[x, 'Win'] = 0
    else:
        phillies.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Phillies Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PHI&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PHI_2018_game_num = get_stat2('team_game_num')

PHI_2018_PA = get_stat2('PA')

PHI_2018_AB = get_stat2('AB')

PHI_2018_R = get_stat2('R')

PHI_2018_H = get_stat2('H')

PHI_2018_2B = get_stat2('2B')

PHI_2018_3B = get_stat2('3B')

PHI_2018_HR = get_stat2('HR')

PHI_2018_RBI = get_stat2('RBI')

PHI_2018_BB = get_stat2('BB')

PHI_2018_SO = get_stat2('SO')

PHI_2018_SB = get_stat2('SB')

PHI_2018_CS = get_stat2('CS')

PHI_2018_BA = get_stat2('batting_avg')

PHI_2018_OBP = get_stat2('onbase_perc')

PHI_2018_SLG = get_stat2('slugging_perc')

PHI_2018_OPS = get_stat2('onbase_plus_slugging')

PHI_2018_LOB = get_stat2('LOB')

phillies_2018_offense = pd.DataFrame({'PA': PHI_2018_PA, 'AB': PHI_2018_AB, 'R':PHI_2018_R,'H':PHI_2018_H,'2B':PHI_2018_2B, '3B': PHI_2018_3B, 'HR':PHI_2018_HR, 'RBI':PHI_2018_RBI,'BB':PHI_2018_BB,'SO':PHI_2018_SO,'SB': PHI_2018_SB,'CS':PHI_2018_CS,'LOB':PHI_2018_LOB})

# %% [markdown]
# # 2018 Phillies Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PHI&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PHI_2018_P_game_num = get_stat3('team_game_num')

PHI_2018_P_IP = get_stat3('IP')

PHI_2018_P_H = get_stat3('H')

PHI_2018_P_R = get_stat3('R')

PHI_2018_P_ER = get_stat3('ER')

PHI_2018_P_UER = get_stat3('UER')

PHI_2018_P_BB = get_stat3('BB')

PHI_2018_P_SO = get_stat3('SO')

PHI_2018_P_HR = get_stat3('HR')

PHI_2018_P_HBP = get_stat3('HBP')

PHI_2018_P_ERA = get_stat3('earned_run_avg')

phillies_2018_pitching = pd.DataFrame({'Game': PHI_2018_P_game_num, 
                                   'IP':PHI_2018_P_IP, 
                                   'H':PHI_2018_P_H,
                                   'R':PHI_2018_P_R,
                                   'ER':PHI_2018_P_ER,
                                   'UER':PHI_2018_P_UER,
                                   'BB':PHI_2018_P_BB,
                                   'SO':PHI_2018_P_SO,
                                   'HR':PHI_2018_P_HR,
                                   'HBP':PHI_2018_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

phillies_2018_pitching = phillies_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [phillies_2018_pitching, phillies_2018_offense]

phillies_2018 = pd.concat(frames, axis=1)

phillies_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(phillies_2018[x])):
        phillies_2018.loc[y,x] = int(phillies_2018.loc[y, x])

for x in columns_float:
    for y in range(len(phillies_2018[x])):
        phillies_2018.loc[y,x] = float(phillies_2018.loc[y, x])  

for x in range(len(phillies_2018['Game'])):
    if phillies_2018.loc[x, 'Runs'] > phillies_2018.loc[x, 'R']:
        phillies_2018.loc[x, 'Win'] = 0
    else:
        phillies_2018.loc[x, 'Win'] = 1

# %%
statistic = soup5.find_all('td', attrs = {'data-stat': 'opp_ID'})
Stat = []
for x in statistic:
    Stat.append(str(x))
final_opps = []
for x in range(len(Stat)):
    bg = re.compile(r'teams/(\D+)/2018')
    lemmon = bg.findall(Stat[x])
    final_opps.append(lemmon)
final_opps_2018 = list(chain.from_iterable(final_opps))
final_opps_2018 = pd.DataFrame(final_opps_2018, columns = {'Opponent'})

# %%
statistic = soup4.find_all('td', attrs = {'data-stat': 'team_homeORaway'})
statistic
Stat = []
for x in statistic:
    Stat.append(str(x))
home_or_away_2018 = []
for x in range(len(Stat)):
    if '@' in Stat[x]:
#         bg = e.compile(r'"team_homeORaway">(.)</td>')
#         lemmon = bg.findall(Stat[x])
        home_or_away_2018.append('Away')
    else:
        home_or_away_2018.append('Home')
        
home_or_away_2018 = pd.DataFrame(home_or_away_2018, columns = {'Location'})

# %% [markdown]
# # 2017 Phillies Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PHI&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PHI_2017_game_num = get_stat2('team_game_num')

PHI_2017_PA = get_stat2('PA')

PHI_2017_AB = get_stat2('AB')

PHI_2017_R = get_stat2('R')

PHI_2017_H = get_stat2('H')

PHI_2017_2B = get_stat2('2B')

PHI_2017_3B = get_stat2('3B')

PHI_2017_HR = get_stat2('HR')

PHI_2017_RBI = get_stat2('RBI')

PHI_2017_BB = get_stat2('BB')

PHI_2017_SO = get_stat2('SO')

PHI_2017_SB = get_stat2('SB')

PHI_2017_CS = get_stat2('CS')

PHI_2017_BA = get_stat2('batting_avg')

PHI_2017_OBP = get_stat2('onbase_perc')

PHI_2017_SLG = get_stat2('slugging_perc')

PHI_2017_OPS = get_stat2('onbase_plus_slugging')

PHI_2017_LOB = get_stat2('LOB')

phillies_2017_offense = pd.DataFrame({
                                  'PA': PHI_2017_PA,
                                  'AB': PHI_2017_AB,
                                  'R':  PHI_2017_R,
                                  'H':  PHI_2017_H,
                                  '2B': PHI_2017_2B,
                                  '3B': PHI_2017_3B, 
                                  'HR': PHI_2017_HR, 
                                  'RBI':PHI_2017_RBI,
                                  'BB': PHI_2017_BB,
                                  'SO': PHI_2017_SO,
                                  'SB': PHI_2017_SB,
                                  'CS': PHI_2017_CS,
                                  'LOB':PHI_2017_LOB})

# %% [markdown]
# # 2017 Phillies Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PHI&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PHI_2017_P_game_num = get_stat3('team_game_num')

PHI_2017_P_IP = get_stat3('IP')

PHI_2017_P_H = get_stat3('H')

PHI_2017_P_R = get_stat3('R')

PHI_2017_P_ER = get_stat3('ER')

PHI_2017_P_UER = get_stat3('UER')

PHI_2017_P_BB = get_stat3('BB')

PHI_2017_P_SO = get_stat3('SO')

PHI_2017_P_HR = get_stat3('HR')

PHI_2017_P_HBP = get_stat3('HBP')

PHI_2017_P_ERA = get_stat3('earned_run_avg')

phillies_2017_pitching = pd.DataFrame({'Game': PHI_2017_P_game_num, 
                                   'IP':PHI_2017_P_IP, 
                                   'H':PHI_2017_P_H,
                                   'R':PHI_2017_P_R,
                                   'ER':PHI_2017_P_ER,
                                   'UER':PHI_2017_P_UER,
                                   'BB':PHI_2017_P_BB,
                                   'SO':PHI_2017_P_SO,
                                   'HR':PHI_2017_P_HR,
                                   'HBP':PHI_2017_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

phillies_2017_pitching = phillies_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [phillies_2017_pitching, phillies_2017_offense]

phillies_2017 = pd.concat(frames, axis=1)

phillies_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(phillies_2017[x])):
        phillies_2017.loc[y,x] = int(phillies_2017.loc[y, x])

for x in columns_float:
    for y in range(len(phillies_2017[x])):
        phillies_2017.loc[y,x] = float(phillies_2017.loc[y, x])  

for x in range(len(phillies_2017['Game'])):
    if phillies_2017.loc[x, 'Runs'] > phillies_2017.loc[x, 'R']:
        phillies_2017.loc[x, 'Win'] = 0
    else:
        phillies_2017.loc[x, 'Win'] = 1

# %%
statistic = soup5.find_all('td', attrs = {'data-stat': 'opp_ID'})
Stat = []
for x in statistic:
    Stat.append(str(x))
final_opps = []
for x in range(len(Stat)):
    bg = re.compile(r'teams/(\D+)/2017')
    lemmon = bg.findall(Stat[x])
    final_opps.append(lemmon)
final_opps_2017 = list(chain.from_iterable(final_opps))
final_opps_2017 = pd.DataFrame(final_opps_2017, columns = {'Opponent'})

# %%
statistic = soup4.find_all('td', attrs = {'data-stat': 'team_homeORaway'})
statistic
Stat = []
for x in statistic:
    Stat.append(str(x))
home_or_away_2017 = []
for x in range(len(Stat)):
    if '@' in Stat[x]:
#         bg = e.compile(r'"team_homeORaway">(.)</td>')
#         lemmon = bg.findall(Stat[x])
        home_or_away_2017.append('Away')
    else:
        home_or_away_2017.append('Home')
        
home_or_away_2017 = pd.DataFrame(home_or_away_2017, columns = {'Location'})

# %% [markdown]
# # 2016 Phillies Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PHI&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PHI_2016_game_num = get_stat2('team_game_num')

PHI_2016_PA = get_stat2('PA')

PHI_2016_AB = get_stat2('AB')

PHI_2016_R = get_stat2('R')

PHI_2016_H = get_stat2('H')

PHI_2016_2B = get_stat2('2B')

PHI_2016_3B = get_stat2('3B')

PHI_2016_HR = get_stat2('HR')

PHI_2016_RBI = get_stat2('RBI')

PHI_2016_BB = get_stat2('BB')

PHI_2016_SO = get_stat2('SO')

PHI_2016_SB = get_stat2('SB')

PHI_2016_CS = get_stat2('CS')

PHI_2016_BA = get_stat2('batting_avg')

PHI_2016_OBP = get_stat2('onbase_perc')

PHI_2016_SLG = get_stat2('slugging_perc')

PHI_2016_OPS = get_stat2('onbase_plus_slugging')

PHI_2016_LOB = get_stat2('LOB')

phillies_2016_offense = pd.DataFrame({
                                  'PA': PHI_2016_PA,
                                  'AB': PHI_2016_AB,
                                  'R':  PHI_2016_R,
                                  'H':  PHI_2016_H,
                                  '2B': PHI_2016_2B,
                                  '3B': PHI_2016_3B, 
                                  'HR': PHI_2016_HR, 
                                  'RBI':PHI_2016_RBI,
                                  'BB': PHI_2016_BB,
                                  'SO': PHI_2016_SO,
                                  'SB': PHI_2016_SB,
                                  'CS': PHI_2016_CS,
                                  'LOB':PHI_2016_LOB})

# %% [markdown]
# # 2016 Phillies Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PHI&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PHI_2016_P_game_num = get_stat3('team_game_num')
PHI_2016_P_IP = get_stat3('IP')
PHI_2016_P_H = get_stat3('H')
PHI_2016_P_R = get_stat3('R')
PHI_2016_P_ER = get_stat3('ER')
PHI_2016_P_UER = get_stat3('UER')
PHI_2016_P_BB = get_stat3('BB')
PHI_2016_P_SO = get_stat3('SO')
PHI_2016_P_HR = get_stat3('HR')
PHI_2016_P_HBP = get_stat3('HBP')
PHI_2016_P_ERA = get_stat3('earned_run_avg')

phillies_2016_pitching = pd.DataFrame({'Game':  PHI_2016_P_game_num, 
                                         'IP':  PHI_2016_P_IP, 
                                         'H':   PHI_2016_P_H,
                                         'R':   PHI_2016_P_R,
                                         'ER':  PHI_2016_P_ER,
                                         'UER': PHI_2016_P_UER,
                                         'BB':  PHI_2016_P_BB,
                                         'SO':  PHI_2016_P_SO,
                                         'HR':  PHI_2016_P_HR,
                                         'HBP': PHI_2016_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

phillies_2016_pitching = phillies_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [phillies_2016_pitching, phillies_2016_offense]

phillies_2016 = pd.concat(frames, axis=1)

phillies_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(phillies_2016[x])):
        phillies_2016.loc[y,x] = int(phillies_2016.loc[y, x])

for x in columns_float:
    for y in range(len(phillies_2016[x])):
        phillies_2016.loc[y,x] = float(phillies_2016.loc[y, x])  

for x in range(len(phillies_2016['Game'])):
    if phillies_2016.loc[x, 'Runs'] > phillies_2016.loc[x, 'R']:
        phillies_2016.loc[x, 'Win'] = 0
    else:
        phillies_2016.loc[x, 'Win'] = 1

# %%
statistic = soup5.find_all('td', attrs = {'data-stat': 'opp_ID'})
Stat = []
for x in statistic:
    Stat.append(str(x))
final_opps = []
for x in range(len(Stat)):
    bg = re.compile(r'teams/(\D+)/2016')
    lemmon = bg.findall(Stat[x])
    final_opps.append(lemmon)
final_opps_2016 = list(chain.from_iterable(final_opps))
final_opps_2016 = pd.DataFrame(final_opps_2016, columns = {'Opponent'})

# %%
statistic = soup4.find_all('td', attrs = {'data-stat': 'team_homeORaway'})
statistic
Stat = []
for x in statistic:
    Stat.append(str(x))
home_or_away_2016 = []
for x in range(len(Stat)):
    if '@' in Stat[x]:
#         bg = e.compile(r'"team_homeORaway">(.)</td>')
#         lemmon = bg.findall(Stat[x])
        home_or_away_2016.append('Away')
    else:
        home_or_away_2016.append('Home')
        
home_or_away_2016 = pd.DataFrame(home_or_away_2016, columns = {'Location'})

# %% [markdown]
# # 2015 Phillies Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PHI&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PHI_2015_game_num = get_stat2('team_game_num')
PHI_2015_PA = get_stat2('PA')
PHI_2015_AB = get_stat2('AB')
PHI_2015_R = get_stat2('R')
PHI_2015_H = get_stat2('H')
PHI_2015_2B = get_stat2('2B')
PHI_2015_3B = get_stat2('3B')
PHI_2015_HR = get_stat2('HR')
PHI_2015_RBI = get_stat2('RBI')
PHI_2015_BB = get_stat2('BB')
PHI_2015_SO = get_stat2('SO')
PHI_2015_SB = get_stat2('SB')
PHI_2015_CS = get_stat2('CS')
PHI_2015_BA = get_stat2('batting_avg')
PHI_2015_OBP = get_stat2('onbase_perc')
PHI_2015_SLG = get_stat2('slugging_perc')
PHI_2015_OPS = get_stat2('onbase_plus_slugging')
PHI_2015_LOB = get_stat2('LOB')
phillies_2015_offense = pd.DataFrame({
                                  'PA': PHI_2015_PA,
                                  'AB': PHI_2015_AB,
                                  'R':  PHI_2015_R,
                                  'H':  PHI_2015_H,
                                  '2B': PHI_2015_2B,
                                  '3B': PHI_2015_3B, 
                                  'HR': PHI_2015_HR, 
                                  'RBI':PHI_2015_RBI,
                                  'BB': PHI_2015_BB,
                                  'SO': PHI_2015_SO,
                                  'SB': PHI_2015_SB,
                                  'CS': PHI_2015_CS,
                                  'LOB':PHI_2015_LOB})

# %% [markdown]
# # 2015 Phillies Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PHI&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PHI_2015_P_game_num = get_stat3('team_game_num')
PHI_2015_P_IP = get_stat3('IP')
PHI_2015_P_H = get_stat3('H')
PHI_2015_P_R = get_stat3('R')
PHI_2015_P_ER = get_stat3('ER')
PHI_2015_P_UER = get_stat3('UER')
PHI_2015_P_BB = get_stat3('BB')
PHI_2015_P_SO = get_stat3('SO')
PHI_2015_P_HR = get_stat3('HR')
PHI_2015_P_HBP = get_stat3('HBP')
PHI_2015_P_ERA = get_stat3('earned_run_avg')

phillies_2015_pitching = pd.DataFrame({'Game':  PHI_2015_P_game_num, 
                                         'IP':  PHI_2015_P_IP, 
                                         'H':   PHI_2015_P_H,
                                         'R':   PHI_2015_P_R,
                                         'ER':  PHI_2015_P_ER,
                                         'UER': PHI_2015_P_UER,
                                         'BB':  PHI_2015_P_BB,
                                         'SO':  PHI_2015_P_SO,
                                         'HR':  PHI_2015_P_HR,
                                         'HBP': PHI_2015_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

phillies_2015_pitching = phillies_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [phillies_2015_pitching, phillies_2015_offense]

phillies_2015 = pd.concat(frames, axis=1)

phillies_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(phillies_2015[x])):
        phillies_2015.loc[y,x] = int(phillies_2015.loc[y, x])

for x in columns_float:
    for y in range(len(phillies_2015[x])):
        phillies_2015.loc[y,x] = float(phillies_2015.loc[y, x])  

for x in range(len(phillies_2015['Game'])):
    if phillies_2015.loc[x, 'Runs'] > phillies_2015.loc[x, 'R']:
        phillies_2015.loc[x, 'Win'] = 0
    else:
        phillies_2015.loc[x, 'Win'] = 1

# %%
statistic = soup5.find_all('td', attrs = {'data-stat': 'opp_ID'})
Stat = []
for x in statistic:
    Stat.append(str(x))
final_opps = []
for x in range(len(Stat)):
    bg = re.compile(r'teams/(\D+)/2015')
    lemmon = bg.findall(Stat[x])
    final_opps.append(lemmon)
final_opps_2015 = list(chain.from_iterable(final_opps))
final_opps_2015 = pd.DataFrame(final_opps_2015, columns = {'Opponent'})
final_opps_2015
# Out:
#     Opponent
# 0        BOS
# 1        BOS
# 2        BOS
# 3        WSN
# 4        WSN
# 5        WSN
# 6        NYM
# 7        NYM
# 8        NYM
# 9        WSN
# 10       WSN
# 11       WSN
# 12       WSN
# 13       MIA
# 14       MIA
# 15       MIA
# 16       ATL
# 17       ATL
# 18       ATL
# 19       STL
# 20       STL
# 21       STL
# 22       STL
# 23       MIA
# 24       MIA
# 25       MIA
# 26       ATL
# 27       ATL
# 28       ATL
# 29       NYM
# 30       NYM
# 31       NYM
# 32       PIT
# 33       PIT
# 34       PIT
# 35       PIT
# 36       ARI
# 37       ARI
# 38       ARI
# 39       COL
# 40       COL
# 41       COL
# 42       COL
# 43       WSN
# 44       WSN
# 45       WSN
# 46       NYM
# 47       NYM
# 48       NYM
# 49       COL
# 50       COL
# 51       COL
# 52       CIN
# 53       CIN
# 54       CIN
# 55       SFG
# 56       SFG
# 57       SFG
# 58       CIN
# 59       CIN
# 60       CIN
# 61       PIT
# 62       PIT
# 63       PIT
# 64       BAL
# ...

# %%
statistic = soup4.find_all('td', attrs = {'data-stat': 'team_homeORaway'})
statistic
Stat = []
for x in statistic:
    Stat.append(str(x))
home_or_away_2015 = []
for x in range(len(Stat)):
    if '@' in Stat[x]:
#         bg = e.compile(r'"team_homeORaway">(.)</td>')
#         lemmon = bg.findall(Stat[x])
        home_or_away_2015.append('Away')
    else:
        home_or_away_2015.append('Home')
        
home_or_away_2015 = pd.DataFrame(home_or_away_2015, columns = {'Location'})

# %% [markdown]
# # 2019 Braves Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ATL&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ATL_game_num = get_stat2('team_game_num')

ATL_PA = get_stat2('PA')

ATL_AB = get_stat2('AB')

ATL_R = get_stat2('R')

ATL_H = get_stat2('H')

ATL_2B = get_stat2('2B')

ATL_3B = get_stat2('3B')

ATL_HR = get_stat2('HR')

ATL_RBI = get_stat2('RBI')

ATL_BB = get_stat2('BB')

ATL_SO = get_stat2('SO')

ATL_SB = get_stat2('SB')

ATL_CS = get_stat2('CS')

ATL_BA = get_stat2('batting_avg')

ATL_OBP = get_stat2('onbase_perc')

ATL_SLG = get_stat2('slugging_perc')

ATL_OPS = get_stat2('onbase_plus_slugging')

ATL_LOB = get_stat2('LOB')

braves_offense = pd.DataFrame({'PA': ATL_PA, 'AB': ATL_AB, 'R':ATL_R,'H':ATL_H,'2B':ATL_2B, '3B': ATL_3B, 'HR':ATL_HR, 'RBI':ATL_RBI,'BB':ATL_BB,'SO':ATL_SO,'SB': ATL_SB,'CS':ATL_CS,'LOB':ATL_LOB})

# %% [markdown]
# # 2019 Braves Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ATL&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ATL_P_game_num = get_stat3('team_game_num')

ATL_P_IP = get_stat3('IP')

ATL_P_H = get_stat3('H')

ATL_P_R = get_stat3('R')

ATL_P_ER = get_stat3('ER')

ATL_P_UER = get_stat3('UER')

ATL_P_BB = get_stat3('BB')

ATL_P_SO = get_stat3('SO')

ATL_P_HR = get_stat3('HR')

ATL_P_HBP = get_stat3('HBP')

ATL_P_ERA = get_stat3('earned_run_avg')

braves_pitching = pd.DataFrame({'Game': ATL_P_game_num, 'IP':ATL_P_IP, 'H':ATL_P_H,'R':ATL_P_R,'ER':ATL_P_ER,'UER':ATL_P_UER,'BB':ATL_P_BB,'SO':ATL_P_SO,'HR':ATL_P_HR,'HBP':ATL_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

braves_pitching = braves_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [braves_pitching, braves_offense]

braves = pd.concat(frames, axis=1)

braves['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(braves[x])):
        braves.loc[y,x] = int(braves.loc[y, x])

for x in columns_float:
    for y in range(len(braves[x])):
        braves.loc[y,x] = float(braves.loc[y, x])  

for x in range(len(braves['Game'])):
    if braves.loc[x, 'Runs'] > braves.loc[x, 'R']:
        braves.loc[x, 'Win'] = 0
    else:
        braves.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Braves Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ATL&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ATL_2018_game_num = get_stat2('team_game_num')
ATL_2018_PA = get_stat2('PA')
ATL_2018_AB = get_stat2('AB')
ATL_2018_R = get_stat2('R')
ATL_2018_H = get_stat2('H')
ATL_2018_2B = get_stat2('2B')
ATL_2018_3B = get_stat2('3B')
ATL_2018_HR = get_stat2('HR')
ATL_2018_RBI = get_stat2('RBI')
ATL_2018_BB = get_stat2('BB')
ATL_2018_SO = get_stat2('SO')
ATL_2018_SB = get_stat2('SB')
ATL_2018_CS = get_stat2('CS')
ATL_2018_BA = get_stat2('batting_avg')
ATL_2018_OBP = get_stat2('onbase_perc')
ATL_2018_SLG = get_stat2('slugging_perc')
ATL_2018_OPS = get_stat2('onbase_plus_slugging')
ATL_2018_LOB = get_stat2('LOB')
braves_2018_offense = pd.DataFrame({
                                  'PA': ATL_2018_PA,
                                  'AB': ATL_2018_AB,
                                  'R':  ATL_2018_R,
                                  'H':  ATL_2018_H,
                                  '2B': ATL_2018_2B,
                                  '3B': ATL_2018_3B, 
                                  'HR': ATL_2018_HR, 
                                  'RBI':ATL_2018_RBI,
                                  'BB': ATL_2018_BB,
                                  'SO': ATL_2018_SO,
                                  'SB': ATL_2018_SB,
                                  'CS': ATL_2018_CS,
                                  'LOB':ATL_2018_LOB})

# %% [markdown]
# # 2018 Braves Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ATL&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ATL_2018_P_game_num = get_stat3('team_game_num')
ATL_2018_P_IP = get_stat3('IP')
ATL_2018_P_H = get_stat3('H')
ATL_2018_P_R = get_stat3('R')
ATL_2018_P_ER = get_stat3('ER')
ATL_2018_P_UER = get_stat3('UER')
ATL_2018_P_BB = get_stat3('BB')
ATL_2018_P_SO = get_stat3('SO')
ATL_2018_P_HR = get_stat3('HR')
ATL_2018_P_HBP = get_stat3('HBP')
ATL_2018_P_ERA = get_stat3('earned_run_avg')

braves_2018_pitching = pd.DataFrame({'Game':  ATL_2018_P_game_num, 
                                         'IP':  ATL_2018_P_IP, 
                                         'H':   ATL_2018_P_H,
                                         'R':   ATL_2018_P_R,
                                         'ER':  ATL_2018_P_ER,
                                         'UER': ATL_2018_P_UER,
                                         'BB':  ATL_2018_P_BB,
                                         'SO':  ATL_2018_P_SO,
                                         'HR':  ATL_2018_P_HR,
                                         'HBP': ATL_2018_P_HBP})

# %%
# braves_offense = braves_offense.drop(columns = ['Game'])

braves_2018_pitching = braves_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [braves_2018_pitching, braves_2018_offense]

braves_2018 = pd.concat(frames, axis=1)

braves_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(braves_2018[x])):
        braves_2018.loc[y,x] = int(braves_2018.loc[y, x])

for x in columns_float:
    for y in range(len(braves_2018[x])):
        braves_2018.loc[y,x] = float(braves_2018.loc[y, x])  

for x in range(len(braves_2018['Game'])):
    if braves_2018.loc[x, 'Runs'] > braves_2018.loc[x, 'R']:
        braves_2018.loc[x, 'Win'] = 0
    else:
        braves_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Braves Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ATL&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ATL_2017_game_num = get_stat2('team_game_num')
ATL_2017_PA = get_stat2('PA')
ATL_2017_AB = get_stat2('AB')
ATL_2017_R = get_stat2('R')
ATL_2017_H = get_stat2('H')
ATL_2017_2B = get_stat2('2B')
ATL_2017_3B = get_stat2('3B')
ATL_2017_HR = get_stat2('HR')
ATL_2017_RBI = get_stat2('RBI')
ATL_2017_BB = get_stat2('BB')
ATL_2017_SO = get_stat2('SO')
ATL_2017_SB = get_stat2('SB')
ATL_2017_CS = get_stat2('CS')
ATL_2017_BA = get_stat2('batting_avg')
ATL_2017_OBP = get_stat2('onbase_perc')
ATL_2017_SLG = get_stat2('slugging_perc')
ATL_2017_OPS = get_stat2('onbase_plus_slugging')
ATL_2017_LOB = get_stat2('LOB')
braves_2017_offense = pd.DataFrame({
                                  'PA': ATL_2017_PA,
                                  'AB': ATL_2017_AB,
                                  'R':  ATL_2017_R,
                                  'H':  ATL_2017_H,
                                  '2B': ATL_2017_2B,
                                  '3B': ATL_2017_3B, 
                                  'HR': ATL_2017_HR, 
                                  'RBI':ATL_2017_RBI,
                                  'BB': ATL_2017_BB,
                                  'SO': ATL_2017_SO,
                                  'SB': ATL_2017_SB,
                                  'CS': ATL_2017_CS,
                                  'LOB':ATL_2017_LOB})

# %% [markdown]
# # 2017 Braves Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ATL&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ATL_2017_P_game_num = get_stat3('team_game_num')
ATL_2017_P_IP = get_stat3('IP')
ATL_2017_P_H = get_stat3('H')
ATL_2017_P_R = get_stat3('R')
ATL_2017_P_ER = get_stat3('ER')
ATL_2017_P_UER = get_stat3('UER')
ATL_2017_P_BB = get_stat3('BB')
ATL_2017_P_SO = get_stat3('SO')
ATL_2017_P_HR = get_stat3('HR')
ATL_2017_P_HBP = get_stat3('HBP')
ATL_2017_P_ERA = get_stat3('earned_run_avg')

braves_2017_pitching = pd.DataFrame({'Game':  ATL_2017_P_game_num, 
                                         'IP':  ATL_2017_P_IP, 
                                         'H':   ATL_2017_P_H,
                                         'R':   ATL_2017_P_R,
                                         'ER':  ATL_2017_P_ER,
                                         'UER': ATL_2017_P_UER,
                                         'BB':  ATL_2017_P_BB,
                                         'SO':  ATL_2017_P_SO,
                                         'HR':  ATL_2017_P_HR,
                                         'HBP': ATL_2017_P_HBP})

# %%
# braves_offense = braves_offense.drop(columns = ['Game'])

braves_2017_pitching = braves_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [braves_2017_pitching, braves_2017_offense]

braves_2017 = pd.concat(frames, axis=1)

braves_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(braves_2017[x])):
        braves_2017.loc[y,x] = int(braves_2017.loc[y, x])

for x in columns_float:
    for y in range(len(braves_2017[x])):
        braves_2017.loc[y,x] = float(braves_2017.loc[y, x])  

for x in range(len(braves_2017['Game'])):
    if braves_2017.loc[x, 'Runs'] > braves_2017.loc[x, 'R']:
        braves_2017.loc[x, 'Win'] = 0
    else:
        braves_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Braves Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ATL&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ATL_2016_game_num = get_stat2('team_game_num')
ATL_2016_PA = get_stat2('PA')
ATL_2016_AB = get_stat2('AB')
ATL_2016_R = get_stat2('R')
ATL_2016_H = get_stat2('H')
ATL_2016_2B = get_stat2('2B')
ATL_2016_3B = get_stat2('3B')
ATL_2016_HR = get_stat2('HR')
ATL_2016_RBI = get_stat2('RBI')
ATL_2016_BB = get_stat2('BB')
ATL_2016_SO = get_stat2('SO')
ATL_2016_SB = get_stat2('SB')
ATL_2016_CS = get_stat2('CS')
ATL_2016_BA = get_stat2('batting_avg')
ATL_2016_OBP = get_stat2('onbase_perc')
ATL_2016_SLG = get_stat2('slugging_perc')
ATL_2016_OPS = get_stat2('onbase_plus_slugging')
ATL_2016_LOB = get_stat2('LOB')
braves_2016_offense = pd.DataFrame({
                                  'PA': ATL_2016_PA,
                                  'AB': ATL_2016_AB,
                                  'R':  ATL_2016_R,
                                  'H':  ATL_2016_H,
                                  '2B': ATL_2016_2B,
                                  '3B': ATL_2016_3B, 
                                  'HR': ATL_2016_HR, 
                                  'RBI':ATL_2016_RBI,
                                  'BB': ATL_2016_BB,
                                  'SO': ATL_2016_SO,
                                  'SB': ATL_2016_SB,
                                  'CS': ATL_2016_CS,
                                  'LOB':ATL_2016_LOB})

# %% [markdown]
# # 2016 Braves Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ATL&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ATL_2016_P_game_num = get_stat3('team_game_num')
ATL_2016_P_IP = get_stat3('IP')
ATL_2016_P_H = get_stat3('H')
ATL_2016_P_R = get_stat3('R')
ATL_2016_P_ER = get_stat3('ER')
ATL_2016_P_UER = get_stat3('UER')
ATL_2016_P_BB = get_stat3('BB')
ATL_2016_P_SO = get_stat3('SO')
ATL_2016_P_HR = get_stat3('HR')
ATL_2016_P_HBP = get_stat3('HBP')
ATL_2016_P_ERA = get_stat3('earned_run_avg')

braves_2016_pitching = pd.DataFrame({'Game':  ATL_2016_P_game_num, 
                                         'IP':  ATL_2016_P_IP, 
                                         'H':   ATL_2016_P_H,
                                         'R':   ATL_2016_P_R,
                                         'ER':  ATL_2016_P_ER,
                                         'UER': ATL_2016_P_UER,
                                         'BB':  ATL_2016_P_BB,
                                         'SO':  ATL_2016_P_SO,
                                         'HR':  ATL_2016_P_HR,
                                         'HBP': ATL_2016_P_HBP})

# %%
# braves_offense = braves_offense.drop(columns = ['Game'])

braves_2016_pitching = braves_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [braves_2016_pitching, braves_2016_offense]

braves_2016 = pd.concat(frames, axis=1)

braves_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(braves_2016[x])):
        braves_2016.loc[y,x] = int(braves_2016.loc[y, x])

for x in columns_float:
    for y in range(len(braves_2016[x])):
        braves_2016.loc[y,x] = float(braves_2016.loc[y, x])  

for x in range(len(braves_2016['Game'])):
    if braves_2016.loc[x, 'Runs'] > braves_2016.loc[x, 'R']:
        braves_2016.loc[x, 'Win'] = 0
    else:
        braves_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Braves Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ATL&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ATL_2015_game_num = get_stat2('team_game_num')
ATL_2015_PA = get_stat2('PA')
ATL_2015_AB = get_stat2('AB')
ATL_2015_R = get_stat2('R')
ATL_2015_H = get_stat2('H')
ATL_2015_2B = get_stat2('2B')
ATL_2015_3B = get_stat2('3B')
ATL_2015_HR = get_stat2('HR')
ATL_2015_RBI = get_stat2('RBI')
ATL_2015_BB = get_stat2('BB')
ATL_2015_SO = get_stat2('SO')
ATL_2015_SB = get_stat2('SB')
ATL_2015_CS = get_stat2('CS')
ATL_2015_BA = get_stat2('batting_avg')
ATL_2015_OBP = get_stat2('onbase_perc')
ATL_2015_SLG = get_stat2('slugging_perc')
ATL_2015_OPS = get_stat2('onbase_plus_slugging')
ATL_2015_LOB = get_stat2('LOB')
braves_2015_offense = pd.DataFrame({
                                  'PA': ATL_2015_PA,
                                  'AB': ATL_2015_AB,
                                  'R':  ATL_2015_R,
                                  'H':  ATL_2015_H,
                                  '2B': ATL_2015_2B,
                                  '3B': ATL_2015_3B, 
                                  'HR': ATL_2015_HR, 
                                  'RBI':ATL_2015_RBI,
                                  'BB': ATL_2015_BB,
                                  'SO': ATL_2015_SO,
                                  'SB': ATL_2015_SB,
                                  'CS': ATL_2015_CS,
                                  'LOB':ATL_2015_LOB})

# %% [markdown]
# # 2015 Braves Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ATL&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ATL_2015_P_game_num = get_stat3('team_game_num')
ATL_2015_P_IP = get_stat3('IP')
ATL_2015_P_H = get_stat3('H')
ATL_2015_P_R = get_stat3('R')
ATL_2015_P_ER = get_stat3('ER')
ATL_2015_P_UER = get_stat3('UER')
ATL_2015_P_BB = get_stat3('BB')
ATL_2015_P_SO = get_stat3('SO')
ATL_2015_P_HR = get_stat3('HR')
ATL_2015_P_HBP = get_stat3('HBP')
ATL_2015_P_ERA = get_stat3('earned_run_avg')

braves_2015_pitching = pd.DataFrame({'Game':  ATL_2015_P_game_num, 
                                         'IP':  ATL_2015_P_IP, 
                                         'H':   ATL_2015_P_H,
                                         'R':   ATL_2015_P_R,
                                         'ER':  ATL_2015_P_ER,
                                         'UER': ATL_2015_P_UER,
                                         'BB':  ATL_2015_P_BB,
                                         'SO':  ATL_2015_P_SO,
                                         'HR':  ATL_2015_P_HR,
                                         'HBP': ATL_2015_P_HBP})

# %%
# braves_offense = braves_offense.drop(columns = ['Game'])

braves_2015_pitching = braves_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [braves_2015_pitching, braves_2015_offense]

braves_2015 = pd.concat(frames, axis=1)

braves_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(braves_2015[x])):
        braves_2015.loc[y,x] = int(braves_2015.loc[y, x])

for x in columns_float:
    for y in range(len(braves_2015[x])):
        braves_2015.loc[y,x] = float(braves_2015.loc[y, x])  

for x in range(len(braves_2015['Game'])):
    if braves_2015.loc[x, 'Runs'] > braves_2015.loc[x, 'R']:
        braves_2015.loc[x, 'Win'] = 0
    else:
        braves_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Nationals Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=WSN&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

WSN_game_num = get_stat2('team_game_num')

WSN_PA = get_stat2('PA')

WSN_AB = get_stat2('AB')

WSN_R = get_stat2('R')

WSN_H = get_stat2('H')

WSN_2B = get_stat2('2B')

WSN_3B = get_stat2('3B')

WSN_HR = get_stat2('HR')

WSN_RBI = get_stat2('RBI')

WSN_BB = get_stat2('BB')

WSN_SO = get_stat2('SO')

WSN_SB = get_stat2('SB')

WSN_CS = get_stat2('CS')

WSN_BA = get_stat2('batting_avg')

WSN_OBP = get_stat2('onbase_perc')

WSN_SLG = get_stat2('slugging_perc')

WSN_OPS = get_stat2('onbase_plus_slugging')

WSN_LOB = get_stat2('LOB')

nationals_offense = pd.DataFrame({
                                  'PA': WSN_PA,
                                  'AB': WSN_AB,
                                  'R':WSN_R,
                                  'H':WSN_H,
                                  '2B':WSN_2B,
                                  '3B': WSN_3B, 
                                  'HR':WSN_HR, 
                                  'RBI':WSN_RBI,
                                  'BB':WSN_BB,
                                  'SO':WSN_SO,
                                  'SB': WSN_SB,
                                  'CS':WSN_CS,
                                  'LOB':WSN_LOB})

# %% [markdown]
# # 2019 Nationals Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=WSN&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

WSN_P_game_num = get_stat3('team_game_num')

WSN_P_IP = get_stat3('IP')

WSN_P_H = get_stat3('H')

WSN_P_R = get_stat3('R')

WSN_P_ER = get_stat3('ER')

WSN_P_UER = get_stat3('UER')

WSN_P_BB = get_stat3('BB')

WSN_P_SO = get_stat3('SO')

WSN_P_HR = get_stat3('HR')

WSN_P_HBP = get_stat3('HBP')

WSN_P_ERA = get_stat3('earned_run_avg')

nationals_pitching = pd.DataFrame({'Game': WSN_P_game_num, 'IP':WSN_P_IP, 'H':WSN_P_H,'R':WSN_P_R,'ER':WSN_P_ER,'UER':WSN_P_UER,'BB':WSN_P_BB,'SO':WSN_P_SO,'HR':WSN_P_HR,'HBP':WSN_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

nationals_pitching = nationals_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [nationals_pitching, nationals_offense]

nationals = pd.concat(frames, axis=1)

nationals['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(nationals[x])):
        nationals.loc[y,x] = int(nationals.loc[y, x])

for x in columns_float:
    for y in range(len(nationals[x])):
        nationals.loc[y,x] = float(nationals.loc[y, x])  

for x in range(len(nationals['Game'])):
    if nationals.loc[x, 'Runs'] > nationals.loc[x, 'R']:
        nationals.loc[x, 'Win'] = 0
    else:
        nationals.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Nationals Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=WSN&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

WSN_2018_game_num = get_stat2('team_game_num')
WSN_2018_PA = get_stat2('PA')
WSN_2018_AB = get_stat2('AB')
WSN_2018_R = get_stat2('R')
WSN_2018_H = get_stat2('H')
WSN_2018_2B = get_stat2('2B')
WSN_2018_3B = get_stat2('3B')
WSN_2018_HR = get_stat2('HR')
WSN_2018_RBI = get_stat2('RBI')
WSN_2018_BB = get_stat2('BB')
WSN_2018_SO = get_stat2('SO')
WSN_2018_SB = get_stat2('SB')
WSN_2018_CS = get_stat2('CS')
WSN_2018_BA = get_stat2('batting_avg')
WSN_2018_OBP = get_stat2('onbase_perc')
WSN_2018_SLG = get_stat2('slugging_perc')
WSN_2018_OPS = get_stat2('onbase_plus_slugging')
WSN_2018_LOB = get_stat2('LOB')
nationals_2018_offense = pd.DataFrame({
                                  'PA': WSN_2018_PA,
                                  'AB': WSN_2018_AB,
                                  'R':  WSN_2018_R,
                                  'H':  WSN_2018_H,
                                  '2B': WSN_2018_2B,
                                  '3B': WSN_2018_3B, 
                                  'HR': WSN_2018_HR, 
                                  'RBI':WSN_2018_RBI,
                                  'BB': WSN_2018_BB,
                                  'SO': WSN_2018_SO,
                                  'SB': WSN_2018_SB,
                                  'CS': WSN_2018_CS,
                                  'LOB':WSN_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=WSN&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

WSN_2018_P_game_num = get_stat3('team_game_num')
WSN_2018_P_IP = get_stat3('IP')
WSN_2018_P_H = get_stat3('H')
WSN_2018_P_R = get_stat3('R')
WSN_2018_P_ER = get_stat3('ER')
WSN_2018_P_UER = get_stat3('UER')
WSN_2018_P_BB = get_stat3('BB')
WSN_2018_P_SO = get_stat3('SO')
WSN_2018_P_HR = get_stat3('HR')
WSN_2018_P_HBP = get_stat3('HBP')
WSN_2018_P_ERA = get_stat3('earned_run_avg')

nationals_2018_pitching = pd.DataFrame({'Game':  WSN_2018_P_game_num, 
                                         'IP':  WSN_2018_P_IP, 
                                         'H':   WSN_2018_P_H,
                                         'R':   WSN_2018_P_R,
                                         'ER':  WSN_2018_P_ER,
                                         'UER': WSN_2018_P_UER,
                                         'BB':  WSN_2018_P_BB,
                                         'SO':  WSN_2018_P_SO,
                                         'HR':  WSN_2018_P_HR,
                                         'HBP': WSN_2018_P_HBP})

# nationals_offense = nationals_offense.drop(columns = ['Game'])

nationals_2018_pitching = nationals_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [nationals_2018_pitching, nationals_2018_offense]

nationals_2018 = pd.concat(frames, axis=1)

nationals_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(nationals_2018[x])):
        nationals_2018.loc[y,x] = int(nationals_2018.loc[y, x])

for x in columns_float:
    for y in range(len(nationals_2018[x])):
        nationals_2018.loc[y,x] = float(nationals_2018.loc[y, x])  

for x in range(len(nationals_2018['Game'])):
    if nationals_2018.loc[x, 'Runs'] > nationals_2018.loc[x, 'R']:
        nationals_2018.loc[x, 'Win'] = 0
    else:
        nationals_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Nationals Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=WSN&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

WSN_2017_game_num = get_stat2('team_game_num')
WSN_2017_PA = get_stat2('PA')
WSN_2017_AB = get_stat2('AB')
WSN_2017_R = get_stat2('R')
WSN_2017_H = get_stat2('H')
WSN_2017_2B = get_stat2('2B')
WSN_2017_3B = get_stat2('3B')
WSN_2017_HR = get_stat2('HR')
WSN_2017_RBI = get_stat2('RBI')
WSN_2017_BB = get_stat2('BB')
WSN_2017_SO = get_stat2('SO')
WSN_2017_SB = get_stat2('SB')
WSN_2017_CS = get_stat2('CS')
WSN_2017_BA = get_stat2('batting_avg')
WSN_2017_OBP = get_stat2('onbase_perc')
WSN_2017_SLG = get_stat2('slugging_perc')
WSN_2017_OPS = get_stat2('onbase_plus_slugging')
WSN_2017_LOB = get_stat2('LOB')
nationals_2017_offense = pd.DataFrame({
                                  'PA': WSN_2017_PA,
                                  'AB': WSN_2017_AB,
                                  'R':  WSN_2017_R,
                                  'H':  WSN_2017_H,
                                  '2B': WSN_2017_2B,
                                  '3B': WSN_2017_3B, 
                                  'HR': WSN_2017_HR, 
                                  'RBI':WSN_2017_RBI,
                                  'BB': WSN_2017_BB,
                                  'SO': WSN_2017_SO,
                                  'SB': WSN_2017_SB,
                                  'CS': WSN_2017_CS,
                                  'LOB':WSN_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=WSN&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

WSN_2017_P_game_num = get_stat3('team_game_num')
WSN_2017_P_IP = get_stat3('IP')
WSN_2017_P_H = get_stat3('H')
WSN_2017_P_R = get_stat3('R')
WSN_2017_P_ER = get_stat3('ER')
WSN_2017_P_UER = get_stat3('UER')
WSN_2017_P_BB = get_stat3('BB')
WSN_2017_P_SO = get_stat3('SO')
WSN_2017_P_HR = get_stat3('HR')
WSN_2017_P_HBP = get_stat3('HBP')
WSN_2017_P_ERA = get_stat3('earned_run_avg')

nationals_2017_pitching = pd.DataFrame({'Game':  WSN_2017_P_game_num, 
                                         'IP':  WSN_2017_P_IP, 
                                         'H':   WSN_2017_P_H,
                                         'R':   WSN_2017_P_R,
                                         'ER':  WSN_2017_P_ER,
                                         'UER': WSN_2017_P_UER,
                                         'BB':  WSN_2017_P_BB,
                                         'SO':  WSN_2017_P_SO,
                                         'HR':  WSN_2017_P_HR,
                                         'HBP': WSN_2017_P_HBP})

# nationals_offense = nationals_offense.drop(columns = ['Game'])

nationals_2017_pitching = nationals_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [nationals_2017_pitching, nationals_2017_offense]

nationals_2017 = pd.concat(frames, axis=1)

nationals_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(nationals_2017[x])):
        nationals_2017.loc[y,x] = int(nationals_2017.loc[y, x])

for x in columns_float:
    for y in range(len(nationals_2017[x])):
        nationals_2017.loc[y,x] = float(nationals_2017.loc[y, x])  

for x in range(len(nationals_2017['Game'])):
    if nationals_2017.loc[x, 'Runs'] > nationals_2017.loc[x, 'R']:
        nationals_2017.loc[x, 'Win'] = 0
    else:
        nationals_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Nationals Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=WSN&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

WSN_2016_game_num = get_stat2('team_game_num')
WSN_2016_PA = get_stat2('PA')
WSN_2016_AB = get_stat2('AB')
WSN_2016_R = get_stat2('R')
WSN_2016_H = get_stat2('H')
WSN_2016_2B = get_stat2('2B')
WSN_2016_3B = get_stat2('3B')
WSN_2016_HR = get_stat2('HR')
WSN_2016_RBI = get_stat2('RBI')
WSN_2016_BB = get_stat2('BB')
WSN_2016_SO = get_stat2('SO')
WSN_2016_SB = get_stat2('SB')
WSN_2016_CS = get_stat2('CS')
WSN_2016_BA = get_stat2('batting_avg')
WSN_2016_OBP = get_stat2('onbase_perc')
WSN_2016_SLG = get_stat2('slugging_perc')
WSN_2016_OPS = get_stat2('onbase_plus_slugging')
WSN_2016_LOB = get_stat2('LOB')
nationals_2016_offense = pd.DataFrame({
                                  'PA': WSN_2016_PA,
                                  'AB': WSN_2016_AB,
                                  'R':  WSN_2016_R,
                                  'H':  WSN_2016_H,
                                  '2B': WSN_2016_2B,
                                  '3B': WSN_2016_3B, 
                                  'HR': WSN_2016_HR, 
                                  'RBI':WSN_2016_RBI,
                                  'BB': WSN_2016_BB,
                                  'SO': WSN_2016_SO,
                                  'SB': WSN_2016_SB,
                                  'CS': WSN_2016_CS,
                                  'LOB':WSN_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=WSN&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

WSN_2016_P_game_num = get_stat3('team_game_num')
WSN_2016_P_IP = get_stat3('IP')
WSN_2016_P_H = get_stat3('H')
WSN_2016_P_R = get_stat3('R')
WSN_2016_P_ER = get_stat3('ER')
WSN_2016_P_UER = get_stat3('UER')
WSN_2016_P_BB = get_stat3('BB')
WSN_2016_P_SO = get_stat3('SO')
WSN_2016_P_HR = get_stat3('HR')
WSN_2016_P_HBP = get_stat3('HBP')
WSN_2016_P_ERA = get_stat3('earned_run_avg')

nationals_2016_pitching = pd.DataFrame({'Game':  WSN_2016_P_game_num, 
                                         'IP':  WSN_2016_P_IP, 
                                         'H':   WSN_2016_P_H,
                                         'R':   WSN_2016_P_R,
                                         'ER':  WSN_2016_P_ER,
                                         'UER': WSN_2016_P_UER,
                                         'BB':  WSN_2016_P_BB,
                                         'SO':  WSN_2016_P_SO,
                                         'HR':  WSN_2016_P_HR,
                                         'HBP': WSN_2016_P_HBP})

# nationals_offense = nationals_offense.drop(columns = ['Game'])

nationals_2016_pitching = nationals_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [nationals_2016_pitching, nationals_2016_offense]

nationals_2016 = pd.concat(frames, axis=1)

nationals_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(nationals_2016[x])):
        nationals_2016.loc[y,x] = int(nationals_2016.loc[y, x])

for x in columns_float:
    for y in range(len(nationals_2016[x])):
        nationals_2016.loc[y,x] = float(nationals_2016.loc[y, x])  

for x in range(len(nationals_2016['Game'])):
    if nationals_2016.loc[x, 'Runs'] > nationals_2016.loc[x, 'R']:
        nationals_2016.loc[x, 'Win'] = 0
    else:
        nationals_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # Nationals 2015 Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=WSN&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

WSN_2015_game_num = get_stat2('team_game_num')
WSN_2015_PA = get_stat2('PA')
WSN_2015_AB = get_stat2('AB')
WSN_2015_R = get_stat2('R')
WSN_2015_H = get_stat2('H')
WSN_2015_2B = get_stat2('2B')
WSN_2015_3B = get_stat2('3B')
WSN_2015_HR = get_stat2('HR')
WSN_2015_RBI = get_stat2('RBI')
WSN_2015_BB = get_stat2('BB')
WSN_2015_SO = get_stat2('SO')
WSN_2015_SB = get_stat2('SB')
WSN_2015_CS = get_stat2('CS')
WSN_2015_BA = get_stat2('batting_avg')
WSN_2015_OBP = get_stat2('onbase_perc')
WSN_2015_SLG = get_stat2('slugging_perc')
WSN_2015_OPS = get_stat2('onbase_plus_slugging')
WSN_2015_LOB = get_stat2('LOB')
nationals_2015_offense = pd.DataFrame({
                                  'PA': WSN_2015_PA,
                                  'AB': WSN_2015_AB,
                                  'R':  WSN_2015_R,
                                  'H':  WSN_2015_H,
                                  '2B': WSN_2015_2B,
                                  '3B': WSN_2015_3B, 
                                  'HR': WSN_2015_HR, 
                                  'RBI':WSN_2015_RBI,
                                  'BB': WSN_2015_BB,
                                  'SO': WSN_2015_SO,
                                  'SB': WSN_2015_SB,
                                  'CS': WSN_2015_CS,
                                  'LOB':WSN_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=WSN&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

WSN_2015_P_game_num = get_stat3('team_game_num')
WSN_2015_P_IP = get_stat3('IP')
WSN_2015_P_H = get_stat3('H')
WSN_2015_P_R = get_stat3('R')
WSN_2015_P_ER = get_stat3('ER')
WSN_2015_P_UER = get_stat3('UER')
WSN_2015_P_BB = get_stat3('BB')
WSN_2015_P_SO = get_stat3('SO')
WSN_2015_P_HR = get_stat3('HR')
WSN_2015_P_HBP = get_stat3('HBP')
WSN_2015_P_ERA = get_stat3('earned_run_avg')

nationals_2015_pitching = pd.DataFrame({'Game':  WSN_2015_P_game_num, 
                                         'IP':  WSN_2015_P_IP, 
                                         'H':   WSN_2015_P_H,
                                         'R':   WSN_2015_P_R,
                                         'ER':  WSN_2015_P_ER,
                                         'UER': WSN_2015_P_UER,
                                         'BB':  WSN_2015_P_BB,
                                         'SO':  WSN_2015_P_SO,
                                         'HR':  WSN_2015_P_HR,
                                         'HBP': WSN_2015_P_HBP})

# nationals_offense = nationals_offense.drop(columns = ['Game'])

nationals_2015_pitching = nationals_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [nationals_2015_pitching, nationals_2015_offense]

nationals_2015 = pd.concat(frames, axis=1)

nationals_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(nationals_2015[x])):
        nationals_2015.loc[y,x] = int(nationals_2015.loc[y, x])

for x in columns_float:
    for y in range(len(nationals_2015[x])):
        nationals_2015.loc[y,x] = float(nationals_2015.loc[y, x])  

for x in range(len(nationals_2015['Game'])):
    if nationals_2015.loc[x, 'Runs'] > nationals_2015.loc[x, 'R']:
        nationals_2015.loc[x, 'Win'] = 0
    else:
        nationals_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Miami Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIA&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIA_game_num = get_stat2('team_game_num')

MIA_PA = get_stat2('PA')

MIA_AB = get_stat2('AB')

MIA_R = get_stat2('R')

MIA_H = get_stat2('H')

MIA_2B = get_stat2('2B')

MIA_3B = get_stat2('3B')

MIA_HR = get_stat2('HR')

MIA_RBI = get_stat2('RBI')

MIA_BB = get_stat2('BB')

MIA_SO = get_stat2('SO')

MIA_SB = get_stat2('SB')

MIA_CS = get_stat2('CS')

MIA_BA = get_stat2('batting_avg')

MIA_OBP = get_stat2('onbase_perc')

MIA_SLG = get_stat2('slugging_perc')

MIA_OPS = get_stat2('onbase_plus_slugging')

MIA_LOB = get_stat2('LOB')

marlins_offense = pd.DataFrame({
                                  'PA': MIA_PA,
                                  'AB': MIA_AB,
                                  'R':MIA_R,
                                  'H':MIA_H,
                                  '2B':MIA_2B,
                                  '3B': MIA_3B, 
                                  'HR':MIA_HR, 
                                  'RBI':MIA_RBI,
                                  'BB':MIA_BB,
                                  'SO':MIA_SO,
                                  'SB': MIA_SB,
                                  'CS':MIA_CS,
                                  'LOB':MIA_LOB})

# %% [markdown]
# # 2019 Miami Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIA&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIA_P_game_num = get_stat3('team_game_num')

MIA_P_IP = get_stat3('IP')

MIA_P_H = get_stat3('H')

MIA_P_R = get_stat3('R')

MIA_P_ER = get_stat3('ER')

MIA_P_UER = get_stat3('UER')

MIA_P_BB = get_stat3('BB')

MIA_P_SO = get_stat3('SO')

MIA_P_HR = get_stat3('HR')

MIA_P_HBP = get_stat3('HBP')

MIA_P_ERA = get_stat3('earned_run_avg')

marlins_pitching = pd.DataFrame({'Game': MIA_P_game_num, 
                                   'IP':MIA_P_IP, 
                                   'H':MIA_P_H,
                                   'R':MIA_P_R,
                                   'ER':MIA_P_ER,
                                   'UER':MIA_P_UER,
                                   'BB':MIA_P_BB,
                                   'SO':MIA_P_SO,
                                   'HR':MIA_P_HR,
                                   'HBP':MIA_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

marlins_pitching = marlins_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [marlins_pitching, marlins_offense]

marlins = pd.concat(frames, axis=1)

marlins['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(marlins[x])):
        marlins.loc[y,x] = int(marlins.loc[y, x])

for x in columns_float:
    for y in range(len(marlins[x])):
        marlins.loc[y,x] = float(marlins.loc[y, x])  

for x in range(len(marlins['Game'])):
    if marlins.loc[x, 'Runs'] > marlins.loc[x, 'R']:
        marlins.loc[x, 'Win'] = 0
    else:
        marlins.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Miami Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIA&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIA_2018_game_num = get_stat2('team_game_num')
MIA_2018_PA = get_stat2('PA')
MIA_2018_AB = get_stat2('AB')
MIA_2018_R = get_stat2('R')
MIA_2018_H = get_stat2('H')
MIA_2018_2B = get_stat2('2B')
MIA_2018_3B = get_stat2('3B')
MIA_2018_HR = get_stat2('HR')
MIA_2018_RBI = get_stat2('RBI')
MIA_2018_BB = get_stat2('BB')
MIA_2018_SO = get_stat2('SO')
MIA_2018_SB = get_stat2('SB')
MIA_2018_CS = get_stat2('CS')
MIA_2018_BA = get_stat2('batting_avg')
MIA_2018_OBP = get_stat2('onbase_perc')
MIA_2018_SLG = get_stat2('slugging_perc')
MIA_2018_OPS = get_stat2('onbase_plus_slugging')
MIA_2018_LOB = get_stat2('LOB')
marlins_2018_offense = pd.DataFrame({
                                  'PA': MIA_2018_PA,
                                  'AB': MIA_2018_AB,
                                  'R':  MIA_2018_R,
                                  'H':  MIA_2018_H,
                                  '2B': MIA_2018_2B,
                                  '3B': MIA_2018_3B, 
                                  'HR': MIA_2018_HR, 
                                  'RBI':MIA_2018_RBI,
                                  'BB': MIA_2018_BB,
                                  'SO': MIA_2018_SO,
                                  'SB': MIA_2018_SB,
                                  'CS': MIA_2018_CS,
                                  'LOB':MIA_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIA&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIA_2018_P_game_num = get_stat3('team_game_num')
MIA_2018_P_IP = get_stat3('IP')
MIA_2018_P_H = get_stat3('H')
MIA_2018_P_R = get_stat3('R')
MIA_2018_P_ER = get_stat3('ER')
MIA_2018_P_UER = get_stat3('UER')
MIA_2018_P_BB = get_stat3('BB')
MIA_2018_P_SO = get_stat3('SO')
MIA_2018_P_HR = get_stat3('HR')
MIA_2018_P_HBP = get_stat3('HBP')
MIA_2018_P_ERA = get_stat3('earned_run_avg')

marlins_2018_pitching = pd.DataFrame({'Game':  MIA_2018_P_game_num, 
                                         'IP':  MIA_2018_P_IP, 
                                         'H':   MIA_2018_P_H,
                                         'R':   MIA_2018_P_R,
                                         'ER':  MIA_2018_P_ER,
                                         'UER': MIA_2018_P_UER,
                                         'BB':  MIA_2018_P_BB,
                                         'SO':  MIA_2018_P_SO,
                                         'HR':  MIA_2018_P_HR,
                                         'HBP': MIA_2018_P_HBP})

# marlins_offense = marlins_offense.drop(columns = ['Game'])

marlins_2018_pitching = marlins_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [marlins_2018_pitching, marlins_2018_offense]

marlins_2018 = pd.concat(frames, axis=1)

marlins_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(marlins_2018[x])):
        marlins_2018.loc[y,x] = int(marlins_2018.loc[y, x])

for x in columns_float:
    for y in range(len(marlins_2018[x])):
        marlins_2018.loc[y,x] = float(marlins_2018.loc[y, x])  

for x in range(len(marlins_2018['Game'])):
    if marlins_2018.loc[x, 'Runs'] > marlins_2018.loc[x, 'R']:
        marlins_2018.loc[x, 'Win'] = 0
    else:
        marlins_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Miami Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIA&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIA_2017_game_num = get_stat2('team_game_num')
MIA_2017_PA = get_stat2('PA')
MIA_2017_AB = get_stat2('AB')
MIA_2017_R = get_stat2('R')
MIA_2017_H = get_stat2('H')
MIA_2017_2B = get_stat2('2B')
MIA_2017_3B = get_stat2('3B')
MIA_2017_HR = get_stat2('HR')
MIA_2017_RBI = get_stat2('RBI')
MIA_2017_BB = get_stat2('BB')
MIA_2017_SO = get_stat2('SO')
MIA_2017_SB = get_stat2('SB')
MIA_2017_CS = get_stat2('CS')
MIA_2017_BA = get_stat2('batting_avg')
MIA_2017_OBP = get_stat2('onbase_perc')
MIA_2017_SLG = get_stat2('slugging_perc')
MIA_2017_OPS = get_stat2('onbase_plus_slugging')
MIA_2017_LOB = get_stat2('LOB')
marlins_2017_offense = pd.DataFrame({
                                  'PA': MIA_2017_PA,
                                  'AB': MIA_2017_AB,
                                  'R':  MIA_2017_R,
                                  'H':  MIA_2017_H,
                                  '2B': MIA_2017_2B,
                                  '3B': MIA_2017_3B, 
                                  'HR': MIA_2017_HR, 
                                  'RBI':MIA_2017_RBI,
                                  'BB': MIA_2017_BB,
                                  'SO': MIA_2017_SO,
                                  'SB': MIA_2017_SB,
                                  'CS': MIA_2017_CS,
                                  'LOB':MIA_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIA&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIA_2017_P_game_num = get_stat3('team_game_num')
MIA_2017_P_IP = get_stat3('IP')
MIA_2017_P_H = get_stat3('H')
MIA_2017_P_R = get_stat3('R')
MIA_2017_P_ER = get_stat3('ER')
MIA_2017_P_UER = get_stat3('UER')
MIA_2017_P_BB = get_stat3('BB')
MIA_2017_P_SO = get_stat3('SO')
MIA_2017_P_HR = get_stat3('HR')
MIA_2017_P_HBP = get_stat3('HBP')
MIA_2017_P_ERA = get_stat3('earned_run_avg')

marlins_2017_pitching = pd.DataFrame({'Game':  MIA_2017_P_game_num, 
                                         'IP':  MIA_2017_P_IP, 
                                         'H':   MIA_2017_P_H,
                                         'R':   MIA_2017_P_R,
                                         'ER':  MIA_2017_P_ER,
                                         'UER': MIA_2017_P_UER,
                                         'BB':  MIA_2017_P_BB,
                                         'SO':  MIA_2017_P_SO,
                                         'HR':  MIA_2017_P_HR,
                                         'HBP': MIA_2017_P_HBP})

# marlins_offense = marlins_offense.drop(columns = ['Game'])

marlins_2017_pitching = marlins_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [marlins_2017_pitching, marlins_2017_offense]

marlins_2017 = pd.concat(frames, axis=1)

marlins_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(marlins_2017[x])):
        marlins_2017.loc[y,x] = int(marlins_2017.loc[y, x])

for x in columns_float:
    for y in range(len(marlins_2017[x])):
        marlins_2017.loc[y,x] = float(marlins_2017.loc[y, x])  

for x in range(len(marlins_2017['Game'])):
    if marlins_2017.loc[x, 'Runs'] > marlins_2017.loc[x, 'R']:
        marlins_2017.loc[x, 'Win'] = 0
    else:
        marlins_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Miami Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIA&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIA_2016_game_num = get_stat2('team_game_num')
MIA_2016_PA = get_stat2('PA')
MIA_2016_AB = get_stat2('AB')
MIA_2016_R = get_stat2('R')
MIA_2016_H = get_stat2('H')
MIA_2016_2B = get_stat2('2B')
MIA_2016_3B = get_stat2('3B')
MIA_2016_HR = get_stat2('HR')
MIA_2016_RBI = get_stat2('RBI')
MIA_2016_BB = get_stat2('BB')
MIA_2016_SO = get_stat2('SO')
MIA_2016_SB = get_stat2('SB')
MIA_2016_CS = get_stat2('CS')
MIA_2016_BA = get_stat2('batting_avg')
MIA_2016_OBP = get_stat2('onbase_perc')
MIA_2016_SLG = get_stat2('slugging_perc')
MIA_2016_OPS = get_stat2('onbase_plus_slugging')
MIA_2016_LOB = get_stat2('LOB')
marlins_2016_offense = pd.DataFrame({
                                  'PA': MIA_2016_PA,
                                  'AB': MIA_2016_AB,
                                  'R':  MIA_2016_R,
                                  'H':  MIA_2016_H,
                                  '2B': MIA_2016_2B,
                                  '3B': MIA_2016_3B, 
                                  'HR': MIA_2016_HR, 
                                  'RBI':MIA_2016_RBI,
                                  'BB': MIA_2016_BB,
                                  'SO': MIA_2016_SO,
                                  'SB': MIA_2016_SB,
                                  'CS': MIA_2016_CS,
                                  'LOB':MIA_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIA&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIA_2016_P_game_num = get_stat3('team_game_num')
MIA_2016_P_IP = get_stat3('IP')
MIA_2016_P_H = get_stat3('H')
MIA_2016_P_R = get_stat3('R')
MIA_2016_P_ER = get_stat3('ER')
MIA_2016_P_UER = get_stat3('UER')
MIA_2016_P_BB = get_stat3('BB')
MIA_2016_P_SO = get_stat3('SO')
MIA_2016_P_HR = get_stat3('HR')
MIA_2016_P_HBP = get_stat3('HBP')
MIA_2016_P_ERA = get_stat3('earned_run_avg')

marlins_2016_pitching = pd.DataFrame({'Game':  MIA_2016_P_game_num, 
                                         'IP':  MIA_2016_P_IP, 
                                         'H':   MIA_2016_P_H,
                                         'R':   MIA_2016_P_R,
                                         'ER':  MIA_2016_P_ER,
                                         'UER': MIA_2016_P_UER,
                                         'BB':  MIA_2016_P_BB,
                                         'SO':  MIA_2016_P_SO,
                                         'HR':  MIA_2016_P_HR,
                                         'HBP': MIA_2016_P_HBP})

# marlins_offense = marlins_offense.drop(columns = ['Game'])

marlins_2016_pitching = marlins_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [marlins_2016_pitching, marlins_2016_offense]

marlins_2016 = pd.concat(frames, axis=1)

marlins_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(marlins_2016[x])):
        marlins_2016.loc[y,x] = int(marlins_2016.loc[y, x])

for x in columns_float:
    for y in range(len(marlins_2016[x])):
        marlins_2016.loc[y,x] = float(marlins_2016.loc[y, x])  

for x in range(len(marlins_2016['Game'])):
    if marlins_2016.loc[x, 'Runs'] > marlins_2016.loc[x, 'R']:
        marlins_2016.loc[x, 'Win'] = 0
    else:
        marlins_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Miami Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIA&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIA_2015_game_num = get_stat2('team_game_num')
MIA_2015_PA = get_stat2('PA')
MIA_2015_AB = get_stat2('AB')
MIA_2015_R = get_stat2('R')
MIA_2015_H = get_stat2('H')
MIA_2015_2B = get_stat2('2B')
MIA_2015_3B = get_stat2('3B')
MIA_2015_HR = get_stat2('HR')
MIA_2015_RBI = get_stat2('RBI')
MIA_2015_BB = get_stat2('BB')
MIA_2015_SO = get_stat2('SO')
MIA_2015_SB = get_stat2('SB')
MIA_2015_CS = get_stat2('CS')
MIA_2015_BA = get_stat2('batting_avg')
MIA_2015_OBP = get_stat2('onbase_perc')
MIA_2015_SLG = get_stat2('slugging_perc')
MIA_2015_OPS = get_stat2('onbase_plus_slugging')
MIA_2015_LOB = get_stat2('LOB')
marlins_2015_offense = pd.DataFrame({
                                  'PA': MIA_2015_PA,
                                  'AB': MIA_2015_AB,
                                  'R':  MIA_2015_R,
                                  'H':  MIA_2015_H,
                                  '2B': MIA_2015_2B,
                                  '3B': MIA_2015_3B, 
                                  'HR': MIA_2015_HR, 
                                  'RBI':MIA_2015_RBI,
                                  'BB': MIA_2015_BB,
                                  'SO': MIA_2015_SO,
                                  'SB': MIA_2015_SB,
                                  'CS': MIA_2015_CS,
                                  'LOB':MIA_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIA&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIA_2015_P_game_num = get_stat3('team_game_num')
MIA_2015_P_IP = get_stat3('IP')
MIA_2015_P_H = get_stat3('H')
MIA_2015_P_R = get_stat3('R')
MIA_2015_P_ER = get_stat3('ER')
MIA_2015_P_UER = get_stat3('UER')
MIA_2015_P_BB = get_stat3('BB')
MIA_2015_P_SO = get_stat3('SO')
MIA_2015_P_HR = get_stat3('HR')
MIA_2015_P_HBP = get_stat3('HBP')
MIA_2015_P_ERA = get_stat3('earned_run_avg')

marlins_2015_pitching = pd.DataFrame({'Game':  MIA_2015_P_game_num, 
                                         'IP':  MIA_2015_P_IP, 
                                         'H':   MIA_2015_P_H,
                                         'R':   MIA_2015_P_R,
                                         'ER':  MIA_2015_P_ER,
                                         'UER': MIA_2015_P_UER,
                                         'BB':  MIA_2015_P_BB,
                                         'SO':  MIA_2015_P_SO,
                                         'HR':  MIA_2015_P_HR,
                                         'HBP': MIA_2015_P_HBP})

# marlins_offense = marlins_offense.drop(columns = ['Game'])

marlins_2015_pitching = marlins_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [marlins_2015_pitching, marlins_2015_offense]

marlins_2015 = pd.concat(frames, axis=1)

marlins_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(marlins_2015[x])):
        marlins_2015.loc[y,x] = int(marlins_2015.loc[y, x])

for x in columns_float:
    for y in range(len(marlins_2015[x])):
        marlins_2015.loc[y,x] = float(marlins_2015.loc[y, x])  

for x in range(len(marlins_2015['Game'])):
    if marlins_2015.loc[x, 'Runs'] > marlins_2015.loc[x, 'R']:
        marlins_2015.loc[x, 'Win'] = 0
    else:
        marlins_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Mets Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYM&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYM_game_num = get_stat2('team_game_num')

NYM_PA = get_stat2('PA')

NYM_AB = get_stat2('AB')

NYM_R = get_stat2('R')

NYM_H = get_stat2('H')

NYM_2B = get_stat2('2B')

NYM_3B = get_stat2('3B')

NYM_HR = get_stat2('HR')

NYM_RBI = get_stat2('RBI')

NYM_BB = get_stat2('BB')

NYM_SO = get_stat2('SO')

NYM_SB = get_stat2('SB')

NYM_CS = get_stat2('CS')

NYM_BA = get_stat2('batting_avg')

NYM_OBP = get_stat2('onbase_perc')

NYM_SLG = get_stat2('slugging_perc')

NYM_OPS = get_stat2('onbase_plus_slugging')

NYM_LOB = get_stat2('LOB')

mets_offense = pd.DataFrame({
                                  'PA': NYM_PA,
                                  'AB': NYM_AB,
                                  'R':NYM_R,
                                  'H':NYM_H,
                                  '2B':NYM_2B,
                                  '3B': NYM_3B, 
                                  'HR':NYM_HR, 
                                  'RBI':NYM_RBI,
                                  'BB':NYM_BB,
                                  'SO':NYM_SO,
                                  'SB': NYM_SB,
                                  'CS':NYM_CS,
                                  'LOB':NYM_LOB})

# %% [markdown]
# # 2019 Met Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYM&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYM_P_game_num = get_stat3('team_game_num')

NYM_P_IP = get_stat3('IP')

NYM_P_H = get_stat3('H')

NYM_P_R = get_stat3('R')

NYM_P_ER = get_stat3('ER')

NYM_P_UER = get_stat3('UER')

NYM_P_BB = get_stat3('BB')

NYM_P_SO = get_stat3('SO')

NYM_P_HR = get_stat3('HR')

NYM_P_HBP = get_stat3('HBP')

NYM_P_ERA = get_stat3('earned_run_avg')

mets_pitching = pd.DataFrame({'Game': NYM_P_game_num, 
                                   'IP':NYM_P_IP, 
                                   'H':NYM_P_H,
                                   'R':NYM_P_R,
                                   'ER':NYM_P_ER,
                                   'UER':NYM_P_UER,
                                   'BB':NYM_P_BB,
                                   'SO':NYM_P_SO,
                                   'HR':NYM_P_HR,
                                   'HBP':NYM_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

mets_pitching = mets_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [mets_pitching, mets_offense]

mets = pd.concat(frames, axis=1)

mets['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(mets[x])):
        mets.loc[y,x] = int(mets.loc[y, x])

for x in columns_float:
    for y in range(len(mets[x])):
        mets.loc[y,x] = float(mets.loc[y, x])  

for x in range(len(mets['Game'])):
    if mets.loc[x, 'Runs'] > mets.loc[x, 'R']:
        mets.loc[x, 'Win'] = 0
    else:
        mets.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Mets Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYM&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYM_2018_game_num = get_stat2('team_game_num')
NYM_2018_PA = get_stat2('PA')
NYM_2018_AB = get_stat2('AB')
NYM_2018_R = get_stat2('R')
NYM_2018_H = get_stat2('H')
NYM_2018_2B = get_stat2('2B')
NYM_2018_3B = get_stat2('3B')
NYM_2018_HR = get_stat2('HR')
NYM_2018_RBI = get_stat2('RBI')
NYM_2018_BB = get_stat2('BB')
NYM_2018_SO = get_stat2('SO')
NYM_2018_SB = get_stat2('SB')
NYM_2018_CS = get_stat2('CS')
NYM_2018_BA = get_stat2('batting_avg')
NYM_2018_OBP = get_stat2('onbase_perc')
NYM_2018_SLG = get_stat2('slugging_perc')
NYM_2018_OPS = get_stat2('onbase_plus_slugging')
NYM_2018_LOB = get_stat2('LOB')
mets_2018_offense = pd.DataFrame({
                                  'PA': NYM_2018_PA,
                                  'AB': NYM_2018_AB,
                                  'R':  NYM_2018_R,
                                  'H':  NYM_2018_H,
                                  '2B': NYM_2018_2B,
                                  '3B': NYM_2018_3B, 
                                  'HR': NYM_2018_HR, 
                                  'RBI':NYM_2018_RBI,
                                  'BB': NYM_2018_BB,
                                  'SO': NYM_2018_SO,
                                  'SB': NYM_2018_SB,
                                  'CS': NYM_2018_CS,
                                  'LOB':NYM_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYM&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYM_2018_P_game_num = get_stat3('team_game_num')
NYM_2018_P_IP = get_stat3('IP')
NYM_2018_P_H = get_stat3('H')
NYM_2018_P_R = get_stat3('R')
NYM_2018_P_ER = get_stat3('ER')
NYM_2018_P_UER = get_stat3('UER')
NYM_2018_P_BB = get_stat3('BB')
NYM_2018_P_SO = get_stat3('SO')
NYM_2018_P_HR = get_stat3('HR')
NYM_2018_P_HBP = get_stat3('HBP')
NYM_2018_P_ERA = get_stat3('earned_run_avg')

mets_2018_pitching = pd.DataFrame({'Game':  NYM_2018_P_game_num, 
                                         'IP':  NYM_2018_P_IP, 
                                         'H':   NYM_2018_P_H,
                                         'R':   NYM_2018_P_R,
                                         'ER':  NYM_2018_P_ER,
                                         'UER': NYM_2018_P_UER,
                                         'BB':  NYM_2018_P_BB,
                                         'SO':  NYM_2018_P_SO,
                                         'HR':  NYM_2018_P_HR,
                                         'HBP': NYM_2018_P_HBP})

# mets_offense = mets_offense.drop(columns = ['Game'])

mets_2018_pitching = mets_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [mets_2018_pitching, mets_2018_offense]

mets_2018 = pd.concat(frames, axis=1)

mets_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(mets_2018[x])):
        mets_2018.loc[y,x] = int(mets_2018.loc[y, x])

for x in columns_float:
    for y in range(len(mets_2018[x])):
        mets_2018.loc[y,x] = float(mets_2018.loc[y, x])  

for x in range(len(mets_2018['Game'])):
    if mets_2018.loc[x, 'Runs'] > mets_2018.loc[x, 'R']:
        mets_2018.loc[x, 'Win'] = 0
    else:
        mets_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Mets Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYM&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYM_2017_game_num = get_stat2('team_game_num')
NYM_2017_PA = get_stat2('PA')
NYM_2017_AB = get_stat2('AB')
NYM_2017_R = get_stat2('R')
NYM_2017_H = get_stat2('H')
NYM_2017_2B = get_stat2('2B')
NYM_2017_3B = get_stat2('3B')
NYM_2017_HR = get_stat2('HR')
NYM_2017_RBI = get_stat2('RBI')
NYM_2017_BB = get_stat2('BB')
NYM_2017_SO = get_stat2('SO')
NYM_2017_SB = get_stat2('SB')
NYM_2017_CS = get_stat2('CS')
NYM_2017_BA = get_stat2('batting_avg')
NYM_2017_OBP = get_stat2('onbase_perc')
NYM_2017_SLG = get_stat2('slugging_perc')
NYM_2017_OPS = get_stat2('onbase_plus_slugging')
NYM_2017_LOB = get_stat2('LOB')
mets_2017_offense = pd.DataFrame({
                                  'PA': NYM_2017_PA,
                                  'AB': NYM_2017_AB,
                                  'R':  NYM_2017_R,
                                  'H':  NYM_2017_H,
                                  '2B': NYM_2017_2B,
                                  '3B': NYM_2017_3B, 
                                  'HR': NYM_2017_HR, 
                                  'RBI':NYM_2017_RBI,
                                  'BB': NYM_2017_BB,
                                  'SO': NYM_2017_SO,
                                  'SB': NYM_2017_SB,
                                  'CS': NYM_2017_CS,
                                  'LOB':NYM_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYM&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYM_2017_P_game_num = get_stat3('team_game_num')
NYM_2017_P_IP = get_stat3('IP')
NYM_2017_P_H = get_stat3('H')
NYM_2017_P_R = get_stat3('R')
NYM_2017_P_ER = get_stat3('ER')
NYM_2017_P_UER = get_stat3('UER')
NYM_2017_P_BB = get_stat3('BB')
NYM_2017_P_SO = get_stat3('SO')
NYM_2017_P_HR = get_stat3('HR')
NYM_2017_P_HBP = get_stat3('HBP')
NYM_2017_P_ERA = get_stat3('earned_run_avg')

mets_2017_pitching = pd.DataFrame({'Game':  NYM_2017_P_game_num, 
                                         'IP':  NYM_2017_P_IP, 
                                         'H':   NYM_2017_P_H,
                                         'R':   NYM_2017_P_R,
                                         'ER':  NYM_2017_P_ER,
                                         'UER': NYM_2017_P_UER,
                                         'BB':  NYM_2017_P_BB,
                                         'SO':  NYM_2017_P_SO,
                                         'HR':  NYM_2017_P_HR,
                                         'HBP': NYM_2017_P_HBP})

# mets_offense = mets_offense.drop(columns = ['Game'])

mets_2017_pitching = mets_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [mets_2017_pitching, mets_2017_offense]

mets_2017 = pd.concat(frames, axis=1)

mets_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(mets_2017[x])):
        mets_2017.loc[y,x] = int(mets_2017.loc[y, x])

for x in columns_float:
    for y in range(len(mets_2017[x])):
        mets_2017.loc[y,x] = float(mets_2017.loc[y, x])  

for x in range(len(mets_2017['Game'])):
    if mets_2017.loc[x, 'Runs'] > mets_2017.loc[x, 'R']:
        mets_2017.loc[x, 'Win'] = 0
    else:
        mets_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Mets Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYM&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYM_2016_game_num = get_stat2('team_game_num')
NYM_2016_PA = get_stat2('PA')
NYM_2016_AB = get_stat2('AB')
NYM_2016_R = get_stat2('R')
NYM_2016_H = get_stat2('H')
NYM_2016_2B = get_stat2('2B')
NYM_2016_3B = get_stat2('3B')
NYM_2016_HR = get_stat2('HR')
NYM_2016_RBI = get_stat2('RBI')
NYM_2016_BB = get_stat2('BB')
NYM_2016_SO = get_stat2('SO')
NYM_2016_SB = get_stat2('SB')
NYM_2016_CS = get_stat2('CS')
NYM_2016_BA = get_stat2('batting_avg')
NYM_2016_OBP = get_stat2('onbase_perc')
NYM_2016_SLG = get_stat2('slugging_perc')
NYM_2016_OPS = get_stat2('onbase_plus_slugging')
NYM_2016_LOB = get_stat2('LOB')
mets_2016_offense = pd.DataFrame({
                                  'PA': NYM_2016_PA,
                                  'AB': NYM_2016_AB,
                                  'R':  NYM_2016_R,
                                  'H':  NYM_2016_H,
                                  '2B': NYM_2016_2B,
                                  '3B': NYM_2016_3B, 
                                  'HR': NYM_2016_HR, 
                                  'RBI':NYM_2016_RBI,
                                  'BB': NYM_2016_BB,
                                  'SO': NYM_2016_SO,
                                  'SB': NYM_2016_SB,
                                  'CS': NYM_2016_CS,
                                  'LOB':NYM_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYM&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYM_2016_P_game_num = get_stat3('team_game_num')
NYM_2016_P_IP = get_stat3('IP')
NYM_2016_P_H = get_stat3('H')
NYM_2016_P_R = get_stat3('R')
NYM_2016_P_ER = get_stat3('ER')
NYM_2016_P_UER = get_stat3('UER')
NYM_2016_P_BB = get_stat3('BB')
NYM_2016_P_SO = get_stat3('SO')
NYM_2016_P_HR = get_stat3('HR')
NYM_2016_P_HBP = get_stat3('HBP')
NYM_2016_P_ERA = get_stat3('earned_run_avg')

mets_2016_pitching = pd.DataFrame({'Game':  NYM_2016_P_game_num, 
                                         'IP':  NYM_2016_P_IP, 
                                         'H':   NYM_2016_P_H,
                                         'R':   NYM_2016_P_R,
                                         'ER':  NYM_2016_P_ER,
                                         'UER': NYM_2016_P_UER,
                                         'BB':  NYM_2016_P_BB,
                                         'SO':  NYM_2016_P_SO,
                                         'HR':  NYM_2016_P_HR,
                                         'HBP': NYM_2016_P_HBP})

# mets_offense = mets_offense.drop(columns = ['Game'])

mets_2016_pitching = mets_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [mets_2016_pitching, mets_2016_offense]

mets_2016 = pd.concat(frames, axis=1)

mets_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(mets_2016[x])):
        mets_2016.loc[y,x] = int(mets_2016.loc[y, x])

for x in columns_float:
    for y in range(len(mets_2016[x])):
        mets_2016.loc[y,x] = float(mets_2016.loc[y, x])  

for x in range(len(mets_2016['Game'])):
    if mets_2016.loc[x, 'Runs'] > mets_2016.loc[x, 'R']:
        mets_2016.loc[x, 'Win'] = 0
    else:
        mets_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Mets Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYM&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYM_2015_game_num = get_stat2('team_game_num')
NYM_2015_PA = get_stat2('PA')
NYM_2015_AB = get_stat2('AB')
NYM_2015_R = get_stat2('R')
NYM_2015_H = get_stat2('H')
NYM_2015_2B = get_stat2('2B')
NYM_2015_3B = get_stat2('3B')
NYM_2015_HR = get_stat2('HR')
NYM_2015_RBI = get_stat2('RBI')
NYM_2015_BB = get_stat2('BB')
NYM_2015_SO = get_stat2('SO')
NYM_2015_SB = get_stat2('SB')
NYM_2015_CS = get_stat2('CS')
NYM_2015_BA = get_stat2('batting_avg')
NYM_2015_OBP = get_stat2('onbase_perc')
NYM_2015_SLG = get_stat2('slugging_perc')
NYM_2015_OPS = get_stat2('onbase_plus_slugging')
NYM_2015_LOB = get_stat2('LOB')
mets_2015_offense = pd.DataFrame({
                                  'PA': NYM_2015_PA,
                                  'AB': NYM_2015_AB,
                                  'R':  NYM_2015_R,
                                  'H':  NYM_2015_H,
                                  '2B': NYM_2015_2B,
                                  '3B': NYM_2015_3B, 
                                  'HR': NYM_2015_HR, 
                                  'RBI':NYM_2015_RBI,
                                  'BB': NYM_2015_BB,
                                  'SO': NYM_2015_SO,
                                  'SB': NYM_2015_SB,
                                  'CS': NYM_2015_CS,
                                  'LOB':NYM_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYM&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYM_2015_P_game_num = get_stat3('team_game_num')
NYM_2015_P_IP = get_stat3('IP')
NYM_2015_P_H = get_stat3('H')
NYM_2015_P_R = get_stat3('R')
NYM_2015_P_ER = get_stat3('ER')
NYM_2015_P_UER = get_stat3('UER')
NYM_2015_P_BB = get_stat3('BB')
NYM_2015_P_SO = get_stat3('SO')
NYM_2015_P_HR = get_stat3('HR')
NYM_2015_P_HBP = get_stat3('HBP')
NYM_2015_P_ERA = get_stat3('earned_run_avg')

mets_2015_pitching = pd.DataFrame({'Game':  NYM_2015_P_game_num, 
                                         'IP':  NYM_2015_P_IP, 
                                         'H':   NYM_2015_P_H,
                                         'R':   NYM_2015_P_R,
                                         'ER':  NYM_2015_P_ER,
                                         'UER': NYM_2015_P_UER,
                                         'BB':  NYM_2015_P_BB,
                                         'SO':  NYM_2015_P_SO,
                                         'HR':  NYM_2015_P_HR,
                                         'HBP': NYM_2015_P_HBP})

# mets_offense = mets_offense.drop(columns = ['Game'])

mets_2015_pitching = mets_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [mets_2015_pitching, mets_2015_offense]

mets_2015 = pd.concat(frames, axis=1)

mets_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(mets_2015[x])):
        mets_2015.loc[y,x] = int(mets_2015.loc[y, x])

for x in columns_float:
    for y in range(len(mets_2015[x])):
        mets_2015.loc[y,x] = float(mets_2015.loc[y, x])  

for x in range(len(mets_2015['Game'])):
    if mets_2015.loc[x, 'Runs'] > mets_2015.loc[x, 'R']:
        mets_2015.loc[x, 'Win'] = 0
    else:
        mets_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Cubs Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHC&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHC_game_num = get_stat2('team_game_num')

CHC_PA = get_stat2('PA')

CHC_AB = get_stat2('AB')

CHC_R = get_stat2('R')

CHC_H = get_stat2('H')

CHC_2B = get_stat2('2B')

CHC_3B = get_stat2('3B')

CHC_HR = get_stat2('HR')

CHC_RBI = get_stat2('RBI')

CHC_BB = get_stat2('BB')

CHC_SO = get_stat2('SO')

CHC_SB = get_stat2('SB')

CHC_CS = get_stat2('CS')

CHC_BA = get_stat2('batting_avg')

CHC_OBP = get_stat2('onbase_perc')

CHC_SLG = get_stat2('slugging_perc')

CHC_OPS = get_stat2('onbase_plus_slugging')

CHC_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


cubs_offense = pd.DataFrame({
                                  'PA': CHC_PA,
                                  'AB': CHC_AB,
                                  'R':CHC_R,
                                  'H':CHC_H,
                                  '2B':CHC_2B,
                                  '3B': CHC_3B, 
                                  'HR':CHC_HR, 
                                  'RBI':CHC_RBI,
                                  'BB':CHC_BB,
                                  'SO':CHC_SO,
                                  'SB': CHC_SB,
                                  'CS':CHC_CS,
                                  'LOB':CHC_LOB})

# %% [markdown]
# # 2019 Cubs Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHC&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHC_P_game_num = get_stat3('team_game_num')

CHC_P_IP = get_stat3('IP')

CHC_P_H = get_stat3('H')

CHC_P_R = get_stat3('R')

CHC_P_ER = get_stat3('ER')

CHC_P_UER = get_stat3('UER')

CHC_P_BB = get_stat3('BB')

CHC_P_SO = get_stat3('SO')

CHC_P_HR = get_stat3('HR')

CHC_P_HBP = get_stat3('HBP')

CHC_P_ERA = get_stat3('earned_run_avg')

cubs_pitching = pd.DataFrame({'Game': CHC_P_game_num, 
                                   'IP':CHC_P_IP, 
                                   'H':CHC_P_H,
                                   'R':CHC_P_R,
                                   'ER':CHC_P_ER,
                                   'UER':CHC_P_UER,
                                   'BB':CHC_P_BB,
                                   'SO':CHC_P_SO,
                                   'HR':CHC_P_HR,
                                   'HBP':CHC_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

cubs_pitching = cubs_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [cubs_pitching, cubs_offense]

cubs = pd.concat(frames, axis=1)

cubs['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(cubs[x])):
        cubs.loc[y,x] = int(cubs.loc[y, x])

for x in columns_float:
    for y in range(len(cubs[x])):
        cubs.loc[y,x] = float(cubs.loc[y, x])  

for x in range(len(cubs['Game'])):
    if cubs.loc[x, 'Runs'] > cubs.loc[x, 'R']:
        cubs.loc[x, 'Win'] = 0
    else:
        cubs.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Cubs Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHC&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHC_2018_game_num = get_stat2('team_game_num')
CHC_2018_PA = get_stat2('PA')
CHC_2018_AB = get_stat2('AB')
CHC_2018_R = get_stat2('R')
CHC_2018_H = get_stat2('H')
CHC_2018_2B = get_stat2('2B')
CHC_2018_3B = get_stat2('3B')
CHC_2018_HR = get_stat2('HR')
CHC_2018_RBI = get_stat2('RBI')
CHC_2018_BB = get_stat2('BB')
CHC_2018_SO = get_stat2('SO')
CHC_2018_SB = get_stat2('SB')
CHC_2018_CS = get_stat2('CS')
CHC_2018_BA = get_stat2('batting_avg')
CHC_2018_OBP = get_stat2('onbase_perc')
CHC_2018_SLG = get_stat2('slugging_perc')
CHC_2018_OPS = get_stat2('onbase_plus_slugging')
CHC_2018_LOB = get_stat2('LOB')
cubs_2018_offense = pd.DataFrame({
                                  'PA': CHC_2018_PA,
                                  'AB': CHC_2018_AB,
                                  'R':  CHC_2018_R,
                                  'H':  CHC_2018_H,
                                  '2B': CHC_2018_2B,
                                  '3B': CHC_2018_3B, 
                                  'HR': CHC_2018_HR, 
                                  'RBI':CHC_2018_RBI,
                                  'BB': CHC_2018_BB,
                                  'SO': CHC_2018_SO,
                                  'SB': CHC_2018_SB,
                                  'CS': CHC_2018_CS,
                                  'LOB':CHC_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHC&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHC_2018_P_game_num = get_stat3('team_game_num')
CHC_2018_P_IP = get_stat3('IP')
CHC_2018_P_H = get_stat3('H')
CHC_2018_P_R = get_stat3('R')
CHC_2018_P_ER = get_stat3('ER')
CHC_2018_P_UER = get_stat3('UER')
CHC_2018_P_BB = get_stat3('BB')
CHC_2018_P_SO = get_stat3('SO')
CHC_2018_P_HR = get_stat3('HR')
CHC_2018_P_HBP = get_stat3('HBP')
CHC_2018_P_ERA = get_stat3('earned_run_avg')

cubs_2018_pitching = pd.DataFrame({'Game':  CHC_2018_P_game_num, 
                                         'IP':  CHC_2018_P_IP, 
                                         'H':   CHC_2018_P_H,
                                         'R':   CHC_2018_P_R,
                                         'ER':  CHC_2018_P_ER,
                                         'UER': CHC_2018_P_UER,
                                         'BB':  CHC_2018_P_BB,
                                         'SO':  CHC_2018_P_SO,
                                         'HR':  CHC_2018_P_HR,
                                         'HBP': CHC_2018_P_HBP})

# cubs_offense = cubs_offense.drop(columns = ['Game'])

cubs_2018_pitching = cubs_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [cubs_2018_pitching, cubs_2018_offense]

cubs_2018 = pd.concat(frames, axis=1)

cubs_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(cubs_2018[x])):
        cubs_2018.loc[y,x] = int(cubs_2018.loc[y, x])

for x in columns_float:
    for y in range(len(cubs_2018[x])):
        cubs_2018.loc[y,x] = float(cubs_2018.loc[y, x])  

for x in range(len(cubs_2018['Game'])):
    if cubs_2018.loc[x, 'Runs'] > cubs_2018.loc[x, 'R']:
        cubs_2018.loc[x, 'Win'] = 0
    else:
        cubs_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Cubs Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHC&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHC_2017_game_num = get_stat2('team_game_num')
CHC_2017_PA = get_stat2('PA')
CHC_2017_AB = get_stat2('AB')
CHC_2017_R = get_stat2('R')
CHC_2017_H = get_stat2('H')
CHC_2017_2B = get_stat2('2B')
CHC_2017_3B = get_stat2('3B')
CHC_2017_HR = get_stat2('HR')
CHC_2017_RBI = get_stat2('RBI')
CHC_2017_BB = get_stat2('BB')
CHC_2017_SO = get_stat2('SO')
CHC_2017_SB = get_stat2('SB')
CHC_2017_CS = get_stat2('CS')
CHC_2017_BA = get_stat2('batting_avg')
CHC_2017_OBP = get_stat2('onbase_perc')
CHC_2017_SLG = get_stat2('slugging_perc')
CHC_2017_OPS = get_stat2('onbase_plus_slugging')
CHC_2017_LOB = get_stat2('LOB')
cubs_2017_offense = pd.DataFrame({
                                  'PA': CHC_2017_PA,
                                  'AB': CHC_2017_AB,
                                  'R':  CHC_2017_R,
                                  'H':  CHC_2017_H,
                                  '2B': CHC_2017_2B,
                                  '3B': CHC_2017_3B, 
                                  'HR': CHC_2017_HR, 
                                  'RBI':CHC_2017_RBI,
                                  'BB': CHC_2017_BB,
                                  'SO': CHC_2017_SO,
                                  'SB': CHC_2017_SB,
                                  'CS': CHC_2017_CS,
                                  'LOB':CHC_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHC&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHC_2017_P_game_num = get_stat3('team_game_num')
CHC_2017_P_IP = get_stat3('IP')
CHC_2017_P_H = get_stat3('H')
CHC_2017_P_R = get_stat3('R')
CHC_2017_P_ER = get_stat3('ER')
CHC_2017_P_UER = get_stat3('UER')
CHC_2017_P_BB = get_stat3('BB')
CHC_2017_P_SO = get_stat3('SO')
CHC_2017_P_HR = get_stat3('HR')
CHC_2017_P_HBP = get_stat3('HBP')
CHC_2017_P_ERA = get_stat3('earned_run_avg')

cubs_2017_pitching = pd.DataFrame({'Game':  CHC_2017_P_game_num, 
                                         'IP':  CHC_2017_P_IP, 
                                         'H':   CHC_2017_P_H,
                                         'R':   CHC_2017_P_R,
                                         'ER':  CHC_2017_P_ER,
                                         'UER': CHC_2017_P_UER,
                                         'BB':  CHC_2017_P_BB,
                                         'SO':  CHC_2017_P_SO,
                                         'HR':  CHC_2017_P_HR,
                                         'HBP': CHC_2017_P_HBP})

# cubs_offense = cubs_offense.drop(columns = ['Game'])

cubs_2017_pitching = cubs_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [cubs_2017_pitching, cubs_2017_offense]

cubs_2017 = pd.concat(frames, axis=1)

cubs_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(cubs_2017[x])):
        cubs_2017.loc[y,x] = int(cubs_2017.loc[y, x])

for x in columns_float:
    for y in range(len(cubs_2017[x])):
        cubs_2017.loc[y,x] = float(cubs_2017.loc[y, x])  

for x in range(len(cubs_2017['Game'])):
    if cubs_2017.loc[x, 'Runs'] > cubs_2017.loc[x, 'R']:
        cubs_2017.loc[x, 'Win'] = 0
    else:
        cubs_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Cubs Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHC&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHC_2016_game_num = get_stat2('team_game_num')
CHC_2016_PA = get_stat2('PA')
CHC_2016_AB = get_stat2('AB')
CHC_2016_R = get_stat2('R')
CHC_2016_H = get_stat2('H')
CHC_2016_2B = get_stat2('2B')
CHC_2016_3B = get_stat2('3B')
CHC_2016_HR = get_stat2('HR')
CHC_2016_RBI = get_stat2('RBI')
CHC_2016_BB = get_stat2('BB')
CHC_2016_SO = get_stat2('SO')
CHC_2016_SB = get_stat2('SB')
CHC_2016_CS = get_stat2('CS')
CHC_2016_BA = get_stat2('batting_avg')
CHC_2016_OBP = get_stat2('onbase_perc')
CHC_2016_SLG = get_stat2('slugging_perc')
CHC_2016_OPS = get_stat2('onbase_plus_slugging')
CHC_2016_LOB = get_stat2('LOB')
cubs_2016_offense = pd.DataFrame({
                                  'PA': CHC_2016_PA,
                                  'AB': CHC_2016_AB,
                                  'R':  CHC_2016_R,
                                  'H':  CHC_2016_H,
                                  '2B': CHC_2016_2B,
                                  '3B': CHC_2016_3B, 
                                  'HR': CHC_2016_HR, 
                                  'RBI':CHC_2016_RBI,
                                  'BB': CHC_2016_BB,
                                  'SO': CHC_2016_SO,
                                  'SB': CHC_2016_SB,
                                  'CS': CHC_2016_CS,
                                  'LOB':CHC_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHC&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHC_2016_P_game_num = get_stat3('team_game_num')
CHC_2016_P_IP = get_stat3('IP')
CHC_2016_P_H = get_stat3('H')
CHC_2016_P_R = get_stat3('R')
CHC_2016_P_ER = get_stat3('ER')
CHC_2016_P_UER = get_stat3('UER')
CHC_2016_P_BB = get_stat3('BB')
CHC_2016_P_SO = get_stat3('SO')
CHC_2016_P_HR = get_stat3('HR')
CHC_2016_P_HBP = get_stat3('HBP')
CHC_2016_P_ERA = get_stat3('earned_run_avg')

cubs_2016_pitching = pd.DataFrame({'Game':  CHC_2016_P_game_num, 
                                         'IP':  CHC_2016_P_IP, 
                                         'H':   CHC_2016_P_H,
                                         'R':   CHC_2016_P_R,
                                         'ER':  CHC_2016_P_ER,
                                         'UER': CHC_2016_P_UER,
                                         'BB':  CHC_2016_P_BB,
                                         'SO':  CHC_2016_P_SO,
                                         'HR':  CHC_2016_P_HR,
                                         'HBP': CHC_2016_P_HBP})

# cubs_offense = cubs_offense.drop(columns = ['Game'])

cubs_2016_pitching = cubs_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [cubs_2016_pitching, cubs_2016_offense]

cubs_2016 = pd.concat(frames, axis=1)

cubs_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(cubs_2016[x])):
        cubs_2016.loc[y,x] = int(cubs_2016.loc[y, x])

for x in columns_float:
    for y in range(len(cubs_2016[x])):
        cubs_2016.loc[y,x] = float(cubs_2016.loc[y, x])  

for x in range(len(cubs_2016['Game'])):
    if cubs_2016.loc[x, 'Runs'] > cubs_2016.loc[x, 'R']:
        cubs_2016.loc[x, 'Win'] = 0
    else:
        cubs_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Cubs

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHC&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHC_2015_game_num = get_stat2('team_game_num')
CHC_2015_PA = get_stat2('PA')
CHC_2015_AB = get_stat2('AB')
CHC_2015_R = get_stat2('R')
CHC_2015_H = get_stat2('H')
CHC_2015_2B = get_stat2('2B')
CHC_2015_3B = get_stat2('3B')
CHC_2015_HR = get_stat2('HR')
CHC_2015_RBI = get_stat2('RBI')
CHC_2015_BB = get_stat2('BB')
CHC_2015_SO = get_stat2('SO')
CHC_2015_SB = get_stat2('SB')
CHC_2015_CS = get_stat2('CS')
CHC_2015_BA = get_stat2('batting_avg')
CHC_2015_OBP = get_stat2('onbase_perc')
CHC_2015_SLG = get_stat2('slugging_perc')
CHC_2015_OPS = get_stat2('onbase_plus_slugging')
CHC_2015_LOB = get_stat2('LOB')
cubs_2015_offense = pd.DataFrame({
                                  'PA': CHC_2015_PA,
                                  'AB': CHC_2015_AB,
                                  'R':  CHC_2015_R,
                                  'H':  CHC_2015_H,
                                  '2B': CHC_2015_2B,
                                  '3B': CHC_2015_3B, 
                                  'HR': CHC_2015_HR, 
                                  'RBI':CHC_2015_RBI,
                                  'BB': CHC_2015_BB,
                                  'SO': CHC_2015_SO,
                                  'SB': CHC_2015_SB,
                                  'CS': CHC_2015_CS,
                                  'LOB':CHC_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHC&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHC_2015_P_game_num = get_stat3('team_game_num')
CHC_2015_P_IP = get_stat3('IP')
CHC_2015_P_H = get_stat3('H')
CHC_2015_P_R = get_stat3('R')
CHC_2015_P_ER = get_stat3('ER')
CHC_2015_P_UER = get_stat3('UER')
CHC_2015_P_BB = get_stat3('BB')
CHC_2015_P_SO = get_stat3('SO')
CHC_2015_P_HR = get_stat3('HR')
CHC_2015_P_HBP = get_stat3('HBP')
CHC_2015_P_ERA = get_stat3('earned_run_avg')

cubs_2015_pitching = pd.DataFrame({'Game':  CHC_2015_P_game_num, 
                                         'IP':  CHC_2015_P_IP, 
                                         'H':   CHC_2015_P_H,
                                         'R':   CHC_2015_P_R,
                                         'ER':  CHC_2015_P_ER,
                                         'UER': CHC_2015_P_UER,
                                         'BB':  CHC_2015_P_BB,
                                         'SO':  CHC_2015_P_SO,
                                         'HR':  CHC_2015_P_HR,
                                         'HBP': CHC_2015_P_HBP})

# cubs_offense = cubs_offense.drop(columns = ['Game'])

cubs_2015_pitching = cubs_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [cubs_2015_pitching, cubs_2015_offense]

cubs_2015 = pd.concat(frames, axis=1)

cubs_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(cubs_2015[x])):
        cubs_2015.loc[y,x] = int(cubs_2015.loc[y, x])

for x in columns_float:
    for y in range(len(cubs_2015[x])):
        cubs_2015.loc[y,x] = float(cubs_2015.loc[y, x])  

for x in range(len(cubs_2015['Game'])):
    if cubs_2015.loc[x, 'Runs'] > cubs_2015.loc[x, 'R']:
        cubs_2015.loc[x, 'Win'] = 0
    else:
        cubs_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Brewers Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIL&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIL_game_num = get_stat2('team_game_num')

MIL_PA = get_stat2('PA')

MIL_AB = get_stat2('AB')

MIL_R = get_stat2('R')

MIL_H = get_stat2('H')

MIL_2B = get_stat2('2B')

MIL_3B = get_stat2('3B')

MIL_HR = get_stat2('HR')

MIL_RBI = get_stat2('RBI')

MIL_BB = get_stat2('BB')

MIL_SO = get_stat2('SO')

MIL_SB = get_stat2('SB')

MIL_CS = get_stat2('CS')

MIL_BA = get_stat2('batting_avg')

MIL_OBP = get_stat2('onbase_perc')

MIL_SLG = get_stat2('slugging_perc')

MIL_OPS = get_stat2('onbase_plus_slugging')

MIL_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


brewers_offense = pd.DataFrame({
                                  'PA': MIL_PA,
                                  'AB': MIL_AB,
                                  'R':MIL_R,
                                  'H':MIL_H,
                                  '2B':MIL_2B,
                                  '3B': MIL_3B, 
                                  'HR':MIL_HR, 
                                  'RBI':MIL_RBI,
                                  'BB':MIL_BB,
                                  'SO':MIL_SO,
                                  'SB': MIL_SB,
                                  'CS':MIL_CS,
                                  'LOB':MIL_LOB})

# %% [markdown]
# # 2019 Brewers Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIL&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIL_P_game_num = get_stat3('team_game_num')

MIL_P_IP = get_stat3('IP')

MIL_P_H = get_stat3('H')

MIL_P_R = get_stat3('R')

MIL_P_ER = get_stat3('ER')

MIL_P_UER = get_stat3('UER')

MIL_P_BB = get_stat3('BB')

MIL_P_SO = get_stat3('SO')

MIL_P_HR = get_stat3('HR')

MIL_P_HBP = get_stat3('HBP')

MIL_P_ERA = get_stat3('earned_run_avg')

brewers_pitching = pd.DataFrame({'Game': MIL_P_game_num, 
                                   'IP':MIL_P_IP, 
                                   'H':MIL_P_H,
                                   'R':MIL_P_R,
                                   'ER':MIL_P_ER,
                                   'UER':MIL_P_UER,
                                   'BB':MIL_P_BB,
                                   'SO':MIL_P_SO,
                                   'HR':MIL_P_HR,
                                   'HBP':MIL_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

brewers_pitching = brewers_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [brewers_pitching, brewers_offense]

brewers = pd.concat(frames, axis=1)

brewers['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(brewers[x])):
        brewers.loc[y,x] = int(brewers.loc[y, x])

for x in columns_float:
    for y in range(len(brewers[x])):
        brewers.loc[y,x] = float(brewers.loc[y, x])  

for x in range(len(brewers['Game'])):
    if brewers.loc[x, 'Runs'] > brewers.loc[x, 'R']:
        brewers.loc[x, 'Win'] = 0
    else:
        brewers.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Brewers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIL&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIL_2018_game_num = get_stat2('team_game_num')
MIL_2018_PA = get_stat2('PA')
MIL_2018_AB = get_stat2('AB')
MIL_2018_R = get_stat2('R')
MIL_2018_H = get_stat2('H')
MIL_2018_2B = get_stat2('2B')
MIL_2018_3B = get_stat2('3B')
MIL_2018_HR = get_stat2('HR')
MIL_2018_RBI = get_stat2('RBI')
MIL_2018_BB = get_stat2('BB')
MIL_2018_SO = get_stat2('SO')
MIL_2018_SB = get_stat2('SB')
MIL_2018_CS = get_stat2('CS')
MIL_2018_BA = get_stat2('batting_avg')
MIL_2018_OBP = get_stat2('onbase_perc')
MIL_2018_SLG = get_stat2('slugging_perc')
MIL_2018_OPS = get_stat2('onbase_plus_slugging')
MIL_2018_LOB = get_stat2('LOB')
brewers_2018_offense = pd.DataFrame({
                                  'PA': MIL_2018_PA,
                                  'AB': MIL_2018_AB,
                                  'R':  MIL_2018_R,
                                  'H':  MIL_2018_H,
                                  '2B': MIL_2018_2B,
                                  '3B': MIL_2018_3B, 
                                  'HR': MIL_2018_HR, 
                                  'RBI':MIL_2018_RBI,
                                  'BB': MIL_2018_BB,
                                  'SO': MIL_2018_SO,
                                  'SB': MIL_2018_SB,
                                  'CS': MIL_2018_CS,
                                  'LOB':MIL_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIL&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIL_2018_P_game_num = get_stat3('team_game_num')
MIL_2018_P_IP = get_stat3('IP')
MIL_2018_P_H = get_stat3('H')
MIL_2018_P_R = get_stat3('R')
MIL_2018_P_ER = get_stat3('ER')
MIL_2018_P_UER = get_stat3('UER')
MIL_2018_P_BB = get_stat3('BB')
MIL_2018_P_SO = get_stat3('SO')
MIL_2018_P_HR = get_stat3('HR')
MIL_2018_P_HBP = get_stat3('HBP')
MIL_2018_P_ERA = get_stat3('earned_run_avg')

brewers_2018_pitching = pd.DataFrame({'Game':  MIL_2018_P_game_num, 
                                         'IP':  MIL_2018_P_IP, 
                                         'H':   MIL_2018_P_H,
                                         'R':   MIL_2018_P_R,
                                         'ER':  MIL_2018_P_ER,
                                         'UER': MIL_2018_P_UER,
                                         'BB':  MIL_2018_P_BB,
                                         'SO':  MIL_2018_P_SO,
                                         'HR':  MIL_2018_P_HR,
                                         'HBP': MIL_2018_P_HBP})

# brewers_offense = brewers_offense.drop(columns = ['Game'])

brewers_2018_pitching = brewers_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [brewers_2018_pitching, brewers_2018_offense]

brewers_2018 = pd.concat(frames, axis=1)

brewers_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(brewers_2018[x])):
        brewers_2018.loc[y,x] = int(brewers_2018.loc[y, x])

for x in columns_float:
    for y in range(len(brewers_2018[x])):
        brewers_2018.loc[y,x] = float(brewers_2018.loc[y, x])  

for x in range(len(brewers_2018['Game'])):
    if brewers_2018.loc[x, 'Runs'] > brewers_2018.loc[x, 'R']:
        brewers_2018.loc[x, 'Win'] = 0
    else:
        brewers_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Brewers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIL&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIL_2017_game_num = get_stat2('team_game_num')
MIL_2017_PA = get_stat2('PA')
MIL_2017_AB = get_stat2('AB')
MIL_2017_R = get_stat2('R')
MIL_2017_H = get_stat2('H')
MIL_2017_2B = get_stat2('2B')
MIL_2017_3B = get_stat2('3B')
MIL_2017_HR = get_stat2('HR')
MIL_2017_RBI = get_stat2('RBI')
MIL_2017_BB = get_stat2('BB')
MIL_2017_SO = get_stat2('SO')
MIL_2017_SB = get_stat2('SB')
MIL_2017_CS = get_stat2('CS')
MIL_2017_BA = get_stat2('batting_avg')
MIL_2017_OBP = get_stat2('onbase_perc')
MIL_2017_SLG = get_stat2('slugging_perc')
MIL_2017_OPS = get_stat2('onbase_plus_slugging')
MIL_2017_LOB = get_stat2('LOB')
brewers_2017_offense = pd.DataFrame({
                                  'PA': MIL_2017_PA,
                                  'AB': MIL_2017_AB,
                                  'R':  MIL_2017_R,
                                  'H':  MIL_2017_H,
                                  '2B': MIL_2017_2B,
                                  '3B': MIL_2017_3B, 
                                  'HR': MIL_2017_HR, 
                                  'RBI':MIL_2017_RBI,
                                  'BB': MIL_2017_BB,
                                  'SO': MIL_2017_SO,
                                  'SB': MIL_2017_SB,
                                  'CS': MIL_2017_CS,
                                  'LOB':MIL_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIL&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIL_2017_P_game_num = get_stat3('team_game_num')
MIL_2017_P_IP = get_stat3('IP')
MIL_2017_P_H = get_stat3('H')
MIL_2017_P_R = get_stat3('R')
MIL_2017_P_ER = get_stat3('ER')
MIL_2017_P_UER = get_stat3('UER')
MIL_2017_P_BB = get_stat3('BB')
MIL_2017_P_SO = get_stat3('SO')
MIL_2017_P_HR = get_stat3('HR')
MIL_2017_P_HBP = get_stat3('HBP')
MIL_2017_P_ERA = get_stat3('earned_run_avg')

brewers_2017_pitching = pd.DataFrame({'Game':  MIL_2017_P_game_num, 
                                         'IP':  MIL_2017_P_IP, 
                                         'H':   MIL_2017_P_H,
                                         'R':   MIL_2017_P_R,
                                         'ER':  MIL_2017_P_ER,
                                         'UER': MIL_2017_P_UER,
                                         'BB':  MIL_2017_P_BB,
                                         'SO':  MIL_2017_P_SO,
                                         'HR':  MIL_2017_P_HR,
                                         'HBP': MIL_2017_P_HBP})

# brewers_offense = brewers_offense.drop(columns = ['Game'])

brewers_2017_pitching = brewers_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [brewers_2017_pitching, brewers_2017_offense]

brewers_2017 = pd.concat(frames, axis=1)

brewers_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(brewers_2017[x])):
        brewers_2017.loc[y,x] = int(brewers_2017.loc[y, x])

for x in columns_float:
    for y in range(len(brewers_2017[x])):
        brewers_2017.loc[y,x] = float(brewers_2017.loc[y, x])  

for x in range(len(brewers_2017['Game'])):
    if brewers_2017.loc[x, 'Runs'] > brewers_2017.loc[x, 'R']:
        brewers_2017.loc[x, 'Win'] = 0
    else:
        brewers_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Brewers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIL&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIL_2016_game_num = get_stat2('team_game_num')
MIL_2016_PA = get_stat2('PA')
MIL_2016_AB = get_stat2('AB')
MIL_2016_R = get_stat2('R')
MIL_2016_H = get_stat2('H')
MIL_2016_2B = get_stat2('2B')
MIL_2016_3B = get_stat2('3B')
MIL_2016_HR = get_stat2('HR')
MIL_2016_RBI = get_stat2('RBI')
MIL_2016_BB = get_stat2('BB')
MIL_2016_SO = get_stat2('SO')
MIL_2016_SB = get_stat2('SB')
MIL_2016_CS = get_stat2('CS')
MIL_2016_BA = get_stat2('batting_avg')
MIL_2016_OBP = get_stat2('onbase_perc')
MIL_2016_SLG = get_stat2('slugging_perc')
MIL_2016_OPS = get_stat2('onbase_plus_slugging')
MIL_2016_LOB = get_stat2('LOB')
brewers_2016_offense = pd.DataFrame({
                                  'PA': MIL_2016_PA,
                                  'AB': MIL_2016_AB,
                                  'R':  MIL_2016_R,
                                  'H':  MIL_2016_H,
                                  '2B': MIL_2016_2B,
                                  '3B': MIL_2016_3B, 
                                  'HR': MIL_2016_HR, 
                                  'RBI':MIL_2016_RBI,
                                  'BB': MIL_2016_BB,
                                  'SO': MIL_2016_SO,
                                  'SB': MIL_2016_SB,
                                  'CS': MIL_2016_CS,
                                  'LOB':MIL_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIL&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIL_2016_P_game_num = get_stat3('team_game_num')
MIL_2016_P_IP = get_stat3('IP')
MIL_2016_P_H = get_stat3('H')
MIL_2016_P_R = get_stat3('R')
MIL_2016_P_ER = get_stat3('ER')
MIL_2016_P_UER = get_stat3('UER')
MIL_2016_P_BB = get_stat3('BB')
MIL_2016_P_SO = get_stat3('SO')
MIL_2016_P_HR = get_stat3('HR')
MIL_2016_P_HBP = get_stat3('HBP')
MIL_2016_P_ERA = get_stat3('earned_run_avg')

brewers_2016_pitching = pd.DataFrame({'Game':  MIL_2016_P_game_num, 
                                         'IP':  MIL_2016_P_IP, 
                                         'H':   MIL_2016_P_H,
                                         'R':   MIL_2016_P_R,
                                         'ER':  MIL_2016_P_ER,
                                         'UER': MIL_2016_P_UER,
                                         'BB':  MIL_2016_P_BB,
                                         'SO':  MIL_2016_P_SO,
                                         'HR':  MIL_2016_P_HR,
                                         'HBP': MIL_2016_P_HBP})

# brewers_offense = brewers_offense.drop(columns = ['Game'])

brewers_2016_pitching = brewers_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [brewers_2016_pitching, brewers_2016_offense]

brewers_2016 = pd.concat(frames, axis=1)

brewers_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(brewers_2016[x])):
        brewers_2016.loc[y,x] = int(brewers_2016.loc[y, x])

for x in columns_float:
    for y in range(len(brewers_2016[x])):
        brewers_2016.loc[y,x] = float(brewers_2016.loc[y, x])  

for x in range(len(brewers_2016['Game'])):
    if brewers_2016.loc[x, 'Runs'] > brewers_2016.loc[x, 'R']:
        brewers_2016.loc[x, 'Win'] = 0
    else:
        brewers_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Brewers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIL&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIL_2015_game_num = get_stat2('team_game_num')
MIL_2015_PA = get_stat2('PA')
MIL_2015_AB = get_stat2('AB')
MIL_2015_R = get_stat2('R')
MIL_2015_H = get_stat2('H')
MIL_2015_2B = get_stat2('2B')
MIL_2015_3B = get_stat2('3B')
MIL_2015_HR = get_stat2('HR')
MIL_2015_RBI = get_stat2('RBI')
MIL_2015_BB = get_stat2('BB')
MIL_2015_SO = get_stat2('SO')
MIL_2015_SB = get_stat2('SB')
MIL_2015_CS = get_stat2('CS')
MIL_2015_BA = get_stat2('batting_avg')
MIL_2015_OBP = get_stat2('onbase_perc')
MIL_2015_SLG = get_stat2('slugging_perc')
MIL_2015_OPS = get_stat2('onbase_plus_slugging')
MIL_2015_LOB = get_stat2('LOB')
brewers_2015_offense = pd.DataFrame({
                                  'PA': MIL_2015_PA,
                                  'AB': MIL_2015_AB,
                                  'R':  MIL_2015_R,
                                  'H':  MIL_2015_H,
                                  '2B': MIL_2015_2B,
                                  '3B': MIL_2015_3B, 
                                  'HR': MIL_2015_HR, 
                                  'RBI':MIL_2015_RBI,
                                  'BB': MIL_2015_BB,
                                  'SO': MIL_2015_SO,
                                  'SB': MIL_2015_SB,
                                  'CS': MIL_2015_CS,
                                  'LOB':MIL_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIL&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIL_2015_P_game_num = get_stat3('team_game_num')
MIL_2015_P_IP = get_stat3('IP')
MIL_2015_P_H = get_stat3('H')
MIL_2015_P_R = get_stat3('R')
MIL_2015_P_ER = get_stat3('ER')
MIL_2015_P_UER = get_stat3('UER')
MIL_2015_P_BB = get_stat3('BB')
MIL_2015_P_SO = get_stat3('SO')
MIL_2015_P_HR = get_stat3('HR')
MIL_2015_P_HBP = get_stat3('HBP')
MIL_2015_P_ERA = get_stat3('earned_run_avg')

brewers_2015_pitching = pd.DataFrame({'Game':  MIL_2015_P_game_num, 
                                         'IP':  MIL_2015_P_IP, 
                                         'H':   MIL_2015_P_H,
                                         'R':   MIL_2015_P_R,
                                         'ER':  MIL_2015_P_ER,
                                         'UER': MIL_2015_P_UER,
                                         'BB':  MIL_2015_P_BB,
                                         'SO':  MIL_2015_P_SO,
                                         'HR':  MIL_2015_P_HR,
                                         'HBP': MIL_2015_P_HBP})

# brewers_offense = brewers_offense.drop(columns = ['Game'])

brewers_2015_pitching = brewers_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [brewers_2015_pitching, brewers_2015_offense]

brewers_2015 = pd.concat(frames, axis=1)

brewers_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(brewers_2015[x])):
        brewers_2015.loc[y,x] = int(brewers_2015.loc[y, x])

for x in columns_float:
    for y in range(len(brewers_2015[x])):
        brewers_2015.loc[y,x] = float(brewers_2015.loc[y, x])  

for x in range(len(brewers_2015['Game'])):
    if brewers_2015.loc[x, 'Runs'] > brewers_2015.loc[x, 'R']:
        brewers_2015.loc[x, 'Win'] = 0
    else:
        brewers_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Cardinals Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=STL&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

STL_game_num = get_stat2('team_game_num')

STL_PA = get_stat2('PA')

STL_AB = get_stat2('AB')

STL_R = get_stat2('R')

STL_H = get_stat2('H')

STL_2B = get_stat2('2B')

STL_3B = get_stat2('3B')

STL_HR = get_stat2('HR')

STL_RBI = get_stat2('RBI')

STL_BB = get_stat2('BB')

STL_SO = get_stat2('SO')

STL_SB = get_stat2('SB')

STL_CS = get_stat2('CS')

STL_BA = get_stat2('batting_avg')

STL_OBP = get_stat2('onbase_perc')

STL_SLG = get_stat2('slugging_perc')

STL_OPS = get_stat2('onbase_plus_slugging')

STL_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


cardinals_offense = pd.DataFrame({
                                  'PA': STL_PA,
                                  'AB': STL_AB,
                                  'R':STL_R,
                                  'H':STL_H,
                                  '2B':STL_2B,
                                  '3B': STL_3B, 
                                  'HR':STL_HR, 
                                  'RBI':STL_RBI,
                                  'BB':STL_BB,
                                  'SO':STL_SO,
                                  'SB': STL_SB,
                                  'CS':STL_CS,
                                  'LOB':STL_LOB})

# %% [markdown]
# # 2019 Cardinals Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=STL&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

STL_P_game_num = get_stat3('team_game_num')

STL_P_IP = get_stat3('IP')

STL_P_H = get_stat3('H')

STL_P_R = get_stat3('R')

STL_P_ER = get_stat3('ER')

STL_P_UER = get_stat3('UER')

STL_P_BB = get_stat3('BB')

STL_P_SO = get_stat3('SO')

STL_P_HR = get_stat3('HR')

STL_P_HBP = get_stat3('HBP')

STL_P_ERA = get_stat3('earned_run_avg')

cardinals_pitching = pd.DataFrame({'Game': STL_P_game_num, 
                                   'IP':STL_P_IP, 
                                   'H':STL_P_H,
                                   'R':STL_P_R,
                                   'ER':STL_P_ER,
                                   'UER':STL_P_UER,
                                   'BB':STL_P_BB,
                                   'SO':STL_P_SO,
                                   'HR':STL_P_HR,
                                   'HBP':STL_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

cardinals_pitching = cardinals_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [cardinals_pitching, cardinals_offense]

cardinals = pd.concat(frames, axis=1)

cardinals['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(cardinals[x])):
        cardinals.loc[y,x] = int(cardinals.loc[y, x])

for x in columns_float:
    for y in range(len(cardinals[x])):
        cardinals.loc[y,x] = float(cardinals.loc[y, x])  

for x in range(len(cardinals['Game'])):
    if cardinals.loc[x, 'Runs'] > cardinals.loc[x, 'R']:
        cardinals.loc[x, 'Win'] = 0
    else:
        cardinals.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Cardinals Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=STL&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

STL_2018_game_num = get_stat2('team_game_num')
STL_2018_PA = get_stat2('PA')
STL_2018_AB = get_stat2('AB')
STL_2018_R = get_stat2('R')
STL_2018_H = get_stat2('H')
STL_2018_2B = get_stat2('2B')
STL_2018_3B = get_stat2('3B')
STL_2018_HR = get_stat2('HR')
STL_2018_RBI = get_stat2('RBI')
STL_2018_BB = get_stat2('BB')
STL_2018_SO = get_stat2('SO')
STL_2018_SB = get_stat2('SB')
STL_2018_CS = get_stat2('CS')
STL_2018_BA = get_stat2('batting_avg')
STL_2018_OBP = get_stat2('onbase_perc')
STL_2018_SLG = get_stat2('slugging_perc')
STL_2018_OPS = get_stat2('onbase_plus_slugging')
STL_2018_LOB = get_stat2('LOB')
cardinals_2018_offense = pd.DataFrame({
                                  'PA': STL_2018_PA,
                                  'AB': STL_2018_AB,
                                  'R':  STL_2018_R,
                                  'H':  STL_2018_H,
                                  '2B': STL_2018_2B,
                                  '3B': STL_2018_3B, 
                                  'HR': STL_2018_HR, 
                                  'RBI':STL_2018_RBI,
                                  'BB': STL_2018_BB,
                                  'SO': STL_2018_SO,
                                  'SB': STL_2018_SB,
                                  'CS': STL_2018_CS,
                                  'LOB':STL_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=STL&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

STL_2018_P_game_num = get_stat3('team_game_num')
STL_2018_P_IP = get_stat3('IP')
STL_2018_P_H = get_stat3('H')
STL_2018_P_R = get_stat3('R')
STL_2018_P_ER = get_stat3('ER')
STL_2018_P_UER = get_stat3('UER')
STL_2018_P_BB = get_stat3('BB')
STL_2018_P_SO = get_stat3('SO')
STL_2018_P_HR = get_stat3('HR')
STL_2018_P_HBP = get_stat3('HBP')
STL_2018_P_ERA = get_stat3('earned_run_avg')

cardinals_2018_pitching = pd.DataFrame({'Game':  STL_2018_P_game_num, 
                                         'IP':  STL_2018_P_IP, 
                                         'H':   STL_2018_P_H,
                                         'R':   STL_2018_P_R,
                                         'ER':  STL_2018_P_ER,
                                         'UER': STL_2018_P_UER,
                                         'BB':  STL_2018_P_BB,
                                         'SO':  STL_2018_P_SO,
                                         'HR':  STL_2018_P_HR,
                                         'HBP': STL_2018_P_HBP})

# cardinals_offense = cardinals_offense.drop(columns = ['Game'])

cardinals_2018_pitching = cardinals_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [cardinals_2018_pitching, cardinals_2018_offense]

cardinals_2018 = pd.concat(frames, axis=1)

cardinals_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(cardinals_2018[x])):
        cardinals_2018.loc[y,x] = int(cardinals_2018.loc[y, x])

for x in columns_float:
    for y in range(len(cardinals_2018[x])):
        cardinals_2018.loc[y,x] = float(cardinals_2018.loc[y, x])  

for x in range(len(cardinals_2018['Game'])):
    if cardinals_2018.loc[x, 'Runs'] > cardinals_2018.loc[x, 'R']:
        cardinals_2018.loc[x, 'Win'] = 0
    else:
        cardinals_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Cardinals Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=STL&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

STL_2017_game_num = get_stat2('team_game_num')
STL_2017_PA = get_stat2('PA')
STL_2017_AB = get_stat2('AB')
STL_2017_R = get_stat2('R')
STL_2017_H = get_stat2('H')
STL_2017_2B = get_stat2('2B')
STL_2017_3B = get_stat2('3B')
STL_2017_HR = get_stat2('HR')
STL_2017_RBI = get_stat2('RBI')
STL_2017_BB = get_stat2('BB')
STL_2017_SO = get_stat2('SO')
STL_2017_SB = get_stat2('SB')
STL_2017_CS = get_stat2('CS')
STL_2017_BA = get_stat2('batting_avg')
STL_2017_OBP = get_stat2('onbase_perc')
STL_2017_SLG = get_stat2('slugging_perc')
STL_2017_OPS = get_stat2('onbase_plus_slugging')
STL_2017_LOB = get_stat2('LOB')
cardinals_2017_offense = pd.DataFrame({
                                  'PA': STL_2017_PA,
                                  'AB': STL_2017_AB,
                                  'R':  STL_2017_R,
                                  'H':  STL_2017_H,
                                  '2B': STL_2017_2B,
                                  '3B': STL_2017_3B, 
                                  'HR': STL_2017_HR, 
                                  'RBI':STL_2017_RBI,
                                  'BB': STL_2017_BB,
                                  'SO': STL_2017_SO,
                                  'SB': STL_2017_SB,
                                  'CS': STL_2017_CS,
                                  'LOB':STL_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=STL&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

STL_2017_P_game_num = get_stat3('team_game_num')
STL_2017_P_IP = get_stat3('IP')
STL_2017_P_H = get_stat3('H')
STL_2017_P_R = get_stat3('R')
STL_2017_P_ER = get_stat3('ER')
STL_2017_P_UER = get_stat3('UER')
STL_2017_P_BB = get_stat3('BB')
STL_2017_P_SO = get_stat3('SO')
STL_2017_P_HR = get_stat3('HR')
STL_2017_P_HBP = get_stat3('HBP')
STL_2017_P_ERA = get_stat3('earned_run_avg')

cardinals_2017_pitching = pd.DataFrame({'Game':  STL_2017_P_game_num, 
                                         'IP':  STL_2017_P_IP, 
                                         'H':   STL_2017_P_H,
                                         'R':   STL_2017_P_R,
                                         'ER':  STL_2017_P_ER,
                                         'UER': STL_2017_P_UER,
                                         'BB':  STL_2017_P_BB,
                                         'SO':  STL_2017_P_SO,
                                         'HR':  STL_2017_P_HR,
                                         'HBP': STL_2017_P_HBP})

# cardinals_offense = cardinals_offense.drop(columns = ['Game'])

cardinals_2017_pitching = cardinals_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [cardinals_2017_pitching, cardinals_2017_offense]

cardinals_2017 = pd.concat(frames, axis=1)

cardinals_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(cardinals_2017[x])):
        cardinals_2017.loc[y,x] = int(cardinals_2017.loc[y, x])

for x in columns_float:
    for y in range(len(cardinals_2017[x])):
        cardinals_2017.loc[y,x] = float(cardinals_2017.loc[y, x])  

for x in range(len(cardinals_2017['Game'])):
    if cardinals_2017.loc[x, 'Runs'] > cardinals_2017.loc[x, 'R']:
        cardinals_2017.loc[x, 'Win'] = 0
    else:
        cardinals_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Cardinals Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=STL&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

STL_2016_game_num = get_stat2('team_game_num')
STL_2016_PA = get_stat2('PA')
STL_2016_AB = get_stat2('AB')
STL_2016_R = get_stat2('R')
STL_2016_H = get_stat2('H')
STL_2016_2B = get_stat2('2B')
STL_2016_3B = get_stat2('3B')
STL_2016_HR = get_stat2('HR')
STL_2016_RBI = get_stat2('RBI')
STL_2016_BB = get_stat2('BB')
STL_2016_SO = get_stat2('SO')
STL_2016_SB = get_stat2('SB')
STL_2016_CS = get_stat2('CS')
STL_2016_BA = get_stat2('batting_avg')
STL_2016_OBP = get_stat2('onbase_perc')
STL_2016_SLG = get_stat2('slugging_perc')
STL_2016_OPS = get_stat2('onbase_plus_slugging')
STL_2016_LOB = get_stat2('LOB')
cardinals_2016_offense = pd.DataFrame({
                                  'PA': STL_2016_PA,
                                  'AB': STL_2016_AB,
                                  'R':  STL_2016_R,
                                  'H':  STL_2016_H,
                                  '2B': STL_2016_2B,
                                  '3B': STL_2016_3B, 
                                  'HR': STL_2016_HR, 
                                  'RBI':STL_2016_RBI,
                                  'BB': STL_2016_BB,
                                  'SO': STL_2016_SO,
                                  'SB': STL_2016_SB,
                                  'CS': STL_2016_CS,
                                  'LOB':STL_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=STL&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

STL_2016_P_game_num = get_stat3('team_game_num')
STL_2016_P_IP = get_stat3('IP')
STL_2016_P_H = get_stat3('H')
STL_2016_P_R = get_stat3('R')
STL_2016_P_ER = get_stat3('ER')
STL_2016_P_UER = get_stat3('UER')
STL_2016_P_BB = get_stat3('BB')
STL_2016_P_SO = get_stat3('SO')
STL_2016_P_HR = get_stat3('HR')
STL_2016_P_HBP = get_stat3('HBP')
STL_2016_P_ERA = get_stat3('earned_run_avg')

cardinals_2016_pitching = pd.DataFrame({'Game':  STL_2016_P_game_num, 
                                         'IP':  STL_2016_P_IP, 
                                         'H':   STL_2016_P_H,
                                         'R':   STL_2016_P_R,
                                         'ER':  STL_2016_P_ER,
                                         'UER': STL_2016_P_UER,
                                         'BB':  STL_2016_P_BB,
                                         'SO':  STL_2016_P_SO,
                                         'HR':  STL_2016_P_HR,
                                         'HBP': STL_2016_P_HBP})

# cardinals_offense = cardinals_offense.drop(columns = ['Game'])

cardinals_2016_pitching = cardinals_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [cardinals_2016_pitching, cardinals_2016_offense]

cardinals_2016 = pd.concat(frames, axis=1)

cardinals_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(cardinals_2016[x])):
        cardinals_2016.loc[y,x] = int(cardinals_2016.loc[y, x])

for x in columns_float:
    for y in range(len(cardinals_2016[x])):
        cardinals_2016.loc[y,x] = float(cardinals_2016.loc[y, x])  

for x in range(len(cardinals_2016['Game'])):
    if cardinals_2016.loc[x, 'Runs'] > cardinals_2016.loc[x, 'R']:
        cardinals_2016.loc[x, 'Win'] = 0
    else:
        cardinals_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Cardinals Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=STL&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

STL_2015_game_num = get_stat2('team_game_num')
STL_2015_PA = get_stat2('PA')
STL_2015_AB = get_stat2('AB')
STL_2015_R = get_stat2('R')
STL_2015_H = get_stat2('H')
STL_2015_2B = get_stat2('2B')
STL_2015_3B = get_stat2('3B')
STL_2015_HR = get_stat2('HR')
STL_2015_RBI = get_stat2('RBI')
STL_2015_BB = get_stat2('BB')
STL_2015_SO = get_stat2('SO')
STL_2015_SB = get_stat2('SB')
STL_2015_CS = get_stat2('CS')
STL_2015_BA = get_stat2('batting_avg')
STL_2015_OBP = get_stat2('onbase_perc')
STL_2015_SLG = get_stat2('slugging_perc')
STL_2015_OPS = get_stat2('onbase_plus_slugging')
STL_2015_LOB = get_stat2('LOB')
cardinals_2015_offense = pd.DataFrame({
                                  'PA': STL_2015_PA,
                                  'AB': STL_2015_AB,
                                  'R':  STL_2015_R,
                                  'H':  STL_2015_H,
                                  '2B': STL_2015_2B,
                                  '3B': STL_2015_3B, 
                                  'HR': STL_2015_HR, 
                                  'RBI':STL_2015_RBI,
                                  'BB': STL_2015_BB,
                                  'SO': STL_2015_SO,
                                  'SB': STL_2015_SB,
                                  'CS': STL_2015_CS,
                                  'LOB':STL_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=STL&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

STL_2015_P_game_num = get_stat3('team_game_num')
STL_2015_P_IP = get_stat3('IP')
STL_2015_P_H = get_stat3('H')
STL_2015_P_R = get_stat3('R')
STL_2015_P_ER = get_stat3('ER')
STL_2015_P_UER = get_stat3('UER')
STL_2015_P_BB = get_stat3('BB')
STL_2015_P_SO = get_stat3('SO')
STL_2015_P_HR = get_stat3('HR')
STL_2015_P_HBP = get_stat3('HBP')
STL_2015_P_ERA = get_stat3('earned_run_avg')

cardinals_2015_pitching = pd.DataFrame({'Game':  STL_2015_P_game_num, 
                                         'IP':  STL_2015_P_IP, 
                                         'H':   STL_2015_P_H,
                                         'R':   STL_2015_P_R,
                                         'ER':  STL_2015_P_ER,
                                         'UER': STL_2015_P_UER,
                                         'BB':  STL_2015_P_BB,
                                         'SO':  STL_2015_P_SO,
                                         'HR':  STL_2015_P_HR,
                                         'HBP': STL_2015_P_HBP})

# cardinals_offense = cardinals_offense.drop(columns = ['Game'])

cardinals_2015_pitching = cardinals_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [cardinals_2015_pitching, cardinals_2015_offense]

cardinals_2015 = pd.concat(frames, axis=1)

cardinals_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(cardinals_2015[x])):
        cardinals_2015.loc[y,x] = int(cardinals_2015.loc[y, x])

for x in columns_float:
    for y in range(len(cardinals_2015[x])):
        cardinals_2015.loc[y,x] = float(cardinals_2015.loc[y, x])  

for x in range(len(cardinals_2015['Game'])):
    if cardinals_2015.loc[x, 'Runs'] > cardinals_2015.loc[x, 'R']:
        cardinals_2015.loc[x, 'Win'] = 0
    else:
        cardinals_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Pirates Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PIT&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PIT_game_num = get_stat2('team_game_num')

PIT_PA = get_stat2('PA')

PIT_AB = get_stat2('AB')

PIT_R = get_stat2('R')

PIT_H = get_stat2('H')

PIT_2B = get_stat2('2B')

PIT_3B = get_stat2('3B')

PIT_HR = get_stat2('HR')

PIT_RBI = get_stat2('RBI')

PIT_BB = get_stat2('BB')

PIT_SO = get_stat2('SO')

PIT_SB = get_stat2('SB')

PIT_CS = get_stat2('CS')

PIT_BA = get_stat2('batting_avg')

PIT_OBP = get_stat2('onbase_perc')

PIT_SLG = get_stat2('slugging_perc')

PIT_OPS = get_stat2('onbase_plus_slugging')

PIT_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


pirates_offense = pd.DataFrame({
                                  'PA': PIT_PA,
                                  'AB': PIT_AB,
                                  'R':PIT_R,
                                  'H':PIT_H,
                                  '2B':PIT_2B,
                                  '3B': PIT_3B, 
                                  'HR':PIT_HR, 
                                  'RBI':PIT_RBI,
                                  'BB':PIT_BB,
                                  'SO':PIT_SO,
                                  'SB': PIT_SB,
                                  'CS':PIT_CS,
                                  'LOB':PIT_LOB})

# %% [markdown]
# # 2019 Pirates Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PIT&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PIT_P_game_num = get_stat3('team_game_num')

PIT_P_IP = get_stat3('IP')

PIT_P_H = get_stat3('H')

PIT_P_R = get_stat3('R')

PIT_P_ER = get_stat3('ER')

PIT_P_UER = get_stat3('UER')

PIT_P_BB = get_stat3('BB')

PIT_P_SO = get_stat3('SO')

PIT_P_HR = get_stat3('HR')

PIT_P_HBP = get_stat3('HBP')

PIT_P_ERA = get_stat3('earned_run_avg')

pirates_pitching = pd.DataFrame({'Game': PIT_P_game_num, 
                                   'IP':PIT_P_IP, 
                                   'H':PIT_P_H,
                                   'R':PIT_P_R,
                                   'ER':PIT_P_ER,
                                   'UER':PIT_P_UER,
                                   'BB':PIT_P_BB,
                                   'SO':PIT_P_SO,
                                   'HR':PIT_P_HR,
                                   'HBP':PIT_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

pirates_pitching = pirates_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [pirates_pitching, pirates_offense]

pirates = pd.concat(frames, axis=1)

pirates['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(pirates[x])):
        pirates.loc[y,x] = int(pirates.loc[y, x])

for x in columns_float:
    for y in range(len(pirates[x])):
        pirates.loc[y,x] = float(pirates.loc[y, x])  

for x in range(len(pirates['Game'])):
    if pirates.loc[x, 'Runs'] > pirates.loc[x, 'R']:
        pirates.loc[x, 'Win'] = 0
    else:
        pirates.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Pirates Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PIT&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PIT_2018_game_num = get_stat2('team_game_num')
PIT_2018_PA = get_stat2('PA')
PIT_2018_AB = get_stat2('AB')
PIT_2018_R = get_stat2('R')
PIT_2018_H = get_stat2('H')
PIT_2018_2B = get_stat2('2B')
PIT_2018_3B = get_stat2('3B')
PIT_2018_HR = get_stat2('HR')
PIT_2018_RBI = get_stat2('RBI')
PIT_2018_BB = get_stat2('BB')
PIT_2018_SO = get_stat2('SO')
PIT_2018_SB = get_stat2('SB')
PIT_2018_CS = get_stat2('CS')
PIT_2018_BA = get_stat2('batting_avg')
PIT_2018_OBP = get_stat2('onbase_perc')
PIT_2018_SLG = get_stat2('slugging_perc')
PIT_2018_OPS = get_stat2('onbase_plus_slugging')
PIT_2018_LOB = get_stat2('LOB')
pirates_2018_offense = pd.DataFrame({
                                  'PA': PIT_2018_PA,
                                  'AB': PIT_2018_AB,
                                  'R':  PIT_2018_R,
                                  'H':  PIT_2018_H,
                                  '2B': PIT_2018_2B,
                                  '3B': PIT_2018_3B, 
                                  'HR': PIT_2018_HR, 
                                  'RBI':PIT_2018_RBI,
                                  'BB': PIT_2018_BB,
                                  'SO': PIT_2018_SO,
                                  'SB': PIT_2018_SB,
                                  'CS': PIT_2018_CS,
                                  'LOB':PIT_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PIT&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PIT_2018_P_game_num = get_stat3('team_game_num')
PIT_2018_P_IP = get_stat3('IP')
PIT_2018_P_H = get_stat3('H')
PIT_2018_P_R = get_stat3('R')
PIT_2018_P_ER = get_stat3('ER')
PIT_2018_P_UER = get_stat3('UER')
PIT_2018_P_BB = get_stat3('BB')
PIT_2018_P_SO = get_stat3('SO')
PIT_2018_P_HR = get_stat3('HR')
PIT_2018_P_HBP = get_stat3('HBP')
PIT_2018_P_ERA = get_stat3('earned_run_avg')

pirates_2018_pitching = pd.DataFrame({'Game':  PIT_2018_P_game_num, 
                                         'IP':  PIT_2018_P_IP, 
                                         'H':   PIT_2018_P_H,
                                         'R':   PIT_2018_P_R,
                                         'ER':  PIT_2018_P_ER,
                                         'UER': PIT_2018_P_UER,
                                         'BB':  PIT_2018_P_BB,
                                         'SO':  PIT_2018_P_SO,
                                         'HR':  PIT_2018_P_HR,
                                         'HBP': PIT_2018_P_HBP})

# pirates_offense = pirates_offense.drop(columns = ['Game'])

pirates_2018_pitching = pirates_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [pirates_2018_pitching, pirates_2018_offense]

pirates_2018 = pd.concat(frames, axis=1)

pirates_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(pirates_2018[x])):
        pirates_2018.loc[y,x] = int(pirates_2018.loc[y, x])

for x in columns_float:
    for y in range(len(pirates_2018[x])):
        pirates_2018.loc[y,x] = float(pirates_2018.loc[y, x])  

for x in range(len(pirates_2018['Game'])):
    if pirates_2018.loc[x, 'Runs'] > pirates_2018.loc[x, 'R']:
        pirates_2018.loc[x, 'Win'] = 0
    else:
        pirates_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Pirates Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PIT&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PIT_2017_game_num = get_stat2('team_game_num')
PIT_2017_PA = get_stat2('PA')
PIT_2017_AB = get_stat2('AB')
PIT_2017_R = get_stat2('R')
PIT_2017_H = get_stat2('H')
PIT_2017_2B = get_stat2('2B')
PIT_2017_3B = get_stat2('3B')
PIT_2017_HR = get_stat2('HR')
PIT_2017_RBI = get_stat2('RBI')
PIT_2017_BB = get_stat2('BB')
PIT_2017_SO = get_stat2('SO')
PIT_2017_SB = get_stat2('SB')
PIT_2017_CS = get_stat2('CS')
PIT_2017_BA = get_stat2('batting_avg')
PIT_2017_OBP = get_stat2('onbase_perc')
PIT_2017_SLG = get_stat2('slugging_perc')
PIT_2017_OPS = get_stat2('onbase_plus_slugging')
PIT_2017_LOB = get_stat2('LOB')
pirates_2017_offense = pd.DataFrame({
                                  'PA': PIT_2017_PA,
                                  'AB': PIT_2017_AB,
                                  'R':  PIT_2017_R,
                                  'H':  PIT_2017_H,
                                  '2B': PIT_2017_2B,
                                  '3B': PIT_2017_3B, 
                                  'HR': PIT_2017_HR, 
                                  'RBI':PIT_2017_RBI,
                                  'BB': PIT_2017_BB,
                                  'SO': PIT_2017_SO,
                                  'SB': PIT_2017_SB,
                                  'CS': PIT_2017_CS,
                                  'LOB':PIT_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PIT&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PIT_2017_P_game_num = get_stat3('team_game_num')
PIT_2017_P_IP = get_stat3('IP')
PIT_2017_P_H = get_stat3('H')
PIT_2017_P_R = get_stat3('R')
PIT_2017_P_ER = get_stat3('ER')
PIT_2017_P_UER = get_stat3('UER')
PIT_2017_P_BB = get_stat3('BB')
PIT_2017_P_SO = get_stat3('SO')
PIT_2017_P_HR = get_stat3('HR')
PIT_2017_P_HBP = get_stat3('HBP')
PIT_2017_P_ERA = get_stat3('earned_run_avg')

pirates_2017_pitching = pd.DataFrame({'Game':  PIT_2017_P_game_num, 
                                         'IP':  PIT_2017_P_IP, 
                                         'H':   PIT_2017_P_H,
                                         'R':   PIT_2017_P_R,
                                         'ER':  PIT_2017_P_ER,
                                         'UER': PIT_2017_P_UER,
                                         'BB':  PIT_2017_P_BB,
                                         'SO':  PIT_2017_P_SO,
                                         'HR':  PIT_2017_P_HR,
                                         'HBP': PIT_2017_P_HBP})

# pirates_offense = pirates_offense.drop(columns = ['Game'])

pirates_2017_pitching = pirates_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [pirates_2017_pitching, pirates_2017_offense]

pirates_2017 = pd.concat(frames, axis=1)

pirates_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(pirates_2017[x])):
        pirates_2017.loc[y,x] = int(pirates_2017.loc[y, x])

for x in columns_float:
    for y in range(len(pirates_2017[x])):
        pirates_2017.loc[y,x] = float(pirates_2017.loc[y, x])  

for x in range(len(pirates_2017['Game'])):
    if pirates_2017.loc[x, 'Runs'] > pirates_2017.loc[x, 'R']:
        pirates_2017.loc[x, 'Win'] = 0
    else:
        pirates_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Pirates Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PIT&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PIT_2016_game_num = get_stat2('team_game_num')
PIT_2016_PA = get_stat2('PA')
PIT_2016_AB = get_stat2('AB')
PIT_2016_R = get_stat2('R')
PIT_2016_H = get_stat2('H')
PIT_2016_2B = get_stat2('2B')
PIT_2016_3B = get_stat2('3B')
PIT_2016_HR = get_stat2('HR')
PIT_2016_RBI = get_stat2('RBI')
PIT_2016_BB = get_stat2('BB')
PIT_2016_SO = get_stat2('SO')
PIT_2016_SB = get_stat2('SB')
PIT_2016_CS = get_stat2('CS')
PIT_2016_BA = get_stat2('batting_avg')
PIT_2016_OBP = get_stat2('onbase_perc')
PIT_2016_SLG = get_stat2('slugging_perc')
PIT_2016_OPS = get_stat2('onbase_plus_slugging')
PIT_2016_LOB = get_stat2('LOB')
pirates_2016_offense = pd.DataFrame({
                                  'PA': PIT_2016_PA,
                                  'AB': PIT_2016_AB,
                                  'R':  PIT_2016_R,
                                  'H':  PIT_2016_H,
                                  '2B': PIT_2016_2B,
                                  '3B': PIT_2016_3B, 
                                  'HR': PIT_2016_HR, 
                                  'RBI':PIT_2016_RBI,
                                  'BB': PIT_2016_BB,
                                  'SO': PIT_2016_SO,
                                  'SB': PIT_2016_SB,
                                  'CS': PIT_2016_CS,
                                  'LOB':PIT_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PIT&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PIT_2016_P_game_num = get_stat3('team_game_num')
PIT_2016_P_IP = get_stat3('IP')
PIT_2016_P_H = get_stat3('H')
PIT_2016_P_R = get_stat3('R')
PIT_2016_P_ER = get_stat3('ER')
PIT_2016_P_UER = get_stat3('UER')
PIT_2016_P_BB = get_stat3('BB')
PIT_2016_P_SO = get_stat3('SO')
PIT_2016_P_HR = get_stat3('HR')
PIT_2016_P_HBP = get_stat3('HBP')
PIT_2016_P_ERA = get_stat3('earned_run_avg')

pirates_2016_pitching = pd.DataFrame({'Game':  PIT_2016_P_game_num, 
                                         'IP':  PIT_2016_P_IP, 
                                         'H':   PIT_2016_P_H,
                                         'R':   PIT_2016_P_R,
                                         'ER':  PIT_2016_P_ER,
                                         'UER': PIT_2016_P_UER,
                                         'BB':  PIT_2016_P_BB,
                                         'SO':  PIT_2016_P_SO,
                                         'HR':  PIT_2016_P_HR,
                                         'HBP': PIT_2016_P_HBP})

# pirates_offense = pirates_offense.drop(columns = ['Game'])

pirates_2016_pitching = pirates_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [pirates_2016_pitching, pirates_2016_offense]

pirates_2016 = pd.concat(frames, axis=1)

pirates_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(pirates_2016[x])):
        pirates_2016.loc[y,x] = int(pirates_2016.loc[y, x])

for x in columns_float:
    for y in range(len(pirates_2016[x])):
        pirates_2016.loc[y,x] = float(pirates_2016.loc[y, x])  

for x in range(len(pirates_2016['Game'])):
    if pirates_2016.loc[x, 'Runs'] > pirates_2016.loc[x, 'R']:
        pirates_2016.loc[x, 'Win'] = 0
    else:
        pirates_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Pirates Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PIT&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PIT_2015_game_num = get_stat2('team_game_num')
PIT_2015_PA = get_stat2('PA')
PIT_2015_AB = get_stat2('AB')
PIT_2015_R = get_stat2('R')
PIT_2015_H = get_stat2('H')
PIT_2015_2B = get_stat2('2B')
PIT_2015_3B = get_stat2('3B')
PIT_2015_HR = get_stat2('HR')
PIT_2015_RBI = get_stat2('RBI')
PIT_2015_BB = get_stat2('BB')
PIT_2015_SO = get_stat2('SO')
PIT_2015_SB = get_stat2('SB')
PIT_2015_CS = get_stat2('CS')
PIT_2015_BA = get_stat2('batting_avg')
PIT_2015_OBP = get_stat2('onbase_perc')
PIT_2015_SLG = get_stat2('slugging_perc')
PIT_2015_OPS = get_stat2('onbase_plus_slugging')
PIT_2015_LOB = get_stat2('LOB')
pirates_2015_offense = pd.DataFrame({
                                  'PA': PIT_2015_PA,
                                  'AB': PIT_2015_AB,
                                  'R':  PIT_2015_R,
                                  'H':  PIT_2015_H,
                                  '2B': PIT_2015_2B,
                                  '3B': PIT_2015_3B, 
                                  'HR': PIT_2015_HR, 
                                  'RBI':PIT_2015_RBI,
                                  'BB': PIT_2015_BB,
                                  'SO': PIT_2015_SO,
                                  'SB': PIT_2015_SB,
                                  'CS': PIT_2015_CS,
                                  'LOB':PIT_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=PIT&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

PIT_2015_P_game_num = get_stat3('team_game_num')
PIT_2015_P_IP = get_stat3('IP')
PIT_2015_P_H = get_stat3('H')
PIT_2015_P_R = get_stat3('R')
PIT_2015_P_ER = get_stat3('ER')
PIT_2015_P_UER = get_stat3('UER')
PIT_2015_P_BB = get_stat3('BB')
PIT_2015_P_SO = get_stat3('SO')
PIT_2015_P_HR = get_stat3('HR')
PIT_2015_P_HBP = get_stat3('HBP')
PIT_2015_P_ERA = get_stat3('earned_run_avg')

pirates_2015_pitching = pd.DataFrame({'Game':  PIT_2015_P_game_num, 
                                         'IP':  PIT_2015_P_IP, 
                                         'H':   PIT_2015_P_H,
                                         'R':   PIT_2015_P_R,
                                         'ER':  PIT_2015_P_ER,
                                         'UER': PIT_2015_P_UER,
                                         'BB':  PIT_2015_P_BB,
                                         'SO':  PIT_2015_P_SO,
                                         'HR':  PIT_2015_P_HR,
                                         'HBP': PIT_2015_P_HBP})

# pirates_offense = pirates_offense.drop(columns = ['Game'])

pirates_2015_pitching = pirates_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [pirates_2015_pitching, pirates_2015_offense]

pirates_2015 = pd.concat(frames, axis=1)

pirates_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(pirates_2015[x])):
        pirates_2015.loc[y,x] = int(pirates_2015.loc[y, x])

for x in columns_float:
    for y in range(len(pirates_2015[x])):
        pirates_2015.loc[y,x] = float(pirates_2015.loc[y, x])  

for x in range(len(pirates_2015['Game'])):
    if pirates_2015.loc[x, 'Runs'] > pirates_2015.loc[x, 'R']:
        pirates_2015.loc[x, 'Win'] = 0
    else:
        pirates_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Cincinnati Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CIN&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CIN_game_num = get_stat2('team_game_num')

CIN_PA = get_stat2('PA')

CIN_AB = get_stat2('AB')

CIN_R = get_stat2('R')

CIN_H = get_stat2('H')

CIN_2B = get_stat2('2B')

CIN_3B = get_stat2('3B')

CIN_HR = get_stat2('HR')

CIN_RBI = get_stat2('RBI')

CIN_BB = get_stat2('BB')

CIN_SO = get_stat2('SO')

CIN_SB = get_stat2('SB')

CIN_CS = get_stat2('CS')

CIN_BA = get_stat2('batting_avg')

CIN_OBP = get_stat2('onbase_perc')

CIN_SLG = get_stat2('slugging_perc')

CIN_OPS = get_stat2('onbase_plus_slugging')

CIN_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


reds_offense = pd.DataFrame({
                                  'PA': CIN_PA,
                                  'AB': CIN_AB,
                                  'R':CIN_R,
                                  'H':CIN_H,
                                  '2B':CIN_2B,
                                  '3B': CIN_3B, 
                                  'HR':CIN_HR, 
                                  'RBI':CIN_RBI,
                                  'BB':CIN_BB,
                                  'SO':CIN_SO,
                                  'SB': CIN_SB,
                                  'CS':CIN_CS,
                                  'LOB':CIN_LOB})

# %% [markdown]
# # 2019 Cincinnati Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CIN&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CIN_P_game_num = get_stat3('team_game_num')

CIN_P_IP = get_stat3('IP')

CIN_P_H = get_stat3('H')

CIN_P_R = get_stat3('R')

CIN_P_ER = get_stat3('ER')

CIN_P_UER = get_stat3('UER')

CIN_P_BB = get_stat3('BB')

CIN_P_SO = get_stat3('SO')

CIN_P_HR = get_stat3('HR')

CIN_P_HBP = get_stat3('HBP')

CIN_P_ERA = get_stat3('earned_run_avg')

reds_pitching = pd.DataFrame({'Game': CIN_P_game_num, 
                                   'IP':CIN_P_IP, 
                                   'H':CIN_P_H,
                                   'R':CIN_P_R,
                                   'ER':CIN_P_ER,
                                   'UER':CIN_P_UER,
                                   'BB':CIN_P_BB,
                                   'SO':CIN_P_SO,
                                   'HR':CIN_P_HR,
                                   'HBP':CIN_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

reds_pitching = reds_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [reds_pitching, reds_offense]

reds = pd.concat(frames, axis=1)

reds['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(reds[x])):
        reds.loc[y,x] = int(reds.loc[y, x])

for x in columns_float:
    for y in range(len(reds[x])):
        reds.loc[y,x] = float(reds.loc[y, x])  

for x in range(len(reds['Game'])):
    if reds.loc[x, 'Runs'] > reds.loc[x, 'R']:
        reds.loc[x, 'Win'] = 0
    else:
        reds.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Reds Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CIN&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CIN_2018_game_num = get_stat2('team_game_num')
CIN_2018_PA = get_stat2('PA')
CIN_2018_AB = get_stat2('AB')
CIN_2018_R = get_stat2('R')
CIN_2018_H = get_stat2('H')
CIN_2018_2B = get_stat2('2B')
CIN_2018_3B = get_stat2('3B')
CIN_2018_HR = get_stat2('HR')
CIN_2018_RBI = get_stat2('RBI')
CIN_2018_BB = get_stat2('BB')
CIN_2018_SO = get_stat2('SO')
CIN_2018_SB = get_stat2('SB')
CIN_2018_CS = get_stat2('CS')
CIN_2018_BA = get_stat2('batting_avg')
CIN_2018_OBP = get_stat2('onbase_perc')
CIN_2018_SLG = get_stat2('slugging_perc')
CIN_2018_OPS = get_stat2('onbase_plus_slugging')
CIN_2018_LOB = get_stat2('LOB')
reds_2018_offense = pd.DataFrame({
                                  'PA': CIN_2018_PA,
                                  'AB': CIN_2018_AB,
                                  'R':  CIN_2018_R,
                                  'H':  CIN_2018_H,
                                  '2B': CIN_2018_2B,
                                  '3B': CIN_2018_3B, 
                                  'HR': CIN_2018_HR, 
                                  'RBI':CIN_2018_RBI,
                                  'BB': CIN_2018_BB,
                                  'SO': CIN_2018_SO,
                                  'SB': CIN_2018_SB,
                                  'CS': CIN_2018_CS,
                                  'LOB':CIN_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CIN&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CIN_2018_P_game_num = get_stat3('team_game_num')
CIN_2018_P_IP = get_stat3('IP')
CIN_2018_P_H = get_stat3('H')
CIN_2018_P_R = get_stat3('R')
CIN_2018_P_ER = get_stat3('ER')
CIN_2018_P_UER = get_stat3('UER')
CIN_2018_P_BB = get_stat3('BB')
CIN_2018_P_SO = get_stat3('SO')
CIN_2018_P_HR = get_stat3('HR')
CIN_2018_P_HBP = get_stat3('HBP')
CIN_2018_P_ERA = get_stat3('earned_run_avg')

reds_2018_pitching = pd.DataFrame({'Game':  CIN_2018_P_game_num, 
                                         'IP':  CIN_2018_P_IP, 
                                         'H':   CIN_2018_P_H,
                                         'R':   CIN_2018_P_R,
                                         'ER':  CIN_2018_P_ER,
                                         'UER': CIN_2018_P_UER,
                                         'BB':  CIN_2018_P_BB,
                                         'SO':  CIN_2018_P_SO,
                                         'HR':  CIN_2018_P_HR,
                                         'HBP': CIN_2018_P_HBP})

# reds_offense = reds_offense.drop(columns = ['Game'])

reds_2018_pitching = reds_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [reds_2018_pitching, reds_2018_offense]

reds_2018 = pd.concat(frames, axis=1)

reds_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(reds_2018[x])):
        reds_2018.loc[y,x] = int(reds_2018.loc[y, x])

for x in columns_float:
    for y in range(len(reds_2018[x])):
        reds_2018.loc[y,x] = float(reds_2018.loc[y, x])  

for x in range(len(reds_2018['Game'])):
    if reds_2018.loc[x, 'Runs'] > reds_2018.loc[x, 'R']:
        reds_2018.loc[x, 'Win'] = 0
    else:
        reds_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Reds Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CIN&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CIN_2017_game_num = get_stat2('team_game_num')
CIN_2017_PA = get_stat2('PA')
CIN_2017_AB = get_stat2('AB')
CIN_2017_R = get_stat2('R')
CIN_2017_H = get_stat2('H')
CIN_2017_2B = get_stat2('2B')
CIN_2017_3B = get_stat2('3B')
CIN_2017_HR = get_stat2('HR')
CIN_2017_RBI = get_stat2('RBI')
CIN_2017_BB = get_stat2('BB')
CIN_2017_SO = get_stat2('SO')
CIN_2017_SB = get_stat2('SB')
CIN_2017_CS = get_stat2('CS')
CIN_2017_BA = get_stat2('batting_avg')
CIN_2017_OBP = get_stat2('onbase_perc')
CIN_2017_SLG = get_stat2('slugging_perc')
CIN_2017_OPS = get_stat2('onbase_plus_slugging')
CIN_2017_LOB = get_stat2('LOB')
reds_2017_offense = pd.DataFrame({
                                  'PA': CIN_2017_PA,
                                  'AB': CIN_2017_AB,
                                  'R':  CIN_2017_R,
                                  'H':  CIN_2017_H,
                                  '2B': CIN_2017_2B,
                                  '3B': CIN_2017_3B, 
                                  'HR': CIN_2017_HR, 
                                  'RBI':CIN_2017_RBI,
                                  'BB': CIN_2017_BB,
                                  'SO': CIN_2017_SO,
                                  'SB': CIN_2017_SB,
                                  'CS': CIN_2017_CS,
                                  'LOB':CIN_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CIN&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CIN_2017_P_game_num = get_stat3('team_game_num')
CIN_2017_P_IP = get_stat3('IP')
CIN_2017_P_H = get_stat3('H')
CIN_2017_P_R = get_stat3('R')
CIN_2017_P_ER = get_stat3('ER')
CIN_2017_P_UER = get_stat3('UER')
CIN_2017_P_BB = get_stat3('BB')
CIN_2017_P_SO = get_stat3('SO')
CIN_2017_P_HR = get_stat3('HR')
CIN_2017_P_HBP = get_stat3('HBP')
CIN_2017_P_ERA = get_stat3('earned_run_avg')

reds_2017_pitching = pd.DataFrame({'Game':  CIN_2017_P_game_num, 
                                         'IP':  CIN_2017_P_IP, 
                                         'H':   CIN_2017_P_H,
                                         'R':   CIN_2017_P_R,
                                         'ER':  CIN_2017_P_ER,
                                         'UER': CIN_2017_P_UER,
                                         'BB':  CIN_2017_P_BB,
                                         'SO':  CIN_2017_P_SO,
                                         'HR':  CIN_2017_P_HR,
                                         'HBP': CIN_2017_P_HBP})

# reds_offense = reds_offense.drop(columns = ['Game'])

reds_2017_pitching = reds_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [reds_2017_pitching, reds_2017_offense]

reds_2017 = pd.concat(frames, axis=1)

reds_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(reds_2017[x])):
        reds_2017.loc[y,x] = int(reds_2017.loc[y, x])

for x in columns_float:
    for y in range(len(reds_2017[x])):
        reds_2017.loc[y,x] = float(reds_2017.loc[y, x])  

for x in range(len(reds_2017['Game'])):
    if reds_2017.loc[x, 'Runs'] > reds_2017.loc[x, 'R']:
        reds_2017.loc[x, 'Win'] = 0
    else:
        reds_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Reds Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CIN&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CIN_2016_game_num = get_stat2('team_game_num')
CIN_2016_PA = get_stat2('PA')
CIN_2016_AB = get_stat2('AB')
CIN_2016_R = get_stat2('R')
CIN_2016_H = get_stat2('H')
CIN_2016_2B = get_stat2('2B')
CIN_2016_3B = get_stat2('3B')
CIN_2016_HR = get_stat2('HR')
CIN_2016_RBI = get_stat2('RBI')
CIN_2016_BB = get_stat2('BB')
CIN_2016_SO = get_stat2('SO')
CIN_2016_SB = get_stat2('SB')
CIN_2016_CS = get_stat2('CS')
CIN_2016_BA = get_stat2('batting_avg')
CIN_2016_OBP = get_stat2('onbase_perc')
CIN_2016_SLG = get_stat2('slugging_perc')
CIN_2016_OPS = get_stat2('onbase_plus_slugging')
CIN_2016_LOB = get_stat2('LOB')
reds_2016_offense = pd.DataFrame({
                                  'PA': CIN_2016_PA,
                                  'AB': CIN_2016_AB,
                                  'R':  CIN_2016_R,
                                  'H':  CIN_2016_H,
                                  '2B': CIN_2016_2B,
                                  '3B': CIN_2016_3B, 
                                  'HR': CIN_2016_HR, 
                                  'RBI':CIN_2016_RBI,
                                  'BB': CIN_2016_BB,
                                  'SO': CIN_2016_SO,
                                  'SB': CIN_2016_SB,
                                  'CS': CIN_2016_CS,
                                  'LOB':CIN_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CIN&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CIN_2016_P_game_num = get_stat3('team_game_num')
CIN_2016_P_IP = get_stat3('IP')
CIN_2016_P_H = get_stat3('H')
CIN_2016_P_R = get_stat3('R')
CIN_2016_P_ER = get_stat3('ER')
CIN_2016_P_UER = get_stat3('UER')
CIN_2016_P_BB = get_stat3('BB')
CIN_2016_P_SO = get_stat3('SO')
CIN_2016_P_HR = get_stat3('HR')
CIN_2016_P_HBP = get_stat3('HBP')
CIN_2016_P_ERA = get_stat3('earned_run_avg')

reds_2016_pitching = pd.DataFrame({'Game':  CIN_2016_P_game_num, 
                                         'IP':  CIN_2016_P_IP, 
                                         'H':   CIN_2016_P_H,
                                         'R':   CIN_2016_P_R,
                                         'ER':  CIN_2016_P_ER,
                                         'UER': CIN_2016_P_UER,
                                         'BB':  CIN_2016_P_BB,
                                         'SO':  CIN_2016_P_SO,
                                         'HR':  CIN_2016_P_HR,
                                         'HBP': CIN_2016_P_HBP})

# reds_offense = reds_offense.drop(columns = ['Game'])

reds_2016_pitching = reds_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [reds_2016_pitching, reds_2016_offense]

reds_2016 = pd.concat(frames, axis=1)

reds_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(reds_2016[x])):
        reds_2016.loc[y,x] = int(reds_2016.loc[y, x])

for x in columns_float:
    for y in range(len(reds_2016[x])):
        reds_2016.loc[y,x] = float(reds_2016.loc[y, x])  

for x in range(len(reds_2016['Game'])):
    if reds_2016.loc[x, 'Runs'] > reds_2016.loc[x, 'R']:
        reds_2016.loc[x, 'Win'] = 0
    else:
        reds_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Reds Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CIN&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CIN_2015_game_num = get_stat2('team_game_num')
CIN_2015_PA = get_stat2('PA')
CIN_2015_AB = get_stat2('AB')
CIN_2015_R = get_stat2('R')
CIN_2015_H = get_stat2('H')
CIN_2015_2B = get_stat2('2B')
CIN_2015_3B = get_stat2('3B')
CIN_2015_HR = get_stat2('HR')
CIN_2015_RBI = get_stat2('RBI')
CIN_2015_BB = get_stat2('BB')
CIN_2015_SO = get_stat2('SO')
CIN_2015_SB = get_stat2('SB')
CIN_2015_CS = get_stat2('CS')
CIN_2015_BA = get_stat2('batting_avg')
CIN_2015_OBP = get_stat2('onbase_perc')
CIN_2015_SLG = get_stat2('slugging_perc')
CIN_2015_OPS = get_stat2('onbase_plus_slugging')
CIN_2015_LOB = get_stat2('LOB')
reds_2015_offense = pd.DataFrame({
                                  'PA': CIN_2015_PA,
                                  'AB': CIN_2015_AB,
                                  'R':  CIN_2015_R,
                                  'H':  CIN_2015_H,
                                  '2B': CIN_2015_2B,
                                  '3B': CIN_2015_3B, 
                                  'HR': CIN_2015_HR, 
                                  'RBI':CIN_2015_RBI,
                                  'BB': CIN_2015_BB,
                                  'SO': CIN_2015_SO,
                                  'SB': CIN_2015_SB,
                                  'CS': CIN_2015_CS,
                                  'LOB':CIN_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CIN&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CIN_2015_P_game_num = get_stat3('team_game_num')
CIN_2015_P_IP = get_stat3('IP')
CIN_2015_P_H = get_stat3('H')
CIN_2015_P_R = get_stat3('R')
CIN_2015_P_ER = get_stat3('ER')
CIN_2015_P_UER = get_stat3('UER')
CIN_2015_P_BB = get_stat3('BB')
CIN_2015_P_SO = get_stat3('SO')
CIN_2015_P_HR = get_stat3('HR')
CIN_2015_P_HBP = get_stat3('HBP')
CIN_2015_P_ERA = get_stat3('earned_run_avg')

reds_2015_pitching = pd.DataFrame({'Game':  CIN_2015_P_game_num, 
                                         'IP':  CIN_2015_P_IP, 
                                         'H':   CIN_2015_P_H,
                                         'R':   CIN_2015_P_R,
                                         'ER':  CIN_2015_P_ER,
                                         'UER': CIN_2015_P_UER,
                                         'BB':  CIN_2015_P_BB,
                                         'SO':  CIN_2015_P_SO,
                                         'HR':  CIN_2015_P_HR,
                                         'HBP': CIN_2015_P_HBP})

# reds_offense = reds_offense.drop(columns = ['Game'])

reds_2015_pitching = reds_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [reds_2015_pitching, reds_2015_offense]

reds_2015 = pd.concat(frames, axis=1)

reds_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(reds_2015[x])):
        reds_2015.loc[y,x] = int(reds_2015.loc[y, x])

for x in columns_float:
    for y in range(len(reds_2015[x])):
        reds_2015.loc[y,x] = float(reds_2015.loc[y, x])  

for x in range(len(reds_2015['Game'])):
    if reds_2015.loc[x, 'Runs'] > reds_2015.loc[x, 'R']:
        reds_2015.loc[x, 'Win'] = 0
    else:
        reds_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Dodgers Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAD&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAD_game_num = get_stat2('team_game_num')

LAD_PA = get_stat2('PA')

LAD_AB = get_stat2('AB')

LAD_R = get_stat2('R')

LAD_H = get_stat2('H')

LAD_2B = get_stat2('2B')

LAD_3B = get_stat2('3B')

LAD_HR = get_stat2('HR')

LAD_RBI = get_stat2('RBI')

LAD_BB = get_stat2('BB')

LAD_SO = get_stat2('SO')

LAD_SB = get_stat2('SB')

LAD_CS = get_stat2('CS')

LAD_BA = get_stat2('batting_avg')

LAD_OBP = get_stat2('onbase_perc')

LAD_SLG = get_stat2('slugging_perc')

LAD_OPS = get_stat2('onbase_plus_slugging')

LAD_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


dodgers_offense = pd.DataFrame({
                                  'PA': LAD_PA,
                                  'AB': LAD_AB,
                                  'R':LAD_R,
                                  'H':LAD_H,
                                  '2B':LAD_2B,
                                  '3B': LAD_3B, 
                                  'HR':LAD_HR, 
                                  'RBI':LAD_RBI,
                                  'BB':LAD_BB,
                                  'SO':LAD_SO,
                                  'SB': LAD_SB,
                                  'CS':LAD_CS,
                                  'LOB':LAD_LOB})

# %% [markdown]
# # 2019 Dodgers Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAD&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAD_P_game_num = get_stat3('team_game_num')

LAD_P_IP = get_stat3('IP')

LAD_P_H = get_stat3('H')

LAD_P_R = get_stat3('R')

LAD_P_ER = get_stat3('ER')

LAD_P_UER = get_stat3('UER')

LAD_P_BB = get_stat3('BB')

LAD_P_SO = get_stat3('SO')

LAD_P_HR = get_stat3('HR')

LAD_P_HBP = get_stat3('HBP')

LAD_P_ERA = get_stat3('earned_run_avg')

dodgers_pitching = pd.DataFrame({'Game': LAD_P_game_num, 
                                   'IP':LAD_P_IP, 
                                   'H':LAD_P_H,
                                   'R':LAD_P_R,
                                   'ER':LAD_P_ER,
                                   'UER':LAD_P_UER,
                                   'BB':LAD_P_BB,
                                   'SO':LAD_P_SO,
                                   'HR':LAD_P_HR,
                                   'HBP':LAD_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

dodgers_pitching = dodgers_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [dodgers_pitching, dodgers_offense]

dodgers = pd.concat(frames, axis=1)

dodgers['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(dodgers[x])):
        dodgers.loc[y,x] = int(dodgers.loc[y, x])

for x in columns_float:
    for y in range(len(dodgers[x])):
        dodgers.loc[y,x] = float(dodgers.loc[y, x])  

for x in range(len(dodgers['Game'])):
    if dodgers.loc[x, 'Runs'] > dodgers.loc[x, 'R']:
        dodgers.loc[x, 'Win'] = 0
    else:
        dodgers.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Dodgers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAD&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAD_2018_game_num = get_stat2('team_game_num')
LAD_2018_PA = get_stat2('PA')
LAD_2018_AB = get_stat2('AB')
LAD_2018_R = get_stat2('R')
LAD_2018_H = get_stat2('H')
LAD_2018_2B = get_stat2('2B')
LAD_2018_3B = get_stat2('3B')
LAD_2018_HR = get_stat2('HR')
LAD_2018_RBI = get_stat2('RBI')
LAD_2018_BB = get_stat2('BB')
LAD_2018_SO = get_stat2('SO')
LAD_2018_SB = get_stat2('SB')
LAD_2018_CS = get_stat2('CS')
LAD_2018_BA = get_stat2('batting_avg')
LAD_2018_OBP = get_stat2('onbase_perc')
LAD_2018_SLG = get_stat2('slugging_perc')
LAD_2018_OPS = get_stat2('onbase_plus_slugging')
LAD_2018_LOB = get_stat2('LOB')
dodgers_2018_offense = pd.DataFrame({
                                  'PA': LAD_2018_PA,
                                  'AB': LAD_2018_AB,
                                  'R':  LAD_2018_R,
                                  'H':  LAD_2018_H,
                                  '2B': LAD_2018_2B,
                                  '3B': LAD_2018_3B, 
                                  'HR': LAD_2018_HR, 
                                  'RBI':LAD_2018_RBI,
                                  'BB': LAD_2018_BB,
                                  'SO': LAD_2018_SO,
                                  'SB': LAD_2018_SB,
                                  'CS': LAD_2018_CS,
                                  'LOB':LAD_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAD&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAD_2018_P_game_num = get_stat3('team_game_num')
LAD_2018_P_IP = get_stat3('IP')
LAD_2018_P_H = get_stat3('H')
LAD_2018_P_R = get_stat3('R')
LAD_2018_P_ER = get_stat3('ER')
LAD_2018_P_UER = get_stat3('UER')
LAD_2018_P_BB = get_stat3('BB')
LAD_2018_P_SO = get_stat3('SO')
LAD_2018_P_HR = get_stat3('HR')
LAD_2018_P_HBP = get_stat3('HBP')
LAD_2018_P_ERA = get_stat3('earned_run_avg')

dodgers_2018_pitching = pd.DataFrame({'Game':  LAD_2018_P_game_num, 
                                         'IP':  LAD_2018_P_IP, 
                                         'H':   LAD_2018_P_H,
                                         'R':   LAD_2018_P_R,
                                         'ER':  LAD_2018_P_ER,
                                         'UER': LAD_2018_P_UER,
                                         'BB':  LAD_2018_P_BB,
                                         'SO':  LAD_2018_P_SO,
                                         'HR':  LAD_2018_P_HR,
                                         'HBP': LAD_2018_P_HBP})

# dodgers_offense = dodgers_offense.drop(columns = ['Game'])

dodgers_2018_pitching = dodgers_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [dodgers_2018_pitching, dodgers_2018_offense]

dodgers_2018 = pd.concat(frames, axis=1)

dodgers_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(dodgers_2018[x])):
        dodgers_2018.loc[y,x] = int(dodgers_2018.loc[y, x])

for x in columns_float:
    for y in range(len(dodgers_2018[x])):
        dodgers_2018.loc[y,x] = float(dodgers_2018.loc[y, x])  

for x in range(len(dodgers_2018['Game'])):
    if dodgers_2018.loc[x, 'Runs'] > dodgers_2018.loc[x, 'R']:
        dodgers_2018.loc[x, 'Win'] = 0
    else:
        dodgers_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Dodgers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAD&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAD_2017_game_num = get_stat2('team_game_num')
LAD_2017_PA = get_stat2('PA')
LAD_2017_AB = get_stat2('AB')
LAD_2017_R = get_stat2('R')
LAD_2017_H = get_stat2('H')
LAD_2017_2B = get_stat2('2B')
LAD_2017_3B = get_stat2('3B')
LAD_2017_HR = get_stat2('HR')
LAD_2017_RBI = get_stat2('RBI')
LAD_2017_BB = get_stat2('BB')
LAD_2017_SO = get_stat2('SO')
LAD_2017_SB = get_stat2('SB')
LAD_2017_CS = get_stat2('CS')
LAD_2017_BA = get_stat2('batting_avg')
LAD_2017_OBP = get_stat2('onbase_perc')
LAD_2017_SLG = get_stat2('slugging_perc')
LAD_2017_OPS = get_stat2('onbase_plus_slugging')
LAD_2017_LOB = get_stat2('LOB')
dodgers_2017_offense = pd.DataFrame({
                                  'PA': LAD_2017_PA,
                                  'AB': LAD_2017_AB,
                                  'R':  LAD_2017_R,
                                  'H':  LAD_2017_H,
                                  '2B': LAD_2017_2B,
                                  '3B': LAD_2017_3B, 
                                  'HR': LAD_2017_HR, 
                                  'RBI':LAD_2017_RBI,
                                  'BB': LAD_2017_BB,
                                  'SO': LAD_2017_SO,
                                  'SB': LAD_2017_SB,
                                  'CS': LAD_2017_CS,
                                  'LOB':LAD_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAD&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAD_2017_P_game_num = get_stat3('team_game_num')
LAD_2017_P_IP = get_stat3('IP')
LAD_2017_P_H = get_stat3('H')
LAD_2017_P_R = get_stat3('R')
LAD_2017_P_ER = get_stat3('ER')
LAD_2017_P_UER = get_stat3('UER')
LAD_2017_P_BB = get_stat3('BB')
LAD_2017_P_SO = get_stat3('SO')
LAD_2017_P_HR = get_stat3('HR')
LAD_2017_P_HBP = get_stat3('HBP')
LAD_2017_P_ERA = get_stat3('earned_run_avg')

dodgers_2017_pitching = pd.DataFrame({'Game':  LAD_2017_P_game_num, 
                                         'IP':  LAD_2017_P_IP, 
                                         'H':   LAD_2017_P_H,
                                         'R':   LAD_2017_P_R,
                                         'ER':  LAD_2017_P_ER,
                                         'UER': LAD_2017_P_UER,
                                         'BB':  LAD_2017_P_BB,
                                         'SO':  LAD_2017_P_SO,
                                         'HR':  LAD_2017_P_HR,
                                         'HBP': LAD_2017_P_HBP})

# dodgers_offense = dodgers_offense.drop(columns = ['Game'])

dodgers_2017_pitching = dodgers_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [dodgers_2017_pitching, dodgers_2017_offense]

dodgers_2017 = pd.concat(frames, axis=1)

dodgers_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(dodgers_2017[x])):
        dodgers_2017.loc[y,x] = int(dodgers_2017.loc[y, x])

for x in columns_float:
    for y in range(len(dodgers_2017[x])):
        dodgers_2017.loc[y,x] = float(dodgers_2017.loc[y, x])  

for x in range(len(dodgers_2017['Game'])):
    if dodgers_2017.loc[x, 'Runs'] > dodgers_2017.loc[x, 'R']:
        dodgers_2017.loc[x, 'Win'] = 0
    else:
        dodgers_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Dodgers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAD&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAD_2016_game_num = get_stat2('team_game_num')
LAD_2016_PA = get_stat2('PA')
LAD_2016_AB = get_stat2('AB')
LAD_2016_R = get_stat2('R')
LAD_2016_H = get_stat2('H')
LAD_2016_2B = get_stat2('2B')
LAD_2016_3B = get_stat2('3B')
LAD_2016_HR = get_stat2('HR')
LAD_2016_RBI = get_stat2('RBI')
LAD_2016_BB = get_stat2('BB')
LAD_2016_SO = get_stat2('SO')
LAD_2016_SB = get_stat2('SB')
LAD_2016_CS = get_stat2('CS')
LAD_2016_BA = get_stat2('batting_avg')
LAD_2016_OBP = get_stat2('onbase_perc')
LAD_2016_SLG = get_stat2('slugging_perc')
LAD_2016_OPS = get_stat2('onbase_plus_slugging')
LAD_2016_LOB = get_stat2('LOB')
dodgers_2016_offense = pd.DataFrame({
                                  'PA': LAD_2016_PA,
                                  'AB': LAD_2016_AB,
                                  'R':  LAD_2016_R,
                                  'H':  LAD_2016_H,
                                  '2B': LAD_2016_2B,
                                  '3B': LAD_2016_3B, 
                                  'HR': LAD_2016_HR, 
                                  'RBI':LAD_2016_RBI,
                                  'BB': LAD_2016_BB,
                                  'SO': LAD_2016_SO,
                                  'SB': LAD_2016_SB,
                                  'CS': LAD_2016_CS,
                                  'LOB':LAD_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAD&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAD_2016_P_game_num = get_stat3('team_game_num')
LAD_2016_P_IP = get_stat3('IP')
LAD_2016_P_H = get_stat3('H')
LAD_2016_P_R = get_stat3('R')
LAD_2016_P_ER = get_stat3('ER')
LAD_2016_P_UER = get_stat3('UER')
LAD_2016_P_BB = get_stat3('BB')
LAD_2016_P_SO = get_stat3('SO')
LAD_2016_P_HR = get_stat3('HR')
LAD_2016_P_HBP = get_stat3('HBP')
LAD_2016_P_ERA = get_stat3('earned_run_avg')

dodgers_2016_pitching = pd.DataFrame({'Game':  LAD_2016_P_game_num, 
                                         'IP':  LAD_2016_P_IP, 
                                         'H':   LAD_2016_P_H,
                                         'R':   LAD_2016_P_R,
                                         'ER':  LAD_2016_P_ER,
                                         'UER': LAD_2016_P_UER,
                                         'BB':  LAD_2016_P_BB,
                                         'SO':  LAD_2016_P_SO,
                                         'HR':  LAD_2016_P_HR,
                                         'HBP': LAD_2016_P_HBP})

# dodgers_offense = dodgers_offense.drop(columns = ['Game'])

dodgers_2016_pitching = dodgers_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [dodgers_2016_pitching, dodgers_2016_offense]

dodgers_2016 = pd.concat(frames, axis=1)

dodgers_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(dodgers_2016[x])):
        dodgers_2016.loc[y,x] = int(dodgers_2016.loc[y, x])

for x in columns_float:
    for y in range(len(dodgers_2016[x])):
        dodgers_2016.loc[y,x] = float(dodgers_2016.loc[y, x])  

for x in range(len(dodgers_2016['Game'])):
    if dodgers_2016.loc[x, 'Runs'] > dodgers_2016.loc[x, 'R']:
        dodgers_2016.loc[x, 'Win'] = 0
    else:
        dodgers_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Dodgers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAD&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAD_2015_game_num = get_stat2('team_game_num')
LAD_2015_PA = get_stat2('PA')
LAD_2015_AB = get_stat2('AB')
LAD_2015_R = get_stat2('R')
LAD_2015_H = get_stat2('H')
LAD_2015_2B = get_stat2('2B')
LAD_2015_3B = get_stat2('3B')
LAD_2015_HR = get_stat2('HR')
LAD_2015_RBI = get_stat2('RBI')
LAD_2015_BB = get_stat2('BB')
LAD_2015_SO = get_stat2('SO')
LAD_2015_SB = get_stat2('SB')
LAD_2015_CS = get_stat2('CS')
LAD_2015_BA = get_stat2('batting_avg')
LAD_2015_OBP = get_stat2('onbase_perc')
LAD_2015_SLG = get_stat2('slugging_perc')
LAD_2015_OPS = get_stat2('onbase_plus_slugging')
LAD_2015_LOB = get_stat2('LOB')
dodgers_2015_offense = pd.DataFrame({
                                  'PA': LAD_2015_PA,
                                  'AB': LAD_2015_AB,
                                  'R':  LAD_2015_R,
                                  'H':  LAD_2015_H,
                                  '2B': LAD_2015_2B,
                                  '3B': LAD_2015_3B, 
                                  'HR': LAD_2015_HR, 
                                  'RBI':LAD_2015_RBI,
                                  'BB': LAD_2015_BB,
                                  'SO': LAD_2015_SO,
                                  'SB': LAD_2015_SB,
                                  'CS': LAD_2015_CS,
                                  'LOB':LAD_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAD&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAD_2015_P_game_num = get_stat3('team_game_num')
LAD_2015_P_IP = get_stat3('IP')
LAD_2015_P_H = get_stat3('H')
LAD_2015_P_R = get_stat3('R')
LAD_2015_P_ER = get_stat3('ER')
LAD_2015_P_UER = get_stat3('UER')
LAD_2015_P_BB = get_stat3('BB')
LAD_2015_P_SO = get_stat3('SO')
LAD_2015_P_HR = get_stat3('HR')
LAD_2015_P_HBP = get_stat3('HBP')
LAD_2015_P_ERA = get_stat3('earned_run_avg')

dodgers_2015_pitching = pd.DataFrame({'Game':  LAD_2015_P_game_num, 
                                         'IP':  LAD_2015_P_IP, 
                                         'H':   LAD_2015_P_H,
                                         'R':   LAD_2015_P_R,
                                         'ER':  LAD_2015_P_ER,
                                         'UER': LAD_2015_P_UER,
                                         'BB':  LAD_2015_P_BB,
                                         'SO':  LAD_2015_P_SO,
                                         'HR':  LAD_2015_P_HR,
                                         'HBP': LAD_2015_P_HBP})

# dodgers_offense = dodgers_offense.drop(columns = ['Game'])

dodgers_2015_pitching = dodgers_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [dodgers_2015_pitching, dodgers_2015_offense]

dodgers_2015 = pd.concat(frames, axis=1)

dodgers_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(dodgers_2015[x])):
        dodgers_2015.loc[y,x] = int(dodgers_2015.loc[y, x])

for x in columns_float:
    for y in range(len(dodgers_2015[x])):
        dodgers_2015.loc[y,x] = float(dodgers_2015.loc[y, x])  

for x in range(len(dodgers_2015['Game'])):
    if dodgers_2015.loc[x, 'Runs'] > dodgers_2015.loc[x, 'R']:
        dodgers_2015.loc[x, 'Win'] = 0
    else:
        dodgers_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Arizona Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ARI&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ARI_game_num = get_stat2('team_game_num')

ARI_PA = get_stat2('PA')

ARI_AB = get_stat2('AB')

ARI_R = get_stat2('R')

ARI_H = get_stat2('H')

ARI_2B = get_stat2('2B')

ARI_3B = get_stat2('3B')

ARI_HR = get_stat2('HR')

ARI_RBI = get_stat2('RBI')

ARI_BB = get_stat2('BB')

ARI_SO = get_stat2('SO')

ARI_SB = get_stat2('SB')

ARI_CS = get_stat2('CS')

ARI_BA = get_stat2('batting_avg')

ARI_OBP = get_stat2('onbase_perc')

ARI_SLG = get_stat2('slugging_perc')

ARI_OPS = get_stat2('onbase_plus_slugging')

ARI_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


diamondbacks_offense = pd.DataFrame({
                                  'PA': ARI_PA,
                                  'AB': ARI_AB,
                                  'R':ARI_R,
                                  'H':ARI_H,
                                  '2B':ARI_2B,
                                  '3B': ARI_3B, 
                                  'HR':ARI_HR, 
                                  'RBI':ARI_RBI,
                                  'BB':ARI_BB,
                                  'SO':ARI_SO,
                                  'SB': ARI_SB,
                                  'CS':ARI_CS,
                                  'LOB':ARI_LOB})

# %% [markdown]
# # 2019 Arizona Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ARI&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ARI_P_game_num = get_stat3('team_game_num')

ARI_P_IP = get_stat3('IP')

ARI_P_H = get_stat3('H')

ARI_P_R = get_stat3('R')

ARI_P_ER = get_stat3('ER')

ARI_P_UER = get_stat3('UER')

ARI_P_BB = get_stat3('BB')

ARI_P_SO = get_stat3('SO')

ARI_P_HR = get_stat3('HR')

ARI_P_HBP = get_stat3('HBP')

ARI_P_ERA = get_stat3('earned_run_avg')

diamondbacks_pitching = pd.DataFrame({'Game': ARI_P_game_num, 
                                   'IP':ARI_P_IP, 
                                   'H':ARI_P_H,
                                   'R':ARI_P_R,
                                   'ER':ARI_P_ER,
                                   'UER':ARI_P_UER,
                                   'BB':ARI_P_BB,
                                   'SO':ARI_P_SO,
                                   'HR':ARI_P_HR,
                                   'HBP':ARI_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

diamondbacks_pitching = diamondbacks_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [diamondbacks_pitching, diamondbacks_offense]

diamondbacks = pd.concat(frames, axis=1)

diamondbacks['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(diamondbacks[x])):
        diamondbacks.loc[y,x] = int(diamondbacks.loc[y, x])

for x in columns_float:
    for y in range(len(diamondbacks[x])):
        diamondbacks.loc[y,x] = float(diamondbacks.loc[y, x])  

for x in range(len(diamondbacks['Game'])):
    if diamondbacks.loc[x, 'Runs'] > diamondbacks.loc[x, 'R']:
        diamondbacks.loc[x, 'Win'] = 0
    else:
        diamondbacks.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Arizona Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ARI&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ARI_2018_game_num = get_stat2('team_game_num')
ARI_2018_PA = get_stat2('PA')
ARI_2018_AB = get_stat2('AB')
ARI_2018_R = get_stat2('R')
ARI_2018_H = get_stat2('H')
ARI_2018_2B = get_stat2('2B')
ARI_2018_3B = get_stat2('3B')
ARI_2018_HR = get_stat2('HR')
ARI_2018_RBI = get_stat2('RBI')
ARI_2018_BB = get_stat2('BB')
ARI_2018_SO = get_stat2('SO')
ARI_2018_SB = get_stat2('SB')
ARI_2018_CS = get_stat2('CS')
ARI_2018_BA = get_stat2('batting_avg')
ARI_2018_OBP = get_stat2('onbase_perc')
ARI_2018_SLG = get_stat2('slugging_perc')
ARI_2018_OPS = get_stat2('onbase_plus_slugging')
ARI_2018_LOB = get_stat2('LOB')
diamondbacks_2018_offense = pd.DataFrame({
                                  'PA': ARI_2018_PA,
                                  'AB': ARI_2018_AB,
                                  'R':  ARI_2018_R,
                                  'H':  ARI_2018_H,
                                  '2B': ARI_2018_2B,
                                  '3B': ARI_2018_3B, 
                                  'HR': ARI_2018_HR, 
                                  'RBI':ARI_2018_RBI,
                                  'BB': ARI_2018_BB,
                                  'SO': ARI_2018_SO,
                                  'SB': ARI_2018_SB,
                                  'CS': ARI_2018_CS,
                                  'LOB':ARI_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ARI&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ARI_2018_P_game_num = get_stat3('team_game_num')
ARI_2018_P_IP = get_stat3('IP')
ARI_2018_P_H = get_stat3('H')
ARI_2018_P_R = get_stat3('R')
ARI_2018_P_ER = get_stat3('ER')
ARI_2018_P_UER = get_stat3('UER')
ARI_2018_P_BB = get_stat3('BB')
ARI_2018_P_SO = get_stat3('SO')
ARI_2018_P_HR = get_stat3('HR')
ARI_2018_P_HBP = get_stat3('HBP')
ARI_2018_P_ERA = get_stat3('earned_run_avg')

diamondbacks_2018_pitching = pd.DataFrame({'Game':  ARI_2018_P_game_num, 
                                         'IP':  ARI_2018_P_IP, 
                                         'H':   ARI_2018_P_H,
                                         'R':   ARI_2018_P_R,
                                         'ER':  ARI_2018_P_ER,
                                         'UER': ARI_2018_P_UER,
                                         'BB':  ARI_2018_P_BB,
                                         'SO':  ARI_2018_P_SO,
                                         'HR':  ARI_2018_P_HR,
                                         'HBP': ARI_2018_P_HBP})

# diamondbacks_offense = diamondbacks_offense.drop(columns = ['Game'])

diamondbacks_2018_pitching = diamondbacks_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [diamondbacks_2018_pitching, diamondbacks_2018_offense]

diamondbacks_2018 = pd.concat(frames, axis=1)

diamondbacks_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(diamondbacks_2018[x])):
        diamondbacks_2018.loc[y,x] = int(diamondbacks_2018.loc[y, x])

for x in columns_float:
    for y in range(len(diamondbacks_2018[x])):
        diamondbacks_2018.loc[y,x] = float(diamondbacks_2018.loc[y, x])  

for x in range(len(diamondbacks_2018['Game'])):
    if diamondbacks_2018.loc[x, 'Runs'] > diamondbacks_2018.loc[x, 'R']:
        diamondbacks_2018.loc[x, 'Win'] = 0
    else:
        diamondbacks_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Arizona Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ARI&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ARI_2017_game_num = get_stat2('team_game_num')
ARI_2017_PA = get_stat2('PA')
ARI_2017_AB = get_stat2('AB')
ARI_2017_R = get_stat2('R')
ARI_2017_H = get_stat2('H')
ARI_2017_2B = get_stat2('2B')
ARI_2017_3B = get_stat2('3B')
ARI_2017_HR = get_stat2('HR')
ARI_2017_RBI = get_stat2('RBI')
ARI_2017_BB = get_stat2('BB')
ARI_2017_SO = get_stat2('SO')
ARI_2017_SB = get_stat2('SB')
ARI_2017_CS = get_stat2('CS')
ARI_2017_BA = get_stat2('batting_avg')
ARI_2017_OBP = get_stat2('onbase_perc')
ARI_2017_SLG = get_stat2('slugging_perc')
ARI_2017_OPS = get_stat2('onbase_plus_slugging')
ARI_2017_LOB = get_stat2('LOB')
diamondbacks_2017_offense = pd.DataFrame({
                                  'PA': ARI_2017_PA,
                                  'AB': ARI_2017_AB,
                                  'R':  ARI_2017_R,
                                  'H':  ARI_2017_H,
                                  '2B': ARI_2017_2B,
                                  '3B': ARI_2017_3B, 
                                  'HR': ARI_2017_HR, 
                                  'RBI':ARI_2017_RBI,
                                  'BB': ARI_2017_BB,
                                  'SO': ARI_2017_SO,
                                  'SB': ARI_2017_SB,
                                  'CS': ARI_2017_CS,
                                  'LOB':ARI_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ARI&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ARI_2017_P_game_num = get_stat3('team_game_num')
ARI_2017_P_IP = get_stat3('IP')
ARI_2017_P_H = get_stat3('H')
ARI_2017_P_R = get_stat3('R')
ARI_2017_P_ER = get_stat3('ER')
ARI_2017_P_UER = get_stat3('UER')
ARI_2017_P_BB = get_stat3('BB')
ARI_2017_P_SO = get_stat3('SO')
ARI_2017_P_HR = get_stat3('HR')
ARI_2017_P_HBP = get_stat3('HBP')
ARI_2017_P_ERA = get_stat3('earned_run_avg')

diamondbacks_2017_pitching = pd.DataFrame({'Game':  ARI_2017_P_game_num, 
                                         'IP':  ARI_2017_P_IP, 
                                         'H':   ARI_2017_P_H,
                                         'R':   ARI_2017_P_R,
                                         'ER':  ARI_2017_P_ER,
                                         'UER': ARI_2017_P_UER,
                                         'BB':  ARI_2017_P_BB,
                                         'SO':  ARI_2017_P_SO,
                                         'HR':  ARI_2017_P_HR,
                                         'HBP': ARI_2017_P_HBP})

# diamondbacks_offense = diamondbacks_offense.drop(columns = ['Game'])

diamondbacks_2017_pitching = diamondbacks_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [diamondbacks_2017_pitching, diamondbacks_2017_offense]

diamondbacks_2017 = pd.concat(frames, axis=1)

diamondbacks_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(diamondbacks_2017[x])):
        diamondbacks_2017.loc[y,x] = int(diamondbacks_2017.loc[y, x])

for x in columns_float:
    for y in range(len(diamondbacks_2017[x])):
        diamondbacks_2017.loc[y,x] = float(diamondbacks_2017.loc[y, x])  

for x in range(len(diamondbacks_2017['Game'])):
    if diamondbacks_2017.loc[x, 'Runs'] > diamondbacks_2017.loc[x, 'R']:
        diamondbacks_2017.loc[x, 'Win'] = 0
    else:
        diamondbacks_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Arizona Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ARI&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ARI_2016_game_num = get_stat2('team_game_num')
ARI_2016_PA = get_stat2('PA')
ARI_2016_AB = get_stat2('AB')
ARI_2016_R = get_stat2('R')
ARI_2016_H = get_stat2('H')
ARI_2016_2B = get_stat2('2B')
ARI_2016_3B = get_stat2('3B')
ARI_2016_HR = get_stat2('HR')
ARI_2016_RBI = get_stat2('RBI')
ARI_2016_BB = get_stat2('BB')
ARI_2016_SO = get_stat2('SO')
ARI_2016_SB = get_stat2('SB')
ARI_2016_CS = get_stat2('CS')
ARI_2016_BA = get_stat2('batting_avg')
ARI_2016_OBP = get_stat2('onbase_perc')
ARI_2016_SLG = get_stat2('slugging_perc')
ARI_2016_OPS = get_stat2('onbase_plus_slugging')
ARI_2016_LOB = get_stat2('LOB')
diamondbacks_2016_offense = pd.DataFrame({
                                  'PA': ARI_2016_PA,
                                  'AB': ARI_2016_AB,
                                  'R':  ARI_2016_R,
                                  'H':  ARI_2016_H,
                                  '2B': ARI_2016_2B,
                                  '3B': ARI_2016_3B, 
                                  'HR': ARI_2016_HR, 
                                  'RBI':ARI_2016_RBI,
                                  'BB': ARI_2016_BB,
                                  'SO': ARI_2016_SO,
                                  'SB': ARI_2016_SB,
                                  'CS': ARI_2016_CS,
                                  'LOB':ARI_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ARI&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ARI_2016_P_game_num = get_stat3('team_game_num')
ARI_2016_P_IP = get_stat3('IP')
ARI_2016_P_H = get_stat3('H')
ARI_2016_P_R = get_stat3('R')
ARI_2016_P_ER = get_stat3('ER')
ARI_2016_P_UER = get_stat3('UER')
ARI_2016_P_BB = get_stat3('BB')
ARI_2016_P_SO = get_stat3('SO')
ARI_2016_P_HR = get_stat3('HR')
ARI_2016_P_HBP = get_stat3('HBP')
ARI_2016_P_ERA = get_stat3('earned_run_avg')

diamondbacks_2016_pitching = pd.DataFrame({'Game':  ARI_2016_P_game_num, 
                                         'IP':  ARI_2016_P_IP, 
                                         'H':   ARI_2016_P_H,
                                         'R':   ARI_2016_P_R,
                                         'ER':  ARI_2016_P_ER,
                                         'UER': ARI_2016_P_UER,
                                         'BB':  ARI_2016_P_BB,
                                         'SO':  ARI_2016_P_SO,
                                         'HR':  ARI_2016_P_HR,
                                         'HBP': ARI_2016_P_HBP})

# diamondbacks_offense = diamondbacks_offense.drop(columns = ['Game'])

diamondbacks_2016_pitching = diamondbacks_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [diamondbacks_2016_pitching, diamondbacks_2016_offense]

diamondbacks_2016 = pd.concat(frames, axis=1)

diamondbacks_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(diamondbacks_2016[x])):
        diamondbacks_2016.loc[y,x] = int(diamondbacks_2016.loc[y, x])

for x in columns_float:
    for y in range(len(diamondbacks_2016[x])):
        diamondbacks_2016.loc[y,x] = float(diamondbacks_2016.loc[y, x])  

for x in range(len(diamondbacks_2016['Game'])):
    if diamondbacks_2016.loc[x, 'Runs'] > diamondbacks_2016.loc[x, 'R']:
        diamondbacks_2016.loc[x, 'Win'] = 0
    else:
        diamondbacks_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Arizona Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ARI&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ARI_2015_game_num = get_stat2('team_game_num')
ARI_2015_PA = get_stat2('PA')
ARI_2015_AB = get_stat2('AB')
ARI_2015_R = get_stat2('R')
ARI_2015_H = get_stat2('H')
ARI_2015_2B = get_stat2('2B')
ARI_2015_3B = get_stat2('3B')
ARI_2015_HR = get_stat2('HR')
ARI_2015_RBI = get_stat2('RBI')
ARI_2015_BB = get_stat2('BB')
ARI_2015_SO = get_stat2('SO')
ARI_2015_SB = get_stat2('SB')
ARI_2015_CS = get_stat2('CS')
ARI_2015_BA = get_stat2('batting_avg')
ARI_2015_OBP = get_stat2('onbase_perc')
ARI_2015_SLG = get_stat2('slugging_perc')
ARI_2015_OPS = get_stat2('onbase_plus_slugging')
ARI_2015_LOB = get_stat2('LOB')
diamondbacks_2015_offense = pd.DataFrame({
                                  'PA': ARI_2015_PA,
                                  'AB': ARI_2015_AB,
                                  'R':  ARI_2015_R,
                                  'H':  ARI_2015_H,
                                  '2B': ARI_2015_2B,
                                  '3B': ARI_2015_3B, 
                                  'HR': ARI_2015_HR, 
                                  'RBI':ARI_2015_RBI,
                                  'BB': ARI_2015_BB,
                                  'SO': ARI_2015_SO,
                                  'SB': ARI_2015_SB,
                                  'CS': ARI_2015_CS,
                                  'LOB':ARI_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=ARI&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

ARI_2015_P_game_num = get_stat3('team_game_num')
ARI_2015_P_IP = get_stat3('IP')
ARI_2015_P_H = get_stat3('H')
ARI_2015_P_R = get_stat3('R')
ARI_2015_P_ER = get_stat3('ER')
ARI_2015_P_UER = get_stat3('UER')
ARI_2015_P_BB = get_stat3('BB')
ARI_2015_P_SO = get_stat3('SO')
ARI_2015_P_HR = get_stat3('HR')
ARI_2015_P_HBP = get_stat3('HBP')
ARI_2015_P_ERA = get_stat3('earned_run_avg')

diamondbacks_2015_pitching = pd.DataFrame({'Game':  ARI_2015_P_game_num, 
                                         'IP':  ARI_2015_P_IP, 
                                         'H':   ARI_2015_P_H,
                                         'R':   ARI_2015_P_R,
                                         'ER':  ARI_2015_P_ER,
                                         'UER': ARI_2015_P_UER,
                                         'BB':  ARI_2015_P_BB,
                                         'SO':  ARI_2015_P_SO,
                                         'HR':  ARI_2015_P_HR,
                                         'HBP': ARI_2015_P_HBP})

# diamondbacks_offense = diamondbacks_offense.drop(columns = ['Game'])

diamondbacks_2015_pitching = diamondbacks_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [diamondbacks_2015_pitching, diamondbacks_2015_offense]

diamondbacks_2015 = pd.concat(frames, axis=1)

diamondbacks_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(diamondbacks_2015[x])):
        diamondbacks_2015.loc[y,x] = int(diamondbacks_2015.loc[y, x])

for x in columns_float:
    for y in range(len(diamondbacks_2015[x])):
        diamondbacks_2015.loc[y,x] = float(diamondbacks_2015.loc[y, x])  

for x in range(len(diamondbacks_2015['Game'])):
    if diamondbacks_2015.loc[x, 'Runs'] > diamondbacks_2015.loc[x, 'R']:
        diamondbacks_2015.loc[x, 'Win'] = 0
    else:
        diamondbacks_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Giants Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SFG&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SFG_game_num = get_stat2('team_game_num')

SFG_PA = get_stat2('PA')

SFG_AB = get_stat2('AB')

SFG_R = get_stat2('R')

SFG_H = get_stat2('H')

SFG_2B = get_stat2('2B')

SFG_3B = get_stat2('3B')

SFG_HR = get_stat2('HR')

SFG_RBI = get_stat2('RBI')

SFG_BB = get_stat2('BB')

SFG_SO = get_stat2('SO')

SFG_SB = get_stat2('SB')

SFG_CS = get_stat2('CS')

SFG_BA = get_stat2('batting_avg')

SFG_OBP = get_stat2('onbase_perc')

SFG_SLG = get_stat2('slugging_perc')

SFG_OPS = get_stat2('onbase_plus_slugging')

SFG_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


giants_offense = pd.DataFrame({
                                  'PA': SFG_PA,
                                  'AB': SFG_AB,
                                  'R':SFG_R,
                                  'H':SFG_H,
                                  '2B':SFG_2B,
                                  '3B': SFG_3B, 
                                  'HR':SFG_HR, 
                                  'RBI':SFG_RBI,
                                  'BB':SFG_BB,
                                  'SO':SFG_SO,
                                  'SB': SFG_SB,
                                  'CS':SFG_CS,
                                  'LOB':SFG_LOB})

# %% [markdown]
# # 2019 Giants Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SFG&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SFG_P_game_num = get_stat3('team_game_num')

SFG_P_IP = get_stat3('IP')

SFG_P_H = get_stat3('H')

SFG_P_R = get_stat3('R')

SFG_P_ER = get_stat3('ER')

SFG_P_UER = get_stat3('UER')

SFG_P_BB = get_stat3('BB')

SFG_P_SO = get_stat3('SO')

SFG_P_HR = get_stat3('HR')

SFG_P_HBP = get_stat3('HBP')

SFG_P_ERA = get_stat3('earned_run_avg')

giants_pitching = pd.DataFrame({'Game': SFG_P_game_num, 
                                   'IP':SFG_P_IP, 
                                   'H':SFG_P_H,
                                   'R':SFG_P_R,
                                   'ER':SFG_P_ER,
                                   'UER':SFG_P_UER,
                                   'BB':SFG_P_BB,
                                   'SO':SFG_P_SO,
                                   'HR':SFG_P_HR,
                                   'HBP':SFG_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

giants_pitching = giants_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [giants_pitching, giants_offense]

giants = pd.concat(frames, axis=1)

giants['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(giants[x])):
        giants.loc[y,x] = int(giants.loc[y, x])

for x in columns_float:
    for y in range(len(giants[x])):
        giants.loc[y,x] = float(giants.loc[y, x])  

for x in range(len(giants['Game'])):
    if giants.loc[x, 'Runs'] > giants.loc[x, 'R']:
        giants.loc[x, 'Win'] = 0
    else:
        giants.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Giants Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SFG&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SFG_2018_game_num = get_stat2('team_game_num')
SFG_2018_PA = get_stat2('PA')
SFG_2018_AB = get_stat2('AB')
SFG_2018_R = get_stat2('R')
SFG_2018_H = get_stat2('H')
SFG_2018_2B = get_stat2('2B')
SFG_2018_3B = get_stat2('3B')
SFG_2018_HR = get_stat2('HR')
SFG_2018_RBI = get_stat2('RBI')
SFG_2018_BB = get_stat2('BB')
SFG_2018_SO = get_stat2('SO')
SFG_2018_SB = get_stat2('SB')
SFG_2018_CS = get_stat2('CS')
SFG_2018_BA = get_stat2('batting_avg')
SFG_2018_OBP = get_stat2('onbase_perc')
SFG_2018_SLG = get_stat2('slugging_perc')
SFG_2018_OPS = get_stat2('onbase_plus_slugging')
SFG_2018_LOB = get_stat2('LOB')
giants_2018_offense = pd.DataFrame({
                                  'PA': SFG_2018_PA,
                                  'AB': SFG_2018_AB,
                                  'R':  SFG_2018_R,
                                  'H':  SFG_2018_H,
                                  '2B': SFG_2018_2B,
                                  '3B': SFG_2018_3B, 
                                  'HR': SFG_2018_HR, 
                                  'RBI':SFG_2018_RBI,
                                  'BB': SFG_2018_BB,
                                  'SO': SFG_2018_SO,
                                  'SB': SFG_2018_SB,
                                  'CS': SFG_2018_CS,
                                  'LOB':SFG_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SFG&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SFG_2018_P_game_num = get_stat3('team_game_num')
SFG_2018_P_IP = get_stat3('IP')
SFG_2018_P_H = get_stat3('H')
SFG_2018_P_R = get_stat3('R')
SFG_2018_P_ER = get_stat3('ER')
SFG_2018_P_UER = get_stat3('UER')
SFG_2018_P_BB = get_stat3('BB')
SFG_2018_P_SO = get_stat3('SO')
SFG_2018_P_HR = get_stat3('HR')
SFG_2018_P_HBP = get_stat3('HBP')
SFG_2018_P_ERA = get_stat3('earned_run_avg')

giants_2018_pitching = pd.DataFrame({'Game':  SFG_2018_P_game_num, 
                                         'IP':  SFG_2018_P_IP, 
                                         'H':   SFG_2018_P_H,
                                         'R':   SFG_2018_P_R,
                                         'ER':  SFG_2018_P_ER,
                                         'UER': SFG_2018_P_UER,
                                         'BB':  SFG_2018_P_BB,
                                         'SO':  SFG_2018_P_SO,
                                         'HR':  SFG_2018_P_HR,
                                         'HBP': SFG_2018_P_HBP})

# giants_offense = giants_offense.drop(columns = ['Game'])

giants_2018_pitching = giants_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [giants_2018_pitching, giants_2018_offense]

giants_2018 = pd.concat(frames, axis=1)

giants_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(giants_2018[x])):
        giants_2018.loc[y,x] = int(giants_2018.loc[y, x])

for x in columns_float:
    for y in range(len(giants_2018[x])):
        giants_2018.loc[y,x] = float(giants_2018.loc[y, x])  

for x in range(len(giants_2018['Game'])):
    if giants_2018.loc[x, 'Runs'] > giants_2018.loc[x, 'R']:
        giants_2018.loc[x, 'Win'] = 0
    else:
        giants_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Giants Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SFG&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SFG_2017_game_num = get_stat2('team_game_num')
SFG_2017_PA = get_stat2('PA')
SFG_2017_AB = get_stat2('AB')
SFG_2017_R = get_stat2('R')
SFG_2017_H = get_stat2('H')
SFG_2017_2B = get_stat2('2B')
SFG_2017_3B = get_stat2('3B')
SFG_2017_HR = get_stat2('HR')
SFG_2017_RBI = get_stat2('RBI')
SFG_2017_BB = get_stat2('BB')
SFG_2017_SO = get_stat2('SO')
SFG_2017_SB = get_stat2('SB')
SFG_2017_CS = get_stat2('CS')
SFG_2017_BA = get_stat2('batting_avg')
SFG_2017_OBP = get_stat2('onbase_perc')
SFG_2017_SLG = get_stat2('slugging_perc')
SFG_2017_OPS = get_stat2('onbase_plus_slugging')
SFG_2017_LOB = get_stat2('LOB')
giants_2017_offense = pd.DataFrame({
                                  'PA': SFG_2017_PA,
                                  'AB': SFG_2017_AB,
                                  'R':  SFG_2017_R,
                                  'H':  SFG_2017_H,
                                  '2B': SFG_2017_2B,
                                  '3B': SFG_2017_3B, 
                                  'HR': SFG_2017_HR, 
                                  'RBI':SFG_2017_RBI,
                                  'BB': SFG_2017_BB,
                                  'SO': SFG_2017_SO,
                                  'SB': SFG_2017_SB,
                                  'CS': SFG_2017_CS,
                                  'LOB':SFG_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SFG&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SFG_2017_P_game_num = get_stat3('team_game_num')
SFG_2017_P_IP = get_stat3('IP')
SFG_2017_P_H = get_stat3('H')
SFG_2017_P_R = get_stat3('R')
SFG_2017_P_ER = get_stat3('ER')
SFG_2017_P_UER = get_stat3('UER')
SFG_2017_P_BB = get_stat3('BB')
SFG_2017_P_SO = get_stat3('SO')
SFG_2017_P_HR = get_stat3('HR')
SFG_2017_P_HBP = get_stat3('HBP')
SFG_2017_P_ERA = get_stat3('earned_run_avg')

giants_2017_pitching = pd.DataFrame({'Game':  SFG_2017_P_game_num, 
                                         'IP':  SFG_2017_P_IP, 
                                         'H':   SFG_2017_P_H,
                                         'R':   SFG_2017_P_R,
                                         'ER':  SFG_2017_P_ER,
                                         'UER': SFG_2017_P_UER,
                                         'BB':  SFG_2017_P_BB,
                                         'SO':  SFG_2017_P_SO,
                                         'HR':  SFG_2017_P_HR,
                                         'HBP': SFG_2017_P_HBP})

# giants_offense = giants_offense.drop(columns = ['Game'])

giants_2017_pitching = giants_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [giants_2017_pitching, giants_2017_offense]

giants_2017 = pd.concat(frames, axis=1)

giants_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(giants_2017[x])):
        giants_2017.loc[y,x] = int(giants_2017.loc[y, x])

for x in columns_float:
    for y in range(len(giants_2017[x])):
        giants_2017.loc[y,x] = float(giants_2017.loc[y, x])  

for x in range(len(giants_2017['Game'])):
    if giants_2017.loc[x, 'Runs'] > giants_2017.loc[x, 'R']:
        giants_2017.loc[x, 'Win'] = 0
    else:
        giants_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Giants Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SFG&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SFG_2016_game_num = get_stat2('team_game_num')
SFG_2016_PA = get_stat2('PA')
SFG_2016_AB = get_stat2('AB')
SFG_2016_R = get_stat2('R')
SFG_2016_H = get_stat2('H')
SFG_2016_2B = get_stat2('2B')
SFG_2016_3B = get_stat2('3B')
SFG_2016_HR = get_stat2('HR')
SFG_2016_RBI = get_stat2('RBI')
SFG_2016_BB = get_stat2('BB')
SFG_2016_SO = get_stat2('SO')
SFG_2016_SB = get_stat2('SB')
SFG_2016_CS = get_stat2('CS')
SFG_2016_BA = get_stat2('batting_avg')
SFG_2016_OBP = get_stat2('onbase_perc')
SFG_2016_SLG = get_stat2('slugging_perc')
SFG_2016_OPS = get_stat2('onbase_plus_slugging')
SFG_2016_LOB = get_stat2('LOB')
giants_2016_offense = pd.DataFrame({
                                  'PA': SFG_2016_PA,
                                  'AB': SFG_2016_AB,
                                  'R':  SFG_2016_R,
                                  'H':  SFG_2016_H,
                                  '2B': SFG_2016_2B,
                                  '3B': SFG_2016_3B, 
                                  'HR': SFG_2016_HR, 
                                  'RBI':SFG_2016_RBI,
                                  'BB': SFG_2016_BB,
                                  'SO': SFG_2016_SO,
                                  'SB': SFG_2016_SB,
                                  'CS': SFG_2016_CS,
                                  'LOB':SFG_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SFG&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SFG_2016_P_game_num = get_stat3('team_game_num')
SFG_2016_P_IP = get_stat3('IP')
SFG_2016_P_H = get_stat3('H')
SFG_2016_P_R = get_stat3('R')
SFG_2016_P_ER = get_stat3('ER')
SFG_2016_P_UER = get_stat3('UER')
SFG_2016_P_BB = get_stat3('BB')
SFG_2016_P_SO = get_stat3('SO')
SFG_2016_P_HR = get_stat3('HR')
SFG_2016_P_HBP = get_stat3('HBP')
SFG_2016_P_ERA = get_stat3('earned_run_avg')

giants_2016_pitching = pd.DataFrame({'Game':  SFG_2016_P_game_num, 
                                         'IP':  SFG_2016_P_IP, 
                                         'H':   SFG_2016_P_H,
                                         'R':   SFG_2016_P_R,
                                         'ER':  SFG_2016_P_ER,
                                         'UER': SFG_2016_P_UER,
                                         'BB':  SFG_2016_P_BB,
                                         'SO':  SFG_2016_P_SO,
                                         'HR':  SFG_2016_P_HR,
                                         'HBP': SFG_2016_P_HBP})

# giants_offense = giants_offense.drop(columns = ['Game'])

giants_2016_pitching = giants_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [giants_2016_pitching, giants_2016_offense]

giants_2016 = pd.concat(frames, axis=1)

giants_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(giants_2016[x])):
        giants_2016.loc[y,x] = int(giants_2016.loc[y, x])

for x in columns_float:
    for y in range(len(giants_2016[x])):
        giants_2016.loc[y,x] = float(giants_2016.loc[y, x])  

for x in range(len(giants_2016['Game'])):
    if giants_2016.loc[x, 'Runs'] > giants_2016.loc[x, 'R']:
        giants_2016.loc[x, 'Win'] = 0
    else:
        giants_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Giants Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SFG&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SFG_2015_game_num = get_stat2('team_game_num')
SFG_2015_PA = get_stat2('PA')
SFG_2015_AB = get_stat2('AB')
SFG_2015_R = get_stat2('R')
SFG_2015_H = get_stat2('H')
SFG_2015_2B = get_stat2('2B')
SFG_2015_3B = get_stat2('3B')
SFG_2015_HR = get_stat2('HR')
SFG_2015_RBI = get_stat2('RBI')
SFG_2015_BB = get_stat2('BB')
SFG_2015_SO = get_stat2('SO')
SFG_2015_SB = get_stat2('SB')
SFG_2015_CS = get_stat2('CS')
SFG_2015_BA = get_stat2('batting_avg')
SFG_2015_OBP = get_stat2('onbase_perc')
SFG_2015_SLG = get_stat2('slugging_perc')
SFG_2015_OPS = get_stat2('onbase_plus_slugging')
SFG_2015_LOB = get_stat2('LOB')
giants_2015_offense = pd.DataFrame({
                                  'PA': SFG_2015_PA,
                                  'AB': SFG_2015_AB,
                                  'R':  SFG_2015_R,
                                  'H':  SFG_2015_H,
                                  '2B': SFG_2015_2B,
                                  '3B': SFG_2015_3B, 
                                  'HR': SFG_2015_HR, 
                                  'RBI':SFG_2015_RBI,
                                  'BB': SFG_2015_BB,
                                  'SO': SFG_2015_SO,
                                  'SB': SFG_2015_SB,
                                  'CS': SFG_2015_CS,
                                  'LOB':SFG_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SFG&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SFG_2015_P_game_num = get_stat3('team_game_num')
SFG_2015_P_IP = get_stat3('IP')
SFG_2015_P_H = get_stat3('H')
SFG_2015_P_R = get_stat3('R')
SFG_2015_P_ER = get_stat3('ER')
SFG_2015_P_UER = get_stat3('UER')
SFG_2015_P_BB = get_stat3('BB')
SFG_2015_P_SO = get_stat3('SO')
SFG_2015_P_HR = get_stat3('HR')
SFG_2015_P_HBP = get_stat3('HBP')
SFG_2015_P_ERA = get_stat3('earned_run_avg')

giants_2015_pitching = pd.DataFrame({'Game':  SFG_2015_P_game_num, 
                                         'IP':  SFG_2015_P_IP, 
                                         'H':   SFG_2015_P_H,
                                         'R':   SFG_2015_P_R,
                                         'ER':  SFG_2015_P_ER,
                                         'UER': SFG_2015_P_UER,
                                         'BB':  SFG_2015_P_BB,
                                         'SO':  SFG_2015_P_SO,
                                         'HR':  SFG_2015_P_HR,
                                         'HBP': SFG_2015_P_HBP})

# giants_offense = giants_offense.drop(columns = ['Game'])

giants_2015_pitching = giants_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [giants_2015_pitching, giants_2015_offense]

giants_2015 = pd.concat(frames, axis=1)

giants_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(giants_2015[x])):
        giants_2015.loc[y,x] = int(giants_2015.loc[y, x])

for x in columns_float:
    for y in range(len(giants_2015[x])):
        giants_2015.loc[y,x] = float(giants_2015.loc[y, x])  

for x in range(len(giants_2015['Game'])):
    if giants_2015.loc[x, 'Runs'] > giants_2015.loc[x, 'R']:
        giants_2015.loc[x, 'Win'] = 0
    else:
        giants_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Padres Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SDP&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SDP_game_num = get_stat2('team_game_num')

SDP_PA = get_stat2('PA')

SDP_AB = get_stat2('AB')

SDP_R = get_stat2('R')

SDP_H = get_stat2('H')

SDP_2B = get_stat2('2B')

SDP_3B = get_stat2('3B')

SDP_HR = get_stat2('HR')

SDP_RBI = get_stat2('RBI')

SDP_BB = get_stat2('BB')

SDP_SO = get_stat2('SO')

SDP_SB = get_stat2('SB')

SDP_CS = get_stat2('CS')

SDP_BA = get_stat2('batting_avg')

SDP_OBP = get_stat2('onbase_perc')

SDP_SLG = get_stat2('slugging_perc')

SDP_OPS = get_stat2('onbase_plus_slugging')

SDP_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


padres_offense = pd.DataFrame({
                                  'PA': SDP_PA,
                                  'AB': SDP_AB,
                                  'R':  SDP_R,
                                  'H':  SDP_H,
                                  '2B': SDP_2B,
                                  '3B': SDP_3B, 
                                  'HR': SDP_HR, 
                                  'RBI':SDP_RBI,
                                  'BB': SDP_BB,
                                  'SO': SDP_SO,
                                  'SB': SDP_SB,
                                  'CS': SDP_CS,
                                  'LOB':SDP_LOB})

# %% [markdown]
# # 2019 Padres Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SDP&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SDP_P_game_num = get_stat3('team_game_num')

SDP_P_IP = get_stat3('IP')

SDP_P_H = get_stat3('H')

SDP_P_R = get_stat3('R')

SDP_P_ER = get_stat3('ER')

SDP_P_UER = get_stat3('UER')

SDP_P_BB = get_stat3('BB')

SDP_P_SO = get_stat3('SO')

SDP_P_HR = get_stat3('HR')

SDP_P_HBP = get_stat3('HBP')

SDP_P_ERA = get_stat3('earned_run_avg')

padres_pitching = pd.DataFrame({'Game':  SDP_P_game_num, 
                                   'IP': SDP_P_IP, 
                                   'H':  SDP_P_H,
                                   'R':  SDP_P_R,
                                   'ER': SDP_P_ER,
                                   'UER':SDP_P_UER,
                                   'BB': SDP_P_BB,
                                   'SO': SDP_P_SO,
                                   'HR': SDP_P_HR,
                                   'HBP':SDP_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

padres_pitching = padres_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [padres_pitching, padres_offense]

padres = pd.concat(frames, axis=1)

padres['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(padres[x])):
        padres.loc[y,x] = int(padres.loc[y, x])

for x in columns_float:
    for y in range(len(padres[x])):
        padres.loc[y,x] = float(padres.loc[y, x])  

for x in range(len(padres['Game'])):
    if padres.loc[x, 'Runs'] > padres.loc[x, 'R']:
        padres.loc[x, 'Win'] = 0
    else:
        padres.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Padres Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SDP&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SDP_2018_game_num = get_stat2('team_game_num')
SDP_2018_PA = get_stat2('PA')
SDP_2018_AB = get_stat2('AB')
SDP_2018_R = get_stat2('R')
SDP_2018_H = get_stat2('H')
SDP_2018_2B = get_stat2('2B')
SDP_2018_3B = get_stat2('3B')
SDP_2018_HR = get_stat2('HR')
SDP_2018_RBI = get_stat2('RBI')
SDP_2018_BB = get_stat2('BB')
SDP_2018_SO = get_stat2('SO')
SDP_2018_SB = get_stat2('SB')
SDP_2018_CS = get_stat2('CS')
SDP_2018_BA = get_stat2('batting_avg')
SDP_2018_OBP = get_stat2('onbase_perc')
SDP_2018_SLG = get_stat2('slugging_perc')
SDP_2018_OPS = get_stat2('onbase_plus_slugging')
SDP_2018_LOB = get_stat2('LOB')
padres_2018_offense = pd.DataFrame({
                                  'PA': SDP_2018_PA,
                                  'AB': SDP_2018_AB,
                                  'R':  SDP_2018_R,
                                  'H':  SDP_2018_H,
                                  '2B': SDP_2018_2B,
                                  '3B': SDP_2018_3B, 
                                  'HR': SDP_2018_HR, 
                                  'RBI':SDP_2018_RBI,
                                  'BB': SDP_2018_BB,
                                  'SO': SDP_2018_SO,
                                  'SB': SDP_2018_SB,
                                  'CS': SDP_2018_CS,
                                  'LOB':SDP_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SDP&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SDP_2018_P_game_num = get_stat3('team_game_num')
SDP_2018_P_IP = get_stat3('IP')
SDP_2018_P_H = get_stat3('H')
SDP_2018_P_R = get_stat3('R')
SDP_2018_P_ER = get_stat3('ER')
SDP_2018_P_UER = get_stat3('UER')
SDP_2018_P_BB = get_stat3('BB')
SDP_2018_P_SO = get_stat3('SO')
SDP_2018_P_HR = get_stat3('HR')
SDP_2018_P_HBP = get_stat3('HBP')
SDP_2018_P_ERA = get_stat3('earned_run_avg')

padres_2018_pitching = pd.DataFrame({'Game':  SDP_2018_P_game_num, 
                                         'IP':  SDP_2018_P_IP, 
                                         'H':   SDP_2018_P_H,
                                         'R':   SDP_2018_P_R,
                                         'ER':  SDP_2018_P_ER,
                                         'UER': SDP_2018_P_UER,
                                         'BB':  SDP_2018_P_BB,
                                         'SO':  SDP_2018_P_SO,
                                         'HR':  SDP_2018_P_HR,
                                         'HBP': SDP_2018_P_HBP})

# padres_offense = padres_offense.drop(columns = ['Game'])

padres_2018_pitching = padres_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [padres_2018_pitching, padres_2018_offense]

padres_2018 = pd.concat(frames, axis=1)

padres_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(padres_2018[x])):
        padres_2018.loc[y,x] = int(padres_2018.loc[y, x])

for x in columns_float:
    for y in range(len(padres_2018[x])):
        padres_2018.loc[y,x] = float(padres_2018.loc[y, x])  

for x in range(len(padres_2018['Game'])):
    if padres_2018.loc[x, 'Runs'] > padres_2018.loc[x, 'R']:
        padres_2018.loc[x, 'Win'] = 0
    else:
        padres_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Padres Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SDP&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SDP_2017_game_num = get_stat2('team_game_num')
SDP_2017_PA = get_stat2('PA')
SDP_2017_AB = get_stat2('AB')
SDP_2017_R = get_stat2('R')
SDP_2017_H = get_stat2('H')
SDP_2017_2B = get_stat2('2B')
SDP_2017_3B = get_stat2('3B')
SDP_2017_HR = get_stat2('HR')
SDP_2017_RBI = get_stat2('RBI')
SDP_2017_BB = get_stat2('BB')
SDP_2017_SO = get_stat2('SO')
SDP_2017_SB = get_stat2('SB')
SDP_2017_CS = get_stat2('CS')
SDP_2017_BA = get_stat2('batting_avg')
SDP_2017_OBP = get_stat2('onbase_perc')
SDP_2017_SLG = get_stat2('slugging_perc')
SDP_2017_OPS = get_stat2('onbase_plus_slugging')
SDP_2017_LOB = get_stat2('LOB')
padres_2017_offense = pd.DataFrame({
                                  'PA': SDP_2017_PA,
                                  'AB': SDP_2017_AB,
                                  'R':  SDP_2017_R,
                                  'H':  SDP_2017_H,
                                  '2B': SDP_2017_2B,
                                  '3B': SDP_2017_3B, 
                                  'HR': SDP_2017_HR, 
                                  'RBI':SDP_2017_RBI,
                                  'BB': SDP_2017_BB,
                                  'SO': SDP_2017_SO,
                                  'SB': SDP_2017_SB,
                                  'CS': SDP_2017_CS,
                                  'LOB':SDP_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SDP&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SDP_2017_P_game_num = get_stat3('team_game_num')
SDP_2017_P_IP = get_stat3('IP')
SDP_2017_P_H = get_stat3('H')
SDP_2017_P_R = get_stat3('R')
SDP_2017_P_ER = get_stat3('ER')
SDP_2017_P_UER = get_stat3('UER')
SDP_2017_P_BB = get_stat3('BB')
SDP_2017_P_SO = get_stat3('SO')
SDP_2017_P_HR = get_stat3('HR')
SDP_2017_P_HBP = get_stat3('HBP')
SDP_2017_P_ERA = get_stat3('earned_run_avg')

padres_2017_pitching = pd.DataFrame({'Game':  SDP_2017_P_game_num, 
                                         'IP':  SDP_2017_P_IP, 
                                         'H':   SDP_2017_P_H,
                                         'R':   SDP_2017_P_R,
                                         'ER':  SDP_2017_P_ER,
                                         'UER': SDP_2017_P_UER,
                                         'BB':  SDP_2017_P_BB,
                                         'SO':  SDP_2017_P_SO,
                                         'HR':  SDP_2017_P_HR,
                                         'HBP': SDP_2017_P_HBP})

# padres_offense = padres_offense.drop(columns = ['Game'])

padres_2017_pitching = padres_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [padres_2017_pitching, padres_2017_offense]

padres_2017 = pd.concat(frames, axis=1)

padres_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(padres_2017[x])):
        padres_2017.loc[y,x] = int(padres_2017.loc[y, x])

for x in columns_float:
    for y in range(len(padres_2017[x])):
        padres_2017.loc[y,x] = float(padres_2017.loc[y, x])  

for x in range(len(padres_2017['Game'])):
    if padres_2017.loc[x, 'Runs'] > padres_2017.loc[x, 'R']:
        padres_2017.loc[x, 'Win'] = 0
    else:
        padres_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Padres Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SDP&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SDP_2016_game_num = get_stat2('team_game_num')
SDP_2016_PA = get_stat2('PA')
SDP_2016_AB = get_stat2('AB')
SDP_2016_R = get_stat2('R')
SDP_2016_H = get_stat2('H')
SDP_2016_2B = get_stat2('2B')
SDP_2016_3B = get_stat2('3B')
SDP_2016_HR = get_stat2('HR')
SDP_2016_RBI = get_stat2('RBI')
SDP_2016_BB = get_stat2('BB')
SDP_2016_SO = get_stat2('SO')
SDP_2016_SB = get_stat2('SB')
SDP_2016_CS = get_stat2('CS')
SDP_2016_BA = get_stat2('batting_avg')
SDP_2016_OBP = get_stat2('onbase_perc')
SDP_2016_SLG = get_stat2('slugging_perc')
SDP_2016_OPS = get_stat2('onbase_plus_slugging')
SDP_2016_LOB = get_stat2('LOB')
padres_2016_offense = pd.DataFrame({
                                  'PA': SDP_2016_PA,
                                  'AB': SDP_2016_AB,
                                  'R':  SDP_2016_R,
                                  'H':  SDP_2016_H,
                                  '2B': SDP_2016_2B,
                                  '3B': SDP_2016_3B, 
                                  'HR': SDP_2016_HR, 
                                  'RBI':SDP_2016_RBI,
                                  'BB': SDP_2016_BB,
                                  'SO': SDP_2016_SO,
                                  'SB': SDP_2016_SB,
                                  'CS': SDP_2016_CS,
                                  'LOB':SDP_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SDP&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SDP_2016_P_game_num = get_stat3('team_game_num')
SDP_2016_P_IP = get_stat3('IP')
SDP_2016_P_H = get_stat3('H')
SDP_2016_P_R = get_stat3('R')
SDP_2016_P_ER = get_stat3('ER')
SDP_2016_P_UER = get_stat3('UER')
SDP_2016_P_BB = get_stat3('BB')
SDP_2016_P_SO = get_stat3('SO')
SDP_2016_P_HR = get_stat3('HR')
SDP_2016_P_HBP = get_stat3('HBP')
SDP_2016_P_ERA = get_stat3('earned_run_avg')

padres_2016_pitching = pd.DataFrame({'Game':  SDP_2016_P_game_num, 
                                         'IP':  SDP_2016_P_IP, 
                                         'H':   SDP_2016_P_H,
                                         'R':   SDP_2016_P_R,
                                         'ER':  SDP_2016_P_ER,
                                         'UER': SDP_2016_P_UER,
                                         'BB':  SDP_2016_P_BB,
                                         'SO':  SDP_2016_P_SO,
                                         'HR':  SDP_2016_P_HR,
                                         'HBP': SDP_2016_P_HBP})

# padres_offense = padres_offense.drop(columns = ['Game'])

padres_2016_pitching = padres_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [padres_2016_pitching, padres_2016_offense]

padres_2016 = pd.concat(frames, axis=1)

padres_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(padres_2016[x])):
        padres_2016.loc[y,x] = int(padres_2016.loc[y, x])

for x in columns_float:
    for y in range(len(padres_2016[x])):
        padres_2016.loc[y,x] = float(padres_2016.loc[y, x])  

for x in range(len(padres_2016['Game'])):
    if padres_2016.loc[x, 'Runs'] > padres_2016.loc[x, 'R']:
        padres_2016.loc[x, 'Win'] = 0
    else:
        padres_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Padres Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SDP&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SDP_2015_game_num = get_stat2('team_game_num')
SDP_2015_PA = get_stat2('PA')
SDP_2015_AB = get_stat2('AB')
SDP_2015_R = get_stat2('R')
SDP_2015_H = get_stat2('H')
SDP_2015_2B = get_stat2('2B')
SDP_2015_3B = get_stat2('3B')
SDP_2015_HR = get_stat2('HR')
SDP_2015_RBI = get_stat2('RBI')
SDP_2015_BB = get_stat2('BB')
SDP_2015_SO = get_stat2('SO')
SDP_2015_SB = get_stat2('SB')
SDP_2015_CS = get_stat2('CS')
SDP_2015_BA = get_stat2('batting_avg')
SDP_2015_OBP = get_stat2('onbase_perc')
SDP_2015_SLG = get_stat2('slugging_perc')
SDP_2015_OPS = get_stat2('onbase_plus_slugging')
SDP_2015_LOB = get_stat2('LOB')
padres_2015_offense = pd.DataFrame({
                                  'PA': SDP_2015_PA,
                                  'AB': SDP_2015_AB,
                                  'R':  SDP_2015_R,
                                  'H':  SDP_2015_H,
                                  '2B': SDP_2015_2B,
                                  '3B': SDP_2015_3B, 
                                  'HR': SDP_2015_HR, 
                                  'RBI':SDP_2015_RBI,
                                  'BB': SDP_2015_BB,
                                  'SO': SDP_2015_SO,
                                  'SB': SDP_2015_SB,
                                  'CS': SDP_2015_CS,
                                  'LOB':SDP_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SDP&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SDP_2015_P_game_num = get_stat3('team_game_num')
SDP_2015_P_IP = get_stat3('IP')
SDP_2015_P_H = get_stat3('H')
SDP_2015_P_R = get_stat3('R')
SDP_2015_P_ER = get_stat3('ER')
SDP_2015_P_UER = get_stat3('UER')
SDP_2015_P_BB = get_stat3('BB')
SDP_2015_P_SO = get_stat3('SO')
SDP_2015_P_HR = get_stat3('HR')
SDP_2015_P_HBP = get_stat3('HBP')
SDP_2015_P_ERA = get_stat3('earned_run_avg')

padres_2015_pitching = pd.DataFrame({'Game':  SDP_2015_P_game_num, 
                                         'IP':  SDP_2015_P_IP, 
                                         'H':   SDP_2015_P_H,
                                         'R':   SDP_2015_P_R,
                                         'ER':  SDP_2015_P_ER,
                                         'UER': SDP_2015_P_UER,
                                         'BB':  SDP_2015_P_BB,
                                         'SO':  SDP_2015_P_SO,
                                         'HR':  SDP_2015_P_HR,
                                         'HBP': SDP_2015_P_HBP})

# padres_offense = padres_offense.drop(columns = ['Game'])

padres_2015_pitching = padres_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [padres_2015_pitching, padres_2015_offense]

padres_2015 = pd.concat(frames, axis=1)

padres_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(padres_2015[x])):
        padres_2015.loc[y,x] = int(padres_2015.loc[y, x])

for x in columns_float:
    for y in range(len(padres_2015[x])):
        padres_2015.loc[y,x] = float(padres_2015.loc[y, x])  

for x in range(len(padres_2015['Game'])):
    if padres_2015.loc[x, 'Runs'] > padres_2015.loc[x, 'R']:
        padres_2015.loc[x, 'Win'] = 0
    else:
        padres_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Rockies Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=COL&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

COL_game_num = get_stat2('team_game_num')
COL_PA = get_stat2('PA')
COL_AB = get_stat2('AB')
COL_R = get_stat2('R')
COL_H = get_stat2('H')
COL_2B = get_stat2('2B')
COL_3B = get_stat2('3B')
COL_HR = get_stat2('HR')
COL_RBI = get_stat2('RBI')
COL_BB = get_stat2('BB')
COL_SO = get_stat2('SO')
COL_SB = get_stat2('SB')
COL_CS = get_stat2('CS')
COL_BA = get_stat2('batting_avg')
COL_OBP = get_stat2('onbase_perc')
COL_SLG = get_stat2('slugging_perc')
COL_OPS = get_stat2('onbase_plus_slugging')
COL_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


rockies_offense = pd.DataFrame({
                                  'PA': COL_PA,
                                  'AB': COL_AB,
                                  'R':  COL_R,
                                  'H':  COL_H,
                                  '2B': COL_2B,
                                  '3B': COL_3B, 
                                  'HR': COL_HR, 
                                  'RBI':COL_RBI,
                                  'BB': COL_BB,
                                  'SO': COL_SO,
                                  'SB': COL_SB,
                                  'CS': COL_CS,
                                  'LOB':COL_LOB})

# %% [markdown]
# # 2019 Rockies Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=COL&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

COL_P_game_num = get_stat3('team_game_num')
COL_P_IP = get_stat3('IP')
COL_P_H = get_stat3('H')
COL_P_R = get_stat3('R')
COL_P_ER = get_stat3('ER')
COL_P_UER = get_stat3('UER')
COL_P_BB = get_stat3('BB')
COL_P_SO = get_stat3('SO')
COL_P_HR = get_stat3('HR')
COL_P_HBP = get_stat3('HBP')
COL_P_ERA = get_stat3('earned_run_avg')

rockies_pitching = pd.DataFrame({'Game':  COL_P_game_num, 
                                   'IP':  COL_P_IP, 
                                   'H':   COL_P_H,
                                   'R':   COL_P_R,
                                   'ER':  COL_P_ER,
                                   'UER': COL_P_UER,
                                   'BB':  COL_P_BB,
                                   'SO':  COL_P_SO,
                                   'HR':  COL_P_HR,
                                   'HBP': COL_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

rockies_pitching = rockies_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rockies_pitching, rockies_offense]

rockies = pd.concat(frames, axis=1)

rockies['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rockies[x])):
        rockies.loc[y,x] = int(rockies.loc[y, x])

for x in columns_float:
    for y in range(len(rockies[x])):
        rockies.loc[y,x] = float(rockies.loc[y, x])  

for x in range(len(rockies['Game'])):
    if rockies.loc[x, 'Runs'] > rockies.loc[x, 'R']:
        rockies.loc[x, 'Win'] = 0
    else:
        rockies.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Rockies Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=COL&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

COL_2018_game_num = get_stat2('team_game_num')
COL_2018_PA = get_stat2('PA')
COL_2018_AB = get_stat2('AB')
COL_2018_R = get_stat2('R')
COL_2018_H = get_stat2('H')
COL_2018_2B = get_stat2('2B')
COL_2018_3B = get_stat2('3B')
COL_2018_HR = get_stat2('HR')
COL_2018_RBI = get_stat2('RBI')
COL_2018_BB = get_stat2('BB')
COL_2018_SO = get_stat2('SO')
COL_2018_SB = get_stat2('SB')
COL_2018_CS = get_stat2('CS')
COL_2018_BA = get_stat2('batting_avg')
COL_2018_OBP = get_stat2('onbase_perc')
COL_2018_SLG = get_stat2('slugging_perc')
COL_2018_OPS = get_stat2('onbase_plus_slugging')
COL_2018_LOB = get_stat2('LOB')
rockies_2018_offense = pd.DataFrame({
                                  'PA': COL_2018_PA,
                                  'AB': COL_2018_AB,
                                  'R':  COL_2018_R,
                                  'H':  COL_2018_H,
                                  '2B': COL_2018_2B,
                                  '3B': COL_2018_3B, 
                                  'HR': COL_2018_HR, 
                                  'RBI':COL_2018_RBI,
                                  'BB': COL_2018_BB,
                                  'SO': COL_2018_SO,
                                  'SB': COL_2018_SB,
                                  'CS': COL_2018_CS,
                                  'LOB':COL_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=COL&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

COL_2018_P_game_num = get_stat3('team_game_num')
COL_2018_P_IP = get_stat3('IP')
COL_2018_P_H = get_stat3('H')
COL_2018_P_R = get_stat3('R')
COL_2018_P_ER = get_stat3('ER')
COL_2018_P_UER = get_stat3('UER')
COL_2018_P_BB = get_stat3('BB')
COL_2018_P_SO = get_stat3('SO')
COL_2018_P_HR = get_stat3('HR')
COL_2018_P_HBP = get_stat3('HBP')
COL_2018_P_ERA = get_stat3('earned_run_avg')

rockies_2018_pitching = pd.DataFrame({'Game':  COL_2018_P_game_num, 
                                         'IP':  COL_2018_P_IP, 
                                         'H':   COL_2018_P_H,
                                         'R':   COL_2018_P_R,
                                         'ER':  COL_2018_P_ER,
                                         'UER': COL_2018_P_UER,
                                         'BB':  COL_2018_P_BB,
                                         'SO':  COL_2018_P_SO,
                                         'HR':  COL_2018_P_HR,
                                         'HBP': COL_2018_P_HBP})

# rockies_offense = rockies_offense.drop(columns = ['Game'])

rockies_2018_pitching = rockies_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rockies_2018_pitching, rockies_2018_offense]

rockies_2018 = pd.concat(frames, axis=1)

rockies_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rockies_2018[x])):
        rockies_2018.loc[y,x] = int(rockies_2018.loc[y, x])

for x in columns_float:
    for y in range(len(rockies_2018[x])):
        rockies_2018.loc[y,x] = float(rockies_2018.loc[y, x])  

for x in range(len(rockies_2018['Game'])):
    if rockies_2018.loc[x, 'Runs'] > rockies_2018.loc[x, 'R']:
        rockies_2018.loc[x, 'Win'] = 0
    else:
        rockies_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Rockies Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=COL&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

COL_2017_game_num = get_stat2('team_game_num')
COL_2017_PA = get_stat2('PA')
COL_2017_AB = get_stat2('AB')
COL_2017_R = get_stat2('R')
COL_2017_H = get_stat2('H')
COL_2017_2B = get_stat2('2B')
COL_2017_3B = get_stat2('3B')
COL_2017_HR = get_stat2('HR')
COL_2017_RBI = get_stat2('RBI')
COL_2017_BB = get_stat2('BB')
COL_2017_SO = get_stat2('SO')
COL_2017_SB = get_stat2('SB')
COL_2017_CS = get_stat2('CS')
COL_2017_BA = get_stat2('batting_avg')
COL_2017_OBP = get_stat2('onbase_perc')
COL_2017_SLG = get_stat2('slugging_perc')
COL_2017_OPS = get_stat2('onbase_plus_slugging')
COL_2017_LOB = get_stat2('LOB')
rockies_2017_offense = pd.DataFrame({
                                  'PA': COL_2017_PA,
                                  'AB': COL_2017_AB,
                                  'R':  COL_2017_R,
                                  'H':  COL_2017_H,
                                  '2B': COL_2017_2B,
                                  '3B': COL_2017_3B, 
                                  'HR': COL_2017_HR, 
                                  'RBI':COL_2017_RBI,
                                  'BB': COL_2017_BB,
                                  'SO': COL_2017_SO,
                                  'SB': COL_2017_SB,
                                  'CS': COL_2017_CS,
                                  'LOB':COL_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=COL&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

COL_2017_P_game_num = get_stat3('team_game_num')
COL_2017_P_IP = get_stat3('IP')
COL_2017_P_H = get_stat3('H')
COL_2017_P_R = get_stat3('R')
COL_2017_P_ER = get_stat3('ER')
COL_2017_P_UER = get_stat3('UER')
COL_2017_P_BB = get_stat3('BB')
COL_2017_P_SO = get_stat3('SO')
COL_2017_P_HR = get_stat3('HR')
COL_2017_P_HBP = get_stat3('HBP')
COL_2017_P_ERA = get_stat3('earned_run_avg')

rockies_2017_pitching = pd.DataFrame({'Game':  COL_2017_P_game_num, 
                                         'IP':  COL_2017_P_IP, 
                                         'H':   COL_2017_P_H,
                                         'R':   COL_2017_P_R,
                                         'ER':  COL_2017_P_ER,
                                         'UER': COL_2017_P_UER,
                                         'BB':  COL_2017_P_BB,
                                         'SO':  COL_2017_P_SO,
                                         'HR':  COL_2017_P_HR,
                                         'HBP': COL_2017_P_HBP})

# rockies_offense = rockies_offense.drop(columns = ['Game'])

rockies_2017_pitching = rockies_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rockies_2017_pitching, rockies_2017_offense]

rockies_2017 = pd.concat(frames, axis=1)

rockies_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rockies_2017[x])):
        rockies_2017.loc[y,x] = int(rockies_2017.loc[y, x])

for x in columns_float:
    for y in range(len(rockies_2017[x])):
        rockies_2017.loc[y,x] = float(rockies_2017.loc[y, x])  

for x in range(len(rockies_2017['Game'])):
    if rockies_2017.loc[x, 'Runs'] > rockies_2017.loc[x, 'R']:
        rockies_2017.loc[x, 'Win'] = 0
    else:
        rockies_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Rockies Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=COL&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

COL_2016_game_num = get_stat2('team_game_num')
COL_2016_PA = get_stat2('PA')
COL_2016_AB = get_stat2('AB')
COL_2016_R = get_stat2('R')
COL_2016_H = get_stat2('H')
COL_2016_2B = get_stat2('2B')
COL_2016_3B = get_stat2('3B')
COL_2016_HR = get_stat2('HR')
COL_2016_RBI = get_stat2('RBI')
COL_2016_BB = get_stat2('BB')
COL_2016_SO = get_stat2('SO')
COL_2016_SB = get_stat2('SB')
COL_2016_CS = get_stat2('CS')
COL_2016_BA = get_stat2('batting_avg')
COL_2016_OBP = get_stat2('onbase_perc')
COL_2016_SLG = get_stat2('slugging_perc')
COL_2016_OPS = get_stat2('onbase_plus_slugging')
COL_2016_LOB = get_stat2('LOB')
rockies_2016_offense = pd.DataFrame({
                                  'PA': COL_2016_PA,
                                  'AB': COL_2016_AB,
                                  'R':  COL_2016_R,
                                  'H':  COL_2016_H,
                                  '2B': COL_2016_2B,
                                  '3B': COL_2016_3B, 
                                  'HR': COL_2016_HR, 
                                  'RBI':COL_2016_RBI,
                                  'BB': COL_2016_BB,
                                  'SO': COL_2016_SO,
                                  'SB': COL_2016_SB,
                                  'CS': COL_2016_CS,
                                  'LOB':COL_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=COL&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

COL_2016_P_game_num = get_stat3('team_game_num')
COL_2016_P_IP = get_stat3('IP')
COL_2016_P_H = get_stat3('H')
COL_2016_P_R = get_stat3('R')
COL_2016_P_ER = get_stat3('ER')
COL_2016_P_UER = get_stat3('UER')
COL_2016_P_BB = get_stat3('BB')
COL_2016_P_SO = get_stat3('SO')
COL_2016_P_HR = get_stat3('HR')
COL_2016_P_HBP = get_stat3('HBP')
COL_2016_P_ERA = get_stat3('earned_run_avg')

rockies_2016_pitching = pd.DataFrame({'Game':  COL_2016_P_game_num, 
                                         'IP':  COL_2016_P_IP, 
                                         'H':   COL_2016_P_H,
                                         'R':   COL_2016_P_R,
                                         'ER':  COL_2016_P_ER,
                                         'UER': COL_2016_P_UER,
                                         'BB':  COL_2016_P_BB,
                                         'SO':  COL_2016_P_SO,
                                         'HR':  COL_2016_P_HR,
                                         'HBP': COL_2016_P_HBP})

# rockies_offense = rockies_offense.drop(columns = ['Game'])

rockies_2016_pitching = rockies_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rockies_2016_pitching, rockies_2016_offense]

rockies_2016 = pd.concat(frames, axis=1)

rockies_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rockies_2016[x])):
        rockies_2016.loc[y,x] = int(rockies_2016.loc[y, x])

for x in columns_float:
    for y in range(len(rockies_2016[x])):
        rockies_2016.loc[y,x] = float(rockies_2016.loc[y, x])  

for x in range(len(rockies_2016['Game'])):
    if rockies_2016.loc[x, 'Runs'] > rockies_2016.loc[x, 'R']:
        rockies_2016.loc[x, 'Win'] = 0
    else:
        rockies_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Rockies Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=COL&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

COL_2015_game_num = get_stat2('team_game_num')
COL_2015_PA = get_stat2('PA')
COL_2015_AB = get_stat2('AB')
COL_2015_R = get_stat2('R')
COL_2015_H = get_stat2('H')
COL_2015_2B = get_stat2('2B')
COL_2015_3B = get_stat2('3B')
COL_2015_HR = get_stat2('HR')
COL_2015_RBI = get_stat2('RBI')
COL_2015_BB = get_stat2('BB')
COL_2015_SO = get_stat2('SO')
COL_2015_SB = get_stat2('SB')
COL_2015_CS = get_stat2('CS')
COL_2015_BA = get_stat2('batting_avg')
COL_2015_OBP = get_stat2('onbase_perc')
COL_2015_SLG = get_stat2('slugging_perc')
COL_2015_OPS = get_stat2('onbase_plus_slugging')
COL_2015_LOB = get_stat2('LOB')
rockies_2015_offense = pd.DataFrame({
                                  'PA': COL_2015_PA,
                                  'AB': COL_2015_AB,
                                  'R':  COL_2015_R,
                                  'H':  COL_2015_H,
                                  '2B': COL_2015_2B,
                                  '3B': COL_2015_3B, 
                                  'HR': COL_2015_HR, 
                                  'RBI':COL_2015_RBI,
                                  'BB': COL_2015_BB,
                                  'SO': COL_2015_SO,
                                  'SB': COL_2015_SB,
                                  'CS': COL_2015_CS,
                                  'LOB':COL_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=COL&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

COL_2015_P_game_num = get_stat3('team_game_num')
COL_2015_P_IP = get_stat3('IP')
COL_2015_P_H = get_stat3('H')
COL_2015_P_R = get_stat3('R')
COL_2015_P_ER = get_stat3('ER')
COL_2015_P_UER = get_stat3('UER')
COL_2015_P_BB = get_stat3('BB')
COL_2015_P_SO = get_stat3('SO')
COL_2015_P_HR = get_stat3('HR')
COL_2015_P_HBP = get_stat3('HBP')
COL_2015_P_ERA = get_stat3('earned_run_avg')

rockies_2015_pitching = pd.DataFrame({'Game':  COL_2015_P_game_num, 
                                         'IP':  COL_2015_P_IP, 
                                         'H':   COL_2015_P_H,
                                         'R':   COL_2015_P_R,
                                         'ER':  COL_2015_P_ER,
                                         'UER': COL_2015_P_UER,
                                         'BB':  COL_2015_P_BB,
                                         'SO':  COL_2015_P_SO,
                                         'HR':  COL_2015_P_HR,
                                         'HBP': COL_2015_P_HBP})

# rockies_offense = rockies_offense.drop(columns = ['Game'])

rockies_2015_pitching = rockies_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rockies_2015_pitching, rockies_2015_offense]

rockies_2015 = pd.concat(frames, axis=1)

rockies_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rockies_2015[x])):
        rockies_2015.loc[y,x] = int(rockies_2015.loc[y, x])

for x in columns_float:
    for y in range(len(rockies_2015[x])):
        rockies_2015.loc[y,x] = float(rockies_2015.loc[y, x])  

for x in range(len(rockies_2015['Game'])):
    if rockies_2015.loc[x, 'Runs'] > rockies_2015.loc[x, 'R']:
        rockies_2015.loc[x, 'Win'] = 0
    else:
        rockies_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Yankees Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYY&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYY_game_num = get_stat2('team_game_num')
NYY_PA = get_stat2('PA')
NYY_AB = get_stat2('AB')
NYY_R = get_stat2('R')
NYY_H = get_stat2('H')
NYY_2B = get_stat2('2B')
NYY_3B = get_stat2('3B')
NYY_HR = get_stat2('HR')
NYY_RBI = get_stat2('RBI')
NYY_BB = get_stat2('BB')
NYY_SO = get_stat2('SO')
NYY_SB = get_stat2('SB')
NYY_CS = get_stat2('CS')
NYY_BA = get_stat2('batting_avg')
NYY_OBP = get_stat2('onbase_perc')
NYY_SLG = get_stat2('slugging_perc')
NYY_OPS = get_stat2('onbase_plus_slugging')
NYY_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


yankees_offense = pd.DataFrame({
                                  'PA': NYY_PA,
                                  'AB': NYY_AB,
                                  'R':  NYY_R,
                                  'H':  NYY_H,
                                  '2B': NYY_2B,
                                  '3B': NYY_3B, 
                                  'HR': NYY_HR, 
                                  'RBI':NYY_RBI,
                                  'BB': NYY_BB,
                                  'SO': NYY_SO,
                                  'SB': NYY_SB,
                                  'CS': NYY_CS,
                                  'LOB':NYY_LOB})

# %% [markdown]
# # 2019 Yankees Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYY&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYY_P_game_num = get_stat3('team_game_num')
NYY_P_IP = get_stat3('IP')
NYY_P_H = get_stat3('H')
NYY_P_R = get_stat3('R')
NYY_P_ER = get_stat3('ER')
NYY_P_UER = get_stat3('UER')
NYY_P_BB = get_stat3('BB')
NYY_P_SO = get_stat3('SO')
NYY_P_HR = get_stat3('HR')
NYY_P_HBP = get_stat3('HBP')
NYY_P_ERA = get_stat3('earned_run_avg')

yankees_pitching = pd.DataFrame({'Game':  NYY_P_game_num, 
                                   'IP':  NYY_P_IP, 
                                   'H':   NYY_P_H,
                                   'R':   NYY_P_R,
                                   'ER':  NYY_P_ER,
                                   'UER': NYY_P_UER,
                                   'BB':  NYY_P_BB,
                                   'SO':  NYY_P_SO,
                                   'HR':  NYY_P_HR,
                                   'HBP': NYY_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

yankees_pitching = yankees_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [yankees_pitching, yankees_offense]

yankees = pd.concat(frames, axis=1)

yankees['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(yankees[x])):
        yankees.loc[y,x] = int(yankees.loc[y, x])

for x in columns_float:
    for y in range(len(yankees[x])):
        yankees.loc[y,x] = float(yankees.loc[y, x])  

for x in range(len(yankees['Game'])):
    if yankees.loc[x, 'Runs'] > yankees.loc[x, 'R']:
        yankees.loc[x, 'Win'] = 0
    else:
        yankees.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Yankees Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYY&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYY_2018_game_num = get_stat2('team_game_num')
NYY_2018_PA = get_stat2('PA')
NYY_2018_AB = get_stat2('AB')
NYY_2018_R = get_stat2('R')
NYY_2018_H = get_stat2('H')
NYY_2018_2B = get_stat2('2B')
NYY_2018_3B = get_stat2('3B')
NYY_2018_HR = get_stat2('HR')
NYY_2018_RBI = get_stat2('RBI')
NYY_2018_BB = get_stat2('BB')
NYY_2018_SO = get_stat2('SO')
NYY_2018_SB = get_stat2('SB')
NYY_2018_CS = get_stat2('CS')
NYY_2018_BA = get_stat2('batting_avg')
NYY_2018_OBP = get_stat2('onbase_perc')
NYY_2018_SLG = get_stat2('slugging_perc')
NYY_2018_OPS = get_stat2('onbase_plus_slugging')
NYY_2018_LOB = get_stat2('LOB')
yankees_2018_offense = pd.DataFrame({
                                  'PA': NYY_2018_PA,
                                  'AB': NYY_2018_AB,
                                  'R':  NYY_2018_R,
                                  'H':  NYY_2018_H,
                                  '2B': NYY_2018_2B,
                                  '3B': NYY_2018_3B, 
                                  'HR': NYY_2018_HR, 
                                  'RBI':NYY_2018_RBI,
                                  'BB': NYY_2018_BB,
                                  'SO': NYY_2018_SO,
                                  'SB': NYY_2018_SB,
                                  'CS': NYY_2018_CS,
                                  'LOB':NYY_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYY&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYY_2018_P_game_num = get_stat3('team_game_num')
NYY_2018_P_IP = get_stat3('IP')
NYY_2018_P_H = get_stat3('H')
NYY_2018_P_R = get_stat3('R')
NYY_2018_P_ER = get_stat3('ER')
NYY_2018_P_UER = get_stat3('UER')
NYY_2018_P_BB = get_stat3('BB')
NYY_2018_P_SO = get_stat3('SO')
NYY_2018_P_HR = get_stat3('HR')
NYY_2018_P_HBP = get_stat3('HBP')
NYY_2018_P_ERA = get_stat3('earned_run_avg')

yankees_2018_pitching = pd.DataFrame({'Game':  NYY_2018_P_game_num, 
                                         'IP':  NYY_2018_P_IP, 
                                         'H':   NYY_2018_P_H,
                                         'R':   NYY_2018_P_R,
                                         'ER':  NYY_2018_P_ER,
                                         'UER': NYY_2018_P_UER,
                                         'BB':  NYY_2018_P_BB,
                                         'SO':  NYY_2018_P_SO,
                                         'HR':  NYY_2018_P_HR,
                                         'HBP': NYY_2018_P_HBP})

# yankees_offense = yankees_offense.drop(columns = ['Game'])

yankees_2018_pitching = yankees_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [yankees_2018_pitching, yankees_2018_offense]

yankees_2018 = pd.concat(frames, axis=1)

yankees_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(yankees_2018[x])):
        yankees_2018.loc[y,x] = int(yankees_2018.loc[y, x])

for x in columns_float:
    for y in range(len(yankees_2018[x])):
        yankees_2018.loc[y,x] = float(yankees_2018.loc[y, x])  

for x in range(len(yankees_2018['Game'])):
    if yankees_2018.loc[x, 'Runs'] > yankees_2018.loc[x, 'R']:
        yankees_2018.loc[x, 'Win'] = 0
    else:
        yankees_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Yankees Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYY&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYY_2017_game_num = get_stat2('team_game_num')
NYY_2017_PA = get_stat2('PA')
NYY_2017_AB = get_stat2('AB')
NYY_2017_R = get_stat2('R')
NYY_2017_H = get_stat2('H')
NYY_2017_2B = get_stat2('2B')
NYY_2017_3B = get_stat2('3B')
NYY_2017_HR = get_stat2('HR')
NYY_2017_RBI = get_stat2('RBI')
NYY_2017_BB = get_stat2('BB')
NYY_2017_SO = get_stat2('SO')
NYY_2017_SB = get_stat2('SB')
NYY_2017_CS = get_stat2('CS')
NYY_2017_BA = get_stat2('batting_avg')
NYY_2017_OBP = get_stat2('onbase_perc')
NYY_2017_SLG = get_stat2('slugging_perc')
NYY_2017_OPS = get_stat2('onbase_plus_slugging')
NYY_2017_LOB = get_stat2('LOB')
yankees_2017_offense = pd.DataFrame({
                                  'PA': NYY_2017_PA,
                                  'AB': NYY_2017_AB,
                                  'R':  NYY_2017_R,
                                  'H':  NYY_2017_H,
                                  '2B': NYY_2017_2B,
                                  '3B': NYY_2017_3B, 
                                  'HR': NYY_2017_HR, 
                                  'RBI':NYY_2017_RBI,
                                  'BB': NYY_2017_BB,
                                  'SO': NYY_2017_SO,
                                  'SB': NYY_2017_SB,
                                  'CS': NYY_2017_CS,
                                  'LOB':NYY_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYY&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYY_2017_P_game_num = get_stat3('team_game_num')
NYY_2017_P_IP = get_stat3('IP')
NYY_2017_P_H = get_stat3('H')
NYY_2017_P_R = get_stat3('R')
NYY_2017_P_ER = get_stat3('ER')
NYY_2017_P_UER = get_stat3('UER')
NYY_2017_P_BB = get_stat3('BB')
NYY_2017_P_SO = get_stat3('SO')
NYY_2017_P_HR = get_stat3('HR')
NYY_2017_P_HBP = get_stat3('HBP')
NYY_2017_P_ERA = get_stat3('earned_run_avg')

yankees_2017_pitching = pd.DataFrame({'Game':  NYY_2017_P_game_num, 
                                         'IP':  NYY_2017_P_IP, 
                                         'H':   NYY_2017_P_H,
                                         'R':   NYY_2017_P_R,
                                         'ER':  NYY_2017_P_ER,
                                         'UER': NYY_2017_P_UER,
                                         'BB':  NYY_2017_P_BB,
                                         'SO':  NYY_2017_P_SO,
                                         'HR':  NYY_2017_P_HR,
                                         'HBP': NYY_2017_P_HBP})

# yankees_offense = yankees_offense.drop(columns = ['Game'])

yankees_2017_pitching = yankees_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [yankees_2017_pitching, yankees_2017_offense]

yankees_2017 = pd.concat(frames, axis=1)

yankees_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(yankees_2017[x])):
        yankees_2017.loc[y,x] = int(yankees_2017.loc[y, x])

for x in columns_float:
    for y in range(len(yankees_2017[x])):
        yankees_2017.loc[y,x] = float(yankees_2017.loc[y, x])  

for x in range(len(yankees_2017['Game'])):
    if yankees_2017.loc[x, 'Runs'] > yankees_2017.loc[x, 'R']:
        yankees_2017.loc[x, 'Win'] = 0
    else:
        yankees_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Yankees Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYY&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYY_2016_game_num = get_stat2('team_game_num')
NYY_2016_PA = get_stat2('PA')
NYY_2016_AB = get_stat2('AB')
NYY_2016_R = get_stat2('R')
NYY_2016_H = get_stat2('H')
NYY_2016_2B = get_stat2('2B')
NYY_2016_3B = get_stat2('3B')
NYY_2016_HR = get_stat2('HR')
NYY_2016_RBI = get_stat2('RBI')
NYY_2016_BB = get_stat2('BB')
NYY_2016_SO = get_stat2('SO')
NYY_2016_SB = get_stat2('SB')
NYY_2016_CS = get_stat2('CS')
NYY_2016_BA = get_stat2('batting_avg')
NYY_2016_OBP = get_stat2('onbase_perc')
NYY_2016_SLG = get_stat2('slugging_perc')
NYY_2016_OPS = get_stat2('onbase_plus_slugging')
NYY_2016_LOB = get_stat2('LOB')
yankees_2016_offense = pd.DataFrame({
                                  'PA': NYY_2016_PA,
                                  'AB': NYY_2016_AB,
                                  'R':  NYY_2016_R,
                                  'H':  NYY_2016_H,
                                  '2B': NYY_2016_2B,
                                  '3B': NYY_2016_3B, 
                                  'HR': NYY_2016_HR, 
                                  'RBI':NYY_2016_RBI,
                                  'BB': NYY_2016_BB,
                                  'SO': NYY_2016_SO,
                                  'SB': NYY_2016_SB,
                                  'CS': NYY_2016_CS,
                                  'LOB':NYY_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYY&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYY_2016_P_game_num = get_stat3('team_game_num')
NYY_2016_P_IP = get_stat3('IP')
NYY_2016_P_H = get_stat3('H')
NYY_2016_P_R = get_stat3('R')
NYY_2016_P_ER = get_stat3('ER')
NYY_2016_P_UER = get_stat3('UER')
NYY_2016_P_BB = get_stat3('BB')
NYY_2016_P_SO = get_stat3('SO')
NYY_2016_P_HR = get_stat3('HR')
NYY_2016_P_HBP = get_stat3('HBP')
NYY_2016_P_ERA = get_stat3('earned_run_avg')

yankees_2016_pitching = pd.DataFrame({'Game':  NYY_2016_P_game_num, 
                                         'IP':  NYY_2016_P_IP, 
                                         'H':   NYY_2016_P_H,
                                         'R':   NYY_2016_P_R,
                                         'ER':  NYY_2016_P_ER,
                                         'UER': NYY_2016_P_UER,
                                         'BB':  NYY_2016_P_BB,
                                         'SO':  NYY_2016_P_SO,
                                         'HR':  NYY_2016_P_HR,
                                         'HBP': NYY_2016_P_HBP})

# yankees_offense = yankees_offense.drop(columns = ['Game'])

yankees_2016_pitching = yankees_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [yankees_2016_pitching, yankees_2016_offense]

yankees_2016 = pd.concat(frames, axis=1)

yankees_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(yankees_2016[x])):
        yankees_2016.loc[y,x] = int(yankees_2016.loc[y, x])

for x in columns_float:
    for y in range(len(yankees_2016[x])):
        yankees_2016.loc[y,x] = float(yankees_2016.loc[y, x])  

for x in range(len(yankees_2016['Game'])):
    if yankees_2016.loc[x, 'Runs'] > yankees_2016.loc[x, 'R']:
        yankees_2016.loc[x, 'Win'] = 0
    else:
        yankees_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Yankees Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYY&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYY_2015_game_num = get_stat2('team_game_num')
NYY_2015_PA = get_stat2('PA')
NYY_2015_AB = get_stat2('AB')
NYY_2015_R = get_stat2('R')
NYY_2015_H = get_stat2('H')
NYY_2015_2B = get_stat2('2B')
NYY_2015_3B = get_stat2('3B')
NYY_2015_HR = get_stat2('HR')
NYY_2015_RBI = get_stat2('RBI')
NYY_2015_BB = get_stat2('BB')
NYY_2015_SO = get_stat2('SO')
NYY_2015_SB = get_stat2('SB')
NYY_2015_CS = get_stat2('CS')
NYY_2015_BA = get_stat2('batting_avg')
NYY_2015_OBP = get_stat2('onbase_perc')
NYY_2015_SLG = get_stat2('slugging_perc')
NYY_2015_OPS = get_stat2('onbase_plus_slugging')
NYY_2015_LOB = get_stat2('LOB')
yankees_2015_offense = pd.DataFrame({
                                  'PA': NYY_2015_PA,
                                  'AB': NYY_2015_AB,
                                  'R':  NYY_2015_R,
                                  'H':  NYY_2015_H,
                                  '2B': NYY_2015_2B,
                                  '3B': NYY_2015_3B, 
                                  'HR': NYY_2015_HR, 
                                  'RBI':NYY_2015_RBI,
                                  'BB': NYY_2015_BB,
                                  'SO': NYY_2015_SO,
                                  'SB': NYY_2015_SB,
                                  'CS': NYY_2015_CS,
                                  'LOB':NYY_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=NYY&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

NYY_2015_P_game_num = get_stat3('team_game_num')
NYY_2015_P_IP = get_stat3('IP')
NYY_2015_P_H = get_stat3('H')
NYY_2015_P_R = get_stat3('R')
NYY_2015_P_ER = get_stat3('ER')
NYY_2015_P_UER = get_stat3('UER')
NYY_2015_P_BB = get_stat3('BB')
NYY_2015_P_SO = get_stat3('SO')
NYY_2015_P_HR = get_stat3('HR')
NYY_2015_P_HBP = get_stat3('HBP')
NYY_2015_P_ERA = get_stat3('earned_run_avg')

yankees_2015_pitching = pd.DataFrame({'Game':  NYY_2015_P_game_num, 
                                         'IP':  NYY_2015_P_IP, 
                                         'H':   NYY_2015_P_H,
                                         'R':   NYY_2015_P_R,
                                         'ER':  NYY_2015_P_ER,
                                         'UER': NYY_2015_P_UER,
                                         'BB':  NYY_2015_P_BB,
                                         'SO':  NYY_2015_P_SO,
                                         'HR':  NYY_2015_P_HR,
                                         'HBP': NYY_2015_P_HBP})

# yankees_offense = yankees_offense.drop(columns = ['Game'])

yankees_2015_pitching = yankees_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [yankees_2015_pitching, yankees_2015_offense]

yankees_2015 = pd.concat(frames, axis=1)

yankees_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(yankees_2015[x])):
        yankees_2015.loc[y,x] = int(yankees_2015.loc[y, x])

for x in columns_float:
    for y in range(len(yankees_2015[x])):
        yankees_2015.loc[y,x] = float(yankees_2015.loc[y, x])  

for x in range(len(yankees_2015['Game'])):
    if yankees_2015.loc[x, 'Runs'] > yankees_2015.loc[x, 'R']:
        yankees_2015.loc[x, 'Win'] = 0
    else:
        yankees_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Red Sox Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BOS&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BOS_game_num = get_stat2('team_game_num')
BOS_PA = get_stat2('PA')
BOS_AB = get_stat2('AB')
BOS_R = get_stat2('R')
BOS_H = get_stat2('H')
BOS_2B = get_stat2('2B')
BOS_3B = get_stat2('3B')
BOS_HR = get_stat2('HR')
BOS_RBI = get_stat2('RBI')
BOS_BB = get_stat2('BB')
BOS_SO = get_stat2('SO')
BOS_SB = get_stat2('SB')
BOS_CS = get_stat2('CS')
BOS_BA = get_stat2('batting_avg')
BOS_OBP = get_stat2('onbase_perc')
BOS_SLG = get_stat2('slugging_perc')
BOS_OPS = get_stat2('onbase_plus_slugging')
BOS_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


red_sox_offense = pd.DataFrame({
                                  'PA': BOS_PA,
                                  'AB': BOS_AB,
                                  'R':  BOS_R,
                                  'H':  BOS_H,
                                  '2B': BOS_2B,
                                  '3B': BOS_3B, 
                                  'HR': BOS_HR, 
                                  'RBI':BOS_RBI,
                                  'BB': BOS_BB,
                                  'SO': BOS_SO,
                                  'SB': BOS_SB,
                                  'CS': BOS_CS,
                                  'LOB':BOS_LOB})

# %% [markdown]
# # 2019 Red Sox Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BOS&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BOS_P_game_num = get_stat3('team_game_num')
BOS_P_IP = get_stat3('IP')
BOS_P_H = get_stat3('H')
BOS_P_R = get_stat3('R')
BOS_P_ER = get_stat3('ER')
BOS_P_UER = get_stat3('UER')
BOS_P_BB = get_stat3('BB')
BOS_P_SO = get_stat3('SO')
BOS_P_HR = get_stat3('HR')
BOS_P_HBP = get_stat3('HBP')
BOS_P_ERA = get_stat3('earned_run_avg')

red_sox_pitching = pd.DataFrame({'Game':  BOS_P_game_num, 
                                   'IP':  BOS_P_IP, 
                                   'H':   BOS_P_H,
                                   'R':   BOS_P_R,
                                   'ER':  BOS_P_ER,
                                   'UER': BOS_P_UER,
                                   'BB':  BOS_P_BB,
                                   'SO':  BOS_P_SO,
                                   'HR':  BOS_P_HR,
                                   'HBP': BOS_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

red_sox_pitching = red_sox_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [red_sox_pitching, red_sox_offense]

red_sox = pd.concat(frames, axis=1)

red_sox['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(red_sox[x])):
        red_sox.loc[y,x] = int(red_sox.loc[y, x])

for x in columns_float:
    for y in range(len(red_sox[x])):
        red_sox.loc[y,x] = float(red_sox.loc[y, x])  

for x in range(len(red_sox['Game'])):
    if red_sox.loc[x, 'Runs'] > red_sox.loc[x, 'R']:
        red_sox.loc[x, 'Win'] = 0
    else:
        red_sox.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Red Sox Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BOS&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BOS_2018_game_num = get_stat2('team_game_num')
BOS_2018_PA = get_stat2('PA')
BOS_2018_AB = get_stat2('AB')
BOS_2018_R = get_stat2('R')
BOS_2018_H = get_stat2('H')
BOS_2018_2B = get_stat2('2B')
BOS_2018_3B = get_stat2('3B')
BOS_2018_HR = get_stat2('HR')
BOS_2018_RBI = get_stat2('RBI')
BOS_2018_BB = get_stat2('BB')
BOS_2018_SO = get_stat2('SO')
BOS_2018_SB = get_stat2('SB')
BOS_2018_CS = get_stat2('CS')
BOS_2018_BA = get_stat2('batting_avg')
BOS_2018_OBP = get_stat2('onbase_perc')
BOS_2018_SLG = get_stat2('slugging_perc')
BOS_2018_OPS = get_stat2('onbase_plus_slugging')
BOS_2018_LOB = get_stat2('LOB')
red_sox_2018_offense = pd.DataFrame({
                                  'PA': BOS_2018_PA,
                                  'AB': BOS_2018_AB,
                                  'R':  BOS_2018_R,
                                  'H':  BOS_2018_H,
                                  '2B': BOS_2018_2B,
                                  '3B': BOS_2018_3B, 
                                  'HR': BOS_2018_HR, 
                                  'RBI':BOS_2018_RBI,
                                  'BB': BOS_2018_BB,
                                  'SO': BOS_2018_SO,
                                  'SB': BOS_2018_SB,
                                  'CS': BOS_2018_CS,
                                  'LOB':BOS_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BOS&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BOS_2018_P_game_num = get_stat3('team_game_num')
BOS_2018_P_IP = get_stat3('IP')
BOS_2018_P_H = get_stat3('H')
BOS_2018_P_R = get_stat3('R')
BOS_2018_P_ER = get_stat3('ER')
BOS_2018_P_UER = get_stat3('UER')
BOS_2018_P_BB = get_stat3('BB')
BOS_2018_P_SO = get_stat3('SO')
BOS_2018_P_HR = get_stat3('HR')
BOS_2018_P_HBP = get_stat3('HBP')
BOS_2018_P_ERA = get_stat3('earned_run_avg')

red_sox_2018_pitching = pd.DataFrame({'Game':  BOS_2018_P_game_num, 
                                         'IP':  BOS_2018_P_IP, 
                                         'H':   BOS_2018_P_H,
                                         'R':   BOS_2018_P_R,
                                         'ER':  BOS_2018_P_ER,
                                         'UER': BOS_2018_P_UER,
                                         'BB':  BOS_2018_P_BB,
                                         'SO':  BOS_2018_P_SO,
                                         'HR':  BOS_2018_P_HR,
                                         'HBP': BOS_2018_P_HBP})

# red_sox_offense = red_sox_offense.drop(columns = ['Game'])

red_sox_2018_pitching = red_sox_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [red_sox_2018_pitching, red_sox_2018_offense]

red_sox_2018 = pd.concat(frames, axis=1)

red_sox_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(red_sox_2018[x])):
        red_sox_2018.loc[y,x] = int(red_sox_2018.loc[y, x])

for x in columns_float:
    for y in range(len(red_sox_2018[x])):
        red_sox_2018.loc[y,x] = float(red_sox_2018.loc[y, x])  

for x in range(len(red_sox_2018['Game'])):
    if red_sox_2018.loc[x, 'Runs'] > red_sox_2018.loc[x, 'R']:
        red_sox_2018.loc[x, 'Win'] = 0
    else:
        red_sox_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Red Sox Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BOS&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BOS_2017_game_num = get_stat2('team_game_num')
BOS_2017_PA = get_stat2('PA')
BOS_2017_AB = get_stat2('AB')
BOS_2017_R = get_stat2('R')
BOS_2017_H = get_stat2('H')
BOS_2017_2B = get_stat2('2B')
BOS_2017_3B = get_stat2('3B')
BOS_2017_HR = get_stat2('HR')
BOS_2017_RBI = get_stat2('RBI')
BOS_2017_BB = get_stat2('BB')
BOS_2017_SO = get_stat2('SO')
BOS_2017_SB = get_stat2('SB')
BOS_2017_CS = get_stat2('CS')
BOS_2017_BA = get_stat2('batting_avg')
BOS_2017_OBP = get_stat2('onbase_perc')
BOS_2017_SLG = get_stat2('slugging_perc')
BOS_2017_OPS = get_stat2('onbase_plus_slugging')
BOS_2017_LOB = get_stat2('LOB')
red_sox_2017_offense = pd.DataFrame({
                                  'PA': BOS_2017_PA,
                                  'AB': BOS_2017_AB,
                                  'R':  BOS_2017_R,
                                  'H':  BOS_2017_H,
                                  '2B': BOS_2017_2B,
                                  '3B': BOS_2017_3B, 
                                  'HR': BOS_2017_HR, 
                                  'RBI':BOS_2017_RBI,
                                  'BB': BOS_2017_BB,
                                  'SO': BOS_2017_SO,
                                  'SB': BOS_2017_SB,
                                  'CS': BOS_2017_CS,
                                  'LOB':BOS_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BOS&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BOS_2017_P_game_num = get_stat3('team_game_num')
BOS_2017_P_IP = get_stat3('IP')
BOS_2017_P_H = get_stat3('H')
BOS_2017_P_R = get_stat3('R')
BOS_2017_P_ER = get_stat3('ER')
BOS_2017_P_UER = get_stat3('UER')
BOS_2017_P_BB = get_stat3('BB')
BOS_2017_P_SO = get_stat3('SO')
BOS_2017_P_HR = get_stat3('HR')
BOS_2017_P_HBP = get_stat3('HBP')
BOS_2017_P_ERA = get_stat3('earned_run_avg')

red_sox_2017_pitching = pd.DataFrame({'Game':  BOS_2017_P_game_num, 
                                         'IP':  BOS_2017_P_IP, 
                                         'H':   BOS_2017_P_H,
                                         'R':   BOS_2017_P_R,
                                         'ER':  BOS_2017_P_ER,
                                         'UER': BOS_2017_P_UER,
                                         'BB':  BOS_2017_P_BB,
                                         'SO':  BOS_2017_P_SO,
                                         'HR':  BOS_2017_P_HR,
                                         'HBP': BOS_2017_P_HBP})

# red_sox_offense = red_sox_offense.drop(columns = ['Game'])

red_sox_2017_pitching = red_sox_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [red_sox_2017_pitching, red_sox_2017_offense]

red_sox_2017 = pd.concat(frames, axis=1)

red_sox_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(red_sox_2017[x])):
        red_sox_2017.loc[y,x] = int(red_sox_2017.loc[y, x])

for x in columns_float:
    for y in range(len(red_sox_2017[x])):
        red_sox_2017.loc[y,x] = float(red_sox_2017.loc[y, x])  

for x in range(len(red_sox_2017['Game'])):
    if red_sox_2017.loc[x, 'Runs'] > red_sox_2017.loc[x, 'R']:
        red_sox_2017.loc[x, 'Win'] = 0
    else:
        red_sox_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Red Sox Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BOS&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BOS_2016_game_num = get_stat2('team_game_num')
BOS_2016_PA = get_stat2('PA')
BOS_2016_AB = get_stat2('AB')
BOS_2016_R = get_stat2('R')
BOS_2016_H = get_stat2('H')
BOS_2016_2B = get_stat2('2B')
BOS_2016_3B = get_stat2('3B')
BOS_2016_HR = get_stat2('HR')
BOS_2016_RBI = get_stat2('RBI')
BOS_2016_BB = get_stat2('BB')
BOS_2016_SO = get_stat2('SO')
BOS_2016_SB = get_stat2('SB')
BOS_2016_CS = get_stat2('CS')
BOS_2016_BA = get_stat2('batting_avg')
BOS_2016_OBP = get_stat2('onbase_perc')
BOS_2016_SLG = get_stat2('slugging_perc')
BOS_2016_OPS = get_stat2('onbase_plus_slugging')
BOS_2016_LOB = get_stat2('LOB')
red_sox_2016_offense = pd.DataFrame({
                                  'PA': BOS_2016_PA,
                                  'AB': BOS_2016_AB,
                                  'R':  BOS_2016_R,
                                  'H':  BOS_2016_H,
                                  '2B': BOS_2016_2B,
                                  '3B': BOS_2016_3B, 
                                  'HR': BOS_2016_HR, 
                                  'RBI':BOS_2016_RBI,
                                  'BB': BOS_2016_BB,
                                  'SO': BOS_2016_SO,
                                  'SB': BOS_2016_SB,
                                  'CS': BOS_2016_CS,
                                  'LOB':BOS_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BOS&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BOS_2016_P_game_num = get_stat3('team_game_num')
BOS_2016_P_IP = get_stat3('IP')
BOS_2016_P_H = get_stat3('H')
BOS_2016_P_R = get_stat3('R')
BOS_2016_P_ER = get_stat3('ER')
BOS_2016_P_UER = get_stat3('UER')
BOS_2016_P_BB = get_stat3('BB')
BOS_2016_P_SO = get_stat3('SO')
BOS_2016_P_HR = get_stat3('HR')
BOS_2016_P_HBP = get_stat3('HBP')
BOS_2016_P_ERA = get_stat3('earned_run_avg')

red_sox_2016_pitching = pd.DataFrame({'Game':  BOS_2016_P_game_num, 
                                         'IP':  BOS_2016_P_IP, 
                                         'H':   BOS_2016_P_H,
                                         'R':   BOS_2016_P_R,
                                         'ER':  BOS_2016_P_ER,
                                         'UER': BOS_2016_P_UER,
                                         'BB':  BOS_2016_P_BB,
                                         'SO':  BOS_2016_P_SO,
                                         'HR':  BOS_2016_P_HR,
                                         'HBP': BOS_2016_P_HBP})

# red_sox_offense = red_sox_offense.drop(columns = ['Game'])

red_sox_2016_pitching = red_sox_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [red_sox_2016_pitching, red_sox_2016_offense]

red_sox_2016 = pd.concat(frames, axis=1)

red_sox_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(red_sox_2016[x])):
        red_sox_2016.loc[y,x] = int(red_sox_2016.loc[y, x])

for x in columns_float:
    for y in range(len(red_sox_2016[x])):
        red_sox_2016.loc[y,x] = float(red_sox_2016.loc[y, x])  

for x in range(len(red_sox_2016['Game'])):
    if red_sox_2016.loc[x, 'Runs'] > red_sox_2016.loc[x, 'R']:
        red_sox_2016.loc[x, 'Win'] = 0
    else:
        red_sox_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Red Sox Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BOS&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BOS_2015_game_num = get_stat2('team_game_num')
BOS_2015_PA = get_stat2('PA')
BOS_2015_AB = get_stat2('AB')
BOS_2015_R = get_stat2('R')
BOS_2015_H = get_stat2('H')
BOS_2015_2B = get_stat2('2B')
BOS_2015_3B = get_stat2('3B')
BOS_2015_HR = get_stat2('HR')
BOS_2015_RBI = get_stat2('RBI')
BOS_2015_BB = get_stat2('BB')
BOS_2015_SO = get_stat2('SO')
BOS_2015_SB = get_stat2('SB')
BOS_2015_CS = get_stat2('CS')
BOS_2015_BA = get_stat2('batting_avg')
BOS_2015_OBP = get_stat2('onbase_perc')
BOS_2015_SLG = get_stat2('slugging_perc')
BOS_2015_OPS = get_stat2('onbase_plus_slugging')
BOS_2015_LOB = get_stat2('LOB')
red_sox_2015_offense = pd.DataFrame({
                                  'PA': BOS_2015_PA,
                                  'AB': BOS_2015_AB,
                                  'R':  BOS_2015_R,
                                  'H':  BOS_2015_H,
                                  '2B': BOS_2015_2B,
                                  '3B': BOS_2015_3B, 
                                  'HR': BOS_2015_HR, 
                                  'RBI':BOS_2015_RBI,
                                  'BB': BOS_2015_BB,
                                  'SO': BOS_2015_SO,
                                  'SB': BOS_2015_SB,
                                  'CS': BOS_2015_CS,
                                  'LOB':BOS_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BOS&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BOS_2015_P_game_num = get_stat3('team_game_num')
BOS_2015_P_IP = get_stat3('IP')
BOS_2015_P_H = get_stat3('H')
BOS_2015_P_R = get_stat3('R')
BOS_2015_P_ER = get_stat3('ER')
BOS_2015_P_UER = get_stat3('UER')
BOS_2015_P_BB = get_stat3('BB')
BOS_2015_P_SO = get_stat3('SO')
BOS_2015_P_HR = get_stat3('HR')
BOS_2015_P_HBP = get_stat3('HBP')
BOS_2015_P_ERA = get_stat3('earned_run_avg')

red_sox_2015_pitching = pd.DataFrame({'Game':  BOS_2015_P_game_num, 
                                         'IP':  BOS_2015_P_IP, 
                                         'H':   BOS_2015_P_H,
                                         'R':   BOS_2015_P_R,
                                         'ER':  BOS_2015_P_ER,
                                         'UER': BOS_2015_P_UER,
                                         'BB':  BOS_2015_P_BB,
                                         'SO':  BOS_2015_P_SO,
                                         'HR':  BOS_2015_P_HR,
                                         'HBP': BOS_2015_P_HBP})

# red_sox_offense = red_sox_offense.drop(columns = ['Game'])

red_sox_2015_pitching = red_sox_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [red_sox_2015_pitching, red_sox_2015_offense]

red_sox_2015 = pd.concat(frames, axis=1)

red_sox_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(red_sox_2015[x])):
        red_sox_2015.loc[y,x] = int(red_sox_2015.loc[y, x])

for x in columns_float:
    for y in range(len(red_sox_2015[x])):
        red_sox_2015.loc[y,x] = float(red_sox_2015.loc[y, x])  

for x in range(len(red_sox_2015['Game'])):
    if red_sox_2015.loc[x, 'Runs'] > red_sox_2015.loc[x, 'R']:
        red_sox_2015.loc[x, 'Win'] = 0
    else:
        red_sox_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Blue Jays Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TOR&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TOR_game_num = get_stat2('team_game_num')
TOR_PA = get_stat2('PA')
TOR_AB = get_stat2('AB')
TOR_R = get_stat2('R')
TOR_H = get_stat2('H')
TOR_2B = get_stat2('2B')
TOR_3B = get_stat2('3B')
TOR_HR = get_stat2('HR')
TOR_RBI = get_stat2('RBI')
TOR_BB = get_stat2('BB')
TOR_SO = get_stat2('SO')
TOR_SB = get_stat2('SB')
TOR_CS = get_stat2('CS')
TOR_BA = get_stat2('batting_avg')
TOR_OBP = get_stat2('onbase_perc')
TOR_SLG = get_stat2('slugging_perc')
TOR_OPS = get_stat2('onbase_plus_slugging')
TOR_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


blue_jays_offense = pd.DataFrame({
                                  'PA': TOR_PA,
                                  'AB': TOR_AB,
                                  'R':  TOR_R,
                                  'H':  TOR_H,
                                  '2B': TOR_2B,
                                  '3B': TOR_3B, 
                                  'HR': TOR_HR, 
                                  'RBI':TOR_RBI,
                                  'BB': TOR_BB,
                                  'SO': TOR_SO,
                                  'SB': TOR_SB,
                                  'CS': TOR_CS,
                                  'LOB':TOR_LOB})

# %% [markdown]
# # 2019 Blue Jays Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TOR&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TOR_P_game_num = get_stat3('team_game_num')
TOR_P_IP = get_stat3('IP')
TOR_P_H = get_stat3('H')
TOR_P_R = get_stat3('R')
TOR_P_ER = get_stat3('ER')
TOR_P_UER = get_stat3('UER')
TOR_P_BB = get_stat3('BB')
TOR_P_SO = get_stat3('SO')
TOR_P_HR = get_stat3('HR')
TOR_P_HBP = get_stat3('HBP')
TOR_P_ERA = get_stat3('earned_run_avg')

blue_jays_pitching = pd.DataFrame({'Game':  TOR_P_game_num, 
                                   'IP':  TOR_P_IP, 
                                   'H':   TOR_P_H,
                                   'R':   TOR_P_R,
                                   'ER':  TOR_P_ER,
                                   'UER': TOR_P_UER,
                                   'BB':  TOR_P_BB,
                                   'SO':  TOR_P_SO,
                                   'HR':  TOR_P_HR,
                                   'HBP': TOR_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

blue_jays_pitching = blue_jays_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [blue_jays_pitching, blue_jays_offense]

blue_jays = pd.concat(frames, axis=1)

blue_jays['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(blue_jays[x])):
        blue_jays.loc[y,x] = int(blue_jays.loc[y, x])

for x in columns_float:
    for y in range(len(blue_jays[x])):
        blue_jays.loc[y,x] = float(blue_jays.loc[y, x])  

for x in range(len(blue_jays['Game'])):
    if blue_jays.loc[x, 'Runs'] > blue_jays.loc[x, 'R']:
        blue_jays.loc[x, 'Win'] = 0
    else:
        blue_jays.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Blue Jays Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TOR&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TOR_2018_game_num = get_stat2('team_game_num')
TOR_2018_PA = get_stat2('PA')
TOR_2018_AB = get_stat2('AB')
TOR_2018_R = get_stat2('R')
TOR_2018_H = get_stat2('H')
TOR_2018_2B = get_stat2('2B')
TOR_2018_3B = get_stat2('3B')
TOR_2018_HR = get_stat2('HR')
TOR_2018_RBI = get_stat2('RBI')
TOR_2018_BB = get_stat2('BB')
TOR_2018_SO = get_stat2('SO')
TOR_2018_SB = get_stat2('SB')
TOR_2018_CS = get_stat2('CS')
TOR_2018_BA = get_stat2('batting_avg')
TOR_2018_OBP = get_stat2('onbase_perc')
TOR_2018_SLG = get_stat2('slugging_perc')
TOR_2018_OPS = get_stat2('onbase_plus_slugging')
TOR_2018_LOB = get_stat2('LOB')
blue_jays_2018_offense = pd.DataFrame({
                                  'PA': TOR_2018_PA,
                                  'AB': TOR_2018_AB,
                                  'R':  TOR_2018_R,
                                  'H':  TOR_2018_H,
                                  '2B': TOR_2018_2B,
                                  '3B': TOR_2018_3B, 
                                  'HR': TOR_2018_HR, 
                                  'RBI':TOR_2018_RBI,
                                  'BB': TOR_2018_BB,
                                  'SO': TOR_2018_SO,
                                  'SB': TOR_2018_SB,
                                  'CS': TOR_2018_CS,
                                  'LOB':TOR_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TOR&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TOR_2018_P_game_num = get_stat3('team_game_num')
TOR_2018_P_IP = get_stat3('IP')
TOR_2018_P_H = get_stat3('H')
TOR_2018_P_R = get_stat3('R')
TOR_2018_P_ER = get_stat3('ER')
TOR_2018_P_UER = get_stat3('UER')
TOR_2018_P_BB = get_stat3('BB')
TOR_2018_P_SO = get_stat3('SO')
TOR_2018_P_HR = get_stat3('HR')
TOR_2018_P_HBP = get_stat3('HBP')
TOR_2018_P_ERA = get_stat3('earned_run_avg')

blue_jays_2018_pitching = pd.DataFrame({'Game':  TOR_2018_P_game_num, 
                                         'IP':  TOR_2018_P_IP, 
                                         'H':   TOR_2018_P_H,
                                         'R':   TOR_2018_P_R,
                                         'ER':  TOR_2018_P_ER,
                                         'UER': TOR_2018_P_UER,
                                         'BB':  TOR_2018_P_BB,
                                         'SO':  TOR_2018_P_SO,
                                         'HR':  TOR_2018_P_HR,
                                         'HBP': TOR_2018_P_HBP})

# blue_jays_offense = blue_jays_offense.drop(columns = ['Game'])

blue_jays_2018_pitching = blue_jays_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [blue_jays_2018_pitching, blue_jays_2018_offense]

blue_jays_2018 = pd.concat(frames, axis=1)

blue_jays_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(blue_jays_2018[x])):
        blue_jays_2018.loc[y,x] = int(blue_jays_2018.loc[y, x])

for x in columns_float:
    for y in range(len(blue_jays_2018[x])):
        blue_jays_2018.loc[y,x] = float(blue_jays_2018.loc[y, x])  

for x in range(len(blue_jays_2018['Game'])):
    if blue_jays_2018.loc[x, 'Runs'] > blue_jays_2018.loc[x, 'R']:
        blue_jays_2018.loc[x, 'Win'] = 0
    else:
        blue_jays_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Blue Jays Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TOR&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TOR_2017_game_num = get_stat2('team_game_num')
TOR_2017_PA = get_stat2('PA')
TOR_2017_AB = get_stat2('AB')
TOR_2017_R = get_stat2('R')
TOR_2017_H = get_stat2('H')
TOR_2017_2B = get_stat2('2B')
TOR_2017_3B = get_stat2('3B')
TOR_2017_HR = get_stat2('HR')
TOR_2017_RBI = get_stat2('RBI')
TOR_2017_BB = get_stat2('BB')
TOR_2017_SO = get_stat2('SO')
TOR_2017_SB = get_stat2('SB')
TOR_2017_CS = get_stat2('CS')
TOR_2017_BA = get_stat2('batting_avg')
TOR_2017_OBP = get_stat2('onbase_perc')
TOR_2017_SLG = get_stat2('slugging_perc')
TOR_2017_OPS = get_stat2('onbase_plus_slugging')
TOR_2017_LOB = get_stat2('LOB')
blue_jays_2017_offense = pd.DataFrame({
                                  'PA': TOR_2017_PA,
                                  'AB': TOR_2017_AB,
                                  'R':  TOR_2017_R,
                                  'H':  TOR_2017_H,
                                  '2B': TOR_2017_2B,
                                  '3B': TOR_2017_3B, 
                                  'HR': TOR_2017_HR, 
                                  'RBI':TOR_2017_RBI,
                                  'BB': TOR_2017_BB,
                                  'SO': TOR_2017_SO,
                                  'SB': TOR_2017_SB,
                                  'CS': TOR_2017_CS,
                                  'LOB':TOR_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TOR&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TOR_2017_P_game_num = get_stat3('team_game_num')
TOR_2017_P_IP = get_stat3('IP')
TOR_2017_P_H = get_stat3('H')
TOR_2017_P_R = get_stat3('R')
TOR_2017_P_ER = get_stat3('ER')
TOR_2017_P_UER = get_stat3('UER')
TOR_2017_P_BB = get_stat3('BB')
TOR_2017_P_SO = get_stat3('SO')
TOR_2017_P_HR = get_stat3('HR')
TOR_2017_P_HBP = get_stat3('HBP')
TOR_2017_P_ERA = get_stat3('earned_run_avg')

blue_jays_2017_pitching = pd.DataFrame({'Game':  TOR_2017_P_game_num, 
                                         'IP':  TOR_2017_P_IP, 
                                         'H':   TOR_2017_P_H,
                                         'R':   TOR_2017_P_R,
                                         'ER':  TOR_2017_P_ER,
                                         'UER': TOR_2017_P_UER,
                                         'BB':  TOR_2017_P_BB,
                                         'SO':  TOR_2017_P_SO,
                                         'HR':  TOR_2017_P_HR,
                                         'HBP': TOR_2017_P_HBP})

# blue_jays_offense = blue_jays_offense.drop(columns = ['Game'])

blue_jays_2017_pitching = blue_jays_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [blue_jays_2017_pitching, blue_jays_2017_offense]

blue_jays_2017 = pd.concat(frames, axis=1)

blue_jays_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(blue_jays_2017[x])):
        blue_jays_2017.loc[y,x] = int(blue_jays_2017.loc[y, x])

for x in columns_float:
    for y in range(len(blue_jays_2017[x])):
        blue_jays_2017.loc[y,x] = float(blue_jays_2017.loc[y, x])  

for x in range(len(blue_jays_2017['Game'])):
    if blue_jays_2017.loc[x, 'Runs'] > blue_jays_2017.loc[x, 'R']:
        blue_jays_2017.loc[x, 'Win'] = 0
    else:
        blue_jays_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Blue Jays Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TOR&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TOR_2016_game_num = get_stat2('team_game_num')
TOR_2016_PA = get_stat2('PA')
TOR_2016_AB = get_stat2('AB')
TOR_2016_R = get_stat2('R')
TOR_2016_H = get_stat2('H')
TOR_2016_2B = get_stat2('2B')
TOR_2016_3B = get_stat2('3B')
TOR_2016_HR = get_stat2('HR')
TOR_2016_RBI = get_stat2('RBI')
TOR_2016_BB = get_stat2('BB')
TOR_2016_SO = get_stat2('SO')
TOR_2016_SB = get_stat2('SB')
TOR_2016_CS = get_stat2('CS')
TOR_2016_BA = get_stat2('batting_avg')
TOR_2016_OBP = get_stat2('onbase_perc')
TOR_2016_SLG = get_stat2('slugging_perc')
TOR_2016_OPS = get_stat2('onbase_plus_slugging')
TOR_2016_LOB = get_stat2('LOB')
blue_jays_2016_offense = pd.DataFrame({
                                  'PA': TOR_2016_PA,
                                  'AB': TOR_2016_AB,
                                  'R':  TOR_2016_R,
                                  'H':  TOR_2016_H,
                                  '2B': TOR_2016_2B,
                                  '3B': TOR_2016_3B, 
                                  'HR': TOR_2016_HR, 
                                  'RBI':TOR_2016_RBI,
                                  'BB': TOR_2016_BB,
                                  'SO': TOR_2016_SO,
                                  'SB': TOR_2016_SB,
                                  'CS': TOR_2016_CS,
                                  'LOB':TOR_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TOR&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TOR_2016_P_game_num = get_stat3('team_game_num')
TOR_2016_P_IP = get_stat3('IP')
TOR_2016_P_H = get_stat3('H')
TOR_2016_P_R = get_stat3('R')
TOR_2016_P_ER = get_stat3('ER')
TOR_2016_P_UER = get_stat3('UER')
TOR_2016_P_BB = get_stat3('BB')
TOR_2016_P_SO = get_stat3('SO')
TOR_2016_P_HR = get_stat3('HR')
TOR_2016_P_HBP = get_stat3('HBP')
TOR_2016_P_ERA = get_stat3('earned_run_avg')

blue_jays_2016_pitching = pd.DataFrame({'Game':  TOR_2016_P_game_num, 
                                         'IP':  TOR_2016_P_IP, 
                                         'H':   TOR_2016_P_H,
                                         'R':   TOR_2016_P_R,
                                         'ER':  TOR_2016_P_ER,
                                         'UER': TOR_2016_P_UER,
                                         'BB':  TOR_2016_P_BB,
                                         'SO':  TOR_2016_P_SO,
                                         'HR':  TOR_2016_P_HR,
                                         'HBP': TOR_2016_P_HBP})

# blue_jays_offense = blue_jays_offense.drop(columns = ['Game'])

blue_jays_2016_pitching = blue_jays_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [blue_jays_2016_pitching, blue_jays_2016_offense]

blue_jays_2016 = pd.concat(frames, axis=1)

blue_jays_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(blue_jays_2016[x])):
        blue_jays_2016.loc[y,x] = int(blue_jays_2016.loc[y, x])

for x in columns_float:
    for y in range(len(blue_jays_2016[x])):
        blue_jays_2016.loc[y,x] = float(blue_jays_2016.loc[y, x])  

for x in range(len(blue_jays_2016['Game'])):
    if blue_jays_2016.loc[x, 'Runs'] > blue_jays_2016.loc[x, 'R']:
        blue_jays_2016.loc[x, 'Win'] = 0
    else:
        blue_jays_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Blue Jays Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TOR&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TOR_2015_game_num = get_stat2('team_game_num')
TOR_2015_PA = get_stat2('PA')
TOR_2015_AB = get_stat2('AB')
TOR_2015_R = get_stat2('R')
TOR_2015_H = get_stat2('H')
TOR_2015_2B = get_stat2('2B')
TOR_2015_3B = get_stat2('3B')
TOR_2015_HR = get_stat2('HR')
TOR_2015_RBI = get_stat2('RBI')
TOR_2015_BB = get_stat2('BB')
TOR_2015_SO = get_stat2('SO')
TOR_2015_SB = get_stat2('SB')
TOR_2015_CS = get_stat2('CS')
TOR_2015_BA = get_stat2('batting_avg')
TOR_2015_OBP = get_stat2('onbase_perc')
TOR_2015_SLG = get_stat2('slugging_perc')
TOR_2015_OPS = get_stat2('onbase_plus_slugging')
TOR_2015_LOB = get_stat2('LOB')
blue_jays_2015_offense = pd.DataFrame({
                                  'PA': TOR_2015_PA,
                                  'AB': TOR_2015_AB,
                                  'R':  TOR_2015_R,
                                  'H':  TOR_2015_H,
                                  '2B': TOR_2015_2B,
                                  '3B': TOR_2015_3B, 
                                  'HR': TOR_2015_HR, 
                                  'RBI':TOR_2015_RBI,
                                  'BB': TOR_2015_BB,
                                  'SO': TOR_2015_SO,
                                  'SB': TOR_2015_SB,
                                  'CS': TOR_2015_CS,
                                  'LOB':TOR_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TOR&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TOR_2015_P_game_num = get_stat3('team_game_num')
TOR_2015_P_IP = get_stat3('IP')
TOR_2015_P_H = get_stat3('H')
TOR_2015_P_R = get_stat3('R')
TOR_2015_P_ER = get_stat3('ER')
TOR_2015_P_UER = get_stat3('UER')
TOR_2015_P_BB = get_stat3('BB')
TOR_2015_P_SO = get_stat3('SO')
TOR_2015_P_HR = get_stat3('HR')
TOR_2015_P_HBP = get_stat3('HBP')
TOR_2015_P_ERA = get_stat3('earned_run_avg')

blue_jays_2015_pitching = pd.DataFrame({'Game':  TOR_2015_P_game_num, 
                                         'IP':  TOR_2015_P_IP, 
                                         'H':   TOR_2015_P_H,
                                         'R':   TOR_2015_P_R,
                                         'ER':  TOR_2015_P_ER,
                                         'UER': TOR_2015_P_UER,
                                         'BB':  TOR_2015_P_BB,
                                         'SO':  TOR_2015_P_SO,
                                         'HR':  TOR_2015_P_HR,
                                         'HBP': TOR_2015_P_HBP})

# blue_jays_offense = blue_jays_offense.drop(columns = ['Game'])

blue_jays_2015_pitching = blue_jays_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [blue_jays_2015_pitching, blue_jays_2015_offense]

blue_jays_2015 = pd.concat(frames, axis=1)

blue_jays_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(blue_jays_2015[x])):
        blue_jays_2015.loc[y,x] = int(blue_jays_2015.loc[y, x])

for x in columns_float:
    for y in range(len(blue_jays_2015[x])):
        blue_jays_2015.loc[y,x] = float(blue_jays_2015.loc[y, x])  

for x in range(len(blue_jays_2015['Game'])):
    if blue_jays_2015.loc[x, 'Runs'] > blue_jays_2015.loc[x, 'R']:
        blue_jays_2015.loc[x, 'Win'] = 0
    else:
        blue_jays_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Rays Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TBR&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TBR_game_num = get_stat2('team_game_num')
TBR_PA = get_stat2('PA')
TBR_AB = get_stat2('AB')
TBR_R = get_stat2('R')
TBR_H = get_stat2('H')
TBR_2B = get_stat2('2B')
TBR_3B = get_stat2('3B')
TBR_HR = get_stat2('HR')
TBR_RBI = get_stat2('RBI')
TBR_BB = get_stat2('BB')
TBR_SO = get_stat2('SO')
TBR_SB = get_stat2('SB')
TBR_CS = get_stat2('CS')
TBR_BA = get_stat2('batting_avg')
TBR_OBP = get_stat2('onbase_perc')
TBR_SLG = get_stat2('slugging_perc')
TBR_OPS = get_stat2('onbase_plus_slugging')
TBR_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


rays_offense = pd.DataFrame({
                                  'PA': TBR_PA,
                                  'AB': TBR_AB,
                                  'R':  TBR_R,
                                  'H':  TBR_H,
                                  '2B': TBR_2B,
                                  '3B': TBR_3B, 
                                  'HR': TBR_HR, 
                                  'RBI':TBR_RBI,
                                  'BB': TBR_BB,
                                  'SO': TBR_SO,
                                  'SB': TBR_SB,
                                  'CS': TBR_CS,
                                  'LOB':TBR_LOB})

# %% [markdown]
# # 2019 Rays Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TBR&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TBR_P_game_num = get_stat3('team_game_num')
TBR_P_IP = get_stat3('IP')
TBR_P_H = get_stat3('H')
TBR_P_R = get_stat3('R')
TBR_P_ER = get_stat3('ER')
TBR_P_UER = get_stat3('UER')
TBR_P_BB = get_stat3('BB')
TBR_P_SO = get_stat3('SO')
TBR_P_HR = get_stat3('HR')
TBR_P_HBP = get_stat3('HBP')
TBR_P_ERA = get_stat3('earned_run_avg')

rays_pitching = pd.DataFrame({'Game':  TBR_P_game_num, 
                                   'IP':  TBR_P_IP, 
                                   'H':   TBR_P_H,
                                   'R':   TBR_P_R,
                                   'ER':  TBR_P_ER,
                                   'UER': TBR_P_UER,
                                   'BB':  TBR_P_BB,
                                   'SO':  TBR_P_SO,
                                   'HR':  TBR_P_HR,
                                   'HBP': TBR_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

rays_pitching = rays_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rays_pitching, rays_offense]

rays = pd.concat(frames, axis=1)

rays['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rays[x])):
        rays.loc[y,x] = int(rays.loc[y, x])

for x in columns_float:
    for y in range(len(rays[x])):
        rays.loc[y,x] = float(rays.loc[y, x])  

for x in range(len(rays['Game'])):
    if rays.loc[x, 'Runs'] > rays.loc[x, 'R']:
        rays.loc[x, 'Win'] = 0
    else:
        rays.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Rays Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TBR&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TBR_2018_game_num = get_stat2('team_game_num')
TBR_2018_PA = get_stat2('PA')
TBR_2018_AB = get_stat2('AB')
TBR_2018_R = get_stat2('R')
TBR_2018_H = get_stat2('H')
TBR_2018_2B = get_stat2('2B')
TBR_2018_3B = get_stat2('3B')
TBR_2018_HR = get_stat2('HR')
TBR_2018_RBI = get_stat2('RBI')
TBR_2018_BB = get_stat2('BB')
TBR_2018_SO = get_stat2('SO')
TBR_2018_SB = get_stat2('SB')
TBR_2018_CS = get_stat2('CS')
TBR_2018_BA = get_stat2('batting_avg')
TBR_2018_OBP = get_stat2('onbase_perc')
TBR_2018_SLG = get_stat2('slugging_perc')
TBR_2018_OPS = get_stat2('onbase_plus_slugging')
TBR_2018_LOB = get_stat2('LOB')
rays_2018_offense = pd.DataFrame({
                                  'PA': TBR_2018_PA,
                                  'AB': TBR_2018_AB,
                                  'R':  TBR_2018_R,
                                  'H':  TBR_2018_H,
                                  '2B': TBR_2018_2B,
                                  '3B': TBR_2018_3B, 
                                  'HR': TBR_2018_HR, 
                                  'RBI':TBR_2018_RBI,
                                  'BB': TBR_2018_BB,
                                  'SO': TBR_2018_SO,
                                  'SB': TBR_2018_SB,
                                  'CS': TBR_2018_CS,
                                  'LOB':TBR_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TBR&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TBR_2018_P_game_num = get_stat3('team_game_num')
TBR_2018_P_IP = get_stat3('IP')
TBR_2018_P_H = get_stat3('H')
TBR_2018_P_R = get_stat3('R')
TBR_2018_P_ER = get_stat3('ER')
TBR_2018_P_UER = get_stat3('UER')
TBR_2018_P_BB = get_stat3('BB')
TBR_2018_P_SO = get_stat3('SO')
TBR_2018_P_HR = get_stat3('HR')
TBR_2018_P_HBP = get_stat3('HBP')
TBR_2018_P_ERA = get_stat3('earned_run_avg')

rays_2018_pitching = pd.DataFrame({'Game':  TBR_2018_P_game_num, 
                                         'IP':  TBR_2018_P_IP, 
                                         'H':   TBR_2018_P_H,
                                         'R':   TBR_2018_P_R,
                                         'ER':  TBR_2018_P_ER,
                                         'UER': TBR_2018_P_UER,
                                         'BB':  TBR_2018_P_BB,
                                         'SO':  TBR_2018_P_SO,
                                         'HR':  TBR_2018_P_HR,
                                         'HBP': TBR_2018_P_HBP})

# rays_offense = rays_offense.drop(columns = ['Game'])

rays_2018_pitching = rays_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rays_2018_pitching, rays_2018_offense]

rays_2018 = pd.concat(frames, axis=1)

rays_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rays_2018[x])):
        rays_2018.loc[y,x] = int(rays_2018.loc[y, x])

for x in columns_float:
    for y in range(len(rays_2018[x])):
        rays_2018.loc[y,x] = float(rays_2018.loc[y, x])  

for x in range(len(rays_2018['Game'])):
    if rays_2018.loc[x, 'Runs'] > rays_2018.loc[x, 'R']:
        rays_2018.loc[x, 'Win'] = 0
    else:
        rays_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Rays Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TBR&t=b&year=2012017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TBR_2012017_game_num = get_stat2('team_game_num')
TBR_2012017_PA = get_stat2('PA')
TBR_2012017_AB = get_stat2('AB')
TBR_2012017_R = get_stat2('R')
TBR_2012017_H = get_stat2('H')
TBR_2012017_2B = get_stat2('2B')
TBR_2012017_3B = get_stat2('3B')
TBR_2012017_HR = get_stat2('HR')
TBR_2012017_RBI = get_stat2('RBI')
TBR_2012017_BB = get_stat2('BB')
TBR_2012017_SO = get_stat2('SO')
TBR_2012017_SB = get_stat2('SB')
TBR_2012017_CS = get_stat2('CS')
TBR_2012017_BA = get_stat2('batting_avg')
TBR_2012017_OBP = get_stat2('onbase_perc')
TBR_2012017_SLG = get_stat2('slugging_perc')
TBR_2012017_OPS = get_stat2('onbase_plus_slugging')
TBR_2012017_LOB = get_stat2('LOB')
rays_2012017_offense = pd.DataFrame({
                                  'PA': TBR_2012017_PA,
                                  'AB': TBR_2012017_AB,
                                  'R':  TBR_2012017_R,
                                  'H':  TBR_2012017_H,
                                  '2B': TBR_2012017_2B,
                                  '3B': TBR_2012017_3B, 
                                  'HR': TBR_2012017_HR, 
                                  'RBI':TBR_2012017_RBI,
                                  'BB': TBR_2012017_BB,
                                  'SO': TBR_2012017_SO,
                                  'SB': TBR_2012017_SB,
                                  'CS': TBR_2012017_CS,
                                  'LOB':TBR_2012017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TBR&t=p&year=2012017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TBR_2012017_P_game_num = get_stat3('team_game_num')
TBR_2012017_P_IP = get_stat3('IP')
TBR_2012017_P_H = get_stat3('H')
TBR_2012017_P_R = get_stat3('R')
TBR_2012017_P_ER = get_stat3('ER')
TBR_2012017_P_UER = get_stat3('UER')
TBR_2012017_P_BB = get_stat3('BB')
TBR_2012017_P_SO = get_stat3('SO')
TBR_2012017_P_HR = get_stat3('HR')
TBR_2012017_P_HBP = get_stat3('HBP')
TBR_2012017_P_ERA = get_stat3('earned_run_avg')

rays_2012017_pitching = pd.DataFrame({'Game':  TBR_2012017_P_game_num, 
                                         'IP':  TBR_2012017_P_IP, 
                                         'H':   TBR_2012017_P_H,
                                         'R':   TBR_2012017_P_R,
                                         'ER':  TBR_2012017_P_ER,
                                         'UER': TBR_2012017_P_UER,
                                         'BB':  TBR_2012017_P_BB,
                                         'SO':  TBR_2012017_P_SO,
                                         'HR':  TBR_2012017_P_HR,
                                         'HBP': TBR_2012017_P_HBP})

# rays_offense = rays_offense.drop(columns = ['Game'])

rays_2012017_pitching = rays_2012017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rays_2012017_pitching, rays_2012017_offense]

rays_2012017 = pd.concat(frames, axis=1)

rays_2012017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rays_2012017[x])):
        rays_2012017.loc[y,x] = int(rays_2012017.loc[y, x])

for x in columns_float:
    for y in range(len(rays_2012017[x])):
        rays_2012017.loc[y,x] = float(rays_2012017.loc[y, x])  

for x in range(len(rays_2012017['Game'])):
    if rays_2012017.loc[x, 'Runs'] > rays_2012017.loc[x, 'R']:
        rays_2012017.loc[x, 'Win'] = 0
    else:
        rays_2012017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Rays Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TBR&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TBR_2016_game_num = get_stat2('team_game_num')
TBR_2016_PA = get_stat2('PA')
TBR_2016_AB = get_stat2('AB')
TBR_2016_R = get_stat2('R')
TBR_2016_H = get_stat2('H')
TBR_2016_2B = get_stat2('2B')
TBR_2016_3B = get_stat2('3B')
TBR_2016_HR = get_stat2('HR')
TBR_2016_RBI = get_stat2('RBI')
TBR_2016_BB = get_stat2('BB')
TBR_2016_SO = get_stat2('SO')
TBR_2016_SB = get_stat2('SB')
TBR_2016_CS = get_stat2('CS')
TBR_2016_BA = get_stat2('batting_avg')
TBR_2016_OBP = get_stat2('onbase_perc')
TBR_2016_SLG = get_stat2('slugging_perc')
TBR_2016_OPS = get_stat2('onbase_plus_slugging')
TBR_2016_LOB = get_stat2('LOB')
rays_2016_offense = pd.DataFrame({
                                  'PA': TBR_2016_PA,
                                  'AB': TBR_2016_AB,
                                  'R':  TBR_2016_R,
                                  'H':  TBR_2016_H,
                                  '2B': TBR_2016_2B,
                                  '3B': TBR_2016_3B, 
                                  'HR': TBR_2016_HR, 
                                  'RBI':TBR_2016_RBI,
                                  'BB': TBR_2016_BB,
                                  'SO': TBR_2016_SO,
                                  'SB': TBR_2016_SB,
                                  'CS': TBR_2016_CS,
                                  'LOB':TBR_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TBR&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TBR_2016_P_game_num = get_stat3('team_game_num')
TBR_2016_P_IP = get_stat3('IP')
TBR_2016_P_H = get_stat3('H')
TBR_2016_P_R = get_stat3('R')
TBR_2016_P_ER = get_stat3('ER')
TBR_2016_P_UER = get_stat3('UER')
TBR_2016_P_BB = get_stat3('BB')
TBR_2016_P_SO = get_stat3('SO')
TBR_2016_P_HR = get_stat3('HR')
TBR_2016_P_HBP = get_stat3('HBP')
TBR_2016_P_ERA = get_stat3('earned_run_avg')

rays_2016_pitching = pd.DataFrame({'Game':  TBR_2016_P_game_num, 
                                         'IP':  TBR_2016_P_IP, 
                                         'H':   TBR_2016_P_H,
                                         'R':   TBR_2016_P_R,
                                         'ER':  TBR_2016_P_ER,
                                         'UER': TBR_2016_P_UER,
                                         'BB':  TBR_2016_P_BB,
                                         'SO':  TBR_2016_P_SO,
                                         'HR':  TBR_2016_P_HR,
                                         'HBP': TBR_2016_P_HBP})

# rays_offense = rays_offense.drop(columns = ['Game'])

rays_2016_pitching = rays_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rays_2016_pitching, rays_2016_offense]

rays_2016 = pd.concat(frames, axis=1)

rays_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rays_2016[x])):
        rays_2016.loc[y,x] = int(rays_2016.loc[y, x])

for x in columns_float:
    for y in range(len(rays_2016[x])):
        rays_2016.loc[y,x] = float(rays_2016.loc[y, x])  

for x in range(len(rays_2016['Game'])):
    if rays_2016.loc[x, 'Runs'] > rays_2016.loc[x, 'R']:
        rays_2016.loc[x, 'Win'] = 0
    else:
        rays_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Rays Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TBR&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TBR_2015_game_num = get_stat2('team_game_num')
TBR_2015_PA = get_stat2('PA')
TBR_2015_AB = get_stat2('AB')
TBR_2015_R = get_stat2('R')
TBR_2015_H = get_stat2('H')
TBR_2015_2B = get_stat2('2B')
TBR_2015_3B = get_stat2('3B')
TBR_2015_HR = get_stat2('HR')
TBR_2015_RBI = get_stat2('RBI')
TBR_2015_BB = get_stat2('BB')
TBR_2015_SO = get_stat2('SO')
TBR_2015_SB = get_stat2('SB')
TBR_2015_CS = get_stat2('CS')
TBR_2015_BA = get_stat2('batting_avg')
TBR_2015_OBP = get_stat2('onbase_perc')
TBR_2015_SLG = get_stat2('slugging_perc')
TBR_2015_OPS = get_stat2('onbase_plus_slugging')
TBR_2015_LOB = get_stat2('LOB')
rays_2015_offense = pd.DataFrame({
                                  'PA': TBR_2015_PA,
                                  'AB': TBR_2015_AB,
                                  'R':  TBR_2015_R,
                                  'H':  TBR_2015_H,
                                  '2B': TBR_2015_2B,
                                  '3B': TBR_2015_3B, 
                                  'HR': TBR_2015_HR, 
                                  'RBI':TBR_2015_RBI,
                                  'BB': TBR_2015_BB,
                                  'SO': TBR_2015_SO,
                                  'SB': TBR_2015_SB,
                                  'CS': TBR_2015_CS,
                                  'LOB':TBR_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TBR&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TBR_2015_P_game_num = get_stat3('team_game_num')
TBR_2015_P_IP = get_stat3('IP')
TBR_2015_P_H = get_stat3('H')
TBR_2015_P_R = get_stat3('R')
TBR_2015_P_ER = get_stat3('ER')
TBR_2015_P_UER = get_stat3('UER')
TBR_2015_P_BB = get_stat3('BB')
TBR_2015_P_SO = get_stat3('SO')
TBR_2015_P_HR = get_stat3('HR')
TBR_2015_P_HBP = get_stat3('HBP')
TBR_2015_P_ERA = get_stat3('earned_run_avg')

rays_2015_pitching = pd.DataFrame({'Game':  TBR_2015_P_game_num, 
                                         'IP':  TBR_2015_P_IP, 
                                         'H':   TBR_2015_P_H,
                                         'R':   TBR_2015_P_R,
                                         'ER':  TBR_2015_P_ER,
                                         'UER': TBR_2015_P_UER,
                                         'BB':  TBR_2015_P_BB,
                                         'SO':  TBR_2015_P_SO,
                                         'HR':  TBR_2015_P_HR,
                                         'HBP': TBR_2015_P_HBP})

# rays_offense = rays_offense.drop(columns = ['Game'])

rays_2015_pitching = rays_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rays_2015_pitching, rays_2015_offense]

rays_2015 = pd.concat(frames, axis=1)

rays_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rays_2015[x])):
        rays_2015.loc[y,x] = int(rays_2015.loc[y, x])

for x in columns_float:
    for y in range(len(rays_2015[x])):
        rays_2015.loc[y,x] = float(rays_2015.loc[y, x])  

for x in range(len(rays_2015['Game'])):
    if rays_2015.loc[x, 'Runs'] > rays_2015.loc[x, 'R']:
        rays_2015.loc[x, 'Win'] = 0
    else:
        rays_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Orioles Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BAL&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BAL_game_num = get_stat2('team_game_num')
BAL_PA = get_stat2('PA')
BAL_AB = get_stat2('AB')
BAL_R = get_stat2('R')
BAL_H = get_stat2('H')
BAL_2B = get_stat2('2B')
BAL_3B = get_stat2('3B')
BAL_HR = get_stat2('HR')
BAL_RBI = get_stat2('RBI')
BAL_BB = get_stat2('BB')
BAL_SO = get_stat2('SO')
BAL_SB = get_stat2('SB')
BAL_CS = get_stat2('CS')
BAL_BA = get_stat2('batting_avg')
BAL_OBP = get_stat2('onbase_perc')
BAL_SLG = get_stat2('slugging_perc')
BAL_OPS = get_stat2('onbase_plus_slugging')
BAL_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


orioles_offense = pd.DataFrame({
                                  'PA': BAL_PA,
                                  'AB': BAL_AB,
                                  'R':  BAL_R,
                                  'H':  BAL_H,
                                  '2B': BAL_2B,
                                  '3B': BAL_3B, 
                                  'HR': BAL_HR, 
                                  'RBI':BAL_RBI,
                                  'BB': BAL_BB,
                                  'SO': BAL_SO,
                                  'SB': BAL_SB,
                                  'CS': BAL_CS,
                                  'LOB':BAL_LOB})

# %% [markdown]
# # 2019 Orioles Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BAL&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BAL_P_game_num = get_stat3('team_game_num')
BAL_P_IP = get_stat3('IP')
BAL_P_H = get_stat3('H')
BAL_P_R = get_stat3('R')
BAL_P_ER = get_stat3('ER')
BAL_P_UER = get_stat3('UER')
BAL_P_BB = get_stat3('BB')
BAL_P_SO = get_stat3('SO')
BAL_P_HR = get_stat3('HR')
BAL_P_HBP = get_stat3('HBP')
BAL_P_ERA = get_stat3('earned_run_avg')

orioles_pitching = pd.DataFrame({'Game':  BAL_P_game_num, 
                                   'IP':  BAL_P_IP, 
                                   'H':   BAL_P_H,
                                   'R':   BAL_P_R,
                                   'ER':  BAL_P_ER,
                                   'UER': BAL_P_UER,
                                   'BB':  BAL_P_BB,
                                   'SO':  BAL_P_SO,
                                   'HR':  BAL_P_HR,
                                   'HBP': BAL_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

orioles_pitching = orioles_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [orioles_pitching, orioles_offense]

orioles = pd.concat(frames, axis=1)

orioles['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(orioles[x])):
        orioles.loc[y,x] = int(orioles.loc[y, x])

for x in columns_float:
    for y in range(len(orioles[x])):
        orioles.loc[y,x] = float(orioles.loc[y, x])  

for x in range(len(orioles['Game'])):
    if orioles.loc[x, 'Runs'] > orioles.loc[x, 'R']:
        orioles.loc[x, 'Win'] = 0
    else:
        orioles.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Orioles Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BAL&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BAL_2018_game_num = get_stat2('team_game_num')
BAL_2018_PA = get_stat2('PA')
BAL_2018_AB = get_stat2('AB')
BAL_2018_R = get_stat2('R')
BAL_2018_H = get_stat2('H')
BAL_2018_2B = get_stat2('2B')
BAL_2018_3B = get_stat2('3B')
BAL_2018_HR = get_stat2('HR')
BAL_2018_RBI = get_stat2('RBI')
BAL_2018_BB = get_stat2('BB')
BAL_2018_SO = get_stat2('SO')
BAL_2018_SB = get_stat2('SB')
BAL_2018_CS = get_stat2('CS')
BAL_2018_BA = get_stat2('batting_avg')
BAL_2018_OBP = get_stat2('onbase_perc')
BAL_2018_SLG = get_stat2('slugging_perc')
BAL_2018_OPS = get_stat2('onbase_plus_slugging')
BAL_2018_LOB = get_stat2('LOB')
orioles_2018_offense = pd.DataFrame({
                                  'PA': BAL_2018_PA,
                                  'AB': BAL_2018_AB,
                                  'R':  BAL_2018_R,
                                  'H':  BAL_2018_H,
                                  '2B': BAL_2018_2B,
                                  '3B': BAL_2018_3B, 
                                  'HR': BAL_2018_HR, 
                                  'RBI':BAL_2018_RBI,
                                  'BB': BAL_2018_BB,
                                  'SO': BAL_2018_SO,
                                  'SB': BAL_2018_SB,
                                  'CS': BAL_2018_CS,
                                  'LOB':BAL_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BAL&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BAL_2018_P_game_num = get_stat3('team_game_num')
BAL_2018_P_IP = get_stat3('IP')
BAL_2018_P_H = get_stat3('H')
BAL_2018_P_R = get_stat3('R')
BAL_2018_P_ER = get_stat3('ER')
BAL_2018_P_UER = get_stat3('UER')
BAL_2018_P_BB = get_stat3('BB')
BAL_2018_P_SO = get_stat3('SO')
BAL_2018_P_HR = get_stat3('HR')
BAL_2018_P_HBP = get_stat3('HBP')
BAL_2018_P_ERA = get_stat3('earned_run_avg')

orioles_2018_pitching = pd.DataFrame({'Game':  BAL_2018_P_game_num, 
                                         'IP':  BAL_2018_P_IP, 
                                         'H':   BAL_2018_P_H,
                                         'R':   BAL_2018_P_R,
                                         'ER':  BAL_2018_P_ER,
                                         'UER': BAL_2018_P_UER,
                                         'BB':  BAL_2018_P_BB,
                                         'SO':  BAL_2018_P_SO,
                                         'HR':  BAL_2018_P_HR,
                                         'HBP': BAL_2018_P_HBP})

# orioles_offense = orioles_offense.drop(columns = ['Game'])

orioles_2018_pitching = orioles_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [orioles_2018_pitching, orioles_2018_offense]

orioles_2018 = pd.concat(frames, axis=1)

orioles_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(orioles_2018[x])):
        orioles_2018.loc[y,x] = int(orioles_2018.loc[y, x])

for x in columns_float:
    for y in range(len(orioles_2018[x])):
        orioles_2018.loc[y,x] = float(orioles_2018.loc[y, x])  

for x in range(len(orioles_2018['Game'])):
    if orioles_2018.loc[x, 'Runs'] > orioles_2018.loc[x, 'R']:
        orioles_2018.loc[x, 'Win'] = 0
    else:
        orioles_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Orioles Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BAL&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BAL_2017_game_num = get_stat2('team_game_num')
BAL_2017_PA = get_stat2('PA')
BAL_2017_AB = get_stat2('AB')
BAL_2017_R = get_stat2('R')
BAL_2017_H = get_stat2('H')
BAL_2017_2B = get_stat2('2B')
BAL_2017_3B = get_stat2('3B')
BAL_2017_HR = get_stat2('HR')
BAL_2017_RBI = get_stat2('RBI')
BAL_2017_BB = get_stat2('BB')
BAL_2017_SO = get_stat2('SO')
BAL_2017_SB = get_stat2('SB')
BAL_2017_CS = get_stat2('CS')
BAL_2017_BA = get_stat2('batting_avg')
BAL_2017_OBP = get_stat2('onbase_perc')
BAL_2017_SLG = get_stat2('slugging_perc')
BAL_2017_OPS = get_stat2('onbase_plus_slugging')
BAL_2017_LOB = get_stat2('LOB')
orioles_2017_offense = pd.DataFrame({
                                  'PA': BAL_2017_PA,
                                  'AB': BAL_2017_AB,
                                  'R':  BAL_2017_R,
                                  'H':  BAL_2017_H,
                                  '2B': BAL_2017_2B,
                                  '3B': BAL_2017_3B, 
                                  'HR': BAL_2017_HR, 
                                  'RBI':BAL_2017_RBI,
                                  'BB': BAL_2017_BB,
                                  'SO': BAL_2017_SO,
                                  'SB': BAL_2017_SB,
                                  'CS': BAL_2017_CS,
                                  'LOB':BAL_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BAL&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BAL_2017_P_game_num = get_stat3('team_game_num')
BAL_2017_P_IP = get_stat3('IP')
BAL_2017_P_H = get_stat3('H')
BAL_2017_P_R = get_stat3('R')
BAL_2017_P_ER = get_stat3('ER')
BAL_2017_P_UER = get_stat3('UER')
BAL_2017_P_BB = get_stat3('BB')
BAL_2017_P_SO = get_stat3('SO')
BAL_2017_P_HR = get_stat3('HR')
BAL_2017_P_HBP = get_stat3('HBP')
BAL_2017_P_ERA = get_stat3('earned_run_avg')

orioles_2017_pitching = pd.DataFrame({'Game':  BAL_2017_P_game_num, 
                                         'IP':  BAL_2017_P_IP, 
                                         'H':   BAL_2017_P_H,
                                         'R':   BAL_2017_P_R,
                                         'ER':  BAL_2017_P_ER,
                                         'UER': BAL_2017_P_UER,
                                         'BB':  BAL_2017_P_BB,
                                         'SO':  BAL_2017_P_SO,
                                         'HR':  BAL_2017_P_HR,
                                         'HBP': BAL_2017_P_HBP})

# orioles_offense = orioles_offense.drop(columns = ['Game'])

orioles_2017_pitching = orioles_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [orioles_2017_pitching, orioles_2017_offense]

orioles_2017 = pd.concat(frames, axis=1)

orioles_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(orioles_2017[x])):
        orioles_2017.loc[y,x] = int(orioles_2017.loc[y, x])

for x in columns_float:
    for y in range(len(orioles_2017[x])):
        orioles_2017.loc[y,x] = float(orioles_2017.loc[y, x])  

for x in range(len(orioles_2017['Game'])):
    if orioles_2017.loc[x, 'Runs'] > orioles_2017.loc[x, 'R']:
        orioles_2017.loc[x, 'Win'] = 0
    else:
        orioles_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Orioles Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BAL&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BAL_2016_game_num = get_stat2('team_game_num')
BAL_2016_PA = get_stat2('PA')
BAL_2016_AB = get_stat2('AB')
BAL_2016_R = get_stat2('R')
BAL_2016_H = get_stat2('H')
BAL_2016_2B = get_stat2('2B')
BAL_2016_3B = get_stat2('3B')
BAL_2016_HR = get_stat2('HR')
BAL_2016_RBI = get_stat2('RBI')
BAL_2016_BB = get_stat2('BB')
BAL_2016_SO = get_stat2('SO')
BAL_2016_SB = get_stat2('SB')
BAL_2016_CS = get_stat2('CS')
BAL_2016_BA = get_stat2('batting_avg')
BAL_2016_OBP = get_stat2('onbase_perc')
BAL_2016_SLG = get_stat2('slugging_perc')
BAL_2016_OPS = get_stat2('onbase_plus_slugging')
BAL_2016_LOB = get_stat2('LOB')
orioles_2016_offense = pd.DataFrame({
                                  'PA': BAL_2016_PA,
                                  'AB': BAL_2016_AB,
                                  'R':  BAL_2016_R,
                                  'H':  BAL_2016_H,
                                  '2B': BAL_2016_2B,
                                  '3B': BAL_2016_3B, 
                                  'HR': BAL_2016_HR, 
                                  'RBI':BAL_2016_RBI,
                                  'BB': BAL_2016_BB,
                                  'SO': BAL_2016_SO,
                                  'SB': BAL_2016_SB,
                                  'CS': BAL_2016_CS,
                                  'LOB':BAL_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BAL&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BAL_2016_P_game_num = get_stat3('team_game_num')
BAL_2016_P_IP = get_stat3('IP')
BAL_2016_P_H = get_stat3('H')
BAL_2016_P_R = get_stat3('R')
BAL_2016_P_ER = get_stat3('ER')
BAL_2016_P_UER = get_stat3('UER')
BAL_2016_P_BB = get_stat3('BB')
BAL_2016_P_SO = get_stat3('SO')
BAL_2016_P_HR = get_stat3('HR')
BAL_2016_P_HBP = get_stat3('HBP')
BAL_2016_P_ERA = get_stat3('earned_run_avg')

orioles_2016_pitching = pd.DataFrame({'Game':  BAL_2016_P_game_num, 
                                         'IP':  BAL_2016_P_IP, 
                                         'H':   BAL_2016_P_H,
                                         'R':   BAL_2016_P_R,
                                         'ER':  BAL_2016_P_ER,
                                         'UER': BAL_2016_P_UER,
                                         'BB':  BAL_2016_P_BB,
                                         'SO':  BAL_2016_P_SO,
                                         'HR':  BAL_2016_P_HR,
                                         'HBP': BAL_2016_P_HBP})

# orioles_offense = orioles_offense.drop(columns = ['Game'])

orioles_2016_pitching = orioles_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [orioles_2016_pitching, orioles_2016_offense]

orioles_2016 = pd.concat(frames, axis=1)

orioles_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(orioles_2016[x])):
        orioles_2016.loc[y,x] = int(orioles_2016.loc[y, x])

for x in columns_float:
    for y in range(len(orioles_2016[x])):
        orioles_2016.loc[y,x] = float(orioles_2016.loc[y, x])  

for x in range(len(orioles_2016['Game'])):
    if orioles_2016.loc[x, 'Runs'] > orioles_2016.loc[x, 'R']:
        orioles_2016.loc[x, 'Win'] = 0
    else:
        orioles_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Orioles Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BAL&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BAL_2015_game_num = get_stat2('team_game_num')
BAL_2015_PA = get_stat2('PA')
BAL_2015_AB = get_stat2('AB')
BAL_2015_R = get_stat2('R')
BAL_2015_H = get_stat2('H')
BAL_2015_2B = get_stat2('2B')
BAL_2015_3B = get_stat2('3B')
BAL_2015_HR = get_stat2('HR')
BAL_2015_RBI = get_stat2('RBI')
BAL_2015_BB = get_stat2('BB')
BAL_2015_SO = get_stat2('SO')
BAL_2015_SB = get_stat2('SB')
BAL_2015_CS = get_stat2('CS')
BAL_2015_BA = get_stat2('batting_avg')
BAL_2015_OBP = get_stat2('onbase_perc')
BAL_2015_SLG = get_stat2('slugging_perc')
BAL_2015_OPS = get_stat2('onbase_plus_slugging')
BAL_2015_LOB = get_stat2('LOB')
orioles_2015_offense = pd.DataFrame({
                                  'PA': BAL_2015_PA,
                                  'AB': BAL_2015_AB,
                                  'R':  BAL_2015_R,
                                  'H':  BAL_2015_H,
                                  '2B': BAL_2015_2B,
                                  '3B': BAL_2015_3B, 
                                  'HR': BAL_2015_HR, 
                                  'RBI':BAL_2015_RBI,
                                  'BB': BAL_2015_BB,
                                  'SO': BAL_2015_SO,
                                  'SB': BAL_2015_SB,
                                  'CS': BAL_2015_CS,
                                  'LOB':BAL_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=BAL&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

BAL_2015_P_game_num = get_stat3('team_game_num')
BAL_2015_P_IP = get_stat3('IP')
BAL_2015_P_H = get_stat3('H')
BAL_2015_P_R = get_stat3('R')
BAL_2015_P_ER = get_stat3('ER')
BAL_2015_P_UER = get_stat3('UER')
BAL_2015_P_BB = get_stat3('BB')
BAL_2015_P_SO = get_stat3('SO')
BAL_2015_P_HR = get_stat3('HR')
BAL_2015_P_HBP = get_stat3('HBP')
BAL_2015_P_ERA = get_stat3('earned_run_avg')

orioles_2015_pitching = pd.DataFrame({'Game':  BAL_2015_P_game_num, 
                                         'IP':  BAL_2015_P_IP, 
                                         'H':   BAL_2015_P_H,
                                         'R':   BAL_2015_P_R,
                                         'ER':  BAL_2015_P_ER,
                                         'UER': BAL_2015_P_UER,
                                         'BB':  BAL_2015_P_BB,
                                         'SO':  BAL_2015_P_SO,
                                         'HR':  BAL_2015_P_HR,
                                         'HBP': BAL_2015_P_HBP})

# orioles_offense = orioles_offense.drop(columns = ['Game'])

orioles_2015_pitching = orioles_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [orioles_2015_pitching, orioles_2015_offense]

orioles_2015 = pd.concat(frames, axis=1)

orioles_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(orioles_2015[x])):
        orioles_2015.loc[y,x] = int(orioles_2015.loc[y, x])

for x in columns_float:
    for y in range(len(orioles_2015[x])):
        orioles_2015.loc[y,x] = float(orioles_2015.loc[y, x])  

for x in range(len(orioles_2015['Game'])):
    if orioles_2015.loc[x, 'Runs'] > orioles_2015.loc[x, 'R']:
        orioles_2015.loc[x, 'Win'] = 0
    else:
        orioles_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Twins Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIN&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIN_game_num = get_stat2('team_game_num')
MIN_PA = get_stat2('PA')
MIN_AB = get_stat2('AB')
MIN_R = get_stat2('R')
MIN_H = get_stat2('H')
MIN_2B = get_stat2('2B')
MIN_3B = get_stat2('3B')
MIN_HR = get_stat2('HR')
MIN_RBI = get_stat2('RBI')
MIN_BB = get_stat2('BB')
MIN_SO = get_stat2('SO')
MIN_SB = get_stat2('SB')
MIN_CS = get_stat2('CS')
MIN_BA = get_stat2('batting_avg')
MIN_OBP = get_stat2('onbase_perc')
MIN_SLG = get_stat2('slugging_perc')
MIN_OPS = get_stat2('onbase_plus_slugging')
MIN_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


twins_offense = pd.DataFrame({
                                  'PA': MIN_PA,
                                  'AB': MIN_AB,
                                  'R':  MIN_R,
                                  'H':  MIN_H,
                                  '2B': MIN_2B,
                                  '3B': MIN_3B, 
                                  'HR': MIN_HR, 
                                  'RBI':MIN_RBI,
                                  'BB': MIN_BB,
                                  'SO': MIN_SO,
                                  'SB': MIN_SB,
                                  'CS': MIN_CS,
                                  'LOB':MIN_LOB})

# %% [markdown]
# # 2019 Twins Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIN&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIN_P_game_num = get_stat3('team_game_num')
MIN_P_IP = get_stat3('IP')
MIN_P_H = get_stat3('H')
MIN_P_R = get_stat3('R')
MIN_P_ER = get_stat3('ER')
MIN_P_UER = get_stat3('UER')
MIN_P_BB = get_stat3('BB')
MIN_P_SO = get_stat3('SO')
MIN_P_HR = get_stat3('HR')
MIN_P_HBP = get_stat3('HBP')
MIN_P_ERA = get_stat3('earned_run_avg')

twins_pitching = pd.DataFrame({'Game':  MIN_P_game_num, 
                                   'IP':  MIN_P_IP, 
                                   'H':   MIN_P_H,
                                   'R':   MIN_P_R,
                                   'ER':  MIN_P_ER,
                                   'UER': MIN_P_UER,
                                   'BB':  MIN_P_BB,
                                   'SO':  MIN_P_SO,
                                   'HR':  MIN_P_HR,
                                   'HBP': MIN_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

twins_pitching = twins_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [twins_pitching, twins_offense]

twins = pd.concat(frames, axis=1)

twins['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(twins[x])):
        twins.loc[y,x] = int(twins.loc[y, x])

for x in columns_float:
    for y in range(len(twins[x])):
        twins.loc[y,x] = float(twins.loc[y, x])  

for x in range(len(twins['Game'])):
    if twins.loc[x, 'Runs'] > twins.loc[x, 'R']:
        twins.loc[x, 'Win'] = 0
    else:
        twins.loc[x, 'Win'] = 1

# %% [markdown]
#  # 2018 Twins Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIN&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIN_2018_game_num = get_stat2('team_game_num')
MIN_2018_PA = get_stat2('PA')
MIN_2018_AB = get_stat2('AB')
MIN_2018_R = get_stat2('R')
MIN_2018_H = get_stat2('H')
MIN_2018_2B = get_stat2('2B')
MIN_2018_3B = get_stat2('3B')
MIN_2018_HR = get_stat2('HR')
MIN_2018_RBI = get_stat2('RBI')
MIN_2018_BB = get_stat2('BB')
MIN_2018_SO = get_stat2('SO')
MIN_2018_SB = get_stat2('SB')
MIN_2018_CS = get_stat2('CS')
MIN_2018_BA = get_stat2('batting_avg')
MIN_2018_OBP = get_stat2('onbase_perc')
MIN_2018_SLG = get_stat2('slugging_perc')
MIN_2018_OPS = get_stat2('onbase_plus_slugging')
MIN_2018_LOB = get_stat2('LOB')
twins_2018_offense = pd.DataFrame({
                                  'PA': MIN_2018_PA,
                                  'AB': MIN_2018_AB,
                                  'R':  MIN_2018_R,
                                  'H':  MIN_2018_H,
                                  '2B': MIN_2018_2B,
                                  '3B': MIN_2018_3B, 
                                  'HR': MIN_2018_HR, 
                                  'RBI':MIN_2018_RBI,
                                  'BB': MIN_2018_BB,
                                  'SO': MIN_2018_SO,
                                  'SB': MIN_2018_SB,
                                  'CS': MIN_2018_CS,
                                  'LOB':MIN_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIN&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIN_2018_P_game_num = get_stat3('team_game_num')
MIN_2018_P_IP = get_stat3('IP')
MIN_2018_P_H = get_stat3('H')
MIN_2018_P_R = get_stat3('R')
MIN_2018_P_ER = get_stat3('ER')
MIN_2018_P_UER = get_stat3('UER')
MIN_2018_P_BB = get_stat3('BB')
MIN_2018_P_SO = get_stat3('SO')
MIN_2018_P_HR = get_stat3('HR')
MIN_2018_P_HBP = get_stat3('HBP')
MIN_2018_P_ERA = get_stat3('earned_run_avg')

twins_2018_pitching = pd.DataFrame({'Game':  MIN_2018_P_game_num, 
                                         'IP':  MIN_2018_P_IP, 
                                         'H':   MIN_2018_P_H,
                                         'R':   MIN_2018_P_R,
                                         'ER':  MIN_2018_P_ER,
                                         'UER': MIN_2018_P_UER,
                                         'BB':  MIN_2018_P_BB,
                                         'SO':  MIN_2018_P_SO,
                                         'HR':  MIN_2018_P_HR,
                                         'HBP': MIN_2018_P_HBP})

# twins_offense = twins_offense.drop(columns = ['Game'])

twins_2018_pitching = twins_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [twins_2018_pitching, twins_2018_offense]

twins_2018 = pd.concat(frames, axis=1)

twins_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(twins_2018[x])):
        twins_2018.loc[y,x] = int(twins_2018.loc[y, x])

for x in columns_float:
    for y in range(len(twins_2018[x])):
        twins_2018.loc[y,x] = float(twins_2018.loc[y, x])  

for x in range(len(twins_2018['Game'])):
    if twins_2018.loc[x, 'Runs'] > twins_2018.loc[x, 'R']:
        twins_2018.loc[x, 'Win'] = 0
    else:
        twins_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Twins Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIN&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIN_2017_game_num = get_stat2('team_game_num')
MIN_2017_PA = get_stat2('PA')
MIN_2017_AB = get_stat2('AB')
MIN_2017_R = get_stat2('R')
MIN_2017_H = get_stat2('H')
MIN_2017_2B = get_stat2('2B')
MIN_2017_3B = get_stat2('3B')
MIN_2017_HR = get_stat2('HR')
MIN_2017_RBI = get_stat2('RBI')
MIN_2017_BB = get_stat2('BB')
MIN_2017_SO = get_stat2('SO')
MIN_2017_SB = get_stat2('SB')
MIN_2017_CS = get_stat2('CS')
MIN_2017_BA = get_stat2('batting_avg')
MIN_2017_OBP = get_stat2('onbase_perc')
MIN_2017_SLG = get_stat2('slugging_perc')
MIN_2017_OPS = get_stat2('onbase_plus_slugging')
MIN_2017_LOB = get_stat2('LOB')
twins_2017_offense = pd.DataFrame({
                                  'PA': MIN_2017_PA,
                                  'AB': MIN_2017_AB,
                                  'R':  MIN_2017_R,
                                  'H':  MIN_2017_H,
                                  '2B': MIN_2017_2B,
                                  '3B': MIN_2017_3B, 
                                  'HR': MIN_2017_HR, 
                                  'RBI':MIN_2017_RBI,
                                  'BB': MIN_2017_BB,
                                  'SO': MIN_2017_SO,
                                  'SB': MIN_2017_SB,
                                  'CS': MIN_2017_CS,
                                  'LOB':MIN_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIN&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIN_2017_P_game_num = get_stat3('team_game_num')
MIN_2017_P_IP = get_stat3('IP')
MIN_2017_P_H = get_stat3('H')
MIN_2017_P_R = get_stat3('R')
MIN_2017_P_ER = get_stat3('ER')
MIN_2017_P_UER = get_stat3('UER')
MIN_2017_P_BB = get_stat3('BB')
MIN_2017_P_SO = get_stat3('SO')
MIN_2017_P_HR = get_stat3('HR')
MIN_2017_P_HBP = get_stat3('HBP')
MIN_2017_P_ERA = get_stat3('earned_run_avg')

twins_2017_pitching = pd.DataFrame({'Game':  MIN_2017_P_game_num, 
                                         'IP':  MIN_2017_P_IP, 
                                         'H':   MIN_2017_P_H,
                                         'R':   MIN_2017_P_R,
                                         'ER':  MIN_2017_P_ER,
                                         'UER': MIN_2017_P_UER,
                                         'BB':  MIN_2017_P_BB,
                                         'SO':  MIN_2017_P_SO,
                                         'HR':  MIN_2017_P_HR,
                                         'HBP': MIN_2017_P_HBP})

# twins_offense = twins_offense.drop(columns = ['Game'])

twins_2017_pitching = twins_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [twins_2017_pitching, twins_2017_offense]

twins_2017 = pd.concat(frames, axis=1)

twins_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(twins_2017[x])):
        twins_2017.loc[y,x] = int(twins_2017.loc[y, x])

for x in columns_float:
    for y in range(len(twins_2017[x])):
        twins_2017.loc[y,x] = float(twins_2017.loc[y, x])  

for x in range(len(twins_2017['Game'])):
    if twins_2017.loc[x, 'Runs'] > twins_2017.loc[x, 'R']:
        twins_2017.loc[x, 'Win'] = 0
    else:
        twins_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Twins Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIN&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIN_2016_game_num = get_stat2('team_game_num')
MIN_2016_PA = get_stat2('PA')
MIN_2016_AB = get_stat2('AB')
MIN_2016_R = get_stat2('R')
MIN_2016_H = get_stat2('H')
MIN_2016_2B = get_stat2('2B')
MIN_2016_3B = get_stat2('3B')
MIN_2016_HR = get_stat2('HR')
MIN_2016_RBI = get_stat2('RBI')
MIN_2016_BB = get_stat2('BB')
MIN_2016_SO = get_stat2('SO')
MIN_2016_SB = get_stat2('SB')
MIN_2016_CS = get_stat2('CS')
MIN_2016_BA = get_stat2('batting_avg')
MIN_2016_OBP = get_stat2('onbase_perc')
MIN_2016_SLG = get_stat2('slugging_perc')
MIN_2016_OPS = get_stat2('onbase_plus_slugging')
MIN_2016_LOB = get_stat2('LOB')
twins_2016_offense = pd.DataFrame({
                                  'PA': MIN_2016_PA,
                                  'AB': MIN_2016_AB,
                                  'R':  MIN_2016_R,
                                  'H':  MIN_2016_H,
                                  '2B': MIN_2016_2B,
                                  '3B': MIN_2016_3B, 
                                  'HR': MIN_2016_HR, 
                                  'RBI':MIN_2016_RBI,
                                  'BB': MIN_2016_BB,
                                  'SO': MIN_2016_SO,
                                  'SB': MIN_2016_SB,
                                  'CS': MIN_2016_CS,
                                  'LOB':MIN_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIN&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIN_2016_P_game_num = get_stat3('team_game_num')
MIN_2016_P_IP = get_stat3('IP')
MIN_2016_P_H = get_stat3('H')
MIN_2016_P_R = get_stat3('R')
MIN_2016_P_ER = get_stat3('ER')
MIN_2016_P_UER = get_stat3('UER')
MIN_2016_P_BB = get_stat3('BB')
MIN_2016_P_SO = get_stat3('SO')
MIN_2016_P_HR = get_stat3('HR')
MIN_2016_P_HBP = get_stat3('HBP')
MIN_2016_P_ERA = get_stat3('earned_run_avg')

twins_2016_pitching = pd.DataFrame({'Game':  MIN_2016_P_game_num, 
                                         'IP':  MIN_2016_P_IP, 
                                         'H':   MIN_2016_P_H,
                                         'R':   MIN_2016_P_R,
                                         'ER':  MIN_2016_P_ER,
                                         'UER': MIN_2016_P_UER,
                                         'BB':  MIN_2016_P_BB,
                                         'SO':  MIN_2016_P_SO,
                                         'HR':  MIN_2016_P_HR,
                                         'HBP': MIN_2016_P_HBP})

# twins_offense = twins_offense.drop(columns = ['Game'])

twins_2016_pitching = twins_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [twins_2016_pitching, twins_2016_offense]

twins_2016 = pd.concat(frames, axis=1)

twins_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(twins_2016[x])):
        twins_2016.loc[y,x] = int(twins_2016.loc[y, x])

for x in columns_float:
    for y in range(len(twins_2016[x])):
        twins_2016.loc[y,x] = float(twins_2016.loc[y, x])  

for x in range(len(twins_2016['Game'])):
    if twins_2016.loc[x, 'Runs'] > twins_2016.loc[x, 'R']:
        twins_2016.loc[x, 'Win'] = 0
    else:
        twins_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Twins Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIN&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIN_2015_game_num = get_stat2('team_game_num')
MIN_2015_PA = get_stat2('PA')
MIN_2015_AB = get_stat2('AB')
MIN_2015_R = get_stat2('R')
MIN_2015_H = get_stat2('H')
MIN_2015_2B = get_stat2('2B')
MIN_2015_3B = get_stat2('3B')
MIN_2015_HR = get_stat2('HR')
MIN_2015_RBI = get_stat2('RBI')
MIN_2015_BB = get_stat2('BB')
MIN_2015_SO = get_stat2('SO')
MIN_2015_SB = get_stat2('SB')
MIN_2015_CS = get_stat2('CS')
MIN_2015_BA = get_stat2('batting_avg')
MIN_2015_OBP = get_stat2('onbase_perc')
MIN_2015_SLG = get_stat2('slugging_perc')
MIN_2015_OPS = get_stat2('onbase_plus_slugging')
MIN_2015_LOB = get_stat2('LOB')
twins_2015_offense = pd.DataFrame({
                                  'PA': MIN_2015_PA,
                                  'AB': MIN_2015_AB,
                                  'R':  MIN_2015_R,
                                  'H':  MIN_2015_H,
                                  '2B': MIN_2015_2B,
                                  '3B': MIN_2015_3B, 
                                  'HR': MIN_2015_HR, 
                                  'RBI':MIN_2015_RBI,
                                  'BB': MIN_2015_BB,
                                  'SO': MIN_2015_SO,
                                  'SB': MIN_2015_SB,
                                  'CS': MIN_2015_CS,
                                  'LOB':MIN_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=MIN&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

MIN_2015_P_game_num = get_stat3('team_game_num')
MIN_2015_P_IP = get_stat3('IP')
MIN_2015_P_H = get_stat3('H')
MIN_2015_P_R = get_stat3('R')
MIN_2015_P_ER = get_stat3('ER')
MIN_2015_P_UER = get_stat3('UER')
MIN_2015_P_BB = get_stat3('BB')
MIN_2015_P_SO = get_stat3('SO')
MIN_2015_P_HR = get_stat3('HR')
MIN_2015_P_HBP = get_stat3('HBP')
MIN_2015_P_ERA = get_stat3('earned_run_avg')

twins_2015_pitching = pd.DataFrame({'Game':  MIN_2015_P_game_num, 
                                         'IP':  MIN_2015_P_IP, 
                                         'H':   MIN_2015_P_H,
                                         'R':   MIN_2015_P_R,
                                         'ER':  MIN_2015_P_ER,
                                         'UER': MIN_2015_P_UER,
                                         'BB':  MIN_2015_P_BB,
                                         'SO':  MIN_2015_P_SO,
                                         'HR':  MIN_2015_P_HR,
                                         'HBP': MIN_2015_P_HBP})

# twins_offense = twins_offense.drop(columns = ['Game'])

twins_2015_pitching = twins_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [twins_2015_pitching, twins_2015_offense]

twins_2015 = pd.concat(frames, axis=1)

twins_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(twins_2015[x])):
        twins_2015.loc[y,x] = int(twins_2015.loc[y, x])

for x in columns_float:
    for y in range(len(twins_2015[x])):
        twins_2015.loc[y,x] = float(twins_2015.loc[y, x])  

for x in range(len(twins_2015['Game'])):
    if twins_2015.loc[x, 'Runs'] > twins_2015.loc[x, 'R']:
        twins_2015.loc[x, 'Win'] = 0
    else:
        twins_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Indians Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CLE&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CLE_game_num = get_stat2('team_game_num')
CLE_PA = get_stat2('PA')
CLE_AB = get_stat2('AB')
CLE_R = get_stat2('R')
CLE_H = get_stat2('H')
CLE_2B = get_stat2('2B')
CLE_3B = get_stat2('3B')
CLE_HR = get_stat2('HR')
CLE_RBI = get_stat2('RBI')
CLE_BB = get_stat2('BB')
CLE_SO = get_stat2('SO')
CLE_SB = get_stat2('SB')
CLE_CS = get_stat2('CS')
CLE_BA = get_stat2('batting_avg')
CLE_OBP = get_stat2('onbase_perc')
CLE_SLG = get_stat2('slugging_perc')
CLE_OPS = get_stat2('onbase_plus_slugging')
CLE_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


indians_offense = pd.DataFrame({
                                  'PA': CLE_PA,
                                  'AB': CLE_AB,
                                  'R':  CLE_R,
                                  'H':  CLE_H,
                                  '2B': CLE_2B,
                                  '3B': CLE_3B, 
                                  'HR': CLE_HR, 
                                  'RBI':CLE_RBI,
                                  'BB': CLE_BB,
                                  'SO': CLE_SO,
                                  'SB': CLE_SB,
                                  'CS': CLE_CS,
                                  'LOB':CLE_LOB})

# %% [markdown]
# # 2019 Indians Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CLE&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CLE_P_game_num = get_stat3('team_game_num')
CLE_P_IP = get_stat3('IP')
CLE_P_H = get_stat3('H')
CLE_P_R = get_stat3('R')
CLE_P_ER = get_stat3('ER')
CLE_P_UER = get_stat3('UER')
CLE_P_BB = get_stat3('BB')
CLE_P_SO = get_stat3('SO')
CLE_P_HR = get_stat3('HR')
CLE_P_HBP = get_stat3('HBP')
CLE_P_ERA = get_stat3('earned_run_avg')

indians_pitching = pd.DataFrame({'Game':  CLE_P_game_num, 
                                   'IP':  CLE_P_IP, 
                                   'H':   CLE_P_H,
                                   'R':   CLE_P_R,
                                   'ER':  CLE_P_ER,
                                   'UER': CLE_P_UER,
                                   'BB':  CLE_P_BB,
                                   'SO':  CLE_P_SO,
                                   'HR':  CLE_P_HR,
                                   'HBP': CLE_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

indians_pitching = indians_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [indians_pitching, indians_offense]

indians = pd.concat(frames, axis=1)

indians['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(indians[x])):
        indians.loc[y,x] = int(indians.loc[y, x])

for x in columns_float:
    for y in range(len(indians[x])):
        indians.loc[y,x] = float(indians.loc[y, x])  

for x in range(len(indians['Game'])):
    if indians.loc[x, 'Runs'] > indians.loc[x, 'R']:
        indians.loc[x, 'Win'] = 0
    else:
        indians.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Indians Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CLE&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CLE_2018_game_num = get_stat2('team_game_num')
CLE_2018_PA = get_stat2('PA')
CLE_2018_AB = get_stat2('AB')
CLE_2018_R = get_stat2('R')
CLE_2018_H = get_stat2('H')
CLE_2018_2B = get_stat2('2B')
CLE_2018_3B = get_stat2('3B')
CLE_2018_HR = get_stat2('HR')
CLE_2018_RBI = get_stat2('RBI')
CLE_2018_BB = get_stat2('BB')
CLE_2018_SO = get_stat2('SO')
CLE_2018_SB = get_stat2('SB')
CLE_2018_CS = get_stat2('CS')
CLE_2018_BA = get_stat2('batting_avg')
CLE_2018_OBP = get_stat2('onbase_perc')
CLE_2018_SLG = get_stat2('slugging_perc')
CLE_2018_OPS = get_stat2('onbase_plus_slugging')
CLE_2018_LOB = get_stat2('LOB')
indians_2018_offense = pd.DataFrame({
                                  'PA': CLE_2018_PA,
                                  'AB': CLE_2018_AB,
                                  'R':  CLE_2018_R,
                                  'H':  CLE_2018_H,
                                  '2B': CLE_2018_2B,
                                  '3B': CLE_2018_3B, 
                                  'HR': CLE_2018_HR, 
                                  'RBI':CLE_2018_RBI,
                                  'BB': CLE_2018_BB,
                                  'SO': CLE_2018_SO,
                                  'SB': CLE_2018_SB,
                                  'CS': CLE_2018_CS,
                                  'LOB':CLE_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CLE&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CLE_2018_P_game_num = get_stat3('team_game_num')
CLE_2018_P_IP = get_stat3('IP')
CLE_2018_P_H = get_stat3('H')
CLE_2018_P_R = get_stat3('R')
CLE_2018_P_ER = get_stat3('ER')
CLE_2018_P_UER = get_stat3('UER')
CLE_2018_P_BB = get_stat3('BB')
CLE_2018_P_SO = get_stat3('SO')
CLE_2018_P_HR = get_stat3('HR')
CLE_2018_P_HBP = get_stat3('HBP')
CLE_2018_P_ERA = get_stat3('earned_run_avg')

indians_2018_pitching = pd.DataFrame({'Game':  CLE_2018_P_game_num, 
                                         'IP':  CLE_2018_P_IP, 
                                         'H':   CLE_2018_P_H,
                                         'R':   CLE_2018_P_R,
                                         'ER':  CLE_2018_P_ER,
                                         'UER': CLE_2018_P_UER,
                                         'BB':  CLE_2018_P_BB,
                                         'SO':  CLE_2018_P_SO,
                                         'HR':  CLE_2018_P_HR,
                                         'HBP': CLE_2018_P_HBP})

# indians_offense = indians_offense.drop(columns = ['Game'])

indians_2018_pitching = indians_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [indians_2018_pitching, indians_2018_offense]

indians_2018 = pd.concat(frames, axis=1)

indians_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(indians_2018[x])):
        indians_2018.loc[y,x] = int(indians_2018.loc[y, x])

for x in columns_float:
    for y in range(len(indians_2018[x])):
        indians_2018.loc[y,x] = float(indians_2018.loc[y, x])  

for x in range(len(indians_2018['Game'])):
    if indians_2018.loc[x, 'Runs'] > indians_2018.loc[x, 'R']:
        indians_2018.loc[x, 'Win'] = 0
    else:
        indians_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Indians Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CLE&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CLE_2017_game_num = get_stat2('team_game_num')
CLE_2017_PA = get_stat2('PA')
CLE_2017_AB = get_stat2('AB')
CLE_2017_R = get_stat2('R')
CLE_2017_H = get_stat2('H')
CLE_2017_2B = get_stat2('2B')
CLE_2017_3B = get_stat2('3B')
CLE_2017_HR = get_stat2('HR')
CLE_2017_RBI = get_stat2('RBI')
CLE_2017_BB = get_stat2('BB')
CLE_2017_SO = get_stat2('SO')
CLE_2017_SB = get_stat2('SB')
CLE_2017_CS = get_stat2('CS')
CLE_2017_BA = get_stat2('batting_avg')
CLE_2017_OBP = get_stat2('onbase_perc')
CLE_2017_SLG = get_stat2('slugging_perc')
CLE_2017_OPS = get_stat2('onbase_plus_slugging')
CLE_2017_LOB = get_stat2('LOB')
indians_2017_offense = pd.DataFrame({
                                  'PA': CLE_2017_PA,
                                  'AB': CLE_2017_AB,
                                  'R':  CLE_2017_R,
                                  'H':  CLE_2017_H,
                                  '2B': CLE_2017_2B,
                                  '3B': CLE_2017_3B, 
                                  'HR': CLE_2017_HR, 
                                  'RBI':CLE_2017_RBI,
                                  'BB': CLE_2017_BB,
                                  'SO': CLE_2017_SO,
                                  'SB': CLE_2017_SB,
                                  'CS': CLE_2017_CS,
                                  'LOB':CLE_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CLE&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CLE_2017_P_game_num = get_stat3('team_game_num')
CLE_2017_P_IP = get_stat3('IP')
CLE_2017_P_H = get_stat3('H')
CLE_2017_P_R = get_stat3('R')
CLE_2017_P_ER = get_stat3('ER')
CLE_2017_P_UER = get_stat3('UER')
CLE_2017_P_BB = get_stat3('BB')
CLE_2017_P_SO = get_stat3('SO')
CLE_2017_P_HR = get_stat3('HR')
CLE_2017_P_HBP = get_stat3('HBP')
CLE_2017_P_ERA = get_stat3('earned_run_avg')

indians_2017_pitching = pd.DataFrame({'Game':  CLE_2017_P_game_num, 
                                         'IP':  CLE_2017_P_IP, 
                                         'H':   CLE_2017_P_H,
                                         'R':   CLE_2017_P_R,
                                         'ER':  CLE_2017_P_ER,
                                         'UER': CLE_2017_P_UER,
                                         'BB':  CLE_2017_P_BB,
                                         'SO':  CLE_2017_P_SO,
                                         'HR':  CLE_2017_P_HR,
                                         'HBP': CLE_2017_P_HBP})

# indians_offense = indians_offense.drop(columns = ['Game'])

indians_2017_pitching = indians_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [indians_2017_pitching, indians_2017_offense]

indians_2017 = pd.concat(frames, axis=1)

indians_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(indians_2017[x])):
        indians_2017.loc[y,x] = int(indians_2017.loc[y, x])

for x in columns_float:
    for y in range(len(indians_2017[x])):
        indians_2017.loc[y,x] = float(indians_2017.loc[y, x])  

for x in range(len(indians_2017['Game'])):
    if indians_2017.loc[x, 'Runs'] > indians_2017.loc[x, 'R']:
        indians_2017.loc[x, 'Win'] = 0
    else:
        indians_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Indians Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CLE&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CLE_2016_game_num = get_stat2('team_game_num')
CLE_2016_PA = get_stat2('PA')
CLE_2016_AB = get_stat2('AB')
CLE_2016_R = get_stat2('R')
CLE_2016_H = get_stat2('H')
CLE_2016_2B = get_stat2('2B')
CLE_2016_3B = get_stat2('3B')
CLE_2016_HR = get_stat2('HR')
CLE_2016_RBI = get_stat2('RBI')
CLE_2016_BB = get_stat2('BB')
CLE_2016_SO = get_stat2('SO')
CLE_2016_SB = get_stat2('SB')
CLE_2016_CS = get_stat2('CS')
CLE_2016_BA = get_stat2('batting_avg')
CLE_2016_OBP = get_stat2('onbase_perc')
CLE_2016_SLG = get_stat2('slugging_perc')
CLE_2016_OPS = get_stat2('onbase_plus_slugging')
CLE_2016_LOB = get_stat2('LOB')
indians_2016_offense = pd.DataFrame({
                                  'PA': CLE_2016_PA,
                                  'AB': CLE_2016_AB,
                                  'R':  CLE_2016_R,
                                  'H':  CLE_2016_H,
                                  '2B': CLE_2016_2B,
                                  '3B': CLE_2016_3B, 
                                  'HR': CLE_2016_HR, 
                                  'RBI':CLE_2016_RBI,
                                  'BB': CLE_2016_BB,
                                  'SO': CLE_2016_SO,
                                  'SB': CLE_2016_SB,
                                  'CS': CLE_2016_CS,
                                  'LOB':CLE_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CLE&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CLE_2016_P_game_num = get_stat3('team_game_num')
CLE_2016_P_IP = get_stat3('IP')
CLE_2016_P_H = get_stat3('H')
CLE_2016_P_R = get_stat3('R')
CLE_2016_P_ER = get_stat3('ER')
CLE_2016_P_UER = get_stat3('UER')
CLE_2016_P_BB = get_stat3('BB')
CLE_2016_P_SO = get_stat3('SO')
CLE_2016_P_HR = get_stat3('HR')
CLE_2016_P_HBP = get_stat3('HBP')
CLE_2016_P_ERA = get_stat3('earned_run_avg')

indians_2016_pitching = pd.DataFrame({'Game':  CLE_2016_P_game_num, 
                                         'IP':  CLE_2016_P_IP, 
                                         'H':   CLE_2016_P_H,
                                         'R':   CLE_2016_P_R,
                                         'ER':  CLE_2016_P_ER,
                                         'UER': CLE_2016_P_UER,
                                         'BB':  CLE_2016_P_BB,
                                         'SO':  CLE_2016_P_SO,
                                         'HR':  CLE_2016_P_HR,
                                         'HBP': CLE_2016_P_HBP})

# indians_offense = indians_offense.drop(columns = ['Game'])

indians_2016_pitching = indians_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [indians_2016_pitching, indians_2016_offense]

indians_2016 = pd.concat(frames, axis=1)

indians_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(indians_2016[x])):
        indians_2016.loc[y,x] = int(indians_2016.loc[y, x])

for x in columns_float:
    for y in range(len(indians_2016[x])):
        indians_2016.loc[y,x] = float(indians_2016.loc[y, x])  

for x in range(len(indians_2016['Game'])):
    if indians_2016.loc[x, 'Runs'] > indians_2016.loc[x, 'R']:
        indians_2016.loc[x, 'Win'] = 0
    else:
        indians_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Indians Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CLE&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CLE_2015_game_num = get_stat2('team_game_num')
CLE_2015_PA = get_stat2('PA')
CLE_2015_AB = get_stat2('AB')
CLE_2015_R = get_stat2('R')
CLE_2015_H = get_stat2('H')
CLE_2015_2B = get_stat2('2B')
CLE_2015_3B = get_stat2('3B')
CLE_2015_HR = get_stat2('HR')
CLE_2015_RBI = get_stat2('RBI')
CLE_2015_BB = get_stat2('BB')
CLE_2015_SO = get_stat2('SO')
CLE_2015_SB = get_stat2('SB')
CLE_2015_CS = get_stat2('CS')
CLE_2015_BA = get_stat2('batting_avg')
CLE_2015_OBP = get_stat2('onbase_perc')
CLE_2015_SLG = get_stat2('slugging_perc')
CLE_2015_OPS = get_stat2('onbase_plus_slugging')
CLE_2015_LOB = get_stat2('LOB')
indians_2015_offense = pd.DataFrame({
                                  'PA': CLE_2015_PA,
                                  'AB': CLE_2015_AB,
                                  'R':  CLE_2015_R,
                                  'H':  CLE_2015_H,
                                  '2B': CLE_2015_2B,
                                  '3B': CLE_2015_3B, 
                                  'HR': CLE_2015_HR, 
                                  'RBI':CLE_2015_RBI,
                                  'BB': CLE_2015_BB,
                                  'SO': CLE_2015_SO,
                                  'SB': CLE_2015_SB,
                                  'CS': CLE_2015_CS,
                                  'LOB':CLE_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CLE&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CLE_2015_P_game_num = get_stat3('team_game_num')
CLE_2015_P_IP = get_stat3('IP')
CLE_2015_P_H = get_stat3('H')
CLE_2015_P_R = get_stat3('R')
CLE_2015_P_ER = get_stat3('ER')
CLE_2015_P_UER = get_stat3('UER')
CLE_2015_P_BB = get_stat3('BB')
CLE_2015_P_SO = get_stat3('SO')
CLE_2015_P_HR = get_stat3('HR')
CLE_2015_P_HBP = get_stat3('HBP')
CLE_2015_P_ERA = get_stat3('earned_run_avg')

indians_2015_pitching = pd.DataFrame({'Game':  CLE_2015_P_game_num, 
                                         'IP':  CLE_2015_P_IP, 
                                         'H':   CLE_2015_P_H,
                                         'R':   CLE_2015_P_R,
                                         'ER':  CLE_2015_P_ER,
                                         'UER': CLE_2015_P_UER,
                                         'BB':  CLE_2015_P_BB,
                                         'SO':  CLE_2015_P_SO,
                                         'HR':  CLE_2015_P_HR,
                                         'HBP': CLE_2015_P_HBP})

# indians_offense = indians_offense.drop(columns = ['Game'])

indians_2015_pitching = indians_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [indians_2015_pitching, indians_2015_offense]

indians_2015 = pd.concat(frames, axis=1)

indians_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(indians_2015[x])):
        indians_2015.loc[y,x] = int(indians_2015.loc[y, x])

for x in columns_float:
    for y in range(len(indians_2015[x])):
        indians_2015.loc[y,x] = float(indians_2015.loc[y, x])  

for x in range(len(indians_2015['Game'])):
    if indians_2015.loc[x, 'Runs'] > indians_2015.loc[x, 'R']:
        indians_2015.loc[x, 'Win'] = 0
    else:
        indians_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 White Sox Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHW&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHW_game_num = get_stat2('team_game_num')
CHW_PA = get_stat2('PA')
CHW_AB = get_stat2('AB')
CHW_R = get_stat2('R')
CHW_H = get_stat2('H')
CHW_2B = get_stat2('2B')
CHW_3B = get_stat2('3B')
CHW_HR = get_stat2('HR')
CHW_RBI = get_stat2('RBI')
CHW_BB = get_stat2('BB')
CHW_SO = get_stat2('SO')
CHW_SB = get_stat2('SB')
CHW_CS = get_stat2('CS')
CHW_BA = get_stat2('batting_avg')
CHW_OBP = get_stat2('onbase_perc')
CHW_SLG = get_stat2('slugging_perc')
CHW_OPS = get_stat2('onbase_plus_slugging')
CHW_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


white_sox_offense = pd.DataFrame({
                                  'PA': CHW_PA,
                                  'AB': CHW_AB,
                                  'R':  CHW_R,
                                  'H':  CHW_H,
                                  '2B': CHW_2B,
                                  '3B': CHW_3B, 
                                  'HR': CHW_HR, 
                                  'RBI':CHW_RBI,
                                  'BB': CHW_BB,
                                  'SO': CHW_SO,
                                  'SB': CHW_SB,
                                  'CS': CHW_CS,
                                  'LOB':CHW_LOB})

# %% [markdown]
# # 2019 White Sox Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHW&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHW_P_game_num = get_stat3('team_game_num')
CHW_P_IP = get_stat3('IP')
CHW_P_H = get_stat3('H')
CHW_P_R = get_stat3('R')
CHW_P_ER = get_stat3('ER')
CHW_P_UER = get_stat3('UER')
CHW_P_BB = get_stat3('BB')
CHW_P_SO = get_stat3('SO')
CHW_P_HR = get_stat3('HR')
CHW_P_HBP = get_stat3('HBP')
CHW_P_ERA = get_stat3('earned_run_avg')

white_sox_pitching = pd.DataFrame({'Game':  CHW_P_game_num, 
                                   'IP':  CHW_P_IP, 
                                   'H':   CHW_P_H,
                                   'R':   CHW_P_R,
                                   'ER':  CHW_P_ER,
                                   'UER': CHW_P_UER,
                                   'BB':  CHW_P_BB,
                                   'SO':  CHW_P_SO,
                                   'HR':  CHW_P_HR,
                                   'HBP': CHW_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

white_sox_pitching = white_sox_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [white_sox_pitching, white_sox_offense]

white_sox = pd.concat(frames, axis=1)

white_sox['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(white_sox[x])):
        white_sox.loc[y,x] = int(white_sox.loc[y, x])

for x in columns_float:
    for y in range(len(white_sox[x])):
        white_sox.loc[y,x] = float(white_sox.loc[y, x])  

for x in range(len(white_sox['Game'])):
    if white_sox.loc[x, 'Runs'] > white_sox.loc[x, 'R']:
        white_sox.loc[x, 'Win'] = 0
    else:
        white_sox.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 White Sox Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHW&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHW_2018_game_num = get_stat2('team_game_num')
CHW_2018_PA = get_stat2('PA')
CHW_2018_AB = get_stat2('AB')
CHW_2018_R = get_stat2('R')
CHW_2018_H = get_stat2('H')
CHW_2018_2B = get_stat2('2B')
CHW_2018_3B = get_stat2('3B')
CHW_2018_HR = get_stat2('HR')
CHW_2018_RBI = get_stat2('RBI')
CHW_2018_BB = get_stat2('BB')
CHW_2018_SO = get_stat2('SO')
CHW_2018_SB = get_stat2('SB')
CHW_2018_CS = get_stat2('CS')
CHW_2018_BA = get_stat2('batting_avg')
CHW_2018_OBP = get_stat2('onbase_perc')
CHW_2018_SLG = get_stat2('slugging_perc')
CHW_2018_OPS = get_stat2('onbase_plus_slugging')
CHW_2018_LOB = get_stat2('LOB')
white_sox_2018_offense = pd.DataFrame({
                                  'PA': CHW_2018_PA,
                                  'AB': CHW_2018_AB,
                                  'R':  CHW_2018_R,
                                  'H':  CHW_2018_H,
                                  '2B': CHW_2018_2B,
                                  '3B': CHW_2018_3B, 
                                  'HR': CHW_2018_HR, 
                                  'RBI':CHW_2018_RBI,
                                  'BB': CHW_2018_BB,
                                  'SO': CHW_2018_SO,
                                  'SB': CHW_2018_SB,
                                  'CS': CHW_2018_CS,
                                  'LOB':CHW_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHW&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHW_2018_P_game_num = get_stat3('team_game_num')
CHW_2018_P_IP = get_stat3('IP')
CHW_2018_P_H = get_stat3('H')
CHW_2018_P_R = get_stat3('R')
CHW_2018_P_ER = get_stat3('ER')
CHW_2018_P_UER = get_stat3('UER')
CHW_2018_P_BB = get_stat3('BB')
CHW_2018_P_SO = get_stat3('SO')
CHW_2018_P_HR = get_stat3('HR')
CHW_2018_P_HBP = get_stat3('HBP')
CHW_2018_P_ERA = get_stat3('earned_run_avg')

white_sox_2018_pitching = pd.DataFrame({'Game':  CHW_2018_P_game_num, 
                                         'IP':  CHW_2018_P_IP, 
                                         'H':   CHW_2018_P_H,
                                         'R':   CHW_2018_P_R,
                                         'ER':  CHW_2018_P_ER,
                                         'UER': CHW_2018_P_UER,
                                         'BB':  CHW_2018_P_BB,
                                         'SO':  CHW_2018_P_SO,
                                         'HR':  CHW_2018_P_HR,
                                         'HBP': CHW_2018_P_HBP})

# white_sox_offense = white_sox_offense.drop(columns = ['Game'])

white_sox_2018_pitching = white_sox_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [white_sox_2018_pitching, white_sox_2018_offense]

white_sox_2018 = pd.concat(frames, axis=1)

white_sox_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(white_sox_2018[x])):
        white_sox_2018.loc[y,x] = int(white_sox_2018.loc[y, x])

for x in columns_float:
    for y in range(len(white_sox_2018[x])):
        white_sox_2018.loc[y,x] = float(white_sox_2018.loc[y, x])  

for x in range(len(white_sox_2018['Game'])):
    if white_sox_2018.loc[x, 'Runs'] > white_sox_2018.loc[x, 'R']:
        white_sox_2018.loc[x, 'Win'] = 0
    else:
        white_sox_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 White Sox Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHW&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHW_2017_game_num = get_stat2('team_game_num')
CHW_2017_PA = get_stat2('PA')
CHW_2017_AB = get_stat2('AB')
CHW_2017_R = get_stat2('R')
CHW_2017_H = get_stat2('H')
CHW_2017_2B = get_stat2('2B')
CHW_2017_3B = get_stat2('3B')
CHW_2017_HR = get_stat2('HR')
CHW_2017_RBI = get_stat2('RBI')
CHW_2017_BB = get_stat2('BB')
CHW_2017_SO = get_stat2('SO')
CHW_2017_SB = get_stat2('SB')
CHW_2017_CS = get_stat2('CS')
CHW_2017_BA = get_stat2('batting_avg')
CHW_2017_OBP = get_stat2('onbase_perc')
CHW_2017_SLG = get_stat2('slugging_perc')
CHW_2017_OPS = get_stat2('onbase_plus_slugging')
CHW_2017_LOB = get_stat2('LOB')
white_sox_2017_offense = pd.DataFrame({
                                  'PA': CHW_2017_PA,
                                  'AB': CHW_2017_AB,
                                  'R':  CHW_2017_R,
                                  'H':  CHW_2017_H,
                                  '2B': CHW_2017_2B,
                                  '3B': CHW_2017_3B, 
                                  'HR': CHW_2017_HR, 
                                  'RBI':CHW_2017_RBI,
                                  'BB': CHW_2017_BB,
                                  'SO': CHW_2017_SO,
                                  'SB': CHW_2017_SB,
                                  'CS': CHW_2017_CS,
                                  'LOB':CHW_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHW&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHW_2017_P_game_num = get_stat3('team_game_num')
CHW_2017_P_IP = get_stat3('IP')
CHW_2017_P_H = get_stat3('H')
CHW_2017_P_R = get_stat3('R')
CHW_2017_P_ER = get_stat3('ER')
CHW_2017_P_UER = get_stat3('UER')
CHW_2017_P_BB = get_stat3('BB')
CHW_2017_P_SO = get_stat3('SO')
CHW_2017_P_HR = get_stat3('HR')
CHW_2017_P_HBP = get_stat3('HBP')
CHW_2017_P_ERA = get_stat3('earned_run_avg')

white_sox_2017_pitching = pd.DataFrame({'Game':  CHW_2017_P_game_num, 
                                         'IP':  CHW_2017_P_IP, 
                                         'H':   CHW_2017_P_H,
                                         'R':   CHW_2017_P_R,
                                         'ER':  CHW_2017_P_ER,
                                         'UER': CHW_2017_P_UER,
                                         'BB':  CHW_2017_P_BB,
                                         'SO':  CHW_2017_P_SO,
                                         'HR':  CHW_2017_P_HR,
                                         'HBP': CHW_2017_P_HBP})

# white_sox_offense = white_sox_offense.drop(columns = ['Game'])

white_sox_2017_pitching = white_sox_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [white_sox_2017_pitching, white_sox_2017_offense]

white_sox_2017 = pd.concat(frames, axis=1)

white_sox_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(white_sox_2017[x])):
        white_sox_2017.loc[y,x] = int(white_sox_2017.loc[y, x])

for x in columns_float:
    for y in range(len(white_sox_2017[x])):
        white_sox_2017.loc[y,x] = float(white_sox_2017.loc[y, x])  

for x in range(len(white_sox_2017['Game'])):
    if white_sox_2017.loc[x, 'Runs'] > white_sox_2017.loc[x, 'R']:
        white_sox_2017.loc[x, 'Win'] = 0
    else:
        white_sox_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 White Sox Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHW&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHW_2016_game_num = get_stat2('team_game_num')
CHW_2016_PA = get_stat2('PA')
CHW_2016_AB = get_stat2('AB')
CHW_2016_R = get_stat2('R')
CHW_2016_H = get_stat2('H')
CHW_2016_2B = get_stat2('2B')
CHW_2016_3B = get_stat2('3B')
CHW_2016_HR = get_stat2('HR')
CHW_2016_RBI = get_stat2('RBI')
CHW_2016_BB = get_stat2('BB')
CHW_2016_SO = get_stat2('SO')
CHW_2016_SB = get_stat2('SB')
CHW_2016_CS = get_stat2('CS')
CHW_2016_BA = get_stat2('batting_avg')
CHW_2016_OBP = get_stat2('onbase_perc')
CHW_2016_SLG = get_stat2('slugging_perc')
CHW_2016_OPS = get_stat2('onbase_plus_slugging')
CHW_2016_LOB = get_stat2('LOB')
white_sox_2016_offense = pd.DataFrame({
                                  'PA': CHW_2016_PA,
                                  'AB': CHW_2016_AB,
                                  'R':  CHW_2016_R,
                                  'H':  CHW_2016_H,
                                  '2B': CHW_2016_2B,
                                  '3B': CHW_2016_3B, 
                                  'HR': CHW_2016_HR, 
                                  'RBI':CHW_2016_RBI,
                                  'BB': CHW_2016_BB,
                                  'SO': CHW_2016_SO,
                                  'SB': CHW_2016_SB,
                                  'CS': CHW_2016_CS,
                                  'LOB':CHW_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHW&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHW_2016_P_game_num = get_stat3('team_game_num')
CHW_2016_P_IP = get_stat3('IP')
CHW_2016_P_H = get_stat3('H')
CHW_2016_P_R = get_stat3('R')
CHW_2016_P_ER = get_stat3('ER')
CHW_2016_P_UER = get_stat3('UER')
CHW_2016_P_BB = get_stat3('BB')
CHW_2016_P_SO = get_stat3('SO')
CHW_2016_P_HR = get_stat3('HR')
CHW_2016_P_HBP = get_stat3('HBP')
CHW_2016_P_ERA = get_stat3('earned_run_avg')

white_sox_2016_pitching = pd.DataFrame({'Game':  CHW_2016_P_game_num, 
                                         'IP':  CHW_2016_P_IP, 
                                         'H':   CHW_2016_P_H,
                                         'R':   CHW_2016_P_R,
                                         'ER':  CHW_2016_P_ER,
                                         'UER': CHW_2016_P_UER,
                                         'BB':  CHW_2016_P_BB,
                                         'SO':  CHW_2016_P_SO,
                                         'HR':  CHW_2016_P_HR,
                                         'HBP': CHW_2016_P_HBP})

# white_sox_offense = white_sox_offense.drop(columns = ['Game'])

white_sox_2016_pitching = white_sox_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [white_sox_2016_pitching, white_sox_2016_offense]

white_sox_2016 = pd.concat(frames, axis=1)

white_sox_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(white_sox_2016[x])):
        white_sox_2016.loc[y,x] = int(white_sox_2016.loc[y, x])

for x in columns_float:
    for y in range(len(white_sox_2016[x])):
        white_sox_2016.loc[y,x] = float(white_sox_2016.loc[y, x])  

for x in range(len(white_sox_2016['Game'])):
    if white_sox_2016.loc[x, 'Runs'] > white_sox_2016.loc[x, 'R']:
        white_sox_2016.loc[x, 'Win'] = 0
    else:
        white_sox_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 White Sox Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHW&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHW_2015_game_num = get_stat2('team_game_num')
CHW_2015_PA = get_stat2('PA')
CHW_2015_AB = get_stat2('AB')
CHW_2015_R = get_stat2('R')
CHW_2015_H = get_stat2('H')
CHW_2015_2B = get_stat2('2B')
CHW_2015_3B = get_stat2('3B')
CHW_2015_HR = get_stat2('HR')
CHW_2015_RBI = get_stat2('RBI')
CHW_2015_BB = get_stat2('BB')
CHW_2015_SO = get_stat2('SO')
CHW_2015_SB = get_stat2('SB')
CHW_2015_CS = get_stat2('CS')
CHW_2015_BA = get_stat2('batting_avg')
CHW_2015_OBP = get_stat2('onbase_perc')
CHW_2015_SLG = get_stat2('slugging_perc')
CHW_2015_OPS = get_stat2('onbase_plus_slugging')
CHW_2015_LOB = get_stat2('LOB')
white_sox_2015_offense = pd.DataFrame({
                                  'PA': CHW_2015_PA,
                                  'AB': CHW_2015_AB,
                                  'R':  CHW_2015_R,
                                  'H':  CHW_2015_H,
                                  '2B': CHW_2015_2B,
                                  '3B': CHW_2015_3B, 
                                  'HR': CHW_2015_HR, 
                                  'RBI':CHW_2015_RBI,
                                  'BB': CHW_2015_BB,
                                  'SO': CHW_2015_SO,
                                  'SB': CHW_2015_SB,
                                  'CS': CHW_2015_CS,
                                  'LOB':CHW_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=CHW&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

CHW_2015_P_game_num = get_stat3('team_game_num')
CHW_2015_P_IP = get_stat3('IP')
CHW_2015_P_H = get_stat3('H')
CHW_2015_P_R = get_stat3('R')
CHW_2015_P_ER = get_stat3('ER')
CHW_2015_P_UER = get_stat3('UER')
CHW_2015_P_BB = get_stat3('BB')
CHW_2015_P_SO = get_stat3('SO')
CHW_2015_P_HR = get_stat3('HR')
CHW_2015_P_HBP = get_stat3('HBP')
CHW_2015_P_ERA = get_stat3('earned_run_avg')

white_sox_2015_pitching = pd.DataFrame({'Game':  CHW_2015_P_game_num, 
                                         'IP':  CHW_2015_P_IP, 
                                         'H':   CHW_2015_P_H,
                                         'R':   CHW_2015_P_R,
                                         'ER':  CHW_2015_P_ER,
                                         'UER': CHW_2015_P_UER,
                                         'BB':  CHW_2015_P_BB,
                                         'SO':  CHW_2015_P_SO,
                                         'HR':  CHW_2015_P_HR,
                                         'HBP': CHW_2015_P_HBP})

# white_sox_offense = white_sox_offense.drop(columns = ['Game'])

white_sox_2015_pitching = white_sox_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [white_sox_2015_pitching, white_sox_2015_offense]

white_sox_2015 = pd.concat(frames, axis=1)

white_sox_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(white_sox_2015[x])):
        white_sox_2015.loc[y,x] = int(white_sox_2015.loc[y, x])

for x in columns_float:
    for y in range(len(white_sox_2015[x])):
        white_sox_2015.loc[y,x] = float(white_sox_2015.loc[y, x])  

for x in range(len(white_sox_2015['Game'])):
    if white_sox_2015.loc[x, 'Runs'] > white_sox_2015.loc[x, 'R']:
        white_sox_2015.loc[x, 'Win'] = 0
    else:
        white_sox_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Royals Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=KCR&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

KCR_game_num = get_stat2('team_game_num')
KCR_PA = get_stat2('PA')
KCR_AB = get_stat2('AB')
KCR_R = get_stat2('R')
KCR_H = get_stat2('H')
KCR_2B = get_stat2('2B')
KCR_3B = get_stat2('3B')
KCR_HR = get_stat2('HR')
KCR_RBI = get_stat2('RBI')
KCR_BB = get_stat2('BB')
KCR_SO = get_stat2('SO')
KCR_SB = get_stat2('SB')
KCR_CS = get_stat2('CS')
KCR_BA = get_stat2('batting_avg')
KCR_OBP = get_stat2('onbase_perc')
KCR_SLG = get_stat2('slugging_perc')
KCR_OPS = get_stat2('onbase_plus_slugging')
KCR_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


royals_offense = pd.DataFrame({
                                  'PA': KCR_PA,
                                  'AB': KCR_AB,
                                  'R':  KCR_R,
                                  'H':  KCR_H,
                                  '2B': KCR_2B,
                                  '3B': KCR_3B, 
                                  'HR': KCR_HR, 
                                  'RBI':KCR_RBI,
                                  'BB': KCR_BB,
                                  'SO': KCR_SO,
                                  'SB': KCR_SB,
                                  'CS': KCR_CS,
                                  'LOB':KCR_LOB})

# %% [markdown]
# # 2019 Royals Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=KCR&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

KCR_P_game_num = get_stat3('team_game_num')
KCR_P_IP = get_stat3('IP')
KCR_P_H = get_stat3('H')
KCR_P_R = get_stat3('R')
KCR_P_ER = get_stat3('ER')
KCR_P_UER = get_stat3('UER')
KCR_P_BB = get_stat3('BB')
KCR_P_SO = get_stat3('SO')
KCR_P_HR = get_stat3('HR')
KCR_P_HBP = get_stat3('HBP')
KCR_P_ERA = get_stat3('earned_run_avg')

royals_pitching = pd.DataFrame({'Game':  KCR_P_game_num, 
                                   'IP':  KCR_P_IP, 
                                   'H':   KCR_P_H,
                                   'R':   KCR_P_R,
                                   'ER':  KCR_P_ER,
                                   'UER': KCR_P_UER,
                                   'BB':  KCR_P_BB,
                                   'SO':  KCR_P_SO,
                                   'HR':  KCR_P_HR,
                                   'HBP': KCR_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

royals_pitching = royals_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [royals_pitching, royals_offense]

royals = pd.concat(frames, axis=1)

royals['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(royals[x])):
        royals.loc[y,x] = int(royals.loc[y, x])

for x in columns_float:
    for y in range(len(royals[x])):
        royals.loc[y,x] = float(royals.loc[y, x])  

for x in range(len(royals['Game'])):
    if royals.loc[x, 'Runs'] > royals.loc[x, 'R']:
        royals.loc[x, 'Win'] = 0
    else:
        royals.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Royals Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=KCR&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

KCR_2018_game_num = get_stat2('team_game_num')
KCR_2018_PA = get_stat2('PA')
KCR_2018_AB = get_stat2('AB')
KCR_2018_R = get_stat2('R')
KCR_2018_H = get_stat2('H')
KCR_2018_2B = get_stat2('2B')
KCR_2018_3B = get_stat2('3B')
KCR_2018_HR = get_stat2('HR')
KCR_2018_RBI = get_stat2('RBI')
KCR_2018_BB = get_stat2('BB')
KCR_2018_SO = get_stat2('SO')
KCR_2018_SB = get_stat2('SB')
KCR_2018_CS = get_stat2('CS')
KCR_2018_BA = get_stat2('batting_avg')
KCR_2018_OBP = get_stat2('onbase_perc')
KCR_2018_SLG = get_stat2('slugging_perc')
KCR_2018_OPS = get_stat2('onbase_plus_slugging')
KCR_2018_LOB = get_stat2('LOB')
royals_2018_offense = pd.DataFrame({
                                  'PA': KCR_2018_PA,
                                  'AB': KCR_2018_AB,
                                  'R':  KCR_2018_R,
                                  'H':  KCR_2018_H,
                                  '2B': KCR_2018_2B,
                                  '3B': KCR_2018_3B, 
                                  'HR': KCR_2018_HR, 
                                  'RBI':KCR_2018_RBI,
                                  'BB': KCR_2018_BB,
                                  'SO': KCR_2018_SO,
                                  'SB': KCR_2018_SB,
                                  'CS': KCR_2018_CS,
                                  'LOB':KCR_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=KCR&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

KCR_2018_P_game_num = get_stat3('team_game_num')
KCR_2018_P_IP = get_stat3('IP')
KCR_2018_P_H = get_stat3('H')
KCR_2018_P_R = get_stat3('R')
KCR_2018_P_ER = get_stat3('ER')
KCR_2018_P_UER = get_stat3('UER')
KCR_2018_P_BB = get_stat3('BB')
KCR_2018_P_SO = get_stat3('SO')
KCR_2018_P_HR = get_stat3('HR')
KCR_2018_P_HBP = get_stat3('HBP')
KCR_2018_P_ERA = get_stat3('earned_run_avg')

royals_2018_pitching = pd.DataFrame({'Game':  KCR_2018_P_game_num, 
                                         'IP':  KCR_2018_P_IP, 
                                         'H':   KCR_2018_P_H,
                                         'R':   KCR_2018_P_R,
                                         'ER':  KCR_2018_P_ER,
                                         'UER': KCR_2018_P_UER,
                                         'BB':  KCR_2018_P_BB,
                                         'SO':  KCR_2018_P_SO,
                                         'HR':  KCR_2018_P_HR,
                                         'HBP': KCR_2018_P_HBP})

# royals_offense = royals_offense.drop(columns = ['Game'])

royals_2018_pitching = royals_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [royals_2018_pitching, royals_2018_offense]

royals_2018 = pd.concat(frames, axis=1)

royals_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(royals_2018[x])):
        royals_2018.loc[y,x] = int(royals_2018.loc[y, x])

for x in columns_float:
    for y in range(len(royals_2018[x])):
        royals_2018.loc[y,x] = float(royals_2018.loc[y, x])  

for x in range(len(royals_2018['Game'])):
    if royals_2018.loc[x, 'Runs'] > royals_2018.loc[x, 'R']:
        royals_2018.loc[x, 'Win'] = 0
    else:
        royals_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Royals Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=KCR&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

KCR_2017_game_num = get_stat2('team_game_num')
KCR_2017_PA = get_stat2('PA')
KCR_2017_AB = get_stat2('AB')
KCR_2017_R = get_stat2('R')
KCR_2017_H = get_stat2('H')
KCR_2017_2B = get_stat2('2B')
KCR_2017_3B = get_stat2('3B')
KCR_2017_HR = get_stat2('HR')
KCR_2017_RBI = get_stat2('RBI')
KCR_2017_BB = get_stat2('BB')
KCR_2017_SO = get_stat2('SO')
KCR_2017_SB = get_stat2('SB')
KCR_2017_CS = get_stat2('CS')
KCR_2017_BA = get_stat2('batting_avg')
KCR_2017_OBP = get_stat2('onbase_perc')
KCR_2017_SLG = get_stat2('slugging_perc')
KCR_2017_OPS = get_stat2('onbase_plus_slugging')
KCR_2017_LOB = get_stat2('LOB')
royals_2017_offense = pd.DataFrame({
                                  'PA': KCR_2017_PA,
                                  'AB': KCR_2017_AB,
                                  'R':  KCR_2017_R,
                                  'H':  KCR_2017_H,
                                  '2B': KCR_2017_2B,
                                  '3B': KCR_2017_3B, 
                                  'HR': KCR_2017_HR, 
                                  'RBI':KCR_2017_RBI,
                                  'BB': KCR_2017_BB,
                                  'SO': KCR_2017_SO,
                                  'SB': KCR_2017_SB,
                                  'CS': KCR_2017_CS,
                                  'LOB':KCR_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=KCR&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

KCR_2017_P_game_num = get_stat3('team_game_num')
KCR_2017_P_IP = get_stat3('IP')
KCR_2017_P_H = get_stat3('H')
KCR_2017_P_R = get_stat3('R')
KCR_2017_P_ER = get_stat3('ER')
KCR_2017_P_UER = get_stat3('UER')
KCR_2017_P_BB = get_stat3('BB')
KCR_2017_P_SO = get_stat3('SO')
KCR_2017_P_HR = get_stat3('HR')
KCR_2017_P_HBP = get_stat3('HBP')
KCR_2017_P_ERA = get_stat3('earned_run_avg')

royals_2017_pitching = pd.DataFrame({'Game':  KCR_2017_P_game_num, 
                                         'IP':  KCR_2017_P_IP, 
                                         'H':   KCR_2017_P_H,
                                         'R':   KCR_2017_P_R,
                                         'ER':  KCR_2017_P_ER,
                                         'UER': KCR_2017_P_UER,
                                         'BB':  KCR_2017_P_BB,
                                         'SO':  KCR_2017_P_SO,
                                         'HR':  KCR_2017_P_HR,
                                         'HBP': KCR_2017_P_HBP})

# royals_offense = royals_offense.drop(columns = ['Game'])

royals_2017_pitching = royals_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [royals_2017_pitching, royals_2017_offense]

royals_2017 = pd.concat(frames, axis=1)

royals_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(royals_2017[x])):
        royals_2017.loc[y,x] = int(royals_2017.loc[y, x])

for x in columns_float:
    for y in range(len(royals_2017[x])):
        royals_2017.loc[y,x] = float(royals_2017.loc[y, x])  

for x in range(len(royals_2017['Game'])):
    if royals_2017.loc[x, 'Runs'] > royals_2017.loc[x, 'R']:
        royals_2017.loc[x, 'Win'] = 0
    else:
        royals_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Royals Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=KCR&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

KCR_2016_game_num = get_stat2('team_game_num')
KCR_2016_PA = get_stat2('PA')
KCR_2016_AB = get_stat2('AB')
KCR_2016_R = get_stat2('R')
KCR_2016_H = get_stat2('H')
KCR_2016_2B = get_stat2('2B')
KCR_2016_3B = get_stat2('3B')
KCR_2016_HR = get_stat2('HR')
KCR_2016_RBI = get_stat2('RBI')
KCR_2016_BB = get_stat2('BB')
KCR_2016_SO = get_stat2('SO')
KCR_2016_SB = get_stat2('SB')
KCR_2016_CS = get_stat2('CS')
KCR_2016_BA = get_stat2('batting_avg')
KCR_2016_OBP = get_stat2('onbase_perc')
KCR_2016_SLG = get_stat2('slugging_perc')
KCR_2016_OPS = get_stat2('onbase_plus_slugging')
KCR_2016_LOB = get_stat2('LOB')
royals_2016_offense = pd.DataFrame({
                                  'PA': KCR_2016_PA,
                                  'AB': KCR_2016_AB,
                                  'R':  KCR_2016_R,
                                  'H':  KCR_2016_H,
                                  '2B': KCR_2016_2B,
                                  '3B': KCR_2016_3B, 
                                  'HR': KCR_2016_HR, 
                                  'RBI':KCR_2016_RBI,
                                  'BB': KCR_2016_BB,
                                  'SO': KCR_2016_SO,
                                  'SB': KCR_2016_SB,
                                  'CS': KCR_2016_CS,
                                  'LOB':KCR_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=KCR&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

KCR_2016_P_game_num = get_stat3('team_game_num')
KCR_2016_P_IP = get_stat3('IP')
KCR_2016_P_H = get_stat3('H')
KCR_2016_P_R = get_stat3('R')
KCR_2016_P_ER = get_stat3('ER')
KCR_2016_P_UER = get_stat3('UER')
KCR_2016_P_BB = get_stat3('BB')
KCR_2016_P_SO = get_stat3('SO')
KCR_2016_P_HR = get_stat3('HR')
KCR_2016_P_HBP = get_stat3('HBP')
KCR_2016_P_ERA = get_stat3('earned_run_avg')

royals_2016_pitching = pd.DataFrame({'Game':  KCR_2016_P_game_num, 
                                         'IP':  KCR_2016_P_IP, 
                                         'H':   KCR_2016_P_H,
                                         'R':   KCR_2016_P_R,
                                         'ER':  KCR_2016_P_ER,
                                         'UER': KCR_2016_P_UER,
                                         'BB':  KCR_2016_P_BB,
                                         'SO':  KCR_2016_P_SO,
                                         'HR':  KCR_2016_P_HR,
                                         'HBP': KCR_2016_P_HBP})

# royals_offense = royals_offense.drop(columns = ['Game'])

royals_2016_pitching = royals_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [royals_2016_pitching, royals_2016_offense]

royals_2016 = pd.concat(frames, axis=1)

royals_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(royals_2016[x])):
        royals_2016.loc[y,x] = int(royals_2016.loc[y, x])

for x in columns_float:
    for y in range(len(royals_2016[x])):
        royals_2016.loc[y,x] = float(royals_2016.loc[y, x])  

for x in range(len(royals_2016['Game'])):
    if royals_2016.loc[x, 'Runs'] > royals_2016.loc[x, 'R']:
        royals_2016.loc[x, 'Win'] = 0
    else:
        royals_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Royals Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=KCR&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

KCR_2015_game_num = get_stat2('team_game_num')
KCR_2015_PA = get_stat2('PA')
KCR_2015_AB = get_stat2('AB')
KCR_2015_R = get_stat2('R')
KCR_2015_H = get_stat2('H')
KCR_2015_2B = get_stat2('2B')
KCR_2015_3B = get_stat2('3B')
KCR_2015_HR = get_stat2('HR')
KCR_2015_RBI = get_stat2('RBI')
KCR_2015_BB = get_stat2('BB')
KCR_2015_SO = get_stat2('SO')
KCR_2015_SB = get_stat2('SB')
KCR_2015_CS = get_stat2('CS')
KCR_2015_BA = get_stat2('batting_avg')
KCR_2015_OBP = get_stat2('onbase_perc')
KCR_2015_SLG = get_stat2('slugging_perc')
KCR_2015_OPS = get_stat2('onbase_plus_slugging')
KCR_2015_LOB = get_stat2('LOB')
royals_2015_offense = pd.DataFrame({
                                  'PA': KCR_2015_PA,
                                  'AB': KCR_2015_AB,
                                  'R':  KCR_2015_R,
                                  'H':  KCR_2015_H,
                                  '2B': KCR_2015_2B,
                                  '3B': KCR_2015_3B, 
                                  'HR': KCR_2015_HR, 
                                  'RBI':KCR_2015_RBI,
                                  'BB': KCR_2015_BB,
                                  'SO': KCR_2015_SO,
                                  'SB': KCR_2015_SB,
                                  'CS': KCR_2015_CS,
                                  'LOB':KCR_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=KCR&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

KCR_2015_P_game_num = get_stat3('team_game_num')
KCR_2015_P_IP = get_stat3('IP')
KCR_2015_P_H = get_stat3('H')
KCR_2015_P_R = get_stat3('R')
KCR_2015_P_ER = get_stat3('ER')
KCR_2015_P_UER = get_stat3('UER')
KCR_2015_P_BB = get_stat3('BB')
KCR_2015_P_SO = get_stat3('SO')
KCR_2015_P_HR = get_stat3('HR')
KCR_2015_P_HBP = get_stat3('HBP')
KCR_2015_P_ERA = get_stat3('earned_run_avg')

royals_2015_pitching = pd.DataFrame({'Game':  KCR_2015_P_game_num, 
                                         'IP':  KCR_2015_P_IP, 
                                         'H':   KCR_2015_P_H,
                                         'R':   KCR_2015_P_R,
                                         'ER':  KCR_2015_P_ER,
                                         'UER': KCR_2015_P_UER,
                                         'BB':  KCR_2015_P_BB,
                                         'SO':  KCR_2015_P_SO,
                                         'HR':  KCR_2015_P_HR,
                                         'HBP': KCR_2015_P_HBP})

# royals_offense = royals_offense.drop(columns = ['Game'])

royals_2015_pitching = royals_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [royals_2015_pitching, royals_2015_offense]

royals_2015 = pd.concat(frames, axis=1)

royals_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(royals_2015[x])):
        royals_2015.loc[y,x] = int(royals_2015.loc[y, x])

for x in columns_float:
    for y in range(len(royals_2015[x])):
        royals_2015.loc[y,x] = float(royals_2015.loc[y, x])  

for x in range(len(royals_2015['Game'])):
    if royals_2015.loc[x, 'Runs'] > royals_2015.loc[x, 'R']:
        royals_2015.loc[x, 'Win'] = 0
    else:
        royals_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Tigers Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=DET&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

DET_game_num = get_stat2('team_game_num')
DET_PA = get_stat2('PA')
DET_AB = get_stat2('AB')
DET_R = get_stat2('R')
DET_H = get_stat2('H')
DET_2B = get_stat2('2B')
DET_3B = get_stat2('3B')
DET_HR = get_stat2('HR')
DET_RBI = get_stat2('RBI')
DET_BB = get_stat2('BB')
DET_SO = get_stat2('SO')
DET_SB = get_stat2('SB')
DET_CS = get_stat2('CS')
DET_BA = get_stat2('batting_avg')
DET_OBP = get_stat2('onbase_perc')
DET_SLG = get_stat2('slugging_perc')
DET_OPS = get_stat2('onbase_plus_slugging')
DET_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


tigers_offense = pd.DataFrame({
                                  'PA': DET_PA,
                                  'AB': DET_AB,
                                  'R':  DET_R,
                                  'H':  DET_H,
                                  '2B': DET_2B,
                                  '3B': DET_3B, 
                                  'HR': DET_HR, 
                                  'RBI':DET_RBI,
                                  'BB': DET_BB,
                                  'SO': DET_SO,
                                  'SB': DET_SB,
                                  'CS': DET_CS,
                                  'LOB':DET_LOB})

# %% [markdown]
# # 2019 Tigers Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=DET&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

DET_P_game_num = get_stat3('team_game_num')
DET_P_IP = get_stat3('IP')
DET_P_H = get_stat3('H')
DET_P_R = get_stat3('R')
DET_P_ER = get_stat3('ER')
DET_P_UER = get_stat3('UER')
DET_P_BB = get_stat3('BB')
DET_P_SO = get_stat3('SO')
DET_P_HR = get_stat3('HR')
DET_P_HBP = get_stat3('HBP')
DET_P_ERA = get_stat3('earned_run_avg')

tigers_pitching = pd.DataFrame({'Game':  DET_P_game_num, 
                                   'IP':  DET_P_IP, 
                                   'H':   DET_P_H,
                                   'R':   DET_P_R,
                                   'ER':  DET_P_ER,
                                   'UER': DET_P_UER,
                                   'BB':  DET_P_BB,
                                   'SO':  DET_P_SO,
                                   'HR':  DET_P_HR,
                                   'HBP': DET_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

tigers_pitching = tigers_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [tigers_pitching, tigers_offense]

tigers = pd.concat(frames, axis=1)

tigers['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(tigers[x])):
        tigers.loc[y,x] = int(tigers.loc[y, x])

for x in columns_float:
    for y in range(len(tigers[x])):
        tigers.loc[y,x] = float(tigers.loc[y, x])  

for x in range(len(tigers['Game'])):
    if tigers.loc[x, 'Runs'] > tigers.loc[x, 'R']:
        tigers.loc[x, 'Win'] = 0
    else:
        tigers.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Tigers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=DET&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

DET_2018_game_num = get_stat2('team_game_num')
DET_2018_PA = get_stat2('PA')
DET_2018_AB = get_stat2('AB')
DET_2018_R = get_stat2('R')
DET_2018_H = get_stat2('H')
DET_2018_2B = get_stat2('2B')
DET_2018_3B = get_stat2('3B')
DET_2018_HR = get_stat2('HR')
DET_2018_RBI = get_stat2('RBI')
DET_2018_BB = get_stat2('BB')
DET_2018_SO = get_stat2('SO')
DET_2018_SB = get_stat2('SB')
DET_2018_CS = get_stat2('CS')
DET_2018_BA = get_stat2('batting_avg')
DET_2018_OBP = get_stat2('onbase_perc')
DET_2018_SLG = get_stat2('slugging_perc')
DET_2018_OPS = get_stat2('onbase_plus_slugging')
DET_2018_LOB = get_stat2('LOB')
tigers_2018_offense = pd.DataFrame({
                                  'PA': DET_2018_PA,
                                  'AB': DET_2018_AB,
                                  'R':  DET_2018_R,
                                  'H':  DET_2018_H,
                                  '2B': DET_2018_2B,
                                  '3B': DET_2018_3B, 
                                  'HR': DET_2018_HR, 
                                  'RBI':DET_2018_RBI,
                                  'BB': DET_2018_BB,
                                  'SO': DET_2018_SO,
                                  'SB': DET_2018_SB,
                                  'CS': DET_2018_CS,
                                  'LOB':DET_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=DET&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

DET_2018_P_game_num = get_stat3('team_game_num')
DET_2018_P_IP = get_stat3('IP')
DET_2018_P_H = get_stat3('H')
DET_2018_P_R = get_stat3('R')
DET_2018_P_ER = get_stat3('ER')
DET_2018_P_UER = get_stat3('UER')
DET_2018_P_BB = get_stat3('BB')
DET_2018_P_SO = get_stat3('SO')
DET_2018_P_HR = get_stat3('HR')
DET_2018_P_HBP = get_stat3('HBP')
DET_2018_P_ERA = get_stat3('earned_run_avg')

tigers_2018_pitching = pd.DataFrame({'Game':  DET_2018_P_game_num, 
                                         'IP':  DET_2018_P_IP, 
                                         'H':   DET_2018_P_H,
                                         'R':   DET_2018_P_R,
                                         'ER':  DET_2018_P_ER,
                                         'UER': DET_2018_P_UER,
                                         'BB':  DET_2018_P_BB,
                                         'SO':  DET_2018_P_SO,
                                         'HR':  DET_2018_P_HR,
                                         'HBP': DET_2018_P_HBP})

# tigers_offense = tigers_offense.drop(columns = ['Game'])

tigers_2018_pitching = tigers_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [tigers_2018_pitching, tigers_2018_offense]

tigers_2018 = pd.concat(frames, axis=1)

tigers_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(tigers_2018[x])):
        tigers_2018.loc[y,x] = int(tigers_2018.loc[y, x])

for x in columns_float:
    for y in range(len(tigers_2018[x])):
        tigers_2018.loc[y,x] = float(tigers_2018.loc[y, x])  

for x in range(len(tigers_2018['Game'])):
    if tigers_2018.loc[x, 'Runs'] > tigers_2018.loc[x, 'R']:
        tigers_2018.loc[x, 'Win'] = 0
    else:
        tigers_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Tigers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=DET&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

DET_2017_game_num = get_stat2('team_game_num')
DET_2017_PA = get_stat2('PA')
DET_2017_AB = get_stat2('AB')
DET_2017_R = get_stat2('R')
DET_2017_H = get_stat2('H')
DET_2017_2B = get_stat2('2B')
DET_2017_3B = get_stat2('3B')
DET_2017_HR = get_stat2('HR')
DET_2017_RBI = get_stat2('RBI')
DET_2017_BB = get_stat2('BB')
DET_2017_SO = get_stat2('SO')
DET_2017_SB = get_stat2('SB')
DET_2017_CS = get_stat2('CS')
DET_2017_BA = get_stat2('batting_avg')
DET_2017_OBP = get_stat2('onbase_perc')
DET_2017_SLG = get_stat2('slugging_perc')
DET_2017_OPS = get_stat2('onbase_plus_slugging')
DET_2017_LOB = get_stat2('LOB')
tigers_2017_offense = pd.DataFrame({
                                  'PA': DET_2017_PA,
                                  'AB': DET_2017_AB,
                                  'R':  DET_2017_R,
                                  'H':  DET_2017_H,
                                  '2B': DET_2017_2B,
                                  '3B': DET_2017_3B, 
                                  'HR': DET_2017_HR, 
                                  'RBI':DET_2017_RBI,
                                  'BB': DET_2017_BB,
                                  'SO': DET_2017_SO,
                                  'SB': DET_2017_SB,
                                  'CS': DET_2017_CS,
                                  'LOB':DET_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=DET&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

DET_2017_P_game_num = get_stat3('team_game_num')
DET_2017_P_IP = get_stat3('IP')
DET_2017_P_H = get_stat3('H')
DET_2017_P_R = get_stat3('R')
DET_2017_P_ER = get_stat3('ER')
DET_2017_P_UER = get_stat3('UER')
DET_2017_P_BB = get_stat3('BB')
DET_2017_P_SO = get_stat3('SO')
DET_2017_P_HR = get_stat3('HR')
DET_2017_P_HBP = get_stat3('HBP')
DET_2017_P_ERA = get_stat3('earned_run_avg')

tigers_2017_pitching = pd.DataFrame({'Game':  DET_2017_P_game_num, 
                                         'IP':  DET_2017_P_IP, 
                                         'H':   DET_2017_P_H,
                                         'R':   DET_2017_P_R,
                                         'ER':  DET_2017_P_ER,
                                         'UER': DET_2017_P_UER,
                                         'BB':  DET_2017_P_BB,
                                         'SO':  DET_2017_P_SO,
                                         'HR':  DET_2017_P_HR,
                                         'HBP': DET_2017_P_HBP})

# tigers_offense = tigers_offense.drop(columns = ['Game'])

tigers_2017_pitching = tigers_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [tigers_2017_pitching, tigers_2017_offense]

tigers_2017 = pd.concat(frames, axis=1)

tigers_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(tigers_2017[x])):
        tigers_2017.loc[y,x] = int(tigers_2017.loc[y, x])

for x in columns_float:
    for y in range(len(tigers_2017[x])):
        tigers_2017.loc[y,x] = float(tigers_2017.loc[y, x])  

for x in range(len(tigers_2017['Game'])):
    if tigers_2017.loc[x, 'Runs'] > tigers_2017.loc[x, 'R']:
        tigers_2017.loc[x, 'Win'] = 0
    else:
        tigers_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Tigers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=DET&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

DET_2016_game_num = get_stat2('team_game_num')
DET_2016_PA = get_stat2('PA')
DET_2016_AB = get_stat2('AB')
DET_2016_R = get_stat2('R')
DET_2016_H = get_stat2('H')
DET_2016_2B = get_stat2('2B')
DET_2016_3B = get_stat2('3B')
DET_2016_HR = get_stat2('HR')
DET_2016_RBI = get_stat2('RBI')
DET_2016_BB = get_stat2('BB')
DET_2016_SO = get_stat2('SO')
DET_2016_SB = get_stat2('SB')
DET_2016_CS = get_stat2('CS')
DET_2016_BA = get_stat2('batting_avg')
DET_2016_OBP = get_stat2('onbase_perc')
DET_2016_SLG = get_stat2('slugging_perc')
DET_2016_OPS = get_stat2('onbase_plus_slugging')
DET_2016_LOB = get_stat2('LOB')
tigers_2016_offense = pd.DataFrame({
                                  'PA': DET_2016_PA,
                                  'AB': DET_2016_AB,
                                  'R':  DET_2016_R,
                                  'H':  DET_2016_H,
                                  '2B': DET_2016_2B,
                                  '3B': DET_2016_3B, 
                                  'HR': DET_2016_HR, 
                                  'RBI':DET_2016_RBI,
                                  'BB': DET_2016_BB,
                                  'SO': DET_2016_SO,
                                  'SB': DET_2016_SB,
                                  'CS': DET_2016_CS,
                                  'LOB':DET_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=DET&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

DET_2016_P_game_num = get_stat3('team_game_num')
DET_2016_P_IP = get_stat3('IP')
DET_2016_P_H = get_stat3('H')
DET_2016_P_R = get_stat3('R')
DET_2016_P_ER = get_stat3('ER')
DET_2016_P_UER = get_stat3('UER')
DET_2016_P_BB = get_stat3('BB')
DET_2016_P_SO = get_stat3('SO')
DET_2016_P_HR = get_stat3('HR')
DET_2016_P_HBP = get_stat3('HBP')
DET_2016_P_ERA = get_stat3('earned_run_avg')

tigers_2016_pitching = pd.DataFrame({'Game':  DET_2016_P_game_num, 
                                         'IP':  DET_2016_P_IP, 
                                         'H':   DET_2016_P_H,
                                         'R':   DET_2016_P_R,
                                         'ER':  DET_2016_P_ER,
                                         'UER': DET_2016_P_UER,
                                         'BB':  DET_2016_P_BB,
                                         'SO':  DET_2016_P_SO,
                                         'HR':  DET_2016_P_HR,
                                         'HBP': DET_2016_P_HBP})

# tigers_offense = tigers_offense.drop(columns = ['Game'])

tigers_2016_pitching = tigers_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [tigers_2016_pitching, tigers_2016_offense]

tigers_2016 = pd.concat(frames, axis=1)

tigers_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(tigers_2016[x])):
        tigers_2016.loc[y,x] = int(tigers_2016.loc[y, x])

for x in columns_float:
    for y in range(len(tigers_2016[x])):
        tigers_2016.loc[y,x] = float(tigers_2016.loc[y, x])  

for x in range(len(tigers_2016['Game'])):
    if tigers_2016.loc[x, 'Runs'] > tigers_2016.loc[x, 'R']:
        tigers_2016.loc[x, 'Win'] = 0
    else:
        tigers_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Tigers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=DET&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

DET_2015_game_num = get_stat2('team_game_num')
DET_2015_PA = get_stat2('PA')
DET_2015_AB = get_stat2('AB')
DET_2015_R = get_stat2('R')
DET_2015_H = get_stat2('H')
DET_2015_2B = get_stat2('2B')
DET_2015_3B = get_stat2('3B')
DET_2015_HR = get_stat2('HR')
DET_2015_RBI = get_stat2('RBI')
DET_2015_BB = get_stat2('BB')
DET_2015_SO = get_stat2('SO')
DET_2015_SB = get_stat2('SB')
DET_2015_CS = get_stat2('CS')
DET_2015_BA = get_stat2('batting_avg')
DET_2015_OBP = get_stat2('onbase_perc')
DET_2015_SLG = get_stat2('slugging_perc')
DET_2015_OPS = get_stat2('onbase_plus_slugging')
DET_2015_LOB = get_stat2('LOB')
tigers_2015_offense = pd.DataFrame({
                                  'PA': DET_2015_PA,
                                  'AB': DET_2015_AB,
                                  'R':  DET_2015_R,
                                  'H':  DET_2015_H,
                                  '2B': DET_2015_2B,
                                  '3B': DET_2015_3B, 
                                  'HR': DET_2015_HR, 
                                  'RBI':DET_2015_RBI,
                                  'BB': DET_2015_BB,
                                  'SO': DET_2015_SO,
                                  'SB': DET_2015_SB,
                                  'CS': DET_2015_CS,
                                  'LOB':DET_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=DET&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

DET_2015_P_game_num = get_stat3('team_game_num')
DET_2015_P_IP = get_stat3('IP')
DET_2015_P_H = get_stat3('H')
DET_2015_P_R = get_stat3('R')
DET_2015_P_ER = get_stat3('ER')
DET_2015_P_UER = get_stat3('UER')
DET_2015_P_BB = get_stat3('BB')
DET_2015_P_SO = get_stat3('SO')
DET_2015_P_HR = get_stat3('HR')
DET_2015_P_HBP = get_stat3('HBP')
DET_2015_P_ERA = get_stat3('earned_run_avg')

tigers_2015_pitching = pd.DataFrame({'Game':  DET_2015_P_game_num, 
                                         'IP':  DET_2015_P_IP, 
                                         'H':   DET_2015_P_H,
                                         'R':   DET_2015_P_R,
                                         'ER':  DET_2015_P_ER,
                                         'UER': DET_2015_P_UER,
                                         'BB':  DET_2015_P_BB,
                                         'SO':  DET_2015_P_SO,
                                         'HR':  DET_2015_P_HR,
                                         'HBP': DET_2015_P_HBP})

# tigers_offense = tigers_offense.drop(columns = ['Game'])

tigers_2015_pitching = tigers_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [tigers_2015_pitching, tigers_2015_offense]

tigers_2015 = pd.concat(frames, axis=1)

tigers_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(tigers_2015[x])):
        tigers_2015.loc[y,x] = int(tigers_2015.loc[y, x])

for x in columns_float:
    for y in range(len(tigers_2015[x])):
        tigers_2015.loc[y,x] = float(tigers_2015.loc[y, x])  

for x in range(len(tigers_2015['Game'])):
    if tigers_2015.loc[x, 'Runs'] > tigers_2015.loc[x, 'R']:
        tigers_2015.loc[x, 'Win'] = 0
    else:
        tigers_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Astros Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=HOU&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

HOU_game_num = get_stat2('team_game_num')
HOU_PA = get_stat2('PA')
HOU_AB = get_stat2('AB')
HOU_R = get_stat2('R')
HOU_H = get_stat2('H')
HOU_2B = get_stat2('2B')
HOU_3B = get_stat2('3B')
HOU_HR = get_stat2('HR')
HOU_RBI = get_stat2('RBI')
HOU_BB = get_stat2('BB')
HOU_SO = get_stat2('SO')
HOU_SB = get_stat2('SB')
HOU_CS = get_stat2('CS')
HOU_BA = get_stat2('batting_avg')
HOU_OBP = get_stat2('onbase_perc')
HOU_SLG = get_stat2('slugging_perc')
HOU_OPS = get_stat2('onbase_plus_slugging')
HOU_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


astros_offense = pd.DataFrame({
                                  'PA': HOU_PA,
                                  'AB': HOU_AB,
                                  'R':  HOU_R,
                                  'H':  HOU_H,
                                  '2B': HOU_2B,
                                  '3B': HOU_3B, 
                                  'HR': HOU_HR, 
                                  'RBI':HOU_RBI,
                                  'BB': HOU_BB,
                                  'SO': HOU_SO,
                                  'SB': HOU_SB,
                                  'CS': HOU_CS,
                                  'LOB':HOU_LOB})

# %% [markdown]
# # 2019 Astros Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=HOU&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

HOU_P_game_num = get_stat3('team_game_num')
HOU_P_IP = get_stat3('IP')
HOU_P_H = get_stat3('H')
HOU_P_R = get_stat3('R')
HOU_P_ER = get_stat3('ER')
HOU_P_UER = get_stat3('UER')
HOU_P_BB = get_stat3('BB')
HOU_P_SO = get_stat3('SO')
HOU_P_HR = get_stat3('HR')
HOU_P_HBP = get_stat3('HBP')
HOU_P_ERA = get_stat3('earned_run_avg')

astros_pitching = pd.DataFrame({'Game':  HOU_P_game_num, 
                                   'IP':  HOU_P_IP, 
                                   'H':   HOU_P_H,
                                   'R':   HOU_P_R,
                                   'ER':  HOU_P_ER,
                                   'UER': HOU_P_UER,
                                   'BB':  HOU_P_BB,
                                   'SO':  HOU_P_SO,
                                   'HR':  HOU_P_HR,
                                   'HBP': HOU_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

astros_pitching = astros_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [astros_pitching, astros_offense]

astros = pd.concat(frames, axis=1)

astros['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(astros[x])):
        astros.loc[y,x] = int(astros.loc[y, x])

for x in columns_float:
    for y in range(len(astros[x])):
        astros.loc[y,x] = float(astros.loc[y, x])  

for x in range(len(astros['Game'])):
    if astros.loc[x, 'Runs'] > astros.loc[x, 'R']:
        astros.loc[x, 'Win'] = 0
    else:
        astros.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Astros Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=HOU&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

HOU_2018_game_num = get_stat2('team_game_num')
HOU_2018_PA = get_stat2('PA')
HOU_2018_AB = get_stat2('AB')
HOU_2018_R = get_stat2('R')
HOU_2018_H = get_stat2('H')
HOU_2018_2B = get_stat2('2B')
HOU_2018_3B = get_stat2('3B')
HOU_2018_HR = get_stat2('HR')
HOU_2018_RBI = get_stat2('RBI')
HOU_2018_BB = get_stat2('BB')
HOU_2018_SO = get_stat2('SO')
HOU_2018_SB = get_stat2('SB')
HOU_2018_CS = get_stat2('CS')
HOU_2018_BA = get_stat2('batting_avg')
HOU_2018_OBP = get_stat2('onbase_perc')
HOU_2018_SLG = get_stat2('slugging_perc')
HOU_2018_OPS = get_stat2('onbase_plus_slugging')
HOU_2018_LOB = get_stat2('LOB')
astros_2018_offense = pd.DataFrame({
                                  'PA': HOU_2018_PA,
                                  'AB': HOU_2018_AB,
                                  'R':  HOU_2018_R,
                                  'H':  HOU_2018_H,
                                  '2B': HOU_2018_2B,
                                  '3B': HOU_2018_3B, 
                                  'HR': HOU_2018_HR, 
                                  'RBI':HOU_2018_RBI,
                                  'BB': HOU_2018_BB,
                                  'SO': HOU_2018_SO,
                                  'SB': HOU_2018_SB,
                                  'CS': HOU_2018_CS,
                                  'LOB':HOU_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=HOU&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

HOU_2018_P_game_num = get_stat3('team_game_num')
HOU_2018_P_IP = get_stat3('IP')
HOU_2018_P_H = get_stat3('H')
HOU_2018_P_R = get_stat3('R')
HOU_2018_P_ER = get_stat3('ER')
HOU_2018_P_UER = get_stat3('UER')
HOU_2018_P_BB = get_stat3('BB')
HOU_2018_P_SO = get_stat3('SO')
HOU_2018_P_HR = get_stat3('HR')
HOU_2018_P_HBP = get_stat3('HBP')
HOU_2018_P_ERA = get_stat3('earned_run_avg')

astros_2018_pitching = pd.DataFrame({'Game':  HOU_2018_P_game_num, 
                                         'IP':  HOU_2018_P_IP, 
                                         'H':   HOU_2018_P_H,
                                         'R':   HOU_2018_P_R,
                                         'ER':  HOU_2018_P_ER,
                                         'UER': HOU_2018_P_UER,
                                         'BB':  HOU_2018_P_BB,
                                         'SO':  HOU_2018_P_SO,
                                         'HR':  HOU_2018_P_HR,
                                         'HBP': HOU_2018_P_HBP})

# astros_offense = astros_offense.drop(columns = ['Game'])

astros_2018_pitching = astros_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [astros_2018_pitching, astros_2018_offense]

astros_2018 = pd.concat(frames, axis=1)

astros_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(astros_2018[x])):
        astros_2018.loc[y,x] = int(astros_2018.loc[y, x])

for x in columns_float:
    for y in range(len(astros_2018[x])):
        astros_2018.loc[y,x] = float(astros_2018.loc[y, x])  

for x in range(len(astros_2018['Game'])):
    if astros_2018.loc[x, 'Runs'] > astros_2018.loc[x, 'R']:
        astros_2018.loc[x, 'Win'] = 0
    else:
        astros_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Astros Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=HOU&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

HOU_2017_game_num = get_stat2('team_game_num')
HOU_2017_PA = get_stat2('PA')
HOU_2017_AB = get_stat2('AB')
HOU_2017_R = get_stat2('R')
HOU_2017_H = get_stat2('H')
HOU_2017_2B = get_stat2('2B')
HOU_2017_3B = get_stat2('3B')
HOU_2017_HR = get_stat2('HR')
HOU_2017_RBI = get_stat2('RBI')
HOU_2017_BB = get_stat2('BB')
HOU_2017_SO = get_stat2('SO')
HOU_2017_SB = get_stat2('SB')
HOU_2017_CS = get_stat2('CS')
HOU_2017_BA = get_stat2('batting_avg')
HOU_2017_OBP = get_stat2('onbase_perc')
HOU_2017_SLG = get_stat2('slugging_perc')
HOU_2017_OPS = get_stat2('onbase_plus_slugging')
HOU_2017_LOB = get_stat2('LOB')
astros_2017_offense = pd.DataFrame({
                                  'PA': HOU_2017_PA,
                                  'AB': HOU_2017_AB,
                                  'R':  HOU_2017_R,
                                  'H':  HOU_2017_H,
                                  '2B': HOU_2017_2B,
                                  '3B': HOU_2017_3B, 
                                  'HR': HOU_2017_HR, 
                                  'RBI':HOU_2017_RBI,
                                  'BB': HOU_2017_BB,
                                  'SO': HOU_2017_SO,
                                  'SB': HOU_2017_SB,
                                  'CS': HOU_2017_CS,
                                  'LOB':HOU_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=HOU&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

HOU_2017_P_game_num = get_stat3('team_game_num')
HOU_2017_P_IP = get_stat3('IP')
HOU_2017_P_H = get_stat3('H')
HOU_2017_P_R = get_stat3('R')
HOU_2017_P_ER = get_stat3('ER')
HOU_2017_P_UER = get_stat3('UER')
HOU_2017_P_BB = get_stat3('BB')
HOU_2017_P_SO = get_stat3('SO')
HOU_2017_P_HR = get_stat3('HR')
HOU_2017_P_HBP = get_stat3('HBP')
HOU_2017_P_ERA = get_stat3('earned_run_avg')

astros_2017_pitching = pd.DataFrame({'Game':  HOU_2017_P_game_num, 
                                         'IP':  HOU_2017_P_IP, 
                                         'H':   HOU_2017_P_H,
                                         'R':   HOU_2017_P_R,
                                         'ER':  HOU_2017_P_ER,
                                         'UER': HOU_2017_P_UER,
                                         'BB':  HOU_2017_P_BB,
                                         'SO':  HOU_2017_P_SO,
                                         'HR':  HOU_2017_P_HR,
                                         'HBP': HOU_2017_P_HBP})

# astros_offense = astros_offense.drop(columns = ['Game'])

astros_2017_pitching = astros_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [astros_2017_pitching, astros_2017_offense]

astros_2017 = pd.concat(frames, axis=1)

astros_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(astros_2017[x])):
        astros_2017.loc[y,x] = int(astros_2017.loc[y, x])

for x in columns_float:
    for y in range(len(astros_2017[x])):
        astros_2017.loc[y,x] = float(astros_2017.loc[y, x])  

for x in range(len(astros_2017['Game'])):
    if astros_2017.loc[x, 'Runs'] > astros_2017.loc[x, 'R']:
        astros_2017.loc[x, 'Win'] = 0
    else:
        astros_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Astros Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=HOU&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

HOU_2016_game_num = get_stat2('team_game_num')
HOU_2016_PA = get_stat2('PA')
HOU_2016_AB = get_stat2('AB')
HOU_2016_R = get_stat2('R')
HOU_2016_H = get_stat2('H')
HOU_2016_2B = get_stat2('2B')
HOU_2016_3B = get_stat2('3B')
HOU_2016_HR = get_stat2('HR')
HOU_2016_RBI = get_stat2('RBI')
HOU_2016_BB = get_stat2('BB')
HOU_2016_SO = get_stat2('SO')
HOU_2016_SB = get_stat2('SB')
HOU_2016_CS = get_stat2('CS')
HOU_2016_BA = get_stat2('batting_avg')
HOU_2016_OBP = get_stat2('onbase_perc')
HOU_2016_SLG = get_stat2('slugging_perc')
HOU_2016_OPS = get_stat2('onbase_plus_slugging')
HOU_2016_LOB = get_stat2('LOB')
astros_2016_offense = pd.DataFrame({
                                  'PA': HOU_2016_PA,
                                  'AB': HOU_2016_AB,
                                  'R':  HOU_2016_R,
                                  'H':  HOU_2016_H,
                                  '2B': HOU_2016_2B,
                                  '3B': HOU_2016_3B, 
                                  'HR': HOU_2016_HR, 
                                  'RBI':HOU_2016_RBI,
                                  'BB': HOU_2016_BB,
                                  'SO': HOU_2016_SO,
                                  'SB': HOU_2016_SB,
                                  'CS': HOU_2016_CS,
                                  'LOB':HOU_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=HOU&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

HOU_2016_P_game_num = get_stat3('team_game_num')
HOU_2016_P_IP = get_stat3('IP')
HOU_2016_P_H = get_stat3('H')
HOU_2016_P_R = get_stat3('R')
HOU_2016_P_ER = get_stat3('ER')
HOU_2016_P_UER = get_stat3('UER')
HOU_2016_P_BB = get_stat3('BB')
HOU_2016_P_SO = get_stat3('SO')
HOU_2016_P_HR = get_stat3('HR')
HOU_2016_P_HBP = get_stat3('HBP')
HOU_2016_P_ERA = get_stat3('earned_run_avg')

astros_2016_pitching = pd.DataFrame({'Game':  HOU_2016_P_game_num, 
                                         'IP':  HOU_2016_P_IP, 
                                         'H':   HOU_2016_P_H,
                                         'R':   HOU_2016_P_R,
                                         'ER':  HOU_2016_P_ER,
                                         'UER': HOU_2016_P_UER,
                                         'BB':  HOU_2016_P_BB,
                                         'SO':  HOU_2016_P_SO,
                                         'HR':  HOU_2016_P_HR,
                                         'HBP': HOU_2016_P_HBP})

# astros_offense = astros_offense.drop(columns = ['Game'])

astros_2016_pitching = astros_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [astros_2016_pitching, astros_2016_offense]

astros_2016 = pd.concat(frames, axis=1)

astros_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(astros_2016[x])):
        astros_2016.loc[y,x] = int(astros_2016.loc[y, x])

for x in columns_float:
    for y in range(len(astros_2016[x])):
        astros_2016.loc[y,x] = float(astros_2016.loc[y, x])  

for x in range(len(astros_2016['Game'])):
    if astros_2016.loc[x, 'Runs'] > astros_2016.loc[x, 'R']:
        astros_2016.loc[x, 'Win'] = 0
    else:
        astros_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Astros Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=HOU&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

HOU_2015_game_num = get_stat2('team_game_num')
HOU_2015_PA = get_stat2('PA')
HOU_2015_AB = get_stat2('AB')
HOU_2015_R = get_stat2('R')
HOU_2015_H = get_stat2('H')
HOU_2015_2B = get_stat2('2B')
HOU_2015_3B = get_stat2('3B')
HOU_2015_HR = get_stat2('HR')
HOU_2015_RBI = get_stat2('RBI')
HOU_2015_BB = get_stat2('BB')
HOU_2015_SO = get_stat2('SO')
HOU_2015_SB = get_stat2('SB')
HOU_2015_CS = get_stat2('CS')
HOU_2015_BA = get_stat2('batting_avg')
HOU_2015_OBP = get_stat2('onbase_perc')
HOU_2015_SLG = get_stat2('slugging_perc')
HOU_2015_OPS = get_stat2('onbase_plus_slugging')
HOU_2015_LOB = get_stat2('LOB')
astros_2015_offense = pd.DataFrame({
                                  'PA': HOU_2015_PA,
                                  'AB': HOU_2015_AB,
                                  'R':  HOU_2015_R,
                                  'H':  HOU_2015_H,
                                  '2B': HOU_2015_2B,
                                  '3B': HOU_2015_3B, 
                                  'HR': HOU_2015_HR, 
                                  'RBI':HOU_2015_RBI,
                                  'BB': HOU_2015_BB,
                                  'SO': HOU_2015_SO,
                                  'SB': HOU_2015_SB,
                                  'CS': HOU_2015_CS,
                                  'LOB':HOU_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=HOU&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

HOU_2015_P_game_num = get_stat3('team_game_num')
HOU_2015_P_IP = get_stat3('IP')
HOU_2015_P_H = get_stat3('H')
HOU_2015_P_R = get_stat3('R')
HOU_2015_P_ER = get_stat3('ER')
HOU_2015_P_UER = get_stat3('UER')
HOU_2015_P_BB = get_stat3('BB')
HOU_2015_P_SO = get_stat3('SO')
HOU_2015_P_HR = get_stat3('HR')
HOU_2015_P_HBP = get_stat3('HBP')
HOU_2015_P_ERA = get_stat3('earned_run_avg')

astros_2015_pitching = pd.DataFrame({'Game':  HOU_2015_P_game_num, 
                                         'IP':  HOU_2015_P_IP, 
                                         'H':   HOU_2015_P_H,
                                         'R':   HOU_2015_P_R,
                                         'ER':  HOU_2015_P_ER,
                                         'UER': HOU_2015_P_UER,
                                         'BB':  HOU_2015_P_BB,
                                         'SO':  HOU_2015_P_SO,
                                         'HR':  HOU_2015_P_HR,
                                         'HBP': HOU_2015_P_HBP})

# astros_offense = astros_offense.drop(columns = ['Game'])

astros_2015_pitching = astros_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [astros_2015_pitching, astros_2015_offense]

astros_2015 = pd.concat(frames, axis=1)

astros_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(astros_2015[x])):
        astros_2015.loc[y,x] = int(astros_2015.loc[y, x])

for x in columns_float:
    for y in range(len(astros_2015[x])):
        astros_2015.loc[y,x] = float(astros_2015.loc[y, x])  

for x in range(len(astros_2015['Game'])):
    if astros_2015.loc[x, 'Runs'] > astros_2015.loc[x, 'R']:
        astros_2015.loc[x, 'Win'] = 0
    else:
        astros_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 A's Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=OAK&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

OAK_game_num = get_stat2('team_game_num')
OAK_PA = get_stat2('PA')
OAK_AB = get_stat2('AB')
OAK_R = get_stat2('R')
OAK_H = get_stat2('H')
OAK_2B = get_stat2('2B')
OAK_3B = get_stat2('3B')
OAK_HR = get_stat2('HR')
OAK_RBI = get_stat2('RBI')
OAK_BB = get_stat2('BB')
OAK_SO = get_stat2('SO')
OAK_SB = get_stat2('SB')
OAK_CS = get_stat2('CS')
OAK_BA = get_stat2('batting_avg')
OAK_OBP = get_stat2('onbase_perc')
OAK_SLG = get_stat2('slugging_perc')
OAK_OPS = get_stat2('onbase_plus_slugging')
OAK_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


athletics_offense = pd.DataFrame({
                                  'PA': OAK_PA,
                                  'AB': OAK_AB,
                                  'R':  OAK_R,
                                  'H':  OAK_H,
                                  '2B': OAK_2B,
                                  '3B': OAK_3B, 
                                  'HR': OAK_HR, 
                                  'RBI':OAK_RBI,
                                  'BB': OAK_BB,
                                  'SO': OAK_SO,
                                  'SB': OAK_SB,
                                  'CS': OAK_CS,
                                  'LOB':OAK_LOB})

# %% [markdown]
# # 2019 A's Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=OAK&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

OAK_P_game_num = get_stat3('team_game_num')
OAK_P_IP = get_stat3('IP')
OAK_P_H = get_stat3('H')
OAK_P_R = get_stat3('R')
OAK_P_ER = get_stat3('ER')
OAK_P_UER = get_stat3('UER')
OAK_P_BB = get_stat3('BB')
OAK_P_SO = get_stat3('SO')
OAK_P_HR = get_stat3('HR')
OAK_P_HBP = get_stat3('HBP')
OAK_P_ERA = get_stat3('earned_run_avg')

athletics_pitching = pd.DataFrame({'Game':  OAK_P_game_num, 
                                   'IP':  OAK_P_IP, 
                                   'H':   OAK_P_H,
                                   'R':   OAK_P_R,
                                   'ER':  OAK_P_ER,
                                   'UER': OAK_P_UER,
                                   'BB':  OAK_P_BB,
                                   'SO':  OAK_P_SO,
                                   'HR':  OAK_P_HR,
                                   'HBP': OAK_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

athletics_pitching = athletics_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [athletics_pitching, athletics_offense]

athletics = pd.concat(frames, axis=1)

athletics['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(athletics[x])):
        athletics.loc[y,x] = int(athletics.loc[y, x])

for x in columns_float:
    for y in range(len(athletics[x])):
        athletics.loc[y,x] = float(athletics.loc[y, x])  

for x in range(len(athletics['Game'])):
    if athletics.loc[x, 'Runs'] > athletics.loc[x, 'R']:
        athletics.loc[x, 'Win'] = 0
    else:
        athletics.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 A's Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=OAK&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

OAK_2018_game_num = get_stat2('team_game_num')
OAK_2018_PA = get_stat2('PA')
OAK_2018_AB = get_stat2('AB')
OAK_2018_R = get_stat2('R')
OAK_2018_H = get_stat2('H')
OAK_2018_2B = get_stat2('2B')
OAK_2018_3B = get_stat2('3B')
OAK_2018_HR = get_stat2('HR')
OAK_2018_RBI = get_stat2('RBI')
OAK_2018_BB = get_stat2('BB')
OAK_2018_SO = get_stat2('SO')
OAK_2018_SB = get_stat2('SB')
OAK_2018_CS = get_stat2('CS')
OAK_2018_BA = get_stat2('batting_avg')
OAK_2018_OBP = get_stat2('onbase_perc')
OAK_2018_SLG = get_stat2('slugging_perc')
OAK_2018_OPS = get_stat2('onbase_plus_slugging')
OAK_2018_LOB = get_stat2('LOB')
athletics_2018_offense = pd.DataFrame({
                                  'PA': OAK_2018_PA,
                                  'AB': OAK_2018_AB,
                                  'R':  OAK_2018_R,
                                  'H':  OAK_2018_H,
                                  '2B': OAK_2018_2B,
                                  '3B': OAK_2018_3B, 
                                  'HR': OAK_2018_HR, 
                                  'RBI':OAK_2018_RBI,
                                  'BB': OAK_2018_BB,
                                  'SO': OAK_2018_SO,
                                  'SB': OAK_2018_SB,
                                  'CS': OAK_2018_CS,
                                  'LOB':OAK_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=OAK&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

OAK_2018_P_game_num = get_stat3('team_game_num')
OAK_2018_P_IP = get_stat3('IP')
OAK_2018_P_H = get_stat3('H')
OAK_2018_P_R = get_stat3('R')
OAK_2018_P_ER = get_stat3('ER')
OAK_2018_P_UER = get_stat3('UER')
OAK_2018_P_BB = get_stat3('BB')
OAK_2018_P_SO = get_stat3('SO')
OAK_2018_P_HR = get_stat3('HR')
OAK_2018_P_HBP = get_stat3('HBP')
OAK_2018_P_ERA = get_stat3('earned_run_avg')

athletics_2018_pitching = pd.DataFrame({'Game':  OAK_2018_P_game_num, 
                                         'IP':  OAK_2018_P_IP, 
                                         'H':   OAK_2018_P_H,
                                         'R':   OAK_2018_P_R,
                                         'ER':  OAK_2018_P_ER,
                                         'UER': OAK_2018_P_UER,
                                         'BB':  OAK_2018_P_BB,
                                         'SO':  OAK_2018_P_SO,
                                         'HR':  OAK_2018_P_HR,
                                         'HBP': OAK_2018_P_HBP})

# athletics_offense = athletics_offense.drop(columns = ['Game'])

athletics_2018_pitching = athletics_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [athletics_2018_pitching, athletics_2018_offense]

athletics_2018 = pd.concat(frames, axis=1)

athletics_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(athletics_2018[x])):
        athletics_2018.loc[y,x] = int(athletics_2018.loc[y, x])

for x in columns_float:
    for y in range(len(athletics_2018[x])):
        athletics_2018.loc[y,x] = float(athletics_2018.loc[y, x])  

for x in range(len(athletics_2018['Game'])):
    if athletics_2018.loc[x, 'Runs'] > athletics_2018.loc[x, 'R']:
        athletics_2018.loc[x, 'Win'] = 0
    else:
        athletics_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 A's Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=OAK&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

OAK_2017_game_num = get_stat2('team_game_num')
OAK_2017_PA = get_stat2('PA')
OAK_2017_AB = get_stat2('AB')
OAK_2017_R = get_stat2('R')
OAK_2017_H = get_stat2('H')
OAK_2017_2B = get_stat2('2B')
OAK_2017_3B = get_stat2('3B')
OAK_2017_HR = get_stat2('HR')
OAK_2017_RBI = get_stat2('RBI')
OAK_2017_BB = get_stat2('BB')
OAK_2017_SO = get_stat2('SO')
OAK_2017_SB = get_stat2('SB')
OAK_2017_CS = get_stat2('CS')
OAK_2017_BA = get_stat2('batting_avg')
OAK_2017_OBP = get_stat2('onbase_perc')
OAK_2017_SLG = get_stat2('slugging_perc')
OAK_2017_OPS = get_stat2('onbase_plus_slugging')
OAK_2017_LOB = get_stat2('LOB')
athletics_2017_offense = pd.DataFrame({
                                  'PA': OAK_2017_PA,
                                  'AB': OAK_2017_AB,
                                  'R':  OAK_2017_R,
                                  'H':  OAK_2017_H,
                                  '2B': OAK_2017_2B,
                                  '3B': OAK_2017_3B, 
                                  'HR': OAK_2017_HR, 
                                  'RBI':OAK_2017_RBI,
                                  'BB': OAK_2017_BB,
                                  'SO': OAK_2017_SO,
                                  'SB': OAK_2017_SB,
                                  'CS': OAK_2017_CS,
                                  'LOB':OAK_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=OAK&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

OAK_2017_P_game_num = get_stat3('team_game_num')
OAK_2017_P_IP = get_stat3('IP')
OAK_2017_P_H = get_stat3('H')
OAK_2017_P_R = get_stat3('R')
OAK_2017_P_ER = get_stat3('ER')
OAK_2017_P_UER = get_stat3('UER')
OAK_2017_P_BB = get_stat3('BB')
OAK_2017_P_SO = get_stat3('SO')
OAK_2017_P_HR = get_stat3('HR')
OAK_2017_P_HBP = get_stat3('HBP')
OAK_2017_P_ERA = get_stat3('earned_run_avg')

athletics_2017_pitching = pd.DataFrame({'Game':  OAK_2017_P_game_num, 
                                         'IP':  OAK_2017_P_IP, 
                                         'H':   OAK_2017_P_H,
                                         'R':   OAK_2017_P_R,
                                         'ER':  OAK_2017_P_ER,
                                         'UER': OAK_2017_P_UER,
                                         'BB':  OAK_2017_P_BB,
                                         'SO':  OAK_2017_P_SO,
                                         'HR':  OAK_2017_P_HR,
                                         'HBP': OAK_2017_P_HBP})

# athletics_offense = athletics_offense.drop(columns = ['Game'])

athletics_2017_pitching = athletics_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [athletics_2017_pitching, athletics_2017_offense]

athletics_2017 = pd.concat(frames, axis=1)

athletics_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(athletics_2017[x])):
        athletics_2017.loc[y,x] = int(athletics_2017.loc[y, x])

for x in columns_float:
    for y in range(len(athletics_2017[x])):
        athletics_2017.loc[y,x] = float(athletics_2017.loc[y, x])  

for x in range(len(athletics_2017['Game'])):
    if athletics_2017.loc[x, 'Runs'] > athletics_2017.loc[x, 'R']:
        athletics_2017.loc[x, 'Win'] = 0
    else:
        athletics_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 A's Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=OAK&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

OAK_2016_game_num = get_stat2('team_game_num')
OAK_2016_PA = get_stat2('PA')
OAK_2016_AB = get_stat2('AB')
OAK_2016_R = get_stat2('R')
OAK_2016_H = get_stat2('H')
OAK_2016_2B = get_stat2('2B')
OAK_2016_3B = get_stat2('3B')
OAK_2016_HR = get_stat2('HR')
OAK_2016_RBI = get_stat2('RBI')
OAK_2016_BB = get_stat2('BB')
OAK_2016_SO = get_stat2('SO')
OAK_2016_SB = get_stat2('SB')
OAK_2016_CS = get_stat2('CS')
OAK_2016_BA = get_stat2('batting_avg')
OAK_2016_OBP = get_stat2('onbase_perc')
OAK_2016_SLG = get_stat2('slugging_perc')
OAK_2016_OPS = get_stat2('onbase_plus_slugging')
OAK_2016_LOB = get_stat2('LOB')
athletics_2016_offense = pd.DataFrame({
                                  'PA': OAK_2016_PA,
                                  'AB': OAK_2016_AB,
                                  'R':  OAK_2016_R,
                                  'H':  OAK_2016_H,
                                  '2B': OAK_2016_2B,
                                  '3B': OAK_2016_3B, 
                                  'HR': OAK_2016_HR, 
                                  'RBI':OAK_2016_RBI,
                                  'BB': OAK_2016_BB,
                                  'SO': OAK_2016_SO,
                                  'SB': OAK_2016_SB,
                                  'CS': OAK_2016_CS,
                                  'LOB':OAK_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=OAK&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

OAK_2016_P_game_num = get_stat3('team_game_num')
OAK_2016_P_IP = get_stat3('IP')
OAK_2016_P_H = get_stat3('H')
OAK_2016_P_R = get_stat3('R')
OAK_2016_P_ER = get_stat3('ER')
OAK_2016_P_UER = get_stat3('UER')
OAK_2016_P_BB = get_stat3('BB')
OAK_2016_P_SO = get_stat3('SO')
OAK_2016_P_HR = get_stat3('HR')
OAK_2016_P_HBP = get_stat3('HBP')
OAK_2016_P_ERA = get_stat3('earned_run_avg')

athletics_2016_pitching = pd.DataFrame({'Game':  OAK_2016_P_game_num, 
                                         'IP':  OAK_2016_P_IP, 
                                         'H':   OAK_2016_P_H,
                                         'R':   OAK_2016_P_R,
                                         'ER':  OAK_2016_P_ER,
                                         'UER': OAK_2016_P_UER,
                                         'BB':  OAK_2016_P_BB,
                                         'SO':  OAK_2016_P_SO,
                                         'HR':  OAK_2016_P_HR,
                                         'HBP': OAK_2016_P_HBP})

# athletics_offense = athletics_offense.drop(columns = ['Game'])

athletics_2016_pitching = athletics_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [athletics_2016_pitching, athletics_2016_offense]

athletics_2016 = pd.concat(frames, axis=1)

athletics_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(athletics_2016[x])):
        athletics_2016.loc[y,x] = int(athletics_2016.loc[y, x])

for x in columns_float:
    for y in range(len(athletics_2016[x])):
        athletics_2016.loc[y,x] = float(athletics_2016.loc[y, x])  

for x in range(len(athletics_2016['Game'])):
    if athletics_2016.loc[x, 'Runs'] > athletics_2016.loc[x, 'R']:
        athletics_2016.loc[x, 'Win'] = 0
    else:
        athletics_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 A's Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=OAK&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

OAK_2015_game_num = get_stat2('team_game_num')
OAK_2015_PA = get_stat2('PA')
OAK_2015_AB = get_stat2('AB')
OAK_2015_R = get_stat2('R')
OAK_2015_H = get_stat2('H')
OAK_2015_2B = get_stat2('2B')
OAK_2015_3B = get_stat2('3B')
OAK_2015_HR = get_stat2('HR')
OAK_2015_RBI = get_stat2('RBI')
OAK_2015_BB = get_stat2('BB')
OAK_2015_SO = get_stat2('SO')
OAK_2015_SB = get_stat2('SB')
OAK_2015_CS = get_stat2('CS')
OAK_2015_BA = get_stat2('batting_avg')
OAK_2015_OBP = get_stat2('onbase_perc')
OAK_2015_SLG = get_stat2('slugging_perc')
OAK_2015_OPS = get_stat2('onbase_plus_slugging')
OAK_2015_LOB = get_stat2('LOB')
athletics_2015_offense = pd.DataFrame({
                                  'PA': OAK_2015_PA,
                                  'AB': OAK_2015_AB,
                                  'R':  OAK_2015_R,
                                  'H':  OAK_2015_H,
                                  '2B': OAK_2015_2B,
                                  '3B': OAK_2015_3B, 
                                  'HR': OAK_2015_HR, 
                                  'RBI':OAK_2015_RBI,
                                  'BB': OAK_2015_BB,
                                  'SO': OAK_2015_SO,
                                  'SB': OAK_2015_SB,
                                  'CS': OAK_2015_CS,
                                  'LOB':OAK_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=OAK&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

OAK_2015_P_game_num = get_stat3('team_game_num')
OAK_2015_P_IP = get_stat3('IP')
OAK_2015_P_H = get_stat3('H')
OAK_2015_P_R = get_stat3('R')
OAK_2015_P_ER = get_stat3('ER')
OAK_2015_P_UER = get_stat3('UER')
OAK_2015_P_BB = get_stat3('BB')
OAK_2015_P_SO = get_stat3('SO')
OAK_2015_P_HR = get_stat3('HR')
OAK_2015_P_HBP = get_stat3('HBP')
OAK_2015_P_ERA = get_stat3('earned_run_avg')

athletics_2015_pitching = pd.DataFrame({'Game':  OAK_2015_P_game_num, 
                                         'IP':  OAK_2015_P_IP, 
                                         'H':   OAK_2015_P_H,
                                         'R':   OAK_2015_P_R,
                                         'ER':  OAK_2015_P_ER,
                                         'UER': OAK_2015_P_UER,
                                         'BB':  OAK_2015_P_BB,
                                         'SO':  OAK_2015_P_SO,
                                         'HR':  OAK_2015_P_HR,
                                         'HBP': OAK_2015_P_HBP})

# athletics_offense = athletics_offense.drop(columns = ['Game'])

athletics_2015_pitching = athletics_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [athletics_2015_pitching, athletics_2015_offense]

athletics_2015 = pd.concat(frames, axis=1)

athletics_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(athletics_2015[x])):
        athletics_2015.loc[y,x] = int(athletics_2015.loc[y, x])

for x in columns_float:
    for y in range(len(athletics_2015[x])):
        athletics_2015.loc[y,x] = float(athletics_2015.loc[y, x])  

for x in range(len(athletics_2015['Game'])):
    if athletics_2015.loc[x, 'Runs'] > athletics_2015.loc[x, 'R']:
        athletics_2015.loc[x, 'Win'] = 0
    else:
        athletics_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Rangers Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TEX&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TEX_game_num = get_stat2('team_game_num')
TEX_PA = get_stat2('PA')
TEX_AB = get_stat2('AB')
TEX_R = get_stat2('R')
TEX_H = get_stat2('H')
TEX_2B = get_stat2('2B')
TEX_3B = get_stat2('3B')
TEX_HR = get_stat2('HR')
TEX_RBI = get_stat2('RBI')
TEX_BB = get_stat2('BB')
TEX_SO = get_stat2('SO')
TEX_SB = get_stat2('SB')
TEX_CS = get_stat2('CS')
TEX_BA = get_stat2('batting_avg')
TEX_OBP = get_stat2('onbase_perc')
TEX_SLG = get_stat2('slugging_perc')
TEX_OPS = get_stat2('onbase_plus_slugging')
TEX_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


rangers_offense = pd.DataFrame({
                                  'PA': TEX_PA,
                                  'AB': TEX_AB,
                                  'R':  TEX_R,
                                  'H':  TEX_H,
                                  '2B': TEX_2B,
                                  '3B': TEX_3B, 
                                  'HR': TEX_HR, 
                                  'RBI':TEX_RBI,
                                  'BB': TEX_BB,
                                  'SO': TEX_SO,
                                  'SB': TEX_SB,
                                  'CS': TEX_CS,
                                  'LOB':TEX_LOB})

# %% [markdown]
# # 2019 Rangers Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TEX&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TEX_P_game_num = get_stat3('team_game_num')
TEX_P_IP = get_stat3('IP')
TEX_P_H = get_stat3('H')
TEX_P_R = get_stat3('R')
TEX_P_ER = get_stat3('ER')
TEX_P_UER = get_stat3('UER')
TEX_P_BB = get_stat3('BB')
TEX_P_SO = get_stat3('SO')
TEX_P_HR = get_stat3('HR')
TEX_P_HBP = get_stat3('HBP')
TEX_P_ERA = get_stat3('earned_run_avg')

rangers_pitching = pd.DataFrame({'Game':  TEX_P_game_num, 
                                   'IP':  TEX_P_IP, 
                                   'H':   TEX_P_H,
                                   'R':   TEX_P_R,
                                   'ER':  TEX_P_ER,
                                   'UER': TEX_P_UER,
                                   'BB':  TEX_P_BB,
                                   'SO':  TEX_P_SO,
                                   'HR':  TEX_P_HR,
                                   'HBP': TEX_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

rangers_pitching = rangers_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rangers_pitching, rangers_offense]

rangers = pd.concat(frames, axis=1)

rangers['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rangers[x])):
        rangers.loc[y,x] = int(rangers.loc[y, x])

for x in columns_float:
    for y in range(len(rangers[x])):
        rangers.loc[y,x] = float(rangers.loc[y, x])  

for x in range(len(rangers['Game'])):
    if rangers.loc[x, 'Runs'] > rangers.loc[x, 'R']:
        rangers.loc[x, 'Win'] = 0
    else:
        rangers.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Rangers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TEX&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TEX_2018_game_num = get_stat2('team_game_num')
TEX_2018_PA = get_stat2('PA')
TEX_2018_AB = get_stat2('AB')
TEX_2018_R = get_stat2('R')
TEX_2018_H = get_stat2('H')
TEX_2018_2B = get_stat2('2B')
TEX_2018_3B = get_stat2('3B')
TEX_2018_HR = get_stat2('HR')
TEX_2018_RBI = get_stat2('RBI')
TEX_2018_BB = get_stat2('BB')
TEX_2018_SO = get_stat2('SO')
TEX_2018_SB = get_stat2('SB')
TEX_2018_CS = get_stat2('CS')
TEX_2018_BA = get_stat2('batting_avg')
TEX_2018_OBP = get_stat2('onbase_perc')
TEX_2018_SLG = get_stat2('slugging_perc')
TEX_2018_OPS = get_stat2('onbase_plus_slugging')
TEX_2018_LOB = get_stat2('LOB')
rangers_2018_offense = pd.DataFrame({
                                  'PA': TEX_2018_PA,
                                  'AB': TEX_2018_AB,
                                  'R':  TEX_2018_R,
                                  'H':  TEX_2018_H,
                                  '2B': TEX_2018_2B,
                                  '3B': TEX_2018_3B, 
                                  'HR': TEX_2018_HR, 
                                  'RBI':TEX_2018_RBI,
                                  'BB': TEX_2018_BB,
                                  'SO': TEX_2018_SO,
                                  'SB': TEX_2018_SB,
                                  'CS': TEX_2018_CS,
                                  'LOB':TEX_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TEX&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TEX_2018_P_game_num = get_stat3('team_game_num')
TEX_2018_P_IP = get_stat3('IP')
TEX_2018_P_H = get_stat3('H')
TEX_2018_P_R = get_stat3('R')
TEX_2018_P_ER = get_stat3('ER')
TEX_2018_P_UER = get_stat3('UER')
TEX_2018_P_BB = get_stat3('BB')
TEX_2018_P_SO = get_stat3('SO')
TEX_2018_P_HR = get_stat3('HR')
TEX_2018_P_HBP = get_stat3('HBP')
TEX_2018_P_ERA = get_stat3('earned_run_avg')

rangers_2018_pitching = pd.DataFrame({'Game':  TEX_2018_P_game_num, 
                                         'IP':  TEX_2018_P_IP, 
                                         'H':   TEX_2018_P_H,
                                         'R':   TEX_2018_P_R,
                                         'ER':  TEX_2018_P_ER,
                                         'UER': TEX_2018_P_UER,
                                         'BB':  TEX_2018_P_BB,
                                         'SO':  TEX_2018_P_SO,
                                         'HR':  TEX_2018_P_HR,
                                         'HBP': TEX_2018_P_HBP})

# rangers_offense = rangers_offense.drop(columns = ['Game'])

rangers_2018_pitching = rangers_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rangers_2018_pitching, rangers_2018_offense]

rangers_2018 = pd.concat(frames, axis=1)

rangers_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rangers_2018[x])):
        rangers_2018.loc[y,x] = int(rangers_2018.loc[y, x])

for x in columns_float:
    for y in range(len(rangers_2018[x])):
        rangers_2018.loc[y,x] = float(rangers_2018.loc[y, x])  

for x in range(len(rangers_2018['Game'])):
    if rangers_2018.loc[x, 'Runs'] > rangers_2018.loc[x, 'R']:
        rangers_2018.loc[x, 'Win'] = 0
    else:
        rangers_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Rangers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TEX&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TEX_2017_game_num = get_stat2('team_game_num')
TEX_2017_PA = get_stat2('PA')
TEX_2017_AB = get_stat2('AB')
TEX_2017_R = get_stat2('R')
TEX_2017_H = get_stat2('H')
TEX_2017_2B = get_stat2('2B')
TEX_2017_3B = get_stat2('3B')
TEX_2017_HR = get_stat2('HR')
TEX_2017_RBI = get_stat2('RBI')
TEX_2017_BB = get_stat2('BB')
TEX_2017_SO = get_stat2('SO')
TEX_2017_SB = get_stat2('SB')
TEX_2017_CS = get_stat2('CS')
TEX_2017_BA = get_stat2('batting_avg')
TEX_2017_OBP = get_stat2('onbase_perc')
TEX_2017_SLG = get_stat2('slugging_perc')
TEX_2017_OPS = get_stat2('onbase_plus_slugging')
TEX_2017_LOB = get_stat2('LOB')
rangers_2017_offense = pd.DataFrame({
                                  'PA': TEX_2017_PA,
                                  'AB': TEX_2017_AB,
                                  'R':  TEX_2017_R,
                                  'H':  TEX_2017_H,
                                  '2B': TEX_2017_2B,
                                  '3B': TEX_2017_3B, 
                                  'HR': TEX_2017_HR, 
                                  'RBI':TEX_2017_RBI,
                                  'BB': TEX_2017_BB,
                                  'SO': TEX_2017_SO,
                                  'SB': TEX_2017_SB,
                                  'CS': TEX_2017_CS,
                                  'LOB':TEX_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TEX&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TEX_2017_P_game_num = get_stat3('team_game_num')
TEX_2017_P_IP = get_stat3('IP')
TEX_2017_P_H = get_stat3('H')
TEX_2017_P_R = get_stat3('R')
TEX_2017_P_ER = get_stat3('ER')
TEX_2017_P_UER = get_stat3('UER')
TEX_2017_P_BB = get_stat3('BB')
TEX_2017_P_SO = get_stat3('SO')
TEX_2017_P_HR = get_stat3('HR')
TEX_2017_P_HBP = get_stat3('HBP')
TEX_2017_P_ERA = get_stat3('earned_run_avg')

rangers_2017_pitching = pd.DataFrame({'Game':  TEX_2017_P_game_num, 
                                         'IP':  TEX_2017_P_IP, 
                                         'H':   TEX_2017_P_H,
                                         'R':   TEX_2017_P_R,
                                         'ER':  TEX_2017_P_ER,
                                         'UER': TEX_2017_P_UER,
                                         'BB':  TEX_2017_P_BB,
                                         'SO':  TEX_2017_P_SO,
                                         'HR':  TEX_2017_P_HR,
                                         'HBP': TEX_2017_P_HBP})

# rangers_offense = rangers_offense.drop(columns = ['Game'])

rangers_2017_pitching = rangers_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rangers_2017_pitching, rangers_2017_offense]

rangers_2017 = pd.concat(frames, axis=1)

rangers_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rangers_2017[x])):
        rangers_2017.loc[y,x] = int(rangers_2017.loc[y, x])

for x in columns_float:
    for y in range(len(rangers_2017[x])):
        rangers_2017.loc[y,x] = float(rangers_2017.loc[y, x])  

for x in range(len(rangers_2017['Game'])):
    if rangers_2017.loc[x, 'Runs'] > rangers_2017.loc[x, 'R']:
        rangers_2017.loc[x, 'Win'] = 0
    else:
        rangers_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Rangers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TEX&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TEX_2016_game_num = get_stat2('team_game_num')
TEX_2016_PA = get_stat2('PA')
TEX_2016_AB = get_stat2('AB')
TEX_2016_R = get_stat2('R')
TEX_2016_H = get_stat2('H')
TEX_2016_2B = get_stat2('2B')
TEX_2016_3B = get_stat2('3B')
TEX_2016_HR = get_stat2('HR')
TEX_2016_RBI = get_stat2('RBI')
TEX_2016_BB = get_stat2('BB')
TEX_2016_SO = get_stat2('SO')
TEX_2016_SB = get_stat2('SB')
TEX_2016_CS = get_stat2('CS')
TEX_2016_BA = get_stat2('batting_avg')
TEX_2016_OBP = get_stat2('onbase_perc')
TEX_2016_SLG = get_stat2('slugging_perc')
TEX_2016_OPS = get_stat2('onbase_plus_slugging')
TEX_2016_LOB = get_stat2('LOB')
rangers_2016_offense = pd.DataFrame({
                                  'PA': TEX_2016_PA,
                                  'AB': TEX_2016_AB,
                                  'R':  TEX_2016_R,
                                  'H':  TEX_2016_H,
                                  '2B': TEX_2016_2B,
                                  '3B': TEX_2016_3B, 
                                  'HR': TEX_2016_HR, 
                                  'RBI':TEX_2016_RBI,
                                  'BB': TEX_2016_BB,
                                  'SO': TEX_2016_SO,
                                  'SB': TEX_2016_SB,
                                  'CS': TEX_2016_CS,
                                  'LOB':TEX_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TEX&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TEX_2016_P_game_num = get_stat3('team_game_num')
TEX_2016_P_IP = get_stat3('IP')
TEX_2016_P_H = get_stat3('H')
TEX_2016_P_R = get_stat3('R')
TEX_2016_P_ER = get_stat3('ER')
TEX_2016_P_UER = get_stat3('UER')
TEX_2016_P_BB = get_stat3('BB')
TEX_2016_P_SO = get_stat3('SO')
TEX_2016_P_HR = get_stat3('HR')
TEX_2016_P_HBP = get_stat3('HBP')
TEX_2016_P_ERA = get_stat3('earned_run_avg')

rangers_2016_pitching = pd.DataFrame({'Game':  TEX_2016_P_game_num, 
                                         'IP':  TEX_2016_P_IP, 
                                         'H':   TEX_2016_P_H,
                                         'R':   TEX_2016_P_R,
                                         'ER':  TEX_2016_P_ER,
                                         'UER': TEX_2016_P_UER,
                                         'BB':  TEX_2016_P_BB,
                                         'SO':  TEX_2016_P_SO,
                                         'HR':  TEX_2016_P_HR,
                                         'HBP': TEX_2016_P_HBP})

# rangers_offense = rangers_offense.drop(columns = ['Game'])

rangers_2016_pitching = rangers_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rangers_2016_pitching, rangers_2016_offense]

rangers_2016 = pd.concat(frames, axis=1)

rangers_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rangers_2016[x])):
        rangers_2016.loc[y,x] = int(rangers_2016.loc[y, x])

for x in columns_float:
    for y in range(len(rangers_2016[x])):
        rangers_2016.loc[y,x] = float(rangers_2016.loc[y, x])  

for x in range(len(rangers_2016['Game'])):
    if rangers_2016.loc[x, 'Runs'] > rangers_2016.loc[x, 'R']:
        rangers_2016.loc[x, 'Win'] = 0
    else:
        rangers_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Rangers Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TEX&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TEX_2015_game_num = get_stat2('team_game_num')
TEX_2015_PA = get_stat2('PA')
TEX_2015_AB = get_stat2('AB')
TEX_2015_R = get_stat2('R')
TEX_2015_H = get_stat2('H')
TEX_2015_2B = get_stat2('2B')
TEX_2015_3B = get_stat2('3B')
TEX_2015_HR = get_stat2('HR')
TEX_2015_RBI = get_stat2('RBI')
TEX_2015_BB = get_stat2('BB')
TEX_2015_SO = get_stat2('SO')
TEX_2015_SB = get_stat2('SB')
TEX_2015_CS = get_stat2('CS')
TEX_2015_BA = get_stat2('batting_avg')
TEX_2015_OBP = get_stat2('onbase_perc')
TEX_2015_SLG = get_stat2('slugging_perc')
TEX_2015_OPS = get_stat2('onbase_plus_slugging')
TEX_2015_LOB = get_stat2('LOB')
rangers_2015_offense = pd.DataFrame({
                                  'PA': TEX_2015_PA,
                                  'AB': TEX_2015_AB,
                                  'R':  TEX_2015_R,
                                  'H':  TEX_2015_H,
                                  '2B': TEX_2015_2B,
                                  '3B': TEX_2015_3B, 
                                  'HR': TEX_2015_HR, 
                                  'RBI':TEX_2015_RBI,
                                  'BB': TEX_2015_BB,
                                  'SO': TEX_2015_SO,
                                  'SB': TEX_2015_SB,
                                  'CS': TEX_2015_CS,
                                  'LOB':TEX_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=TEX&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

TEX_2015_P_game_num = get_stat3('team_game_num')
TEX_2015_P_IP = get_stat3('IP')
TEX_2015_P_H = get_stat3('H')
TEX_2015_P_R = get_stat3('R')
TEX_2015_P_ER = get_stat3('ER')
TEX_2015_P_UER = get_stat3('UER')
TEX_2015_P_BB = get_stat3('BB')
TEX_2015_P_SO = get_stat3('SO')
TEX_2015_P_HR = get_stat3('HR')
TEX_2015_P_HBP = get_stat3('HBP')
TEX_2015_P_ERA = get_stat3('earned_run_avg')

rangers_2015_pitching = pd.DataFrame({'Game':  TEX_2015_P_game_num, 
                                         'IP':  TEX_2015_P_IP, 
                                         'H':   TEX_2015_P_H,
                                         'R':   TEX_2015_P_R,
                                         'ER':  TEX_2015_P_ER,
                                         'UER': TEX_2015_P_UER,
                                         'BB':  TEX_2015_P_BB,
                                         'SO':  TEX_2015_P_SO,
                                         'HR':  TEX_2015_P_HR,
                                         'HBP': TEX_2015_P_HBP})

# rangers_offense = rangers_offense.drop(columns = ['Game'])

rangers_2015_pitching = rangers_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [rangers_2015_pitching, rangers_2015_offense]

rangers_2015 = pd.concat(frames, axis=1)

rangers_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(rangers_2015[x])):
        rangers_2015.loc[y,x] = int(rangers_2015.loc[y, x])

for x in columns_float:
    for y in range(len(rangers_2015[x])):
        rangers_2015.loc[y,x] = float(rangers_2015.loc[y, x])  

for x in range(len(rangers_2015['Game'])):
    if rangers_2015.loc[x, 'Runs'] > rangers_2015.loc[x, 'R']:
        rangers_2015.loc[x, 'Win'] = 0
    else:
        rangers_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Angels Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAA&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAA_game_num = get_stat2('team_game_num')
LAA_PA = get_stat2('PA')
LAA_AB = get_stat2('AB')
LAA_R = get_stat2('R')
LAA_H = get_stat2('H')
LAA_2B = get_stat2('2B')
LAA_3B = get_stat2('3B')
LAA_HR = get_stat2('HR')
LAA_RBI = get_stat2('RBI')
LAA_BB = get_stat2('BB')
LAA_SO = get_stat2('SO')
LAA_SB = get_stat2('SB')
LAA_CS = get_stat2('CS')
LAA_BA = get_stat2('batting_avg')
LAA_OBP = get_stat2('onbase_perc')
LAA_SLG = get_stat2('slugging_perc')
LAA_OPS = get_stat2('onbase_plus_slugging')
LAA_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


angels_offense = pd.DataFrame({
                                  'PA': LAA_PA,
                                  'AB': LAA_AB,
                                  'R':  LAA_R,
                                  'H':  LAA_H,
                                  '2B': LAA_2B,
                                  '3B': LAA_3B, 
                                  'HR': LAA_HR, 
                                  'RBI':LAA_RBI,
                                  'BB': LAA_BB,
                                  'SO': LAA_SO,
                                  'SB': LAA_SB,
                                  'CS': LAA_CS,
                                  'LOB':LAA_LOB})

# %% [markdown]
# # 2019 Angels Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAA&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAA_P_game_num = get_stat3('team_game_num')
LAA_P_IP = get_stat3('IP')
LAA_P_H = get_stat3('H')
LAA_P_R = get_stat3('R')
LAA_P_ER = get_stat3('ER')
LAA_P_UER = get_stat3('UER')
LAA_P_BB = get_stat3('BB')
LAA_P_SO = get_stat3('SO')
LAA_P_HR = get_stat3('HR')
LAA_P_HBP = get_stat3('HBP')
LAA_P_ERA = get_stat3('earned_run_avg')

angels_pitching = pd.DataFrame({'Game':  LAA_P_game_num, 
                                   'IP':  LAA_P_IP, 
                                   'H':   LAA_P_H,
                                   'R':   LAA_P_R,
                                   'ER':  LAA_P_ER,
                                   'UER': LAA_P_UER,
                                   'BB':  LAA_P_BB,
                                   'SO':  LAA_P_SO,
                                   'HR':  LAA_P_HR,
                                   'HBP': LAA_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

angels_pitching = angels_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [angels_pitching, angels_offense]

angels = pd.concat(frames, axis=1)

angels['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(angels[x])):
        angels.loc[y,x] = int(angels.loc[y, x])

for x in columns_float:
    for y in range(len(angels[x])):
        angels.loc[y,x] = float(angels.loc[y, x])  

for x in range(len(angels['Game'])):
    if angels.loc[x, 'Runs'] > angels.loc[x, 'R']:
        angels.loc[x, 'Win'] = 0
    else:
        angels.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Angels Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAA&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAA_2018_game_num = get_stat2('team_game_num')
LAA_2018_PA = get_stat2('PA')
LAA_2018_AB = get_stat2('AB')
LAA_2018_R = get_stat2('R')
LAA_2018_H = get_stat2('H')
LAA_2018_2B = get_stat2('2B')
LAA_2018_3B = get_stat2('3B')
LAA_2018_HR = get_stat2('HR')
LAA_2018_RBI = get_stat2('RBI')
LAA_2018_BB = get_stat2('BB')
LAA_2018_SO = get_stat2('SO')
LAA_2018_SB = get_stat2('SB')
LAA_2018_CS = get_stat2('CS')
LAA_2018_BA = get_stat2('batting_avg')
LAA_2018_OBP = get_stat2('onbase_perc')
LAA_2018_SLG = get_stat2('slugging_perc')
LAA_2018_OPS = get_stat2('onbase_plus_slugging')
LAA_2018_LOB = get_stat2('LOB')
angels_2018_offense = pd.DataFrame({
                                  'PA': LAA_2018_PA,
                                  'AB': LAA_2018_AB,
                                  'R':  LAA_2018_R,
                                  'H':  LAA_2018_H,
                                  '2B': LAA_2018_2B,
                                  '3B': LAA_2018_3B, 
                                  'HR': LAA_2018_HR, 
                                  'RBI':LAA_2018_RBI,
                                  'BB': LAA_2018_BB,
                                  'SO': LAA_2018_SO,
                                  'SB': LAA_2018_SB,
                                  'CS': LAA_2018_CS,
                                  'LOB':LAA_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAA&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAA_2018_P_game_num = get_stat3('team_game_num')
LAA_2018_P_IP = get_stat3('IP')
LAA_2018_P_H = get_stat3('H')
LAA_2018_P_R = get_stat3('R')
LAA_2018_P_ER = get_stat3('ER')
LAA_2018_P_UER = get_stat3('UER')
LAA_2018_P_BB = get_stat3('BB')
LAA_2018_P_SO = get_stat3('SO')
LAA_2018_P_HR = get_stat3('HR')
LAA_2018_P_HBP = get_stat3('HBP')
LAA_2018_P_ERA = get_stat3('earned_run_avg')

angels_2018_pitching = pd.DataFrame({'Game':  LAA_2018_P_game_num, 
                                         'IP':  LAA_2018_P_IP, 
                                         'H':   LAA_2018_P_H,
                                         'R':   LAA_2018_P_R,
                                         'ER':  LAA_2018_P_ER,
                                         'UER': LAA_2018_P_UER,
                                         'BB':  LAA_2018_P_BB,
                                         'SO':  LAA_2018_P_SO,
                                         'HR':  LAA_2018_P_HR,
                                         'HBP': LAA_2018_P_HBP})

# angels_offense = angels_offense.drop(columns = ['Game'])

angels_2018_pitching = angels_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [angels_2018_pitching, angels_2018_offense]

angels_2018 = pd.concat(frames, axis=1)

angels_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(angels_2018[x])):
        angels_2018.loc[y,x] = int(angels_2018.loc[y, x])

for x in columns_float:
    for y in range(len(angels_2018[x])):
        angels_2018.loc[y,x] = float(angels_2018.loc[y, x])  

for x in range(len(angels_2018['Game'])):
    if angels_2018.loc[x, 'Runs'] > angels_2018.loc[x, 'R']:
        angels_2018.loc[x, 'Win'] = 0
    else:
        angels_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Angels Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAA&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAA_2017_game_num = get_stat2('team_game_num')
LAA_2017_PA = get_stat2('PA')
LAA_2017_AB = get_stat2('AB')
LAA_2017_R = get_stat2('R')
LAA_2017_H = get_stat2('H')
LAA_2017_2B = get_stat2('2B')
LAA_2017_3B = get_stat2('3B')
LAA_2017_HR = get_stat2('HR')
LAA_2017_RBI = get_stat2('RBI')
LAA_2017_BB = get_stat2('BB')
LAA_2017_SO = get_stat2('SO')
LAA_2017_SB = get_stat2('SB')
LAA_2017_CS = get_stat2('CS')
LAA_2017_BA = get_stat2('batting_avg')
LAA_2017_OBP = get_stat2('onbase_perc')
LAA_2017_SLG = get_stat2('slugging_perc')
LAA_2017_OPS = get_stat2('onbase_plus_slugging')
LAA_2017_LOB = get_stat2('LOB')
angels_2017_offense = pd.DataFrame({
                                  'PA': LAA_2017_PA,
                                  'AB': LAA_2017_AB,
                                  'R':  LAA_2017_R,
                                  'H':  LAA_2017_H,
                                  '2B': LAA_2017_2B,
                                  '3B': LAA_2017_3B, 
                                  'HR': LAA_2017_HR, 
                                  'RBI':LAA_2017_RBI,
                                  'BB': LAA_2017_BB,
                                  'SO': LAA_2017_SO,
                                  'SB': LAA_2017_SB,
                                  'CS': LAA_2017_CS,
                                  'LOB':LAA_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAA&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAA_2017_P_game_num = get_stat3('team_game_num')
LAA_2017_P_IP = get_stat3('IP')
LAA_2017_P_H = get_stat3('H')
LAA_2017_P_R = get_stat3('R')
LAA_2017_P_ER = get_stat3('ER')
LAA_2017_P_UER = get_stat3('UER')
LAA_2017_P_BB = get_stat3('BB')
LAA_2017_P_SO = get_stat3('SO')
LAA_2017_P_HR = get_stat3('HR')
LAA_2017_P_HBP = get_stat3('HBP')
LAA_2017_P_ERA = get_stat3('earned_run_avg')

angels_2017_pitching = pd.DataFrame({'Game':  LAA_2017_P_game_num, 
                                         'IP':  LAA_2017_P_IP, 
                                         'H':   LAA_2017_P_H,
                                         'R':   LAA_2017_P_R,
                                         'ER':  LAA_2017_P_ER,
                                         'UER': LAA_2017_P_UER,
                                         'BB':  LAA_2017_P_BB,
                                         'SO':  LAA_2017_P_SO,
                                         'HR':  LAA_2017_P_HR,
                                         'HBP': LAA_2017_P_HBP})

# angels_offense = angels_offense.drop(columns = ['Game'])

angels_2017_pitching = angels_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [angels_2017_pitching, angels_2017_offense]

angels_2017 = pd.concat(frames, axis=1)

angels_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(angels_2017[x])):
        angels_2017.loc[y,x] = int(angels_2017.loc[y, x])

for x in columns_float:
    for y in range(len(angels_2017[x])):
        angels_2017.loc[y,x] = float(angels_2017.loc[y, x])  

for x in range(len(angels_2017['Game'])):
    if angels_2017.loc[x, 'Runs'] > angels_2017.loc[x, 'R']:
        angels_2017.loc[x, 'Win'] = 0
    else:
        angels_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Angels Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAA&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAA_2016_game_num = get_stat2('team_game_num')
LAA_2016_PA = get_stat2('PA')
LAA_2016_AB = get_stat2('AB')
LAA_2016_R = get_stat2('R')
LAA_2016_H = get_stat2('H')
LAA_2016_2B = get_stat2('2B')
LAA_2016_3B = get_stat2('3B')
LAA_2016_HR = get_stat2('HR')
LAA_2016_RBI = get_stat2('RBI')
LAA_2016_BB = get_stat2('BB')
LAA_2016_SO = get_stat2('SO')
LAA_2016_SB = get_stat2('SB')
LAA_2016_CS = get_stat2('CS')
LAA_2016_BA = get_stat2('batting_avg')
LAA_2016_OBP = get_stat2('onbase_perc')
LAA_2016_SLG = get_stat2('slugging_perc')
LAA_2016_OPS = get_stat2('onbase_plus_slugging')
LAA_2016_LOB = get_stat2('LOB')
angels_2016_offense = pd.DataFrame({
                                  'PA': LAA_2016_PA,
                                  'AB': LAA_2016_AB,
                                  'R':  LAA_2016_R,
                                  'H':  LAA_2016_H,
                                  '2B': LAA_2016_2B,
                                  '3B': LAA_2016_3B, 
                                  'HR': LAA_2016_HR, 
                                  'RBI':LAA_2016_RBI,
                                  'BB': LAA_2016_BB,
                                  'SO': LAA_2016_SO,
                                  'SB': LAA_2016_SB,
                                  'CS': LAA_2016_CS,
                                  'LOB':LAA_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAA&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAA_2016_P_game_num = get_stat3('team_game_num')
LAA_2016_P_IP = get_stat3('IP')
LAA_2016_P_H = get_stat3('H')
LAA_2016_P_R = get_stat3('R')
LAA_2016_P_ER = get_stat3('ER')
LAA_2016_P_UER = get_stat3('UER')
LAA_2016_P_BB = get_stat3('BB')
LAA_2016_P_SO = get_stat3('SO')
LAA_2016_P_HR = get_stat3('HR')
LAA_2016_P_HBP = get_stat3('HBP')
LAA_2016_P_ERA = get_stat3('earned_run_avg')

angels_2016_pitching = pd.DataFrame({'Game':  LAA_2016_P_game_num, 
                                         'IP':  LAA_2016_P_IP, 
                                         'H':   LAA_2016_P_H,
                                         'R':   LAA_2016_P_R,
                                         'ER':  LAA_2016_P_ER,
                                         'UER': LAA_2016_P_UER,
                                         'BB':  LAA_2016_P_BB,
                                         'SO':  LAA_2016_P_SO,
                                         'HR':  LAA_2016_P_HR,
                                         'HBP': LAA_2016_P_HBP})

# angels_offense = angels_offense.drop(columns = ['Game'])

angels_2016_pitching = angels_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [angels_2016_pitching, angels_2016_offense]

angels_2016 = pd.concat(frames, axis=1)

angels_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(angels_2016[x])):
        angels_2016.loc[y,x] = int(angels_2016.loc[y, x])

for x in columns_float:
    for y in range(len(angels_2016[x])):
        angels_2016.loc[y,x] = float(angels_2016.loc[y, x])  

for x in range(len(angels_2016['Game'])):
    if angels_2016.loc[x, 'Runs'] > angels_2016.loc[x, 'R']:
        angels_2016.loc[x, 'Win'] = 0
    else:
        angels_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Angels Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAA&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAA_2015_game_num = get_stat2('team_game_num')
LAA_2015_PA = get_stat2('PA')
LAA_2015_AB = get_stat2('AB')
LAA_2015_R = get_stat2('R')
LAA_2015_H = get_stat2('H')
LAA_2015_2B = get_stat2('2B')
LAA_2015_3B = get_stat2('3B')
LAA_2015_HR = get_stat2('HR')
LAA_2015_RBI = get_stat2('RBI')
LAA_2015_BB = get_stat2('BB')
LAA_2015_SO = get_stat2('SO')
LAA_2015_SB = get_stat2('SB')
LAA_2015_CS = get_stat2('CS')
LAA_2015_BA = get_stat2('batting_avg')
LAA_2015_OBP = get_stat2('onbase_perc')
LAA_2015_SLG = get_stat2('slugging_perc')
LAA_2015_OPS = get_stat2('onbase_plus_slugging')
LAA_2015_LOB = get_stat2('LOB')
angels_2015_offense = pd.DataFrame({
                                  'PA': LAA_2015_PA,
                                  'AB': LAA_2015_AB,
                                  'R':  LAA_2015_R,
                                  'H':  LAA_2015_H,
                                  '2B': LAA_2015_2B,
                                  '3B': LAA_2015_3B, 
                                  'HR': LAA_2015_HR, 
                                  'RBI':LAA_2015_RBI,
                                  'BB': LAA_2015_BB,
                                  'SO': LAA_2015_SO,
                                  'SB': LAA_2015_SB,
                                  'CS': LAA_2015_CS,
                                  'LOB':LAA_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=LAA&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

LAA_2015_P_game_num = get_stat3('team_game_num')
LAA_2015_P_IP = get_stat3('IP')
LAA_2015_P_H = get_stat3('H')
LAA_2015_P_R = get_stat3('R')
LAA_2015_P_ER = get_stat3('ER')
LAA_2015_P_UER = get_stat3('UER')
LAA_2015_P_BB = get_stat3('BB')
LAA_2015_P_SO = get_stat3('SO')
LAA_2015_P_HR = get_stat3('HR')
LAA_2015_P_HBP = get_stat3('HBP')
LAA_2015_P_ERA = get_stat3('earned_run_avg')

angels_2015_pitching = pd.DataFrame({'Game':  LAA_2015_P_game_num, 
                                         'IP':  LAA_2015_P_IP, 
                                         'H':   LAA_2015_P_H,
                                         'R':   LAA_2015_P_R,
                                         'ER':  LAA_2015_P_ER,
                                         'UER': LAA_2015_P_UER,
                                         'BB':  LAA_2015_P_BB,
                                         'SO':  LAA_2015_P_SO,
                                         'HR':  LAA_2015_P_HR,
                                         'HBP': LAA_2015_P_HBP})

# angels_offense = angels_offense.drop(columns = ['Game'])

angels_2015_pitching = angels_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [angels_2015_pitching, angels_2015_offense]

angels_2015 = pd.concat(frames, axis=1)

angels_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(angels_2015[x])):
        angels_2015.loc[y,x] = int(angels_2015.loc[y, x])

for x in columns_float:
    for y in range(len(angels_2015[x])):
        angels_2015.loc[y,x] = float(angels_2015.loc[y, x])  

for x in range(len(angels_2015['Game'])):
    if angels_2015.loc[x, 'Runs'] > angels_2015.loc[x, 'R']:
        angels_2015.loc[x, 'Win'] = 0
    else:
        angels_2015.loc[x, 'Win'] = 1

# %% [markdown]
# # 2019 Mariners Batting Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SEA&t=b&year=2019'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(\d?.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SEA_game_num = get_stat2('team_game_num')
SEA_PA = get_stat2('PA')
SEA_AB = get_stat2('AB')
SEA_R = get_stat2('R')
SEA_H = get_stat2('H')
SEA_2B = get_stat2('2B')
SEA_3B = get_stat2('3B')
SEA_HR = get_stat2('HR')
SEA_RBI = get_stat2('RBI')
SEA_BB = get_stat2('BB')
SEA_SO = get_stat2('SO')
SEA_SB = get_stat2('SB')
SEA_CS = get_stat2('CS')
SEA_BA = get_stat2('batting_avg')
SEA_OBP = get_stat2('onbase_perc')
SEA_SLG = get_stat2('slugging_perc')
SEA_OPS = get_stat2('onbase_plus_slugging')
SEA_LOB = get_stat2('LOB')

# print(len(CHC_game_num))
# print(len(CHC_PA))
# print(len(CHC_AB))
# print(len(CHC_R))
# print(len(CHC_H))
# print(len(CHC_2B))
# print(len(CHC_3B))
# print(len(CHC_HR))
# print(len(CHC_RBI))
# print(len(CHC_BB))
# print(len(CHC_SO))
# print(len(CHC_SB))
# print(len(CHC_CS))
# print(len(CHC_BA))
# print(len(CHC_OBP))
# print(len(CHC_SLG))
# print(len(CHC_OPS))
# print(len(CHC_LOB))


mariners_offense = pd.DataFrame({
                                  'PA': SEA_PA,
                                  'AB': SEA_AB,
                                  'R':  SEA_R,
                                  'H':  SEA_H,
                                  '2B': SEA_2B,
                                  '3B': SEA_3B, 
                                  'HR': SEA_HR, 
                                  'RBI':SEA_RBI,
                                  'BB': SEA_BB,
                                  'SO': SEA_SO,
                                  'SB': SEA_SB,
                                  'CS': SEA_CS,
                                  'LOB':SEA_LOB})

# %% [markdown]
# # 2019 Mariners Pitching Stats

# %%
url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SEA&t=p&year=2019'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SEA_P_game_num = get_stat3('team_game_num')
SEA_P_IP = get_stat3('IP')
SEA_P_H = get_stat3('H')
SEA_P_R = get_stat3('R')
SEA_P_ER = get_stat3('ER')
SEA_P_UER = get_stat3('UER')
SEA_P_BB = get_stat3('BB')
SEA_P_SO = get_stat3('SO')
SEA_P_HR = get_stat3('HR')
SEA_P_HBP = get_stat3('HBP')
SEA_P_ERA = get_stat3('earned_run_avg')

mariners_pitching = pd.DataFrame({'Game':  SEA_P_game_num, 
                                   'IP':  SEA_P_IP, 
                                   'H':   SEA_P_H,
                                   'R':   SEA_P_R,
                                   'ER':  SEA_P_ER,
                                   'UER': SEA_P_UER,
                                   'BB':  SEA_P_BB,
                                   'SO':  SEA_P_SO,
                                   'HR':  SEA_P_HR,
                                   'HBP': SEA_P_HBP})

# %%
# phillies_offense = phillies_offense.drop(columns = ['Game'])

mariners_pitching = mariners_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [mariners_pitching, mariners_offense]

mariners = pd.concat(frames, axis=1)

mariners['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(mariners[x])):
        mariners.loc[y,x] = int(mariners.loc[y, x])

for x in columns_float:
    for y in range(len(mariners[x])):
        mariners.loc[y,x] = float(mariners.loc[y, x])  

for x in range(len(mariners['Game'])):
    if mariners.loc[x, 'Runs'] > mariners.loc[x, 'R']:
        mariners.loc[x, 'Win'] = 0
    else:
        mariners.loc[x, 'Win'] = 1

# %% [markdown]
# # 2018 Mariners Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SEA&t=b&year=2018'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SEA_2018_game_num = get_stat2('team_game_num')
SEA_2018_PA = get_stat2('PA')
SEA_2018_AB = get_stat2('AB')
SEA_2018_R = get_stat2('R')
SEA_2018_H = get_stat2('H')
SEA_2018_2B = get_stat2('2B')
SEA_2018_3B = get_stat2('3B')
SEA_2018_HR = get_stat2('HR')
SEA_2018_RBI = get_stat2('RBI')
SEA_2018_BB = get_stat2('BB')
SEA_2018_SO = get_stat2('SO')
SEA_2018_SB = get_stat2('SB')
SEA_2018_CS = get_stat2('CS')
SEA_2018_BA = get_stat2('batting_avg')
SEA_2018_OBP = get_stat2('onbase_perc')
SEA_2018_SLG = get_stat2('slugging_perc')
SEA_2018_OPS = get_stat2('onbase_plus_slugging')
SEA_2018_LOB = get_stat2('LOB')
mariners_2018_offense = pd.DataFrame({
                                  'PA': SEA_2018_PA,
                                  'AB': SEA_2018_AB,
                                  'R':  SEA_2018_R,
                                  'H':  SEA_2018_H,
                                  '2B': SEA_2018_2B,
                                  '3B': SEA_2018_3B, 
                                  'HR': SEA_2018_HR, 
                                  'RBI':SEA_2018_RBI,
                                  'BB': SEA_2018_BB,
                                  'SO': SEA_2018_SO,
                                  'SB': SEA_2018_SB,
                                  'CS': SEA_2018_CS,
                                  'LOB':SEA_2018_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SEA&t=p&year=2018'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SEA_2018_P_game_num = get_stat3('team_game_num')
SEA_2018_P_IP = get_stat3('IP')
SEA_2018_P_H = get_stat3('H')
SEA_2018_P_R = get_stat3('R')
SEA_2018_P_ER = get_stat3('ER')
SEA_2018_P_UER = get_stat3('UER')
SEA_2018_P_BB = get_stat3('BB')
SEA_2018_P_SO = get_stat3('SO')
SEA_2018_P_HR = get_stat3('HR')
SEA_2018_P_HBP = get_stat3('HBP')
SEA_2018_P_ERA = get_stat3('earned_run_avg')

mariners_2018_pitching = pd.DataFrame({'Game':  SEA_2018_P_game_num, 
                                         'IP':  SEA_2018_P_IP, 
                                         'H':   SEA_2018_P_H,
                                         'R':   SEA_2018_P_R,
                                         'ER':  SEA_2018_P_ER,
                                         'UER': SEA_2018_P_UER,
                                         'BB':  SEA_2018_P_BB,
                                         'SO':  SEA_2018_P_SO,
                                         'HR':  SEA_2018_P_HR,
                                         'HBP': SEA_2018_P_HBP})

# mariners_offense = mariners_offense.drop(columns = ['Game'])

mariners_2018_pitching = mariners_2018_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [mariners_2018_pitching, mariners_2018_offense]

mariners_2018 = pd.concat(frames, axis=1)

mariners_2018['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(mariners_2018[x])):
        mariners_2018.loc[y,x] = int(mariners_2018.loc[y, x])

for x in columns_float:
    for y in range(len(mariners_2018[x])):
        mariners_2018.loc[y,x] = float(mariners_2018.loc[y, x])  

for x in range(len(mariners_2018['Game'])):
    if mariners_2018.loc[x, 'Runs'] > mariners_2018.loc[x, 'R']:
        mariners_2018.loc[x, 'Win'] = 0
    else:
        mariners_2018.loc[x, 'Win'] = 1

# %% [markdown]
# # 2017 Mariners Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SEA&t=b&year=2017'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SEA_2017_game_num = get_stat2('team_game_num')
SEA_2017_PA = get_stat2('PA')
SEA_2017_AB = get_stat2('AB')
SEA_2017_R = get_stat2('R')
SEA_2017_H = get_stat2('H')
SEA_2017_2B = get_stat2('2B')
SEA_2017_3B = get_stat2('3B')
SEA_2017_HR = get_stat2('HR')
SEA_2017_RBI = get_stat2('RBI')
SEA_2017_BB = get_stat2('BB')
SEA_2017_SO = get_stat2('SO')
SEA_2017_SB = get_stat2('SB')
SEA_2017_CS = get_stat2('CS')
SEA_2017_BA = get_stat2('batting_avg')
SEA_2017_OBP = get_stat2('onbase_perc')
SEA_2017_SLG = get_stat2('slugging_perc')
SEA_2017_OPS = get_stat2('onbase_plus_slugging')
SEA_2017_LOB = get_stat2('LOB')
mariners_2017_offense = pd.DataFrame({
                                  'PA': SEA_2017_PA,
                                  'AB': SEA_2017_AB,
                                  'R':  SEA_2017_R,
                                  'H':  SEA_2017_H,
                                  '2B': SEA_2017_2B,
                                  '3B': SEA_2017_3B, 
                                  'HR': SEA_2017_HR, 
                                  'RBI':SEA_2017_RBI,
                                  'BB': SEA_2017_BB,
                                  'SO': SEA_2017_SO,
                                  'SB': SEA_2017_SB,
                                  'CS': SEA_2017_CS,
                                  'LOB':SEA_2017_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SEA&t=p&year=2017'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SEA_2017_P_game_num = get_stat3('team_game_num')
SEA_2017_P_IP = get_stat3('IP')
SEA_2017_P_H = get_stat3('H')
SEA_2017_P_R = get_stat3('R')
SEA_2017_P_ER = get_stat3('ER')
SEA_2017_P_UER = get_stat3('UER')
SEA_2017_P_BB = get_stat3('BB')
SEA_2017_P_SO = get_stat3('SO')
SEA_2017_P_HR = get_stat3('HR')
SEA_2017_P_HBP = get_stat3('HBP')
SEA_2017_P_ERA = get_stat3('earned_run_avg')

mariners_2017_pitching = pd.DataFrame({'Game':  SEA_2017_P_game_num, 
                                         'IP':  SEA_2017_P_IP, 
                                         'H':   SEA_2017_P_H,
                                         'R':   SEA_2017_P_R,
                                         'ER':  SEA_2017_P_ER,
                                         'UER': SEA_2017_P_UER,
                                         'BB':  SEA_2017_P_BB,
                                         'SO':  SEA_2017_P_SO,
                                         'HR':  SEA_2017_P_HR,
                                         'HBP': SEA_2017_P_HBP})

# mariners_offense = mariners_offense.drop(columns = ['Game'])

mariners_2017_pitching = mariners_2017_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [mariners_2017_pitching, mariners_2017_offense]

mariners_2017 = pd.concat(frames, axis=1)

mariners_2017['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(mariners_2017[x])):
        mariners_2017.loc[y,x] = int(mariners_2017.loc[y, x])

for x in columns_float:
    for y in range(len(mariners_2017[x])):
        mariners_2017.loc[y,x] = float(mariners_2017.loc[y, x])  

for x in range(len(mariners_2017['Game'])):
    if mariners_2017.loc[x, 'Runs'] > mariners_2017.loc[x, 'R']:
        mariners_2017.loc[x, 'Win'] = 0
    else:
        mariners_2017.loc[x, 'Win'] = 1

# %% [markdown]
# # 2016 Mariners Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SEA&t=b&year=2016'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SEA_2016_game_num = get_stat2('team_game_num')
SEA_2016_PA = get_stat2('PA')
SEA_2016_AB = get_stat2('AB')
SEA_2016_R = get_stat2('R')
SEA_2016_H = get_stat2('H')
SEA_2016_2B = get_stat2('2B')
SEA_2016_3B = get_stat2('3B')
SEA_2016_HR = get_stat2('HR')
SEA_2016_RBI = get_stat2('RBI')
SEA_2016_BB = get_stat2('BB')
SEA_2016_SO = get_stat2('SO')
SEA_2016_SB = get_stat2('SB')
SEA_2016_CS = get_stat2('CS')
SEA_2016_BA = get_stat2('batting_avg')
SEA_2016_OBP = get_stat2('onbase_perc')
SEA_2016_SLG = get_stat2('slugging_perc')
SEA_2016_OPS = get_stat2('onbase_plus_slugging')
SEA_2016_LOB = get_stat2('LOB')
mariners_2016_offense = pd.DataFrame({
                                  'PA': SEA_2016_PA,
                                  'AB': SEA_2016_AB,
                                  'R':  SEA_2016_R,
                                  'H':  SEA_2016_H,
                                  '2B': SEA_2016_2B,
                                  '3B': SEA_2016_3B, 
                                  'HR': SEA_2016_HR, 
                                  'RBI':SEA_2016_RBI,
                                  'BB': SEA_2016_BB,
                                  'SO': SEA_2016_SO,
                                  'SB': SEA_2016_SB,
                                  'CS': SEA_2016_CS,
                                  'LOB':SEA_2016_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SEA&t=p&year=2016'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SEA_2016_P_game_num = get_stat3('team_game_num')
SEA_2016_P_IP = get_stat3('IP')
SEA_2016_P_H = get_stat3('H')
SEA_2016_P_R = get_stat3('R')
SEA_2016_P_ER = get_stat3('ER')
SEA_2016_P_UER = get_stat3('UER')
SEA_2016_P_BB = get_stat3('BB')
SEA_2016_P_SO = get_stat3('SO')
SEA_2016_P_HR = get_stat3('HR')
SEA_2016_P_HBP = get_stat3('HBP')
SEA_2016_P_ERA = get_stat3('earned_run_avg')

mariners_2016_pitching = pd.DataFrame({'Game':  SEA_2016_P_game_num, 
                                         'IP':  SEA_2016_P_IP, 
                                         'H':   SEA_2016_P_H,
                                         'R':   SEA_2016_P_R,
                                         'ER':  SEA_2016_P_ER,
                                         'UER': SEA_2016_P_UER,
                                         'BB':  SEA_2016_P_BB,
                                         'SO':  SEA_2016_P_SO,
                                         'HR':  SEA_2016_P_HR,
                                         'HBP': SEA_2016_P_HBP})

# mariners_offense = mariners_offense.drop(columns = ['Game'])

mariners_2016_pitching = mariners_2016_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [mariners_2016_pitching, mariners_2016_offense]

mariners_2016 = pd.concat(frames, axis=1)

mariners_2016['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(mariners_2016[x])):
        mariners_2016.loc[y,x] = int(mariners_2016.loc[y, x])

for x in columns_float:
    for y in range(len(mariners_2016[x])):
        mariners_2016.loc[y,x] = float(mariners_2016.loc[y, x])  

for x in range(len(mariners_2016['Game'])):
    if mariners_2016.loc[x, 'Runs'] > mariners_2016.loc[x, 'R']:
        mariners_2016.loc[x, 'Win'] = 0
    else:
        mariners_2016.loc[x, 'Win'] = 1

# %% [markdown]
# # 2015 Mariners Stats

# %%
url4 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SEA&t=b&year=2015'
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.text, 'html.parser')

def get_stat2(stat):
    statistic = soup4.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.?\d+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SEA_2015_game_num = get_stat2('team_game_num')
SEA_2015_PA = get_stat2('PA')
SEA_2015_AB = get_stat2('AB')
SEA_2015_R = get_stat2('R')
SEA_2015_H = get_stat2('H')
SEA_2015_2B = get_stat2('2B')
SEA_2015_3B = get_stat2('3B')
SEA_2015_HR = get_stat2('HR')
SEA_2015_RBI = get_stat2('RBI')
SEA_2015_BB = get_stat2('BB')
SEA_2015_SO = get_stat2('SO')
SEA_2015_SB = get_stat2('SB')
SEA_2015_CS = get_stat2('CS')
SEA_2015_BA = get_stat2('batting_avg')
SEA_2015_OBP = get_stat2('onbase_perc')
SEA_2015_SLG = get_stat2('slugging_perc')
SEA_2015_OPS = get_stat2('onbase_plus_slugging')
SEA_2015_LOB = get_stat2('LOB')
mariners_2015_offense = pd.DataFrame({
                                  'PA': SEA_2015_PA,
                                  'AB': SEA_2015_AB,
                                  'R':  SEA_2015_R,
                                  'H':  SEA_2015_H,
                                  '2B': SEA_2015_2B,
                                  '3B': SEA_2015_3B, 
                                  'HR': SEA_2015_HR, 
                                  'RBI':SEA_2015_RBI,
                                  'BB': SEA_2015_BB,
                                  'SO': SEA_2015_SO,
                                  'SB': SEA_2015_SB,
                                  'CS': SEA_2015_CS,
                                  'LOB':SEA_2015_LOB})

url5 = 'https://www.baseball-reference.com/teams/tgl.cgi?team=SEA&t=p&year=2015'
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.text, 'html.parser')

def get_stat3(stat):
    statistic = soup5.find_all('td', attrs = {'data-stat': stat})
    Stat = []
    for x in statistic:
        Stat.append(str(x))
    final_stat = []
    for x in range(len(Stat)):
        bg = re.compile(r'>(.+)</td>')
        lemmon =bg.findall(Stat[x])
        final_stat.append(lemmon)
    final_stat = list(chain.from_iterable(final_stat))
    return final_stat

SEA_2015_P_game_num = get_stat3('team_game_num')
SEA_2015_P_IP = get_stat3('IP')
SEA_2015_P_H = get_stat3('H')
SEA_2015_P_R = get_stat3('R')
SEA_2015_P_ER = get_stat3('ER')
SEA_2015_P_UER = get_stat3('UER')
SEA_2015_P_BB = get_stat3('BB')
SEA_2015_P_SO = get_stat3('SO')
SEA_2015_P_HR = get_stat3('HR')
SEA_2015_P_HBP = get_stat3('HBP')
SEA_2015_P_ERA = get_stat3('earned_run_avg')

mariners_2015_pitching = pd.DataFrame({'Game':  SEA_2015_P_game_num, 
                                         'IP':  SEA_2015_P_IP, 
                                         'H':   SEA_2015_P_H,
                                         'R':   SEA_2015_P_R,
                                         'ER':  SEA_2015_P_ER,
                                         'UER': SEA_2015_P_UER,
                                         'BB':  SEA_2015_P_BB,
                                         'SO':  SEA_2015_P_SO,
                                         'HR':  SEA_2015_P_HR,
                                         'HBP': SEA_2015_P_HBP})

# mariners_offense = mariners_offense.drop(columns = ['Game'])

mariners_2015_pitching = mariners_2015_pitching.rename(columns = {'H': 'Hits', 'R':'Runs', 'BB':'Walks', 'SO':'Strikeouts', 'HR': 'HR_Allowed'})

frames = [mariners_2015_pitching, mariners_2015_offense]

mariners_2015 = pd.concat(frames, axis=1)

mariners_2015['Win'] =''

columns_int = ['Hits', 'Runs', 'ER', 'UER', 'Walks','Strikeouts', 'HR_Allowed', 'HBP', 'PA', 'AB', 'R', 'H', '2B','3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'LOB']

columns_float = ['IP']

for x in columns_int:
    for y in range(len(mariners_2015[x])):
        mariners_2015.loc[y,x] = int(mariners_2015.loc[y, x])

for x in columns_float:
    for y in range(len(mariners_2015[x])):
        mariners_2015.loc[y,x] = float(mariners_2015.loc[y, x])  

for x in range(len(mariners_2015['Game'])):
    if mariners_2015.loc[x, 'Runs'] > mariners_2015.loc[x, 'R']:
        mariners_2015.loc[x, 'Win'] = 0
    else:
        mariners_2015.loc[x, 'Win'] = 1

# %%
# url6 = 'http://www.espn.com/mlb/history/leaders/_/breakdown/season/year/2019/'
# page6 = requests.get(url6)
# soup6 = BeautifulSoup(page6.text, 'html.parser')
        
# statistic = soup6.find_all('a', attrs = {'href': re.compile('(www.espn.com/mlb/player/_/id/\d+/)')})

# %%
# str(statistic[0])
# bg = re.compile(r'"(http://www.espn.com/mlb/player/_/id/\d+)/.+"')
# lemmon = bg.findall(str(statistic[0]))

# %%
# blackmore = str(lemmon[0])

# %%
# url7 = blackmore
# page7 = requests.get(url7)
# soup7 = BeautifulSoup(page7.text, 'html.parser')

# statistic1 = soup7.find_all('a', attrs = {'href': re.compile('http://www.espn.com/mlb/team/_/\D+/\D+')})

# %%
# statistic1

# %% [markdown]
# # Players Stats

# %%
columns = ['Name', 'G', 'AB', 'R', 'H', '2B', '3B',
           'HR', 'RBI', 'BB', 'SO', 'SB', 'CS']
big_one = pd.DataFrame(columns = columns)
try:
    for i in range (1,351,50):
    
        url6 = 'http://www.espn.com/mlb/history/leaders/_/breakdown/season/year/2019/start/{}'.format(i)
        page6 = requests.get(url6)
        soup6 = BeautifulSoup(page6.text, 'html.parser')
        
        statistic = soup6.find_all('tr', attrs = {'class': re.compile('row player-10-')})
    
        
        for x in range(len(statistic)):
            test = statistic[x].find_all('td')
            Test = []
            for y in test:
                Test.append(str(y))
            final_test=[]
            name=[]
            for z in range(len(Test)):
                bg = re.compile(r'<td>(.?\d+)</td>')
                lemmon = bg.findall(Test[z])
                final_test.append(lemmon)
                blackmore = re.compile(r'/id/\d+/(\D*.\D)\"')
                hammarskjold = blackmore.findall(Test[z])
                name.append(hammarskjold)
            final_test = list(chain.from_iterable(final_test))
            name = list(chain.from_iterable(name))
            final_name = []
            for x in name:
                y = x.split('">')
                q = y[0].split('-')
                r = q[0] + ' ' + q[1]
                s = r.title()
                final_name.append(s)
            temp_df = pd.DataFrame(final_name+final_test).T
            temp_df.columns = columns
            big_one = pd.concat([big_one,temp_df], ignore_index=True)
except ValueError:
    pass

big_one['BA'] = ''
big_one['SLG'] = ''
big_one = big_one.reset_index(drop=True)
for x in range(len(big_one['H'])):
    big_one.loc[x,'BA'] = round(int(big_one.loc[x,'H'])/int(big_one.loc[x,'AB']), 3)
for x in range(len(big_one['H'])):
    big_one.loc[x,'SLG'] = round(((int(big_one.loc[x,'2B'])*2)+
                                 (int(big_one.loc[x,'3B'])*3)+
                                 (int(big_one.loc[x,'HR'])*4)+
                                 ((int(big_one.loc[x,'H'])-(int(big_one.loc[x,'2B']))-(int(big_one.loc[x,'3B']))-
                                                                                     (int(big_one.loc[x,'HR'])))))/(int(big_one.loc[x,'AB'])), 3)

big_one
# Out:
#                      Name    G   AB   R    H  2B 3B  HR RBI  BB   SO  SB CS  \
# 0             Jeff Mcneil   88  337  50  115  27  1   9  41  20   48   4  5
# 1        Christian Yelich   94  352  77  118  20  3  35  77  59   80  23  2
# 2             Dj Lemahieu   94  387  74  129  23  2  15  71  30   60   4  1
# 3          Cody Bellinger   99  357  81  118  20  2  34  77  64   67   9  5
# 4          Bryan Reynolds   79  268  43   88  20  2   7  40  29   67   1  2
# 5        Michael Brantley   97  380  57  124  27  1  15  55  34   43   3  2
# 6          Fernando Tatis   67  261  50   85  11  5  16  41  24   89  14  3
# 7           Rafael Devers  101  406  82  131  31  3  21  81  33   69   8  6
# 8           Danny Santana   75  258  47   83  16  4  14  42  11   77  12  5
# 9             Ketel Marte   99  399  67  128  25  6  22  62  33   61   5  0
# 10       Charlie Blackmon   86  370  75  118  25  7  21  60  23   73   2  3
# ...

# %%
teams = [phillies, braves, mets, nationals, marlins, cardinals, brewers, cubs, pirates, reds, dodgers, diamondbacks, padres, rockies, giants, yankees, red_sox, blue_jays, orioles, rays, twins, indians, white_sox, royals, tigers, astros, athletics, angels, rangers, mariners]

mlb_teams = pd.concat(teams)

# %%
phillies_test = phillies.copy()

# %%
phillies_test = phillies_test.drop(columns = {'Win'})

# %%
phillies_2019_opp = pd.concat([braves[0:3], nationals[3:5], twins[5:8], nationals[8:11], marlins[13:16], mets[15:18], rockies[18:22],
          mets[21:24], marlins[24:28], tigers[26:28], nationals [30:33], cardinals[34:37], royals[38:41], brewers[42:46],
          rockies[42:45], cubs[44:48], brewers[51:54], cardinals[52:55], dodgers[57:60], padres[59:62], reds[61:64],
          diamondbacks[66:69], braves[69:72], nationals[71:74], marlins[73:76], mets[78:82], marlins[79:82],
          braves[85:88], mets[87:90], nationals[89:92], dodgers[95:99], pirates[95:98], tigers[96:98]])

# as of 7/25 @ 2:15 PM

# %%
phillies_2019_opp = phillies_2019_opp.rename(columns = {'Game': 'opp_Game', 'IP':'opp_IP', 'Hits':'opp_Hits', 'Runs':'opp_Runs', 'ER':'opp_ER',
                               'UER':'opp_UER', 'Walks':'opp_Walks', 'Strikeouts':'opp_Strikeouts','HR_Allowed': 'opp_HR_Allowed',
                               'HBP':'opp_HBP', 'PA':'opp_PA', 'AB':'opp_AB', 'R':'opp_R', 'H':'opp_H', 
                               '2B':'opp_2B', '3B':'opp_3B', 'HR':'opp_HR','RBI':'opp_RBI', 'BB':'opp_BB', 'SO':'opp_SO', 
                               'SB':'opp_SB', 'CS':'opp_CS','LOB':'opp_LOB', 'Win':'opp_Win'})

# %%
phillies_2018_opp = pd.concat([braves_2018[0:3], mets_2018[3:5], marlins_2018[6:9], reds_2018[8:11], rays_2018[12:15],
                              braves_2018[14:17], pirates_2018[18:22], diamondbacks_2018[21:24], braves_2018[24:27],
                              marlins_2018[27:30], nationals_2018[32:35], giants_2018[34:38], mets_2018[35:37],
                              orioles_2018[41:42], cardinals_2018[40:44], braves_2018[45:48], blue_jays_2018[50:53],
                              dodgers_2018[52:56], giants_2018[56:59], cubs_2018[56:59], brewers_2018[62:65],
                              rockies_2018[65:68], brewers_2018[68:71], cardinals_2018[69:72], nationals_2018[73:76],
                              yankees_2018[75:78], nationals_2018[78:82],orioles_2018[83:85], pirates_2018[86:89],
                               mets_2018[86:90], orioles_2018[93:94], marlins_2018[95:98], padres_2018[99:102],
                              dodgers_2018[99:102], reds_2018[102:106], red_sox_2018[107:109], marlins_2018[109:113],
                              diamondbacks_2018[113:116], padres_2018[117:120], red_sox_2018[120:122], mets_2018[118:123],
                              nationals_2018[125:128], blue_jays_2018[127:130], nationals_2018[131:134], cubs_2018[133:136],
                              marlins_2018[137:140], mets_2018[139:142], nationals_2018[143:146], marlins_2018[146:149],
                              mets_2018[149:152], braves_2018[152:156], rockies_2018[155:159], braves_2018[159:162]])

phillies_2018_opp = phillies_2018_opp.rename(columns = {'Game': 'opp_Game', 'IP':'opp_IP', 'Hits':'opp_Hits', 'Runs':'opp_Runs', 'ER':'opp_ER',
                               'UER':'opp_UER', 'Walks':'opp_Walks', 'Strikeouts':'opp_Strikeouts','HR_Allowed': 'opp_HR_Allowed',
                               'HBP':'opp_HBP', 'PA':'opp_PA', 'AB':'opp_AB', 'R':'opp_R', 'H':'opp_H', 
                               '2B':'opp_2B', '3B':'opp_3B', 'HR':'opp_HR','RBI':'opp_RBI', 'BB':'opp_BB', 'SO':'opp_SO', 
                               'SB':'opp_SB', 'CS':'opp_CS','LOB':'opp_LOB', 'Win':'opp_Win'})

# %%
phillies_2017_opp = pd.concat([reds_2017[0:3], nationals_2017[3:6], mets_2017[6:9], nationals_2017[9:12], mets_2017[13:16],
                              braves_2017[15:18], marlins_2017[18:20], dodgers_2017[23:26], cubs_2017[24:28],
                              nationals_2017[28:31], mariners_2017[32:34], nationals_2017[34:37], rangers_2017[39:42],
                              pirates_2017[41:44], rockies_2017[45:49], reds_2017[46:49], marlins_2017[48:51],
                              giants_2017[55:58], braves_2017[54:58], cardinals_2017[58:61], red_sox_2017[62:66],
                              diamondbacks_2017[67:70], cardinals_2017[68:71], diamondbacks_2017[73:77], 
                              mariners_2017[78:80], mets_2017[78:81], pirates_2017[82:86], padres_2017[85:88],
                              brewers_2017[91:94], marlins_2017[90:93], brewers_2017[98:101], astros_2017[98:101],
                              braves_2017[100:104], angels_2017[106:109], rockies_2017[109:112], braves_2017[ 110:112],
                              mets_2017[111:115], padres_2017[117:120], giants_2017[122:126], marlins_2017[122:126],
                              cubs_2017[126:129], braves_2017[128:131], marlins_2017[132:136], mets_2017[136:139],
                              nationals_2017[139:143], marlins_2017[143:146], athletics_2017[146:149],
                              dodgers_2017[149:153], braves_2017[151:154], nationals_2017[155:158], mets_2017[159:162]])

phillies_2017_opp = phillies_2017_opp.rename(columns = {'Game': 'opp_Game', 'IP':'opp_IP', 'Hits':'opp_Hits', 'Runs':'opp_Runs', 'ER':'opp_ER',
                               'UER':'opp_UER', 'Walks':'opp_Walks', 'Strikeouts':'opp_Strikeouts','HR_Allowed': 'opp_HR_Allowed',
                               'HBP':'opp_HBP', 'PA':'opp_PA', 'AB':'opp_AB', 'R':'opp_R', 'H':'opp_H', 
                               '2B':'opp_2B', '3B':'opp_3B', 'HR':'opp_HR','RBI':'opp_RBI', 'BB':'opp_BB', 'SO':'opp_SO', 
                               'SB':'opp_SB', 'CS':'opp_CS','LOB':'opp_LOB', 'Win':'opp_Win'})
# print(len(phillies_2017_opp))
# print(sum(phillies_2017_opp['opp_Win']))

# %%
phillies_2016_opp = pd.concat([reds_2016[0:3], mets_2016[2:5], padres_2016[6:10], nationals_2016[8:11],
                              mets_2016[11:14], brewers_2016[16:19], nationals_2016[18:21], indians_2016[19:22],
                              cardinals_2016[25:29], marlins_2016[27:30], braves_2016[30:33], reds_2016[34:37],
                              marlins_2016[37:40], braves_2016[40:43], tigers_2016[43:46], cubs_2016[45:48],
                              nationals_2016[51:54], brewers_2016[53:57], cubs_2016[55:58], nationals_2016[60:63],
                              blue_jays_2016[65:69], diamondbacks_2016[68:72], twins_2016[69:72], giants_2016[74:77],
                              diamondbacks_2016[78:81], royals_2016[78:81], braves_2016[82:85], rockies_2016[84:88],
                              mets_2016[88:91], marlins_2016[91:95], pirates_2016[95:98], marlins_2016[98:101],
                              braves_2016[101:105], giants_2016[105:108], padres_2016[108:111], dodgers_2016[111:114],
                              rockies_2016[115:118], dodgers_2016[117:120], cardinals_2016[120:123], white_sox_2016[123:125],
                              mets_2016[127:130], nationals_2016[130:133], braves_2016[134:137], marlins_2016[137:140],
                              nationals_2016[139:143], pirates_2016[141:145], marlins_2016[146:149], white_sox_2016[150:152],
                              mets_2016[152:156], braves_2016[155:158], mets_2016[159:162]])

phillies_2016_opp = phillies_2016_opp.rename(columns = {'Game': 'opp_Game', 'IP':'opp_IP', 'Hits':'opp_Hits', 'Runs':'opp_Runs', 'ER':'opp_ER',
                               'UER':'opp_UER', 'Walks':'opp_Walks', 'Strikeouts':'opp_Strikeouts','HR_Allowed': 'opp_HR_Allowed',
                               'HBP':'opp_HBP', 'PA':'opp_PA', 'AB':'opp_AB', 'R':'opp_R', 'H':'opp_H', 
                               '2B':'opp_2B', '3B':'opp_3B', 'HR':'opp_HR','RBI':'opp_RBI', 'BB':'opp_BB', 'SO':'opp_SO', 
                               'SB':'opp_SB', 'CS':'opp_CS','LOB':'opp_LOB', 'Win':'opp_Win'})

# print(len(phillies_2016_opp))
# print(sum(phillies_2016_opp['Win']))

# %%
phillies_2015_opp = pd.concat([red_sox_2015[0:3], nationals_2015[3:6], mets_2015[6:9], nationals_2015[9:13],
                              marlins_2015[13:16], braves_2015[15:18], cardinals_2015[17:21], marlins_2015[22:25],
                              braves_2015[25:28], mets_2015[28:31], pirates_2015[31:35], diamondbacks_2015[33:36],
                              rockies_2015[34:38], nationals_2015[41:44], mets_2015[45:48], rockies_2015[45:48],
                              reds_2015[49:52], giants_2015[55:58], reds_2015[55:58], pirates_2015[59:62],
                              orioles_2015[62:66], cardinals_2015[66:69], yankees_2015[69:72], nationals_2015[73:76],
                              brewers_2015[77:81], braves_2015[79:82], dodgers_2015[83:87], giants_2015[86:89],
                              marlins_2015[89:92], rays_2015[94:97], cubs_2015[94:97], blue_jays_2015[100:102],
                              braves_2015[101:105], dodgers_2015[105:108], padres_2015[109:112], diamondbacks_2015[110:113],
                              brewers_2015[116:119], blue_jays_2015[119:121], marlins_2015[120:124], mets_2015[123:127],
                              padres_2015[127:130], mets_2015[130:133], red_sox_2015[133:136], braves_2015[137:140],
                              cubs_2015[138:142], nationals_2015[142:145], braves_2015[147:150], marlins_2015[150:153],
                              nationals_2015[152:155], mets_2015[156:159], marlins_2015[159:162]])

phillies_2015_opp = phillies_2015_opp.rename(columns = {'Game': 'opp_Game', 'IP':'opp_IP', 'Hits':'opp_Hits', 'Runs':'opp_Runs', 'ER':'opp_ER',
                               'UER':'opp_UER', 'Walks':'opp_Walks', 'Strikeouts':'opp_Strikeouts','HR_Allowed': 'opp_HR_Allowed',
                               'HBP':'opp_HBP', 'PA':'opp_PA', 'AB':'opp_AB', 'R':'opp_R', 'H':'opp_H', 
                               '2B':'opp_2B', '3B':'opp_3B', 'HR':'opp_HR','RBI':'opp_RBI', 'BB':'opp_BB', 'SO':'opp_SO', 
                               'SB':'opp_SB', 'CS':'opp_CS','LOB':'opp_LOB', 'Win':'opp_Win'})

# %%
phillies_test.reset_index(drop=True, inplace = True)

phillies_2019_opp.reset_index(drop=True, inplace = True)

# phils_frames = [phillies_test, phillies_2019_opp]

phils_games_2019_sum = pd.concat([phillies_test, phillies_2019_opp], axis = 1)

# %%
# phillies_2018 = phillies_2018.drop(['Win'], axis=1)

phillies_2018.reset_index(drop=True, inplace = True)

phillies_2018_opp.reset_index(drop=True, inplace = True)

# phils_frames = [phillies_2018, phillies_2018_opp]

phils_games_2018_sum = pd.concat([phillies_2018, phillies_2018_opp, final_opps_2018, home_or_away_2018], axis = 1)

for x in range(len(phils_games_2018_sum['Opponent'])):
    if phils_games_2018_sum.loc[x, 'Location'] == 'Home':
        phils_games_2018_sum.loc[x, 'Location'] = 'PHI'
    else:
        phils_games_2018_sum.loc[x, 'Location'] = phils_games_2018_sum.loc[x, 'Opponent']

# %%
# phillies_2017 = phillies_2017.drop(['Win'], axis=1)

phillies_2017.reset_index(drop=True, inplace = True)

phillies_2017_opp.reset_index(drop=True, inplace = True)

phils_frames = [phillies_2017, phillies_2017_opp]

phils_games_2017_sum = pd.concat([phillies_2017, phillies_2017_opp, final_opps_2017, home_or_away_2017], axis = 1)

for x in range(len(phils_games_2017_sum['Opponent'])):
    if phils_games_2017_sum.loc[x, 'Location'] == 'Home':
        phils_games_2017_sum.loc[x, 'Location'] = 'PHI'
    else:
        phils_games_2017_sum.loc[x, 'Location'] = phils_games_2017_sum.loc[x, 'Opponent']

# %%
# phillies_2016 = phillies_2016.drop(['Win'], axis=1)

phillies_2016.reset_index(drop=True, inplace = True)

phillies_2016_opp.reset_index(drop=True, inplace = True)

# phils_frames = [phillies_test, phillies_2016_opp]

phils_games_2016_sum = pd.concat([phillies_2016, phillies_2016_opp, final_opps_2016, home_or_away_2016], axis = 1)

for x in range(len(phils_games_2016_sum['Opponent'])):
    if phils_games_2016_sum.loc[x, 'Location'] == 'Home':
        phils_games_2016_sum.loc[x, 'Location'] = 'PHI'
    else:
        phils_games_2016_sum.loc[x, 'Location'] = phils_games_2016_sum.loc[x, 'Opponent']

# %%
# phillies_2015 = phillies_2015.drop(['Win'], axis=1)

phillies_2015.reset_index(drop=True, inplace = True)

phillies_2015_opp.reset_index(drop=True, inplace = True)

# phils_frames = [phillies_test, phillies_2015_opp]

phils_games_2015_sum = pd.concat([phillies_2015, phillies_2015_opp, final_opps_2015, home_or_away_2015], axis = 1)

for x in range(len(phils_games_2015_sum['Opponent'])):
    if phils_games_2015_sum.loc[x, 'Location'] == 'Home':
        phils_games_2015_sum.loc[x, 'Location'] = 'PHI'
    else:
        phils_games_2015_sum.loc[x, 'Location'] = phils_games_2015_sum.loc[x, 'Opponent']

# %%
phils_prior_sum = pd.concat([phils_games_2015_sum, phils_games_2016_sum, phils_games_2017_sum, phils_games_2018_sum])

# %%
import pickle

# %%
with open('phils_prior.pickle', 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(phils_prior_sum, f, pickle.HIGHEST_PROTOCOL)
